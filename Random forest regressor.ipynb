# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import warnings
import gc

# %%
train_df2 = feather.read_dataframe('train_df_alpha')
test_df2 = feather.read_dataframe('test_df_alpha')

# %%
for df in [train_df2, test_df2]:
    for f in ['purchase_date_max','purchase_date_min','purchase_date_max_old',\
                     'purchase_date_min_old', 'observation_date_old']:
        df[f] = df[f].astype(np.int64) * 1e-9

# %%
cols_excluded = ['purchase_date_max', 'purchase_date_max_old', 'card_id', 'first_active_month',
                 'target','outliers','card_id_size', 'card_id_size_old', 
                 'purchase_date_min', 'purchase_date_min_old','first_active_monthYear',
                 'first_active_monthMonth',
                 'first_active_monthWeek',
                 'first_active_monthDay',
                 'first_active_monthDayofweek',
                 'first_active_monthDayofyear',
                 'first_active_monthIs_month_end',
                 'first_active_monthIs_month_start',
                 'first_active_monthIs_quarter_end',
                 'first_active_monthIs_quarter_start',
                 'first_active_monthIs_year_end',
                 'Black_Friday_2017_mean',
                 'amount_month_ratio_max',
                 'purchase_Month_mean_old',
                 'purchase_amount_total_max',
                 'first_active_monthIs_year_start']

# %%
cols_included = ['feature_1','feature_2','feature_3','transactions_count','subsector_id_nunique','merchant_id_nunique','merchant_category_id_nunique','purchase_Month_mean','purchase_Month_min','purchase_Month_max','purchase_Week_nunique','purchase_Week_mean','purchase_Week_min','purchase_Week_max','purchase_Dayofweek_mean','purchase_Dayofweek_min','purchase_Dayofweek_max','purchase_Day_nunique','purchase_Day_mean','purchase_Day_min','purchase_Day_max','purchase_Hour_nunique','purchase_Hour_mean','purchase_Hour_min','purchase_Hour_max','purchase_amount_sum','purchase_amount_max','purchase_amount_min','purchase_amount_mean','purchase_amount_var','purchase_amount_skew','installments_sum','installments_max','installments_mean','installments_var','installments_skew','month_lag_max','month_lag_min','month_lag_mean','month_lag_var','month_lag_skew','month_diff_mean','month_diff_var','month_diff_skew','purchased_on_weekend_mean','category_1_mean','category_2_mean','category_3_mean','card_id_count','price_mean','price_max','price_min','price_var','Christmas_Day_2017_mean','Children_day_2017_mean','Black_Friday_2017_mean','Mothers_Day_2018_mean','duration_mean','duration_min','duration_max','duration_var','duration_skew','amount_month_ratio_mean','amount_month_ratio_min','amount_month_ratio_max','amount_month_ratio_var','amount_month_ratio_skew','category_2_mean_mean','category_3_mean_mean','purchase_date_diff','purchase_date_average','purchase_date_uptonow','purchase_date_uptomin','transactions_count_old','subsector_id_nunique_old','merchant_id_nunique_old','merchant_category_id_nunique_old','purchase_Month_nunique','purchase_Month_mean_old','purchase_Month_min_old','purchase_Month_max_old','purchase_Week_nunique_old','purchase_Week_mean_old','purchase_Week_min_old','purchase_Week_max_old','purchase_Dayofweek_mean_old','purchase_Day_nunique_old','purchase_Day_mean_old','purchase_Day_min_old','purchase_Hour_nunique_old','purchase_Hour_mean_old','purchase_Hour_min_old','purchase_Hour_max_old','purchase_amount_sum_old','purchase_amount_max_old','purchase_amount_min_old','purchase_amount_mean_old','purchase_amount_var_old','purchase_amount_skew_old','installments_sum_old','installments_max_old','installments_mean_old','installments_var_old','installments_skew_old','month_lag_max_old','month_lag_min_old','month_lag_mean_old','month_lag_var_old','month_lag_skew_old','month_diff_max','month_diff_min','month_diff_mean_old','month_diff_var_old','month_diff_skew_old','authorized_flag_mean','purchased_on_weekend_mean_old','category_1_mean_old','category_2_mean_old','category_3_mean_old','card_id_count_old','price_sum','price_mean_old','price_max_old','price_min_old','price_var_old','Christmas_Day_2017_mean_old','Mothers_Day_2017_mean','fathers_day_2017_mean','Children_day_2017_mean_old','Valentine_Day_2017_mean','Black_Friday_2017_mean_old','Mothers_Day_2018_mean_old','duration_mean_old','duration_min_old','duration_max_old','duration_var_old','duration_skew_old','amount_month_ratio_mean_old','amount_month_ratio_min_old','amount_month_ratio_max_old','amount_month_ratio_var_old','amount_month_ratio_skew_old','category_2_mean_mean_old','category_3_mean_mean_old','purchase_date_diff_old','purchase_date_average_old','purchase_date_uptonow_old','purchase_date_uptomin_old','quarter','observed_elapsed_time','days_feature1','days_feature2','days_feature3','days_feature1_ratio','days_feature2_ratio','days_feature3_ratio','feature_sum','feature_mean','feature_max','feature_min','feature_var','card_id_total','card_id_count_total','card_id_count_ratio','purchase_amount_total','purchase_amount_total_mean','purchase_amount_total_max','purchase_amount_total_min','purchase_amount_sum_ratio','hist_first_buy','new_first_buy','hist_last_buy','new_last_buy','month_diff_ratio','installments_total','installments_ratio','price_total','CLV','CLV_old','CLV_ratio']

# %%
df_train_columns = [c for c in cols_included if c not in cols_excluded]

# %%
len(df_train_columns)
# Out:
# 176

# %%
extra_cols = ['merchant_address_id_nunique', 'merchant_rating_nunique']

# %%
df_train_columns = df_train_columns + extra_cols

# %%
len(df_train_columns)
# Out:
# 178

# %%
target = train_df2['target']

# %%
del train_df2['target']

# %%
len(df_train_columns)
# Out:
# 178

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
df_train = train_df2[df_train_columns]
df_test = test_df2[df_train_columns]

# %%
df_train = reduce_mem_usage(df_train)
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# Mem. usage decreased to 87.62 Mb (68.0% reduction)

# %%
df_test = reduce_mem_usage(df_test)
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# Mem. usage decreased to 52.35 Mb (68.8% reduction)

# %%
df_train.select_dtypes(include=['float16']).columns.values
# Out:
# array(['feature_1', 'feature_2', 'feature_3', 'transactions_count', 'subsector_id_nunique',
#        'merchant_id_nunique', 'merchant_category_id_nunique', 'purchase_Month_mean', 'purchase_Month_min',
#        'purchase_Month_max', 'purchase_Week_nunique', 'purchase_Week_mean', 'purchase_Week_min',
#        'purchase_Week_max', 'purchase_Dayofweek_mean', 'purchase_Dayofweek_min', 'purchase_Dayofweek_max',
#        'purchase_Day_nunique', 'purchase_Day_mean', 'purchase_Day_min', 'purchase_Day_max',
#        'purchase_Hour_nunique', 'purchase_Hour_mean', 'purchase_Hour_min', 'purchase_Hour_max',
#        'purchase_amount_max', 'purchase_amount_min', 'purchase_amount_mean', 'purchase_amount_skew',
#        'installments_sum', 'installments_max', 'installments_mean', 'installments_var', 'installments_skew',
#        'month_lag_max', 'month_lag_min', 'month_lag_mean', 'month_lag_var', 'month_lag_skew',
#        'month_diff_mean', 'month_diff_var', 'month_diff_skew', 'purchased_on_weekend_mean',
#        'category_1_mean', 'category_2_mean', 'category_3_mean', 'card_id_count', 'Christmas_Day_2017_mean',
#        'Children_day_2017_mean', 'Mothers_Day_2018_mean', 'duration_skew', 'amount_month_ratio_mean',
#        'amount_month_ratio_min', 'amount_month_ratio_skew', 'category_2_mean_mean', 'category_3_mean_mean',
#        'purchase_date_diff', 'purchase_date_average', 'purchase_date_uptonow', 'purchase_date_uptomin',
#        'purchase_Week_mean_old', 'purchase_Dayofweek_mean_old', 'purchase_Day_mean_old',
#        'purchase_Hour_mean_old', 'purchase_amount_min_old', 'purchase_amount_skew_old',
#        'installments_sum_old', 'installments_max_old', 'installments_mean_old', 'installments_var_old',
#        'installments_skew_old', 'month_lag_mean_old', 'month_lag_var_old', 'month_lag_skew_old',
#        'month_diff_mean_old', 'month_diff_var_old', 'month_diff_skew_old', 'authorized_flag_mean',
#        'purchased_on_weekend_mean_old', 'category_1_mean_old', 'category_2_mean_old', 'category_3_mean_old',
#        'Christmas_Day_2017_mean_old', 'Mothers_Day_2017_mean', 'fathers_day_2017_mean',
#        'Children_day_2017_mean_old', 'Valentine_Day_2017_mean', 'Black_Friday_2017_mean_old',
#        'Mothers_Day_2018_mean_old', 'duration_skew_old', 'amount_month_ratio_min_old',
#        'amount_month_ratio_skew_old', 'category_2_mean_mean_old', 'category_3_mean_mean_old',
#        'purchase_date_average_old', 'purchase_date_uptonow_old', 'purchase_date_uptomin_old',
#        'observed_elapsed_time', 'days_feature1', 'days_feature2', 'days_feature3', 'feature_mean',
#        'feature_var', 'card_id_total', 'card_id_count_total', 'card_id_count_ratio',
#        'purchase_amount_total_min', 'purchase_amount_sum_ratio', 'new_first_buy', 'new_last_buy',
#        'month_diff_ratio', 'installments_total', 'CLV_ratio', 'merchant_address_id_nunique',
#        'merchant_rating_nunique'], dtype=object)

# %%
pd.set_option('display.max_rows', 200)

# %%
DataFrameSummary(df_train).summary().T
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/lib/function_base.py:3768: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
#                                    count         mean          std  \
# feature_1                         201917            0            0
# feature_2                         201917            0            0
# feature_3                         201917            0            0
# transactions_count                179986          NaN            0
# subsector_id_nunique              179986          NaN            0
# merchant_id_nunique               179986          NaN            0
# merchant_category_id_nunique      179986          NaN            0
# purchase_Month_mean               179986          NaN            0
# purchase_Month_min                179986          NaN            0
# purchase_Month_max                179986          NaN            0
# purchase_Week_nunique             179986          NaN            0
# purchase_Week_mean                179986          NaN            0
# purchase_Week_min                 179986          NaN            0
# purchase_Week_max                 179986          NaN            0
# purchase_Dayofweek_mean           179986          NaN            0
# purchase_Dayofweek_min            179986          NaN            0
# purchase_Dayofweek_max            179986          NaN            0
# purchase_Day_nunique              179986          NaN            0
# purchase_Day_mean                 179986          NaN            0
# purchase_Day_min                  179986          NaN            0
# purchase_Day_max                  179986          NaN            0
# purchase_Hour_nunique             179986          NaN            0
# purchase_Hour_mean                179986          NaN            0
# purchase_Hour_min                 179986          NaN            0
# purchase_Hour_max                 179986          NaN            0
# purchase_amount_sum               179986      878.164      1742.16
# purchase_amount_max               179986          NaN          NaN
# purchase_amount_min               179986          NaN          NaN
# purchase_amount_mean              179986          NaN          NaN
# purchase_amount_var               153199       179113  4.20289e+06
# purchase_amount_skew              130048          NaN            0
# installments_sum                  179986          NaN            0
# installments_max                  178586          NaN            0
# installments_mean                 178586          NaN            0
# installments_var                  150921          NaN            0
# installments_skew                 127352          NaN            0
# month_lag_max                     179986          NaN            0
# month_lag_min                     179986          NaN            0
# month_lag_mean                    179986          NaN            0
# month_lag_var                     153199            0            0
# month_lag_skew                    130048            0            0
# month_diff_mean                   179986          NaN            0
# month_diff_var                    153199            0            0
# month_diff_skew                   130048          NaN            0
# purchased_on_weekend_mean         179986            0            0
# category_1_mean                   179986            0            0
# category_2_mean                   179986          NaN            0
# category_3_mean                   179986          NaN            0
# card_id_count                     179986          NaN            0
# price_mean                        178586          inf          NaN
# price_max                         178586          inf          NaN
# price_min                         178586          inf          NaN
# price_var                          76989      59704.7   1.5895e+06
# Christmas_Day_2017_mean           179986          NaN            0
# Children_day_2017_mean            179986          NaN            0
# Mothers_Day_2018_mean             179986          NaN            0
# duration_mean                     179986      1899.42      4681.37
# duration_min                      179986      736.169      3645.64
# duration_max                      179986      5254.47      13057.9
# duration_var                      153199  2.91121e+07  6.40873e+08
# duration_skew                     130048          NaN            0
# amount_month_ratio_mean           179986          NaN          NaN
# amount_month_ratio_min            179986          NaN          NaN
# amount_month_ratio_var            153199      1188.41      30430.9
# amount_month_ratio_skew           130048          NaN            0
# category_2_mean_mean              179986          NaN            0
# category_3_mean_mean              179986          NaN          NaN
# purchase_date_diff                179986          NaN            0
# purchase_date_average             179986          NaN            0
# purchase_date_uptonow             179986          NaN            0
# purchase_date_uptomin             179986          NaN            0
# transactions_count_old            201917      89.2942      104.606
# subsector_id_nunique_old          201917      11.4608      5.18197
# merchant_id_nunique_old           201917      33.7136      30.6869
# merchant_category_id_nunique_old  201917       18.278      11.4705
# purchase_Month_nunique            201917       7.4613      3.07644
# purchase_Month_min_old            201917      1.55287      1.62411
# purchase_Month_max_old            201917      11.2122      1.84991
# purchase_Week_nunique_old         201917      20.5641      12.2114
# purchase_Week_mean_old            201917          NaN            0
# purchase_Week_min_old             201917      4.11507      7.35093
# purchase_Week_max_old             201917      48.0692      7.97437
# purchase_Dayofweek_mean_old       201917          NaN            0
# purchase_Day_nunique_old          201917      20.5434      8.22634
# purchase_Day_mean_old             201917          NaN            0
# purchase_Day_min_old              201917      2.19061      2.55724
# purchase_Hour_nunique_old         201917      14.9714      4.83848
# purchase_Hour_mean_old            201917          NaN            0
# purchase_Hour_min_old             201917      2.23729      3.74154
# purchase_Hour_max_old             201917      21.9001      1.72075
# purchase_amount_sum_old           201917      53984.7  8.95023e+06
# purchase_amount_max_old           201917      44866.4  8.94988e+06
# purchase_amount_min_old           201917          NaN          NaN
# purchase_amount_mean_old          201917      2133.79       742134
# purchase_amount_var_old           201917  6.61666e+12  2.96724e+15
# purchase_amount_skew_old          201883          NaN            0
# installments_sum_old              201917          NaN          NaN
# installments_max_old              201917          NaN            0
# installments_mean_old             201917          NaN            0
# installments_var_old              201910          NaN            0
# installments_skew_old             201839          NaN            0
# month_lag_max_old                 201917    -0.166058     0.636972
# month_lag_min_old                 201917     -7.87778      3.84331
# month_lag_mean_old                201917          NaN            0
# month_lag_var_old                 201917          NaN            0
# month_lag_skew_old                201883           -0            0
# month_diff_max                    201917      13.1442      2.35678
# month_diff_min                    201917      12.2436      2.45579
# month_diff_mean_old               201917          NaN            0
# month_diff_var_old                201917            0            0
# month_diff_skew_old               201883          NaN            0
# authorized_flag_mean              201917          NaN            0
# purchased_on_weekend_mean_old     201917            0            0
# category_1_mean_old               201917            0            0
# category_2_mean_old               201917          NaN            0
# category_3_mean_old               201917          NaN            0
# card_id_count_old                 201917      89.2942      104.606
# price_sum                         201917          inf          NaN
# price_mean_old                    201917          inf          NaN
# price_max_old                     201917          inf          NaN
# price_min_old                     201917          inf          NaN
# price_var_old                     100272  9.85043e+09  2.34041e+12
# Christmas_Day_2017_mean_old       201917          NaN            0
# Mothers_Day_2017_mean             201917          NaN            0
# fathers_day_2017_mean             201917          NaN            0
# Children_day_2017_mean_old        201917          NaN            0
# Valentine_Day_2017_mean           201917          NaN            0
# Black_Friday_2017_mean_old        201917          NaN            0
# Mothers_Day_2018_mean_old         201917          NaN            0
# duration_mean_old                 201917      37677.2  1.40971e+07
# duration_min_old                  201917      147.638      797.826
# duration_max_old                  201917       698566  1.69552e+08
# duration_var_old                  201917  2.38603e+15          inf
# duration_skew_old                 201883          NaN            0
# amount_month_ratio_mean_old       201917      124.733      39084.5
# amount_month_ratio_min_old        201917          NaN          NaN
# amount_month_ratio_max_old        201917      3028.84       474348
# amount_month_ratio_var_old        201917  1.83777e+10   8.2195e+12
# amount_month_ratio_skew_old       201883          NaN            0
# category_2_mean_mean_old          201917          NaN          NaN
# category_3_mean_mean_old          201917          NaN          NaN
# purchase_date_diff_old            201917      243.678      118.292
# purchase_date_average_old         201917          NaN            0
# purchase_date_uptonow_old         179986          NaN          NaN
# purchase_date_uptomin_old         179986          NaN          NaN
# quarter                           201917      2.78428       1.0774
# observed_elapsed_time             179986          NaN          NaN
# days_feature1                     179986          NaN          NaN
# days_feature2                     179986          NaN          NaN
# days_feature3                     179986          NaN          NaN
# days_feature1_ratio               179986          inf          NaN
# days_feature2_ratio               179986          inf          NaN
# days_feature3_ratio               179986          inf          NaN
# feature_sum                       201917      5.41629      1.64767
# feature_mean                      201917          NaN            0
# feature_max                       201917      3.17985       1.1209
# feature_min                       201917     0.565569     0.495683
# feature_var                       201917          NaN            0
# card_id_total                     179986          NaN          NaN
# card_id_count_total               179986          NaN          NaN
# card_id_count_ratio               179986            0            0
# purchase_amount_total             179986      57096.2  9.47071e+06
# purchase_amount_total_mean        179986      2418.31       785826
# purchase_amount_total_min         179986          NaN          NaN
# purchase_amount_sum_ratio         179986            0            0
# hist_first_buy                    201917      118.748      224.136
# new_first_buy                     179986          NaN          NaN
# hist_last_buy                     201917      362.948      285.303
# new_last_buy                      179986          NaN          NaN
# month_diff_ratio                  179986          NaN            0
# installments_total                179986          NaN          NaN
# installments_ratio                135649          inf          NaN
# price_total                       179986          inf          NaN
# CLV                               179986      913.297      3431.23
# CLV_old                           201917       518918  1.98438e+07
# CLV_ratio                         179986            0          NaN
# merchant_address_id_nunique       179986          NaN            0
# merchant_rating_nunique           179986          NaN            0
#
#                                           min         25%          50%  \
# feature_1                          0.00805664   0.0104828    0.0106125
# feature_2                          0.00875092  0.00875092    0.0113831
# feature_3                           0.0102844   0.0102844    0.0114288
# transactions_count                          1           2            5
# subsector_id_nunique                        1           2            4
# merchant_id_nunique                         1           2            5
# merchant_category_id_nunique                1           2            4
# purchase_Month_mean                         1           3          3.5
# purchase_Month_min                          1           3            3
# purchase_Month_max                          1           3            4
# purchase_Week_nunique                       1           2            3
# purchase_Week_mean                          1     11.5703      13.2031
# purchase_Week_min                           1           9           10
# purchase_Week_max                           1          13           16
# purchase_Dayofweek_mean                     0     2.33398            3
# purchase_Dayofweek_min                      0           0            1
# purchase_Dayofweek_max                      0           4            5
# purchase_Day_nunique                        1           2            4
# purchase_Day_mean                           1          12      15.6641
# purchase_Day_min                            1           2            6
# purchase_Day_max                            1          19           26
# purchase_Hour_nunique                       1           2            4
# purchase_Hour_mean                          0     11.8359         13.5
# purchase_Hour_min                           0           6            9
# purchase_Hour_max                           0          15           18
# purchase_amount_sum                      0.01     132.533        364.4
# purchase_amount_max                 0.0100021      65.875      155.625
# purchase_amount_min                 0.0100021         7.5      15.6016
# purchase_amount_mean                0.0100021     36.0312           70
# purchase_amount_var                         0     683.531      3508.18
# purchase_amount_skew                  -2.5918    0.661133      1.44922
# installments_sum                            0           0            1
# installments_max                            0           0            1
# installments_mean                           0           0            1
# installments_var                            0           0            0
# installments_skew                    -6.70703           0            0
# month_lag_max                               1           2            2
# month_lag_min                               1           1            1
# month_lag_mean                              1     1.23047          1.5
# month_lag_var                               0    0.123291         0.25
# month_lag_skew                       -6.63281   -0.608398            0
# month_diff_mean                            11     11.7656           12
# month_diff_var                              0           0     0.116638
# month_diff_skew                      -8.94531    -1.97559    -0.538574
# purchased_on_weekend_mean                   0           0         0.25
# category_1_mean                             0           0            0
# category_2_mean                             1           1            1
# category_3_mean                             0           0     0.666504
# card_id_count                               1           2            5
# price_mean                               0.01       72.09      389.555
# price_max                                0.01         105      850.231
# price_min                                0.01        19.9          160
# price_var                                   0     542.522      2028.85
# Christmas_Day_2017_mean                     0           0            0
# Children_day_2017_mean                      0           0            0
# Mothers_Day_2018_mean                       0          27           41
# duration_mean                            0.11       457.2      898.485
# duration_min                             0.11          96      201.895
# duration_max                             0.11         840      1999.08
# duration_var                                0      111133       577117
# duration_skew                        -2.59766    0.661621       1.4502
# amount_month_ratio_mean           0.000666618      2.7832      5.48047
# amount_month_ratio_min            0.000454664     0.58252         1.25
# amount_month_ratio_var                      0     4.07776      21.4946
# amount_month_ratio_skew              -2.58398    0.661621      1.44922
# category_2_mean_mean                      126       130.5      130.875
# category_3_mean_mean                  93.4375     102.438      102.438
# purchase_date_diff                          0           8           32
# purchase_date_average                       0     1.70605      4.14453
# purchase_date_uptonow                     -62         -58          -50
# purchase_date_uptomin                     -62         -23          -10
# transactions_count_old                      2          26           55
# subsector_id_nunique_old                    1           8           11
# merchant_id_nunique_old                     1          13           25
# merchant_category_id_nunique_old            1          10           16
# purchase_Month_nunique                      2           5            7
# purchase_Month_min_old                      1           1            1
# purchase_Month_max_old                      2          12           12
# purchase_Week_nunique_old                   1          11           17
# purchase_Week_mean_old                  1.875     21.8438      26.6875
# purchase_Week_min_old                       1           1            1
# purchase_Week_max_old                       5          49           51
# purchase_Dayofweek_mean_old                 0     2.66992            3
# purchase_Day_nunique_old                    1          14           22
# purchase_Day_mean_old                       1     14.4609      15.9453
# purchase_Day_min_old                        1           1            1
# purchase_Hour_nunique_old                   1          12           16
# purchase_Hour_mean_old               0.600098      13.125       14.125
# purchase_Hour_min_old                       0           0            0
# purchase_Hour_max_old                       1          21           23
# purchase_amount_sum_old                  11.8      2142.3      4895.62
# purchase_amount_max_old                  1.06         266       579.28
# purchase_amount_min_old           0.000100017           2      4.39844
# purchase_amount_mean_old              1.02286     45.1133      83.5011
# purchase_amount_var_old                     0     2604.22      11406.4
# purchase_amount_skew_old             -9.27344     1.78516      2.74219
# installments_sum_old                        0           0           16
# installments_max_old                        0           0            2
# installments_mean_old                       0           0            1
# installments_var_old                        0           0    0.0724487
# installments_skew_old                -24.9531           0      2.63672
# month_lag_max_old                         -11           0            0
# month_lag_min_old                         -13         -12           -8
# month_lag_mean_old                   -12.4531    -5.51953     -3.57227
# month_lag_var_old                   0.0149231     1.89551      5.16797
# month_lag_skew_old                    -8.1875   -0.395752   -0.0775757
# month_diff_max                             11          12           12
# month_diff_min                             11          11           11
# month_diff_mean_old                        11     11.8281      11.9062
# month_diff_var_old                          0   0.0616455     0.109741
# month_diff_skew_old                  -22.2656          -3     -2.08594
# authorized_flag_mean                0.0304871    0.853027     0.926758
# purchased_on_weekend_mean_old               0    0.186035     0.269775
# category_1_mean_old                         0           0            0
# category_2_mean_old                         1           1      1.16113
# category_3_mean_old                         0           0            1
# card_id_count_old                           2          26           55
# price_sum                                  14     3583.58          NaN
# price_mean_old                        1.02286     75.8583          NaN
# price_max_old                            1.06      350.09          NaN
# price_min_old                           0.005           4         14.5
# price_var_old                               0     1654.85      5025.49
# Christmas_Day_2017_mean_old                 0     6.24609      13.0703
# Mothers_Day_2017_mean                       0           0      1.95117
# fathers_day_2017_mean                       0           0      5.95703
# Children_day_2017_mean_old                  0    0.660156      9.47656
# Valentine_Day_2017_mean                     0           0      2.49414
# Black_Friday_2017_mean_old                  0      3.8418      11.3203
# Mothers_Day_2018_mean_old                   0           0      4.63672
# duration_mean_old                     15.0414     578.173      1074.15
# duration_min_old                           -0          24         56.1
# duration_max_old                        15.45     3439.04         7384
# duration_var_old                            0      430276  1.88413e+06
# duration_skew_old                    -9.27344     1.78613      2.74219
# amount_month_ratio_mean_old         0.0696258     3.47717      6.54308
# amount_month_ratio_min_old                 -0    0.153809     0.333252
# amount_month_ratio_max_old          0.0757143     20.4227      45.3036
# amount_month_ratio_var_old                  0     15.4977      69.9199
# amount_month_ratio_skew_old          -9.27344     1.78613      2.74219
# category_2_mean_mean_old               386.75       482.5        546.5
# category_3_mean_mean_old              227.875      284.25       482.25
# purchase_date_diff_old                      1         138          233
# purchase_date_average_old           0.0869751           2      3.76172
# purchase_date_uptonow_old                   0           1            4
# purchase_date_uptomin_old                  28         145          240
# quarter                                     1           2            3
# observed_elapsed_time                       0         153          273
# days_feature1                               0         450          819
# days_feature2                               0         240          453
# days_feature3                               0           0          120
# days_feature1_ratio               0.000865801  0.00581395     0.010101
# days_feature2_ratio               0.000432526  0.00328947   0.00547945
# days_feature3_ratio                         0           0   0.00117509
# feature_sum                                 2           4            5
# feature_mean                         0.666504     1.33301      1.66699
# feature_max                                 1           2            3
# feature_min                                 0           0            1
# feature_var                          0.577148           1       1.1543
# card_id_total                               3          33           64
# card_id_count_total                         3          33           64
# card_id_count_ratio               0.000962257   0.0370483    0.0791626
# purchase_amount_total                   21.58     2633.71      5713.42
# purchase_amount_total_mean            2.89417     92.1522      167.429
# purchase_amount_total_min           0.0200043        11.5      22.2656
# purchase_amount_sum_ratio                   0   0.0271759    0.0713501
# hist_first_buy                           -331          10           22
# new_first_buy                              16         182          294
# hist_last_buy                             -28         153          272
# new_last_buy                               54         210          324
# month_diff_ratio                     0.916504    0.987305      1.00098
# installments_total                          0           1           21
# installments_ratio                          0           0    0.0409836
# price_total                           7.20154     84.1258      276.907
# CLV                               0.000666667     27.0838      134.946
# CLV_old                               2.24167      4941.7      20572.5
# CLV_ratio                                   0  0.00107956   0.00561523
# merchant_address_id_nunique                 1           2            5
# merchant_rating_nunique                     1           2            4
#
#                                           75%          max  counts uniques  \
# feature_1                           0.0107117    0.0131454  201917       5
# feature_2                           0.0113831    0.0141678  201917       3
# feature_3                           0.0114288    0.0114288  201917       2
# transactions_count                          9          109  179986      87
# subsector_id_nunique                        6           24  179986      24
# merchant_id_nunique                         9          109  179986      86
# merchant_category_id_nunique                7           40  179986      39
# purchase_Month_mean                         4           12  179986    1959
# purchase_Month_min                          3           12  179986      12
# purchase_Month_max                          4           12  179986      12
# purchase_Week_nunique                       5           10  179986      10
# purchase_Week_mean                         15           52  179986    3297
# purchase_Week_min                          13           52  179986      52
# purchase_Week_max                          17           52  179986      52
# purchase_Dayofweek_mean                3.9043            6  179986    1268
# purchase_Dayofweek_min                      2            6  179986       7
# purchase_Dayofweek_max                      6            6  179986       7
# purchase_Day_nunique                        7           30  179986      30
# purchase_Day_mean                     19.3281           31  179986    2034
# purchase_Day_min                           12           31  179986      31
# purchase_Day_max                           29           31  179986      31
# purchase_Hour_nunique                       7           23  179986      23
# purchase_Hour_mean                    15.1641           23  179986    1281
# purchase_Hour_min                          11           23  179986      24
# purchase_Hour_max                          21           23  179986      24
# purchase_amount_sum                    919.08      78560.5  179986   98482
# purchase_amount_max                       376        51520  179986    9878
# purchase_amount_min                      36.5        29904  179986    7677
# purchase_amount_mean                   143.25        29904  179986    9227
# purchase_amount_var                   19925.1  9.92008e+08  153199  140584
# purchase_amount_skew                        2      8.57031  130048   12761
# installments_sum                            7          154  179986     103
# installments_max                            2           12  178586      13
# installments_mean                     1.15625           12  178586     986
# installments_var                         0.25           72  150921    3371
# installments_skew                     1.45801      8.82812  127352    2794
# month_lag_max                               2            2  179986       2
# month_lag_min                               1            2  179986       2
# month_lag_mean                        1.71387            2  179986     597
# month_lag_var                        0.285645          0.5  153199     474
# month_lag_skew                       0.856934      6.55859  130048    1029
# month_diff_mean                            13           24  179986     753
# month_diff_var                           0.25          0.5  153199     579
# month_diff_skew                             0      4.47266  130048     777
# purchased_on_weekend_mean                 0.5            1  179986     579
# category_1_mean                             0            1  179986     234
# category_2_mean                             3            5  179986    1320
# category_3_mean                             1            2  179986     535
# card_id_count                               9          109  179986      87
# price_mean                                inf          inf  178586   77372
# price_max                                 inf          inf  178586   36657
# price_min                                 inf          inf  178586   15435
# price_var                              7677.5   2.1177e+08   76989   72604
# Christmas_Day_2017_mean                     0           99  179986    3294
# Children_day_2017_mean                      0           99  179986    2646
# Mothers_Day_2018_mean                      51           99  179986    2561
# duration_mean                         1836.35       358800  179986  144451
# duration_min                          475.418       358800  179986   29804
# duration_max                             4800       730704  179986   63863
# duration_var                      3.30073e+06  1.29391e+11  153199  145671
# duration_skew                               2      8.42188  130048   12778
# amount_month_ratio_mean               11.3984         2492  179986    9642
# amount_month_ratio_min                2.90039         2492  179986    9680
# amount_month_ratio_var                125.091  8.20939e+06  153199  146336
# amount_month_ratio_skew                     2      8.71094  130048   12747
# category_2_mean_mean                  130.875       131.75  179986      63
# category_3_mean_mean                   133.25          522  179986    1173
# purchase_date_diff                         47           61  179986      62
# purchase_date_average                   7.125           30  179986    1252
# purchase_date_uptonow                     -37            0  179986      63
# purchase_date_uptomin                      -4            0  179986      63
# transactions_count_old                    111         2912  201917    1023
# subsector_id_nunique_old                   15           34  201917      34
# merchant_id_nunique_old                    44          398  201917     313
# merchant_category_id_nunique_old           24           95  201917      92
# purchase_Month_nunique                     10           12  201917      11
# purchase_Month_min_old                      1           11  201917      11
# purchase_Month_max_old                     12           12  201917      11
# purchase_Week_nunique_old                  28           52  201917      52
# purchase_Week_mean_old                31.6875      51.1875  201917    3481
# purchase_Week_min_old                       3           48  201917      48
# purchase_Week_max_old                      52           52  201917      48
# purchase_Dayofweek_mean_old            3.3418            6  201917    2038
# purchase_Day_nunique_old                   28           31  201917      31
# purchase_Day_mean_old                 17.4219      30.3281  201917    2427
# purchase_Day_min_old                        2           30  201917      30
# purchase_Hour_nunique_old                  19           24  201917      24
# purchase_Hour_mean_old                15.0469        22.75  201917    1664
# purchase_Hour_min_old                       5           22  201917      23
# purchase_Hour_max_old                      23           23  201917      22
# purchase_amount_sum_old               11197.4        4e+09  201917  188890
# purchase_amount_max_old                  1347        4e+09  201917   74899
# purchase_amount_min_old                    10        19504  201917    5065
# purchase_amount_mean_old              163.175  3.33333e+08  201917  199717
# purchase_amount_var_old               57953.6  1.33333e+18  201917  201305
# purchase_amount_skew_old              4.09766      34.4375  201883    9796
# installments_sum_old                       78         2076  201917     964
# installments_max_old                        6           12  201917      13
# installments_mean_old                 1.39453      11.7969  201917    7048
# installments_var_old                   1.2002         60.5  201910   11915
# installments_skew_old                 5.12891       38.125  201839    8002
# month_lag_max_old                           0            0  201917      12
# month_lag_min_old                          -4           -1  201917      13
# month_lag_mean_old                   -2.03516   -0.0149231  201917    4786
# month_lag_var_old                      11.875           49  201917    7461
# month_lag_skew_old                   0.224854      5.87891  201883   19019
# month_diff_max                             13           24  201917      14
# month_diff_min                             12           24  201917      14
# month_diff_mean_old                   12.8984           24  201917     720
# month_diff_var_old                   0.158569          0.5  201917    3630
# month_diff_skew_old                  -1.29688      3.87305  201883    4519
# authorized_flag_mean                 0.972656            1  201917    1630
# purchased_on_weekend_mean_old        0.356445            1  201917    3969
# category_1_mean_old                 0.0908813            1  201917    6169
# category_2_mean_old                   2.94531            5  201917    2293
# category_3_mean_old                   1.13379            2  201917    5077
# card_id_count_old                         111         2912  201917    1023
# price_sum                                 NaN          inf  201917   99853
# price_mean_old                            NaN          inf  201917   99922
# price_max_old                             NaN          inf  201917   49388
# price_min_old                             NaN          inf  201917   13425
# price_var_old                         18428.3  7.31154e+14  100272   99792
# Christmas_Day_2017_mean_old           20.5625         88.5  201917    7543
# Mothers_Day_2017_mean                 11.7812           96  201917    8882
# fathers_day_2017_mean                 13.1797        82.75  201917    8673
# Children_day_2017_mean_old            16.0469           91  201917    8373
# Valentine_Day_2017_mean               12.0234        85.75  201917    8972
# Black_Friday_2017_mean_old            18.1406           86  201917    7989
# Mothers_Day_2018_mean_old             11.8594       81.875  201917    7080
# duration_mean_old                     2098.89  6.33333e+09  201917  201101
# duration_min_old                       131.89       220000  201917   17585
# duration_max_old                      17152.9      7.6e+10  201917   94542
# duration_var_old                  9.43615e+06  4.81333e+20  201917  201393
# duration_skew_old                     4.10156      34.4375  201883    9782
# amount_month_ratio_mean_old           12.9593  1.75439e+07  201917  201181
# amount_month_ratio_min_old           0.825195         1625  201917    7959
# amount_month_ratio_max_old            107.414  2.10526e+08  201917   97495
# amount_month_ratio_var_old            363.599  3.69344e+15  201917  201397
# amount_month_ratio_skew_old           4.09766      34.4375  201883    9762
# category_2_mean_mean_old                546.5          617  201917     712
# category_3_mean_mean_old                735.5        735.5  201917    1683
# purchase_date_diff_old                    361          423  201917     422
# purchase_date_average_old             7.35938      135.625  201917    7289
# purchase_date_uptonow_old                  12          354  179986     319
# purchase_date_uptomin_old                 376          423  179986     396
# quarter                                     4            4  201917       4
# observed_elapsed_time                     485         2312  179986     226
# days_feature1                            1520         7904  179986     596
# days_feature2                             854         6936  179986     465
# days_feature3                             365         2312  179986     226
# days_feature1_ratio                 0.0166667          inf  179986     626
# days_feature2_ratio                0.00943396          inf  179986     485
# days_feature3_ratio                  0.003663          inf  179986     227
# feature_sum                                 7            8  201917       7
# feature_mean                          2.33398      2.66602  201917       7
# feature_max                                 4            5  201917       5
# feature_min                                 1            1  201917       2
# feature_var                           2.08203      2.30859  201917       7
# card_id_total                             124         2916  179986    1034
# card_id_count_total                       124         2916  179986    1034
# card_id_count_ratio                  0.170166        15.25  179986    6171
# purchase_amount_total                 12779.3        4e+09  179986  171017
# purchase_amount_total_mean             322.91  3.33333e+08  179986  179261
# purchase_amount_total_min             49.4062        29920  179986    8249
# purchase_amount_sum_ratio            0.173462      66.9375  179986   13113
# hist_first_buy                            123         1995  201917    1905
# new_first_buy                             489         2352  179986    1895
# hist_last_buy                             473         2311  201917    1879
# new_last_buy                              514         2370  179986    1897
# month_diff_ratio                      1.00977      1.09082  179986     256
# installments_total                         89         1692  179986     979
# installments_ratio                      0.125          inf  135649    9039
# price_total                           36795.2          inf  179986  135480
# CLV                                   559.105       227985  179986  150885
# CLV_old                                 85540  3.80847e+09  201917  201542
# CLV_ratio                           0.0272064       408.75  179986   16658
# merchant_address_id_nunique                 9          109  179986      86
# merchant_rating_nunique                     6           14  179986      14
#
#                                  missing missing_perc    types
# feature_1                              0           0%  numeric
# feature_2                              0           0%  numeric
# feature_3                              0           0%     bool
# transactions_count                 21931       10.86%  numeric
# subsector_id_nunique               21931       10.86%  numeric
# merchant_id_nunique                21931       10.86%  numeric
# merchant_category_id_nunique       21931       10.86%  numeric
# purchase_Month_mean                21931       10.86%  numeric
# purchase_Month_min                 21931       10.86%  numeric
# purchase_Month_max                 21931       10.86%  numeric
# purchase_Week_nunique              21931       10.86%  numeric
# purchase_Week_mean                 21931       10.86%  numeric
# purchase_Week_min                  21931       10.86%  numeric
# purchase_Week_max                  21931       10.86%  numeric
# purchase_Dayofweek_mean            21931       10.86%  numeric
# purchase_Dayofweek_min             21931       10.86%  numeric
# purchase_Dayofweek_max             21931       10.86%  numeric
# purchase_Day_nunique               21931       10.86%  numeric
# purchase_Day_mean                  21931       10.86%  numeric
# purchase_Day_min                   21931       10.86%  numeric
# purchase_Day_max                   21931       10.86%  numeric
# purchase_Hour_nunique              21931       10.86%  numeric
# purchase_Hour_mean                 21931       10.86%  numeric
# purchase_Hour_min                  21931       10.86%  numeric
# purchase_Hour_max                  21931       10.86%  numeric
# purchase_amount_sum                21931       10.86%  numeric
# purchase_amount_max                21931       10.86%  numeric
# purchase_amount_min                21931       10.86%  numeric
# purchase_amount_mean               21931       10.86%  numeric
# purchase_amount_var                48718       24.13%  numeric
# purchase_amount_skew               71869       35.59%  numeric
# installments_sum                   21931       10.86%  numeric
# installments_max                   23331       11.55%  numeric
# installments_mean                  23331       11.55%  numeric
# installments_var                   50996       25.26%  numeric
# installments_skew                  74565       36.93%  numeric
# month_lag_max                      21931       10.86%     bool
# month_lag_min                      21931       10.86%     bool
# month_lag_mean                     21931       10.86%  numeric
# month_lag_var                      48718       24.13%  numeric
# month_lag_skew                     71869       35.59%  numeric
# month_diff_mean                    21931       10.86%  numeric
# month_diff_var                     48718       24.13%  numeric
# month_diff_skew                    71869       35.59%  numeric
# purchased_on_weekend_mean          21931       10.86%  numeric
# category_1_mean                    21931       10.86%  numeric
# category_2_mean                    21931       10.86%  numeric
# category_3_mean                    21931       10.86%  numeric
# card_id_count                      21931       10.86%  numeric
# price_mean                         23331       11.55%  numeric
# price_max                          23331       11.55%  numeric
# price_min                          23331       11.55%  numeric
# price_var                         124928       61.87%  numeric
# Christmas_Day_2017_mean            21931       10.86%  numeric
# Children_day_2017_mean             21931       10.86%  numeric
# Mothers_Day_2018_mean              21931       10.86%  numeric
# duration_mean                      21931       10.86%  numeric
# duration_min                       21931       10.86%  numeric
# duration_max                       21931       10.86%  numeric
# duration_var                       48718       24.13%  numeric
# duration_skew                      71869       35.59%  numeric
# amount_month_ratio_mean            21931       10.86%  numeric
# amount_month_ratio_min             21931       10.86%  numeric
# amount_month_ratio_var             48718       24.13%  numeric
# amount_month_ratio_skew            71869       35.59%  numeric
# category_2_mean_mean               21931       10.86%  numeric
# category_3_mean_mean               21931       10.86%  numeric
# purchase_date_diff                 21931       10.86%  numeric
# purchase_date_average              21931       10.86%  numeric
# purchase_date_uptonow              21931       10.86%  numeric
# purchase_date_uptomin              21931       10.86%  numeric
# transactions_count_old                 0           0%  numeric
# subsector_id_nunique_old               0           0%  numeric
# merchant_id_nunique_old                0           0%  numeric
# merchant_category_id_nunique_old       0           0%  numeric
# purchase_Month_nunique                 0           0%  numeric
# purchase_Month_min_old                 0           0%  numeric
# purchase_Month_max_old                 0           0%  numeric
# purchase_Week_nunique_old              0           0%  numeric
# purchase_Week_mean_old                 0           0%  numeric
# purchase_Week_min_old                  0           0%  numeric
# purchase_Week_max_old                  0           0%  numeric
# purchase_Dayofweek_mean_old            0           0%  numeric
# purchase_Day_nunique_old               0           0%  numeric
# purchase_Day_mean_old                  0           0%  numeric
# purchase_Day_min_old                   0           0%  numeric
# purchase_Hour_nunique_old              0           0%  numeric
# purchase_Hour_mean_old                 0           0%  numeric
# purchase_Hour_min_old                  0           0%  numeric
# purchase_Hour_max_old                  0           0%  numeric
# purchase_amount_sum_old                0           0%  numeric
# purchase_amount_max_old                0           0%  numeric
# purchase_amount_min_old                0           0%  numeric
# purchase_amount_mean_old               0           0%  numeric
# purchase_amount_var_old                0           0%  numeric
# purchase_amount_skew_old              34        0.02%  numeric
# installments_sum_old                   0           0%  numeric
# installments_max_old                   0           0%  numeric
# installments_mean_old                  0           0%  numeric
# installments_var_old                   7        0.00%  numeric
# installments_skew_old                 78        0.04%  numeric
# month_lag_max_old                      0           0%  numeric
# month_lag_min_old                      0           0%  numeric
# month_lag_mean_old                     0           0%  numeric
# month_lag_var_old                      0           0%  numeric
# month_lag_skew_old                    34        0.02%  numeric
# month_diff_max                         0           0%  numeric
# month_diff_min                         0           0%  numeric
# month_diff_mean_old                    0           0%  numeric
# month_diff_var_old                     0           0%  numeric
# month_diff_skew_old                   34        0.02%  numeric
# authorized_flag_mean                   0           0%  numeric
# purchased_on_weekend_mean_old          0           0%  numeric
# category_1_mean_old                    0           0%  numeric
# category_2_mean_old                    0           0%  numeric
# category_3_mean_old                    0           0%  numeric
# card_id_count_old                      0           0%  numeric
# price_sum                              0           0%  numeric
# price_mean_old                         0           0%  numeric
# price_max_old                          0           0%  numeric
# price_min_old                          0           0%  numeric
# price_var_old                     101645       50.34%  numeric
# Christmas_Day_2017_mean_old            0           0%  numeric
# Mothers_Day_2017_mean                  0           0%  numeric
# fathers_day_2017_mean                  0           0%  numeric
# Children_day_2017_mean_old             0           0%  numeric
# Valentine_Day_2017_mean                0           0%  numeric
# Black_Friday_2017_mean_old             0           0%  numeric
# Mothers_Day_2018_mean_old              0           0%  numeric
# duration_mean_old                      0           0%  numeric
# duration_min_old                       0           0%  numeric
# duration_max_old                       0           0%  numeric
# duration_var_old                       0           0%  numeric
# duration_skew_old                     34        0.02%  numeric
# amount_month_ratio_mean_old            0           0%  numeric
# amount_month_ratio_min_old             0           0%  numeric
# amount_month_ratio_max_old             0           0%  numeric
# amount_month_ratio_var_old             0           0%  numeric
# amount_month_ratio_skew_old           34        0.02%  numeric
# category_2_mean_mean_old               0           0%  numeric
# category_3_mean_mean_old               0           0%  numeric
# purchase_date_diff_old                 0           0%  numeric
# purchase_date_average_old              0           0%  numeric
# purchase_date_uptonow_old          21931       10.86%  numeric
# purchase_date_uptomin_old          21931       10.86%  numeric
# quarter                                0           0%  numeric
# observed_elapsed_time              21931       10.86%  numeric
# days_feature1                      21931       10.86%  numeric
# days_feature2                      21931       10.86%  numeric
# days_feature3                      21931       10.86%  numeric
# days_feature1_ratio                21931       10.86%  numeric
# days_feature2_ratio                21931       10.86%  numeric
# days_feature3_ratio                21931       10.86%  numeric
# feature_sum                            0           0%  numeric
# feature_mean                           0           0%  numeric
# feature_max                            0           0%  numeric
# feature_min                            0           0%     bool
# feature_var                            0           0%  numeric
# card_id_total                      21931       10.86%  numeric
# card_id_count_total                21931       10.86%  numeric
# card_id_count_ratio                21931       10.86%  numeric
# purchase_amount_total              21931       10.86%  numeric
# purchase_amount_total_mean         21931       10.86%  numeric
# purchase_amount_total_min          21931       10.86%  numeric
# purchase_amount_sum_ratio          21931       10.86%  numeric
# hist_first_buy                         0           0%  numeric
# new_first_buy                      21931       10.86%  numeric
# hist_last_buy                          0           0%  numeric
# new_last_buy                       21931       10.86%  numeric
# month_diff_ratio                   21931       10.86%  numeric
# installments_total                 21931       10.86%  numeric
# installments_ratio                 66268       32.82%  numeric
# price_total                        21931       10.86%  numeric
# CLV                                21931       10.86%  numeric
# CLV_old                                0           0%  numeric
# CLV_ratio                          21931       10.86%  numeric
# merchant_address_id_nunique        21931       10.86%  numeric
# merchant_rating_nunique            21931       10.86%  numeric

# %%
df_train.fillna(0, inplace=True)
df_test.fillna(0, inplace=True)
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
df_train.replace(np.inf, 0, inplace=True)
df_train.replace(-np.inf, 0, inplace=True)
df_test.replace(np.inf, 0, inplace=True)
df_test.replace(-np.inf, 0, inplace=True)
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
m = RandomForestRegressor(n_estimators=40, min_samples_leaf=5, max_depth=10, max_features=0.9)

# %%
m.fit(df_train, target)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features=0.9, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=5, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=40, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
m.score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-caf3a5f35aea> in <module>
# ----> 1 m.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'
