# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Feature-tools-on-entirety" data-toc-modified-id="Feature-tools-on-entirety-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Feature tools on entirety</a></span></li><li><span><a href="#Interactions-in-test&amp;train-dfs" data-toc-modified-id="Interactions-in-test&amp;train-dfs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Interactions in test&amp;train dfs</a></span></li><li><span><a href="#Merge-automated-&amp;-manual-aggs" data-toc-modified-id="Merge-automated-&amp;-manual-aggs-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Merge automated &amp; manual aggs</a></span></li></ul></div>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather
import gc
import featuretools as ft

# %%
hist_trans = feather.read_dataframe('hist_trans_beta')
new_hist_trans = feather.read_dataframe('new_hist_trans_beta')

# %%
def additional_feats(hist_df):
#     hist_df['price'] = hist_df['purchase_amount'] / hist_df['installments']
    hist_df['duration'] = hist_df['purchase_amount']*hist_df['month_diff']
    hist_df['amount_month_ratio'] = hist_df['purchase_amount']/hist_df['month_diff']
    return hist_df

# %%
dfs = [hist_trans, new_hist_trans]

# %%
hist_trans, new_hist_trans = [additional_feats(df) for df in dfs]

# %%
PATH = 'data/elo/'
train, test = [pd.read_csv(f'{PATH}{c}') for c in ['train.csv', 'test.csv']]

# %%
temp_hist_trans = hist_trans.loc[hist_trans['card_id'].isin(['C_ID_92a2005557', 'C_ID_2223b33279', "C_ID_ae86f7d5fb"])]

# %%
temp_new_trans = new_hist_trans.loc[new_hist_trans['card_id'].isin(['C_ID_92a2005557', 'C_ID_2223b33279', "C_ID_ae86f7d5fb"])]

# %%
for df in [temp_hist_trans, temp_new_trans]:
    df.drop(['purchase_Year', 'purchase_Month', 'purchase_Week', 'purchase_Day',
       'purchase_Dayofweek', 'purchase_Dayofyear', 'purchase_Is_month_end', 'purchase_Is_month_start',
       'purchase_Is_quarter_end', 'purchase_Is_quarter_start', 'purchase_Is_year_end',
       'purchase_Is_year_start', 'purchase_Elapsed'], axis=1, inplace=True)

# %%
temp_hist_trans.shape, temp_new_trans.shape
# Out:
# ((1028, 20), (68, 20))

# %%
temp_new_trans.columns.values
# Out:
# array(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments', 'category_3',
#        'merchant_category_id', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2',
#        'state_id', 'subsector_id', 'purchased_on_weekend', 'purchased_on_weekday', 'month_diff',
#        'purchase_date_successive_diff', 'duration', 'amount_month_ratio'], dtype=object)

# %%
cat_cols = ['authorized_flag', 'card_id', 'city_id', 'category_1', 'category_3',
       'merchant_category_id', 'merchant_id', 'category_2',
       'state_id', 'subsector_id', 'purchased_on_weekend']

# %%
cat_dict = {c:ft.variable_types.Categorical for c in cat_cols}

# %%
cat_dict['purchase_date'] = ft.variable_types.Datetime

# %%
cat_dict
# Out:
# {'authorized_flag': featuretools.variable_types.variable.Categorical,
#  'card_id': featuretools.variable_types.variable.Categorical,
#  'city_id': featuretools.variable_types.variable.Categorical,
#  'category_1': featuretools.variable_types.variable.Categorical,
#  'category_3': featuretools.variable_types.variable.Categorical,
#  'merchant_category_id': featuretools.variable_types.variable.Categorical,
#  'merchant_id': featuretools.variable_types.variable.Categorical,
#  'category_2': featuretools.variable_types.variable.Categorical,
#  'state_id': featuretools.variable_types.variable.Categorical,
#  'subsector_id': featuretools.variable_types.variable.Categorical,
#  'purchased_on_weekend': featuretools.variable_types.variable.Categorical,
#  'purchase_date': featuretools.variable_types.variable.Datetime}

# %% [markdown]
# ### Feature tools on entirety

# %%
es = ft.EntitySet()

# %%
temp_es = es.entity_from_dataframe('temp_hist_trans', temp_hist_trans, 'index', time_index='purchase_date',
                                        variable_types=cat_dict)
temp_es = es.entity_from_dataframe('temp_new_trans', temp_new_trans, 'index', time_index='purchase_date',
                                        variable_types=cat_dict)
# Out:
# 2019-02-06 23:16:45,030 featuretools.entityset - WARNING    index index not found in dataframe, creating new integer column
# 2019-02-06 23:16:45,041 featuretools.entityset - WARNING    index index not found in dataframe, creating new integer column

# %%
temp_es
# Out:
# Entityset: None
#   Entities:
#     temp_hist_trans [Rows: 1028, Columns: 21]
#     temp_new_trans [Rows: 68, Columns: 21]
#   Relationships:
#     No relationships

# %%
temp_es['temp_new_trans']
# Out:
# Entity: temp_new_trans
#   Variables:
#     index (dtype: index)
#     installments (dtype: numeric)
#     month_lag (dtype: numeric)
#     purchase_amount (dtype: numeric)
#     purchased_on_weekday (dtype: numeric)
#     month_diff (dtype: numeric)
#     purchase_date_successive_diff (dtype: numeric)
#     duration (dtype: numeric)
#     amount_month_ratio (dtype: numeric)
#     authorized_flag (dtype: categorical)
#     card_id (dtype: categorical)
#     city_id (dtype: categorical)
#     category_1 (dtype: categorical)
#     category_3 (dtype: categorical)
#     merchant_category_id (dtype: categorical)
#     merchant_id (dtype: categorical)
#     category_2 (dtype: categorical)
#     state_id (dtype: categorical)
#     subsector_id (dtype: categorical)
#     purchased_on_weekend (dtype: categorical)
#     purchase_date (dtype: datetime_time_index)
#   Shape:
#     (Rows: 68, Columns: 21)

# %%
temp_train = train[train['card_id'].isin(['C_ID_92a2005557', 'C_ID_2223b33279', "C_ID_ae86f7d5fb"])]

# %%
temp_test = test[test['card_id'].isin(['C_ID_92a2005557', 'C_ID_2223b33279', "C_ID_ae86f7d5fb"])]

# %%
temp_train.shape, temp_test.shape
# Out:
# ((2, 6), (1, 5))

# %%
temp_train
# Out:
#       first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0                2017-06  C_ID_92a2005557          5          2          1
# 91918            2017-06  C_ID_ae86f7d5fb          5          2          1
#
#          target
# 0     -0.820283
# 91918 -0.563362

# %%
temp_test
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3
# 116681            2016-12  C_ID_2223b33279          3          2          1

# %%
train_cat_cols = ['feature_1', 'feature_2', 'feature_3']

# %%
train_cat_cols = {c:ft.variable_types.Ordinal for c in train_cat_cols}

# %%
temp_es = es.entity_from_dataframe('train', temp_train, 'card_id', time_index='first_active_month',
                                        variable_types=train_cat_cols)

# %%
temp_es['train']
# Out:
# Entity: train
#   Variables:
#     card_id (dtype: index)
#     first_active_month (dtype: datetime_time_index)
#     target (dtype: numeric)
#     feature_1 (dtype: ordinal)
#     feature_2 (dtype: ordinal)
#     feature_3 (dtype: ordinal)
#   Shape:
#     (Rows: 2, Columns: 6)

# %%
temp_es = es.entity_from_dataframe('test', temp_train, 'card_id', time_index='first_active_month',
                                        variable_types=train_cat_cols)

# %%
new_r1 = ft.Relationship( temp_es['train']['card_id'],temp_es['temp_hist_trans']['card_id'])
new_r2 = ft.Relationship( temp_es['train']['card_id'],temp_es['temp_new_trans']['card_id'])
new_r3 = ft.Relationship( temp_es['test']['card_id'],temp_es['temp_hist_trans']['card_id'])
new_r4 = ft.Relationship( temp_es['test']['card_id'],temp_es['temp_new_trans']['card_id'])

# %%
for r in [new_r1, new_r2, new_r3, new_r4]:
    
    temp_es = temp_es.add_relationship(r)

# %%
temp_es
# Out:
# Entityset: None
#   Entities:
#     temp_hist_trans [Rows: 1028, Columns: 21]
#     temp_new_trans [Rows: 68, Columns: 21]
#     train [Rows: 2, Columns: 6]
#     test [Rows: 2, Columns: 6]
#   Relationships:
#     temp_hist_trans.card_id -> train.card_id
#     temp_new_trans.card_id -> train.card_id
#     temp_hist_trans.card_id -> test.card_id
#     temp_new_trans.card_id -> test.card_id

# %%
default_agg_primitives =  ["sum", "std", "max", "skew", "min", "mean", "count", "median",
                           "percent_true", "num_unique", "mode", "avg_time_between", "time_since_last",
                           "percent_true", "trend"]
default_trans_primitives =  ["day", "month","weekday","days_since", "percentile", "hour"]

# %%
temp_es['temp_hist_trans']['authorized_flag'].interesting_values = [1]
temp_es['temp_hist_trans']['purchased_on_weekend'].interesting_values = [1]
temp_es['temp_new_trans']['purchased_on_weekend'].interesting_values = [1]

# %%
feature_matrix, feature_names = ft.dfs(entityset = temp_es, target_entity = 'train',
                                       trans_primitives = default_trans_primitives,
                                       agg_primitives=default_agg_primitives,
                                       ignore_entities=['test'],
                                       where_primitives = ['mean', 'sum'],
                                        max_depth = 2, features_only=False, verbose = True)

pd.options.display.max_columns = 1700
pd.options.display.max_rows = 1700
# Out:
# Built 601 features
# Elapsed: 00:00 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 1/1 chunks

# %%
feature_matrix.T
# Out:
# card_id                                             C_ID_92a2005557  \
# target                                                    -0.820283
# feature_1                                                         5
# feature_2                                                         2
# feature_3                                                         1
# SUM(temp_hist_trans.installments)                                 4
# SUM(temp_hist_trans.month_lag)                                -1017
# SUM(temp_hist_trans.purchase_amount)                       -165.969
# SUM(temp_hist_trans.purchased_on_weekday)                       170
# SUM(temp_hist_trans.month_diff)                                2951
# SUM(temp_hist_trans.purchase_date_successive_diff)       2.0978e+07
# SUM(temp_hist_trans.duration)                              -1885.49
# SUM(temp_hist_trans.amount_month_ratio)                    -14.6348
# STD(temp_hist_trans.installments)                          0.123314
# STD(temp_hist_trans.month_lag)                              2.39769
# STD(temp_hist_trans.purchase_amount)                       0.212139
# STD(temp_hist_trans.purchased_on_weekday)                   0.47666
# STD(temp_hist_trans.month_diff)                             0.47789
# STD(temp_hist_trans.purchase_date_successive_diff)           107376
# STD(temp_hist_trans.duration)                               2.39005
# STD(temp_hist_trans.amount_month_ratio)                   0.0191685
# MAX(temp_hist_trans.installments)                                 1
# MAX(temp_hist_trans.month_lag)                                    0
# MAX(temp_hist_trans.purchase_amount)                        2.25839
# MAX(temp_hist_trans.purchased_on_weekday)                         1
# MAX(temp_hist_trans.month_diff)                                  12
# MAX(temp_hist_trans.purchase_date_successive_diff)      1.04474e+06
# MAX(temp_hist_trans.duration)                               24.8423
# MAX(temp_hist_trans.amount_month_ratio)                    0.205309
# SKEW(temp_hist_trans.installments)                          7.92077
# SKEW(temp_hist_trans.month_lag)                           0.0659603
# SKEW(temp_hist_trans.purchase_amount)                       10.2431
# SKEW(temp_hist_trans.purchased_on_weekday)                -0.650521
# SKEW(temp_hist_trans.month_diff)                           0.632627
# SKEW(temp_hist_trans.purchase_date_successive_d...          3.89701
# SKEW(temp_hist_trans.duration)                              9.75999
# SKEW(temp_hist_trans.amount_month_ratio)                    10.1906
# MIN(temp_hist_trans.installments)                                 0
# MIN(temp_hist_trans.month_lag)                                   -8
# MIN(temp_hist_trans.purchase_amount)                      -0.739395
# MIN(temp_hist_trans.purchased_on_weekday)                         0
# MIN(temp_hist_trans.month_diff)                                  11
# MIN(temp_hist_trans.purchase_date_successive_diff)                0
# MIN(temp_hist_trans.duration)                              -8.80602
# MIN(temp_hist_trans.amount_month_ratio)                  -0.0672177
# MEAN(temp_hist_trans.installments)                        0.0153846
# MEAN(temp_hist_trans.month_lag)                            -3.91154
# MEAN(temp_hist_trans.purchase_amount)                     -0.638341
# MEAN(temp_hist_trans.purchased_on_weekday)                 0.653846
# MEAN(temp_hist_trans.month_diff)                              11.35
# MEAN(temp_hist_trans.purchase_date_successive_d...          80684.6
# MEAN(temp_hist_trans.duration)                             -7.25187
# MEAN(temp_hist_trans.amount_month_ratio)                 -0.0562877
# COUNT(temp_hist_trans)                                          260
# MEDIAN(temp_hist_trans.installments)                              0
# MEDIAN(temp_hist_trans.month_lag)                                -4
# MEDIAN(temp_hist_trans.purchase_amount)                   -0.698042
# MEDIAN(temp_hist_trans.purchased_on_weekday)                      1
# MEDIAN(temp_hist_trans.month_diff)                               11
# MEDIAN(temp_hist_trans.purchase_date_successive...          62157.5
# MEDIAN(temp_hist_trans.duration)                            -7.8022
# MEDIAN(temp_hist_trans.amount_month_ratio)               -0.0595747
# NUM_UNIQUE(temp_hist_trans.authorized_flag)                       2
# NUM_UNIQUE(temp_hist_trans.city_id)                               7
# NUM_UNIQUE(temp_hist_trans.category_1)                            1
# NUM_UNIQUE(temp_hist_trans.category_3)                            2
# NUM_UNIQUE(temp_hist_trans.merchant_category_id)                 41
# NUM_UNIQUE(temp_hist_trans.merchant_id)                          94
# NUM_UNIQUE(temp_hist_trans.category_2)                            2
# NUM_UNIQUE(temp_hist_trans.state_id)                              3
# NUM_UNIQUE(temp_hist_trans.subsector_id)                         21
# NUM_UNIQUE(temp_hist_trans.purchased_on_weekend)                  2
# MODE(temp_hist_trans.authorized_flag)                             1
# MODE(temp_hist_trans.city_id)                                    69
# MODE(temp_hist_trans.category_1)                                  0
# MODE(temp_hist_trans.category_3)                                  0
# MODE(temp_hist_trans.merchant_category_id)                      560
# MODE(temp_hist_trans.merchant_id)                   M_ID_1a81c358a3
# MODE(temp_hist_trans.category_2)                                  1
# MODE(temp_hist_trans.state_id)                                    9
# MODE(temp_hist_trans.subsector_id)                               34
# MODE(temp_hist_trans.purchased_on_weekend)                        0
# AVG_TIME_BETWEEN(temp_hist_trans.purchase_date)             80996.1
# TIME_SINCE_LAST(temp_hist_trans.purchase_date)          5.07859e+07
# TREND(temp_hist_trans.month_diff, purchase_date)       -2.03099e-08
# TREND(temp_hist_trans.installments, purchase_date)      -8.9272e-10
# TREND(temp_hist_trans.amount_month_ratio, purch...      3.09112e-10
# TREND(temp_hist_trans.purchase_amount, purchase...      4.55973e-09
# TREND(temp_hist_trans.purchase_date_successive_...       0.00159676
# TREND(temp_hist_trans.duration, purchase_date)           6.4071e-08
# TREND(temp_hist_trans.month_lag, purchase_date)         3.71169e-07
# TREND(temp_hist_trans.purchased_on_weekday, pur...     -6.85407e-09
# SUM(temp_new_trans.installments)                                  0
# SUM(temp_new_trans.month_lag)                                    34
# SUM(temp_new_trans.purchase_amount)                        -13.2442
# SUM(temp_new_trans.purchased_on_weekday)                         17
# SUM(temp_new_trans.month_diff)                                  261
# SUM(temp_new_trans.purchase_date_successive_diff)       4.74231e+06
# SUM(temp_new_trans.duration)                               -150.358
# SUM(temp_new_trans.amount_month_ratio)                     -1.16863
# STD(temp_new_trans.installments)                                  0
# STD(temp_new_trans.month_lag)                              0.510754
# STD(temp_new_trans.purchase_amount)                        0.135812
# STD(temp_new_trans.purchased_on_weekday)                   0.448978
# STD(temp_new_trans.month_diff)                             0.486985
# STD(temp_new_trans.purchase_date_successive_diff)            205878
# STD(temp_new_trans.duration)                                1.57293
# STD(temp_new_trans.amount_month_ratio)                    0.0121497
# MAX(temp_new_trans.installments)                                  0
# MAX(temp_new_trans.month_lag)                                     2
# MAX(temp_new_trans.purchase_amount)                       -0.296112
# MAX(temp_new_trans.purchased_on_weekday)                          1
# MAX(temp_new_trans.month_diff)                                   12
# MAX(temp_new_trans.purchase_date_successive_diff)            778975
# MAX(temp_new_trans.duration)                               -3.25724
# MAX(temp_new_trans.amount_month_ratio)                   -0.0256465
# SKEW(temp_new_trans.installments)                                 0
# SKEW(temp_new_trans.month_lag)                            0.0932329
# SKEW(temp_new_trans.purchase_amount)                       0.899623
# SKEW(temp_new_trans.purchased_on_weekday)                  -1.16667
# SKEW(temp_new_trans.month_diff)                            0.684484
# SKEW(temp_new_trans.purchase_date_successive_diff)          1.69853
# SKEW(temp_new_trans.duration)                              0.857694
# SKEW(temp_new_trans.amount_month_ratio)                    0.771362
# MIN(temp_new_trans.installments)                                  0
# MIN(temp_new_trans.month_lag)                                     1
# MIN(temp_new_trans.purchase_amount)                       -0.724368
# MIN(temp_new_trans.purchased_on_weekday)                          0
# MIN(temp_new_trans.month_diff)                                   11
# MIN(temp_new_trans.purchase_date_successive_diff)                 0
# MIN(temp_new_trans.duration)                               -8.63868
# MIN(temp_new_trans.amount_month_ratio)                   -0.0658516
# MEAN(temp_new_trans.installments)                                 0
# MEAN(temp_new_trans.month_lag)                              1.47826
# MEAN(temp_new_trans.purchase_amount)                      -0.575835
# MEAN(temp_new_trans.purchased_on_weekday)                   0.73913
# MEAN(temp_new_trans.month_diff)                             11.3478
# MEAN(temp_new_trans.purchase_date_successive_diff)           206187
# MEAN(temp_new_trans.duration)                              -6.53729
# MEAN(temp_new_trans.amount_month_ratio)                  -0.0508099
# COUNT(temp_new_trans)                                            23
# MEDIAN(temp_new_trans.installments)                               0
# MEDIAN(temp_new_trans.month_lag)                                  1
# MEDIAN(temp_new_trans.purchase_amount)                     -0.58118
# MEDIAN(temp_new_trans.purchased_on_weekday)                       1
# MEDIAN(temp_new_trans.month_diff)                                11
# MEDIAN(temp_new_trans.purchase_date_successive_...           164976
# MEDIAN(temp_new_trans.duration)                            -6.83875
# MEDIAN(temp_new_trans.amount_month_ratio)                -0.0488853
# NUM_UNIQUE(temp_new_trans.authorized_flag)                        1
# NUM_UNIQUE(temp_new_trans.city_id)                                3
# NUM_UNIQUE(temp_new_trans.category_1)                             1
# NUM_UNIQUE(temp_new_trans.category_3)                             1
# NUM_UNIQUE(temp_new_trans.merchant_category_id)                  14
# NUM_UNIQUE(temp_new_trans.merchant_id)                           23
# NUM_UNIQUE(temp_new_trans.category_2)                             1
# NUM_UNIQUE(temp_new_trans.state_id)                               1
# NUM_UNIQUE(temp_new_trans.subsector_id)                          10
# NUM_UNIQUE(temp_new_trans.purchased_on_weekend)                   2
# MODE(temp_new_trans.authorized_flag)                              1
# MODE(temp_new_trans.city_id)                                     69
# MODE(temp_new_trans.category_1)                                   0
# MODE(temp_new_trans.category_3)                                   0
# MODE(temp_new_trans.merchant_category_id)                       278
# MODE(temp_new_trans.merchant_id)                    M_ID_0703c10cc0
# MODE(temp_new_trans.category_2)                                   1
# MODE(temp_new_trans.state_id)                                     9
# MODE(temp_new_trans.subsector_id)                                37
# MODE(temp_new_trans.purchased_on_weekend)                         0
# AVG_TIME_BETWEEN(temp_new_trans.purchase_date)               215560
# TIME_SINCE_LAST(temp_new_trans.purchase_date)           2.91004e+07
# TREND(temp_new_trans.installments, purchase_date)                 0
# TREND(temp_new_trans.amount_month_ratio, purcha...     -1.46783e-09
# TREND(temp_new_trans.purchase_amount, purchase_...     -1.10757e-08
# TREND(temp_new_trans.purchase_date_successive_d...          0.03212
# TREND(temp_new_trans.duration, purchase_date)          -6.09874e-08
# TREND(temp_new_trans.purchased_on_weekday, purc...     -5.64721e-08
# TREND(temp_new_trans.month_diff, purchase_date)        -8.02519e-08
# TREND(temp_new_trans.month_lag, purchase_date)          2.96858e-07
# DAY(first_active_month)                                           1
# MONTH(first_active_month)                                         6
# WEEKDAY(first_active_month)                                       3
# DAYS_SINCE(first_active_month)                                  614
# PERCENTILE(target)                                              0.5
# HOUR(first_active_month)                                          0
# SUM(temp_hist_trans.installments WHERE purchase...                1
# SUM(temp_hist_trans.installments WHERE authoriz...                0
# SUM(temp_hist_trans.month_lag WHERE purchased_o...             -326
# SUM(temp_hist_trans.month_lag WHERE authorized_...             -959
# SUM(temp_hist_trans.purchase_amount WHERE purch...         -55.8855
# SUM(temp_hist_trans.purchase_amount WHERE autho...         -157.397
# SUM(temp_hist_trans.purchased_on_weekday WHERE ...                0
# SUM(temp_hist_trans.purchased_on_weekday WHERE ...              161
# SUM(temp_hist_trans.month_diff WHERE purchased_...             1017
# SUM(temp_hist_trans.month_diff WHERE authorized...             2802
# SUM(temp_hist_trans.purchase_date_successive_di...      7.96363e+06
# SUM(temp_hist_trans.purchase_date_successive_di...      1.94592e+07
# SUM(temp_hist_trans.duration WHERE purchased_on...         -630.755
# SUM(temp_hist_trans.duration WHERE authorized_f...         -1787.31
# SUM(temp_hist_trans.amount_month_ratio WHERE pu...         -4.95917
# SUM(temp_hist_trans.amount_month_ratio WHERE au...          -13.885
# SUM(temp_hist_trans.DAYS_SINCE(purchase_date))               123197
# SUM(temp_hist_trans.DAYS_SINCE(purchase_date) W...            41802
# SUM(temp_hist_trans.DAYS_SINCE(purchase_date) W...           116792
# SUM(temp_hist_trans.PERCENTILE(installments))               129.684
# SUM(temp_hist_trans.PERCENTILE(installments) WH...          44.6985
# SUM(temp_hist_trans.PERCENTILE(installments) WH...            121.3
# SUM(temp_hist_trans.PERCENTILE(month_lag))                  113.419
# SUM(temp_hist_trans.PERCENTILE(month_lag) WHERE...          42.1234
# SUM(temp_hist_trans.PERCENTILE(month_lag) WHERE...          108.859
# SUM(temp_hist_trans.PERCENTILE(purchase_amount))            130.022
# SUM(temp_hist_trans.PERCENTILE(purchase_amount)...          51.9046
# SUM(temp_hist_trans.PERCENTILE(purchase_amount)...          124.229
# SUM(temp_hist_trans.PERCENTILE(purchased_on_wee...           131.31
# SUM(temp_hist_trans.PERCENTILE(purchased_on_wee...          16.0305
# SUM(temp_hist_trans.PERCENTILE(purchased_on_wee...          124.495
# SUM(temp_hist_trans.PERCENTILE(month_diff))                 86.3359
# SUM(temp_hist_trans.PERCENTILE(month_diff) WHER...          28.3969
# SUM(temp_hist_trans.PERCENTILE(month_diff) WHER...          81.5394
# SUM(temp_hist_trans.PERCENTILE(purchase_date_su...          135.628
# SUM(temp_hist_trans.PERCENTILE(purchase_date_su...          46.6476
# SUM(temp_hist_trans.PERCENTILE(purchase_date_su...          129.425
# SUM(temp_hist_trans.PERCENTILE(duration))                   158.537
# SUM(temp_hist_trans.PERCENTILE(duration) WHERE ...          61.1387
# SUM(temp_hist_trans.PERCENTILE(duration) WHERE ...          151.294
# SUM(temp_hist_trans.PERCENTILE(amount_month_rat...          96.2774
# SUM(temp_hist_trans.PERCENTILE(amount_month_rat...          38.3702
# SUM(temp_hist_trans.PERCENTILE(amount_month_rat...          91.6578
# STD(temp_hist_trans.DAYS_SINCE(purchase_date))              74.2452
# STD(temp_hist_trans.PERCENTILE(installments))             0.0616571
# STD(temp_hist_trans.PERCENTILE(month_lag))                   0.2978
# STD(temp_hist_trans.PERCENTILE(purchase_amount))           0.273598
# STD(temp_hist_trans.PERCENTILE(purchased_on_wee...          0.23833
# STD(temp_hist_trans.PERCENTILE(month_diff))                 0.15808
# STD(temp_hist_trans.PERCENTILE(purchase_date_su...         0.280444
# STD(temp_hist_trans.PERCENTILE(duration))                   0.20574
# STD(temp_hist_trans.PERCENTILE(amount_month_rat...         0.258088
# MAX(temp_hist_trans.DAYS_SINCE(purchase_date))                  587
# MAX(temp_hist_trans.PERCENTILE(installments))              0.991094
# MAX(temp_hist_trans.PERCENTILE(month_lag))                 0.959288
# MAX(temp_hist_trans.PERCENTILE(purchase_amount))           0.994911
# MAX(temp_hist_trans.PERCENTILE(purchased_on_wee...         0.678117
# MAX(temp_hist_trans.PERCENTILE(month_diff))                0.547074
# MAX(temp_hist_trans.PERCENTILE(purchase_date_su...         0.992366
# MAX(temp_hist_trans.PERCENTILE(duration))                  0.994911
# MAX(temp_hist_trans.PERCENTILE(amount_month_rat...                1
# SKEW(temp_hist_trans.DAYS_SINCE(purchase_date))          -0.0534497
# SKEW(temp_hist_trans.PERCENTILE(installments))              7.92077
# SKEW(temp_hist_trans.PERCENTILE(month_lag))                0.290522
# SKEW(temp_hist_trans.PERCENTILE(purchase_amount))         0.0065437
# SKEW(temp_hist_trans.PERCENTILE(purchased_on_we...        -0.650521
# SKEW(temp_hist_trans.PERCENTILE(month_diff))               0.632627
# SKEW(temp_hist_trans.PERCENTILE(purchase_date_s...        -0.158507
# SKEW(temp_hist_trans.PERCENTILE(duration))               0.00399592
# SKEW(temp_hist_trans.PERCENTILE(amount_month_ra...         0.745192
# MIN(temp_hist_trans.DAYS_SINCE(purchase_date))                  344
# MIN(temp_hist_trans.PERCENTILE(installments))              0.491094
# MIN(temp_hist_trans.PERCENTILE(month_lag))               0.00508906
# MIN(temp_hist_trans.PERCENTILE(purchase_amount))          0.0114504
# MIN(temp_hist_trans.PERCENTILE(purchased_on_wee...         0.178117
# MIN(temp_hist_trans.PERCENTILE(month_diff))                0.216285
# MIN(temp_hist_trans.PERCENTILE(purchase_date_su...       0.00508906
# MIN(temp_hist_trans.PERCENTILE(duration))                  0.246819
# MIN(temp_hist_trans.PERCENTILE(amount_month_rat...       0.00254453
# MEAN(temp_hist_trans.installments WHERE purchas...        0.0111111
# MEAN(temp_hist_trans.installments WHERE authori...                0
# MEAN(temp_hist_trans.month_lag WHERE purchased_...         -3.62222
# MEAN(temp_hist_trans.month_lag WHERE authorized...         -3.88259
# MEAN(temp_hist_trans.purchase_amount WHERE purc...         -0.62095
# MEAN(temp_hist_trans.purchase_amount WHERE auth...        -0.637235
# MEAN(temp_hist_trans.purchased_on_weekday WHERE...                0
# MEAN(temp_hist_trans.purchased_on_weekday WHERE...         0.651822
# MEAN(temp_hist_trans.month_diff WHERE purchased...             11.3
# MEAN(temp_hist_trans.month_diff WHERE authorize...          11.3441
# MEAN(temp_hist_trans.purchase_date_successive_d...          88484.8
# MEAN(temp_hist_trans.purchase_date_successive_d...          78782.3
# MEAN(temp_hist_trans.duration WHERE purchased_o...         -7.00839
# MEAN(temp_hist_trans.duration WHERE authorized_...         -7.23609
# MEAN(temp_hist_trans.amount_month_ratio WHERE p...       -0.0551019
# MEAN(temp_hist_trans.amount_month_ratio WHERE a...       -0.0562145
# MEAN(temp_hist_trans.DAYS_SINCE(purchase_date))             473.835
# MEAN(temp_hist_trans.DAYS_SINCE(purchase_date) ...          464.467
# MEAN(temp_hist_trans.DAYS_SINCE(purchase_date) ...          472.842
# MEAN(temp_hist_trans.PERCENTILE(installments))             0.498786
# MEAN(temp_hist_trans.PERCENTILE(installments) W...          0.49665
# MEAN(temp_hist_trans.PERCENTILE(installments) W...         0.491094
# MEAN(temp_hist_trans.PERCENTILE(month_lag))                0.436225
# MEAN(temp_hist_trans.PERCENTILE(month_lag) WHER...         0.468038
# MEAN(temp_hist_trans.PERCENTILE(month_lag) WHER...         0.440724
# MEAN(temp_hist_trans.PERCENTILE(purchase_amount))          0.500083
# MEAN(temp_hist_trans.PERCENTILE(purchase_amount...         0.576718
# MEAN(temp_hist_trans.PERCENTILE(purchase_amount...         0.502951
# MEAN(temp_hist_trans.PERCENTILE(purchased_on_we...          0.50504
# MEAN(temp_hist_trans.PERCENTILE(purchased_on_we...         0.178117
# MEAN(temp_hist_trans.PERCENTILE(purchased_on_we...         0.504028
# MEAN(temp_hist_trans.PERCENTILE(month_diff))               0.332061
# MEAN(temp_hist_trans.PERCENTILE(month_diff) WHE...         0.315522
# MEAN(temp_hist_trans.PERCENTILE(month_diff) WHE...         0.330119
# MEAN(temp_hist_trans.PERCENTILE(purchase_date_s...         0.521648
# MEAN(temp_hist_trans.PERCENTILE(purchase_date_s...         0.518306
# MEAN(temp_hist_trans.PERCENTILE(purchase_date_s...         0.523988
# MEAN(temp_hist_trans.PERCENTILE(duration))                 0.609757
# MEAN(temp_hist_trans.PERCENTILE(duration) WHERE...         0.679319
# MEAN(temp_hist_trans.PERCENTILE(duration) WHERE...         0.612526
# MEAN(temp_hist_trans.PERCENTILE(amount_month_ra...         0.370298
# MEAN(temp_hist_trans.PERCENTILE(amount_month_ra...         0.426336
# MEAN(temp_hist_trans.PERCENTILE(amount_month_ra...         0.371084
# MEDIAN(temp_hist_trans.DAYS_SINCE(purchase_date))             475.5
# MEDIAN(temp_hist_trans.PERCENTILE(installments))           0.491094
# MEDIAN(temp_hist_trans.PERCENTILE(month_lag))              0.382952
# MEDIAN(temp_hist_trans.PERCENTILE(purchase_amou...         0.510178
# MEDIAN(temp_hist_trans.PERCENTILE(purchased_on_...         0.678117
# MEDIAN(temp_hist_trans.PERCENTILE(month_diff))             0.216285
# MEDIAN(temp_hist_trans.PERCENTILE(purchase_date...         0.553435
# MEDIAN(temp_hist_trans.PERCENTILE(duration))                0.60687
# MEDIAN(temp_hist_trans.PERCENTILE(amount_month_...         0.332061
# NUM_UNIQUE(temp_hist_trans.DAY(purchase_date))                   31
# NUM_UNIQUE(temp_hist_trans.MONTH(purchase_date))                  9
# NUM_UNIQUE(temp_hist_trans.WEEKDAY(purchase_date))                7
# NUM_UNIQUE(temp_hist_trans.HOUR(purchase_date))                  23
# MODE(temp_hist_trans.DAY(purchase_date))                         11
# MODE(temp_hist_trans.MONTH(purchase_date))                       12
# MODE(temp_hist_trans.WEEKDAY(purchase_date))                      5
# MODE(temp_hist_trans.HOUR(purchase_date))                        14
# TREND(temp_hist_trans.PERCENTILE(month_lag), pu...      4.58304e-08
# TREND(temp_hist_trans.PERCENTILE(duration), pur...       8.4611e-09
# TREND(temp_hist_trans.PERCENTILE(amount_month_r...      4.19797e-09
# TREND(temp_hist_trans.PERCENTILE(purchase_amoun...      6.24958e-09
# TREND(temp_hist_trans.DAYS_SINCE(purchase_date)...     -1.15739e-05
# TREND(temp_hist_trans.PERCENTILE(installments),...      -4.4636e-10
# TREND(temp_hist_trans.PERCENTILE(purchased_on_w...     -3.42703e-09
# TREND(temp_hist_trans.PERCENTILE(purchase_date_...      2.49699e-09
# TREND(temp_hist_trans.PERCENTILE(month_diff), p...     -6.71828e-09
# SUM(temp_new_trans.installments WHERE purchased...                0
# SUM(temp_new_trans.month_lag WHERE purchased_on...                9
# SUM(temp_new_trans.purchase_amount WHERE purcha...         -2.81409
# SUM(temp_new_trans.purchased_on_weekday WHERE p...                0
# SUM(temp_new_trans.month_diff WHERE purchased_o...               67
# SUM(temp_new_trans.purchase_date_successive_dif...      1.48362e+06
# SUM(temp_new_trans.duration WHERE purchased_on_...         -31.2627
# SUM(temp_new_trans.amount_month_ratio WHERE pur...        -0.253495
# SUM(temp_new_trans.DAYS_SINCE(purchase_date))                  7125
# SUM(temp_new_trans.DAYS_SINCE(purchase_date) WH...             1829
# SUM(temp_new_trans.PERCENTILE(installments))                11.7447
# SUM(temp_new_trans.PERCENTILE(installments) WHE...          3.06383
# SUM(temp_new_trans.PERCENTILE(month_lag))                   12.5957
# SUM(temp_new_trans.PERCENTILE(month_lag) WHERE ...          3.35106
# SUM(temp_new_trans.PERCENTILE(purchase_amount))             11.6277
# SUM(temp_new_trans.PERCENTILE(purchase_amount) ...          4.28723
# SUM(temp_new_trans.PERCENTILE(purchased_on_week...          13.1489
# SUM(temp_new_trans.PERCENTILE(purchased_on_week...          1.21277
# SUM(temp_new_trans.PERCENTILE(month_diff))                  5.87234
# SUM(temp_new_trans.PERCENTILE(month_diff) WHERE...          1.26596
# SUM(temp_new_trans.PERCENTILE(purchase_date_suc...          12.3511
# SUM(temp_new_trans.PERCENTILE(purchase_date_suc...          3.68085
# SUM(temp_new_trans.PERCENTILE(duration))                    14.4043
# SUM(temp_new_trans.PERCENTILE(duration) WHERE p...          4.71277
# SUM(temp_new_trans.PERCENTILE(amount_month_ratio))          8.80851
# SUM(temp_new_trans.PERCENTILE(amount_month_rati...          3.62766
# STD(temp_new_trans.DAYS_SINCE(purchase_date))               16.6022
# STD(temp_new_trans.PERCENTILE(installments))                      0
# STD(temp_new_trans.PERCENTILE(month_lag))                  0.255377
# STD(temp_new_trans.PERCENTILE(purchase_amount))            0.271089
# STD(temp_new_trans.PERCENTILE(purchased_on_week...         0.224489
# STD(temp_new_trans.PERCENTILE(month_diff))                 0.119156
# STD(temp_new_trans.PERCENTILE(purchase_date_suc...          0.26951
# STD(temp_new_trans.PERCENTILE(duration))                   0.199755
# STD(temp_new_trans.PERCENTILE(amount_month_ratio))         0.286876
# MAX(temp_new_trans.DAYS_SINCE(purchase_date))                   336
# MAX(temp_new_trans.PERCENTILE(installments))               0.510638
# MAX(temp_new_trans.PERCENTILE(month_lag))                  0.808511
# MAX(temp_new_trans.PERCENTILE(purchase_amount))            0.904255
# MAX(temp_new_trans.PERCENTILE(purchased_on_week...         0.702128
# MAX(temp_new_trans.PERCENTILE(month_diff))                 0.414894
# MAX(temp_new_trans.PERCENTILE(purchase_date_suc...                1
# MAX(temp_new_trans.PERCENTILE(duration))                   0.925532
# MAX(temp_new_trans.PERCENTILE(amount_month_ratio))         0.914894
# SKEW(temp_new_trans.DAYS_SINCE(purchase_date))            0.0263921
# SKEW(temp_new_trans.PERCENTILE(installments))                     0
# SKEW(temp_new_trans.PERCENTILE(month_lag))                0.0932329
# SKEW(temp_new_trans.PERCENTILE(purchase_amount))          -0.113279
# SKEW(temp_new_trans.PERCENTILE(purchased_on_wee...         -1.16667
# SKEW(temp_new_trans.PERCENTILE(month_diff))                0.684484
# SKEW(temp_new_trans.PERCENTILE(purchase_date_su...        -0.127311
# SKEW(temp_new_trans.PERCENTILE(duration))                 -0.128077
# SKEW(temp_new_trans.PERCENTILE(amount_month_rat...          0.50927
# MIN(temp_new_trans.DAYS_SINCE(purchase_date))                   281
# MIN(temp_new_trans.PERCENTILE(installments))               0.510638
# MIN(temp_new_trans.PERCENTILE(month_lag))                  0.308511
# MIN(temp_new_trans.PERCENTILE(purchase_amount))           0.0638298
# MIN(temp_new_trans.PERCENTILE(purchased_on_week...         0.202128
# MIN(temp_new_trans.PERCENTILE(month_diff))                 0.170213
# MIN(temp_new_trans.PERCENTILE(purchase_date_suc...        0.0319149
# MIN(temp_new_trans.PERCENTILE(duration))                   0.276596
# MIN(temp_new_trans.PERCENTILE(amount_month_ratio))        0.0212766
# MEAN(temp_new_trans.installments WHERE purchase...                0
# MEAN(temp_new_trans.month_lag WHERE purchased_o...              1.5
# MEAN(temp_new_trans.purchase_amount WHERE purch...        -0.469015
# MEAN(temp_new_trans.purchased_on_weekday WHERE ...                0
# MEAN(temp_new_trans.month_diff WHERE purchased_...          11.1667
# MEAN(temp_new_trans.purchase_date_successive_di...           247271
# MEAN(temp_new_trans.duration WHERE purchased_on...         -5.21046
# MEAN(temp_new_trans.amount_month_ratio WHERE pu...       -0.0422491
# MEAN(temp_new_trans.DAYS_SINCE(purchase_date))              309.783
# MEAN(temp_new_trans.DAYS_SINCE(purchase_date) W...          304.833
# MEAN(temp_new_trans.PERCENTILE(installments))              0.510638
# MEAN(temp_new_trans.PERCENTILE(installments) WH...         0.510638
# MEAN(temp_new_trans.PERCENTILE(month_lag))                 0.547641
# MEAN(temp_new_trans.PERCENTILE(month_lag) WHERE...         0.558511
# MEAN(temp_new_trans.PERCENTILE(purchase_amount))            0.50555
# MEAN(temp_new_trans.PERCENTILE(purchase_amount)...         0.714539
# MEAN(temp_new_trans.PERCENTILE(purchased_on_wee...         0.571693
# MEAN(temp_new_trans.PERCENTILE(purchased_on_wee...         0.202128
# MEAN(temp_new_trans.PERCENTILE(month_diff))                0.255319
# MEAN(temp_new_trans.PERCENTILE(month_diff) WHER...         0.210993
# MEAN(temp_new_trans.PERCENTILE(purchase_date_su...         0.537003
# MEAN(temp_new_trans.PERCENTILE(purchase_date_su...         0.613475
# MEAN(temp_new_trans.PERCENTILE(duration))                  0.626272
# MEAN(temp_new_trans.PERCENTILE(duration) WHERE ...         0.785461
# MEAN(temp_new_trans.PERCENTILE(amount_month_rat...         0.382979
# MEAN(temp_new_trans.PERCENTILE(amount_month_rat...          0.60461
# MEDIAN(temp_new_trans.DAYS_SINCE(purchase_date))                310
# MEDIAN(temp_new_trans.PERCENTILE(installments))            0.510638
# MEDIAN(temp_new_trans.PERCENTILE(month_lag))               0.308511
# MEDIAN(temp_new_trans.PERCENTILE(purchase_amount))         0.553191
# MEDIAN(temp_new_trans.PERCENTILE(purchased_on_w...         0.702128
# MEDIAN(temp_new_trans.PERCENTILE(month_diff))              0.170213
# MEDIAN(temp_new_trans.PERCENTILE(purchase_date_...         0.553191
# MEDIAN(temp_new_trans.PERCENTILE(duration))                0.638298
# MEDIAN(temp_new_trans.PERCENTILE(amount_month_r...         0.404255
# NUM_UNIQUE(temp_new_trans.DAY(purchase_date))                    17
# NUM_UNIQUE(temp_new_trans.MONTH(purchase_date))                   2
# NUM_UNIQUE(temp_new_trans.WEEKDAY(purchase_date))                 7
# NUM_UNIQUE(temp_new_trans.HOUR(purchase_date))                    8
# MODE(temp_new_trans.DAY(purchase_date))                           6
# MODE(temp_new_trans.MONTH(purchase_date))                         3
# MODE(temp_new_trans.WEEKDAY(purchase_date))                       4
# MODE(temp_new_trans.HOUR(purchase_date))                         13
# TREND(temp_new_trans.PERCENTILE(purchased_on_we...      -2.8236e-08
# TREND(temp_new_trans.PERCENTILE(duration), purc...      1.50261e-09
# TREND(temp_new_trans.PERCENTILE(month_diff), pu...     -1.96361e-08
# TREND(temp_new_trans.PERCENTILE(amount_month_ra...     -2.25804e-08
# TREND(temp_new_trans.PERCENTILE(installments), ...                0
# TREND(temp_new_trans.DAYS_SINCE(purchase_date),...     -1.15877e-05
# TREND(temp_new_trans.PERCENTILE(purchase_amount...     -1.18799e-08
# TREND(temp_new_trans.PERCENTILE(month_lag), pur...      1.48429e-07
# TREND(temp_new_trans.PERCENTILE(purchase_date_s...       3.6465e-08
# PERCENTILE(SUM(temp_hist_trans.installments))                  0.75
# PERCENTILE(SUM(temp_hist_trans.month_lag))                      0.5
# PERCENTILE(SUM(temp_hist_trans.purchase_amount))                0.5
# PERCENTILE(SUM(temp_hist_trans.purchased_on_wee...                1
# PERCENTILE(SUM(temp_hist_trans.month_diff))                       1
# PERCENTILE(SUM(temp_hist_trans.purchase_date_su...                1
# PERCENTILE(SUM(temp_hist_trans.duration))                       0.5
# PERCENTILE(SUM(temp_hist_trans.amount_month_rat...              0.5
# PERCENTILE(STD(temp_hist_trans.installments))                   0.5
# PERCENTILE(STD(temp_hist_trans.month_lag))                        1
# PERCENTILE(STD(temp_hist_trans.purchase_amount))                0.5
# PERCENTILE(STD(temp_hist_trans.purchased_on_wee...              0.5
# PERCENTILE(STD(temp_hist_trans.month_diff))                     0.5
# PERCENTILE(STD(temp_hist_trans.purchase_date_su...              0.5
# PERCENTILE(STD(temp_hist_trans.duration))                       0.5
# PERCENTILE(STD(temp_hist_trans.amount_month_rat...              0.5
# PERCENTILE(MAX(temp_hist_trans.installments))                  0.75
# PERCENTILE(MAX(temp_hist_trans.month_lag))                     0.75
# PERCENTILE(MAX(temp_hist_trans.purchase_amount))                0.5
# PERCENTILE(MAX(temp_hist_trans.purchased_on_wee...             0.75
# PERCENTILE(MAX(temp_hist_trans.month_diff))                     0.5
# PERCENTILE(MAX(temp_hist_trans.purchase_date_su...              0.5
# PERCENTILE(MAX(temp_hist_trans.duration))                       0.5
# PERCENTILE(MAX(temp_hist_trans.amount_month_rat...                1
# PERCENTILE(SKEW(temp_hist_trans.installments))                    1
# PERCENTILE(SKEW(temp_hist_trans.month_lag))                       1
# PERCENTILE(SKEW(temp_hist_trans.purchase_amount))                 1
# PERCENTILE(SKEW(temp_hist_trans.purchased_on_we...              0.5
# PERCENTILE(SKEW(temp_hist_trans.month_diff))                      1
# PERCENTILE(SKEW(temp_hist_trans.purchase_date_s...              0.5
# PERCENTILE(SKEW(temp_hist_trans.duration))                        1
# PERCENTILE(SKEW(temp_hist_trans.amount_month_ra...                1
# PERCENTILE(MIN(temp_hist_trans.installments))                  0.75
# PERCENTILE(MIN(temp_hist_trans.month_lag))                      0.5
# PERCENTILE(MIN(temp_hist_trans.purchase_amount))                  1
# PERCENTILE(MIN(temp_hist_trans.purchased_on_wee...             0.75
# PERCENTILE(MIN(temp_hist_trans.month_diff))                     0.5
# PERCENTILE(MIN(temp_hist_trans.purchase_date_su...             0.75
# PERCENTILE(MIN(temp_hist_trans.duration))                         1
# PERCENTILE(MIN(temp_hist_trans.amount_month_rat...              0.5
# PERCENTILE(MEAN(temp_hist_trans.installments))                  0.5
# PERCENTILE(MEAN(temp_hist_trans.month_lag))                     0.5
# PERCENTILE(MEAN(temp_hist_trans.purchase_amount))               0.5
# PERCENTILE(MEAN(temp_hist_trans.purchased_on_we...                1
# PERCENTILE(MEAN(temp_hist_trans.month_diff))                    0.5
# PERCENTILE(MEAN(temp_hist_trans.purchase_date_s...              0.5
# PERCENTILE(MEAN(temp_hist_trans.duration))                        1
# PERCENTILE(MEAN(temp_hist_trans.amount_month_ra...              0.5
# PERCENTILE(COUNT(temp_hist_trans))                                1
# PERCENTILE(MEDIAN(temp_hist_trans.installments))               0.75
# PERCENTILE(MEDIAN(temp_hist_trans.month_lag))                   0.5
# PERCENTILE(MEDIAN(temp_hist_trans.purchase_amou...                1
# PERCENTILE(MEDIAN(temp_hist_trans.purchased_on_...             0.75
# PERCENTILE(MEDIAN(temp_hist_trans.month_diff))                  0.5
# PERCENTILE(MEDIAN(temp_hist_trans.purchase_date...                1
# PERCENTILE(MEDIAN(temp_hist_trans.duration))                      1
# PERCENTILE(MEDIAN(temp_hist_trans.amount_month_...              0.5
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.authorize...             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.city_id))                   1
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.category_1))             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.category_3))             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.merchant_...                1
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.merchant_...                1
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.category_2))             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.state_id))                  1
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.subsector...                1
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.purchased...             0.75
# PERCENTILE(AVG_TIME_BETWEEN(temp_hist_trans.pur...              0.5
# PERCENTILE(TIME_SINCE_LAST(temp_hist_trans.purc...              0.5
# PERCENTILE(TREND(temp_hist_trans.month_diff, pu...                1
# PERCENTILE(TREND(temp_hist_trans.installments, ...              0.5
# PERCENTILE(TREND(temp_hist_trans.amount_month_r...                1
# PERCENTILE(TREND(temp_hist_trans.purchase_amoun...                1
# PERCENTILE(TREND(temp_hist_trans.purchase_date_...              0.5
# PERCENTILE(TREND(temp_hist_trans.duration, purc...                1
# PERCENTILE(TREND(temp_hist_trans.month_lag, pur...                1
# PERCENTILE(TREND(temp_hist_trans.purchased_on_w...              0.5
# PERCENTILE(SUM(temp_new_trans.installments))                   0.75
# PERCENTILE(SUM(temp_new_trans.month_lag))                         1
# PERCENTILE(SUM(temp_new_trans.purchase_amount))                 0.5
# PERCENTILE(SUM(temp_new_trans.purchased_on_week...                1
# PERCENTILE(SUM(temp_new_trans.month_diff))                      0.5
# PERCENTILE(SUM(temp_new_trans.purchase_date_suc...                1
# PERCENTILE(SUM(temp_new_trans.duration))                        0.5
# PERCENTILE(SUM(temp_new_trans.amount_month_ratio))              0.5
# PERCENTILE(STD(temp_new_trans.installments))                   0.75
# PERCENTILE(STD(temp_new_trans.month_lag))                         1
# PERCENTILE(STD(temp_new_trans.purchase_amount))                 0.5
# PERCENTILE(STD(temp_new_trans.purchased_on_week...              0.5
# PERCENTILE(STD(temp_new_trans.month_diff))                        1
# PERCENTILE(STD(temp_new_trans.purchase_date_suc...              0.5
# PERCENTILE(STD(temp_new_trans.duration))                        0.5
# PERCENTILE(STD(temp_new_trans.amount_month_ratio))              0.5
# PERCENTILE(MAX(temp_new_trans.installments))                   0.75
# PERCENTILE(MAX(temp_new_trans.month_lag))                      0.75
# PERCENTILE(MAX(temp_new_trans.purchase_amount))                 0.5
# PERCENTILE(MAX(temp_new_trans.purchased_on_week...             0.75
# PERCENTILE(MAX(temp_new_trans.month_diff))                      0.5
# PERCENTILE(MAX(temp_new_trans.purchase_date_suc...                1
# PERCENTILE(MAX(temp_new_trans.duration))                        0.5
# PERCENTILE(MAX(temp_new_trans.amount_month_ratio))              0.5
# PERCENTILE(SKEW(temp_new_trans.installments))                  0.75
# PERCENTILE(SKEW(temp_new_trans.month_lag))                      0.5
# PERCENTILE(SKEW(temp_new_trans.purchase_amount))                0.5
# PERCENTILE(SKEW(temp_new_trans.purchased_on_wee...              0.5
# PERCENTILE(SKEW(temp_new_trans.month_diff))                     0.5
# PERCENTILE(SKEW(temp_new_trans.purchase_date_su...                1
# PERCENTILE(SKEW(temp_new_trans.duration))                       0.5
# PERCENTILE(SKEW(temp_new_trans.amount_month_rat...              0.5
# PERCENTILE(MIN(temp_new_trans.installments))                   0.75
# PERCENTILE(MIN(temp_new_trans.month_lag))                      0.75
# PERCENTILE(MIN(temp_new_trans.purchase_amount))                   1
# PERCENTILE(MIN(temp_new_trans.purchased_on_week...             0.75
# PERCENTILE(MIN(temp_new_trans.month_diff))                      0.5
# PERCENTILE(MIN(temp_new_trans.purchase_date_suc...             0.75
# PERCENTILE(MIN(temp_new_trans.duration))                          1
# PERCENTILE(MIN(temp_new_trans.amount_month_ratio))              0.5
# PERCENTILE(MEAN(temp_new_trans.installments))                  0.75
# PERCENTILE(MEAN(temp_new_trans.month_lag))                        1
# PERCENTILE(MEAN(temp_new_trans.purchase_amount))                0.5
# PERCENTILE(MEAN(temp_new_trans.purchased_on_wee...                1
# PERCENTILE(MEAN(temp_new_trans.month_diff))                     0.5
# PERCENTILE(MEAN(temp_new_trans.purchase_date_su...                1
# PERCENTILE(MEAN(temp_new_trans.duration))                       0.5
# PERCENTILE(MEAN(temp_new_trans.amount_month_rat...              0.5
# PERCENTILE(COUNT(temp_new_trans))                               0.5
# PERCENTILE(MEDIAN(temp_new_trans.installments))                0.75
# PERCENTILE(MEDIAN(temp_new_trans.month_lag))                   0.75
# PERCENTILE(MEDIAN(temp_new_trans.purchase_amount))                1
# PERCENTILE(MEDIAN(temp_new_trans.purchased_on_w...                1
# PERCENTILE(MEDIAN(temp_new_trans.month_diff))                   0.5
# PERCENTILE(MEDIAN(temp_new_trans.purchase_date_...                1
# PERCENTILE(MEDIAN(temp_new_trans.duration))                       1
# PERCENTILE(MEDIAN(temp_new_trans.amount_month_r...              0.5
# PERCENTILE(NUM_UNIQUE(temp_new_trans.authorized...             0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.city_id))                  0.5
# PERCENTILE(NUM_UNIQUE(temp_new_trans.category_1))              0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.category_3))              0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.merchant_c...             0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.merchant_id))              0.5
# PERCENTILE(NUM_UNIQUE(temp_new_trans.category_2))               0.5
# PERCENTILE(NUM_UNIQUE(temp_new_trans.state_id))                 0.5
# PERCENTILE(NUM_UNIQUE(temp_new_trans.subsector_...              0.5
# PERCENTILE(NUM_UNIQUE(temp_new_trans.purchased_...             0.75
# PERCENTILE(AVG_TIME_BETWEEN(temp_new_trans.purc...                1
# PERCENTILE(TIME_SINCE_LAST(temp_new_trans.purch...              0.5
# PERCENTILE(TREND(temp_new_trans.installments, p...             0.75
# PERCENTILE(TREND(temp_new_trans.amount_month_ra...                1
# PERCENTILE(TREND(temp_new_trans.purchase_amount...                1
# PERCENTILE(TREND(temp_new_trans.purchase_date_s...              0.5
# PERCENTILE(TREND(temp_new_trans.duration, purch...                1
# PERCENTILE(TREND(temp_new_trans.purchased_on_we...              0.5
# PERCENTILE(TREND(temp_new_trans.month_diff, pur...              0.5
# PERCENTILE(TREND(temp_new_trans.month_lag, purc...              0.5
# PERCENTILE(DAYS_SINCE(first_active_month))                     0.75
#
# card_id                                             C_ID_ae86f7d5fb
# target                                                    -0.563362
# feature_1                                                         5
# feature_2                                                         2
# feature_3                                                         1
# SUM(temp_hist_trans.installments)                                 4
# SUM(temp_hist_trans.month_lag)                                 -308
# SUM(temp_hist_trans.purchase_amount)                       -74.8775
# SUM(temp_hist_trans.purchased_on_weekday)                        84
# SUM(temp_hist_trans.month_diff)                                1933
# SUM(temp_hist_trans.purchase_date_successive_diff)      1.45427e+07
# SUM(temp_hist_trans.duration)                              -1085.41
# SUM(temp_hist_trans.amount_month_ratio)                    -5.17162
# STD(temp_hist_trans.installments)                           0.17144
# STD(temp_hist_trans.month_lag)                              1.40005
# STD(temp_hist_trans.purchase_amount)                       0.415112
# STD(temp_hist_trans.purchased_on_weekday)                    0.4842
# STD(temp_hist_trans.month_diff)                             0.50074
# STD(temp_hist_trans.purchase_date_successive_diff)           246098
# STD(temp_hist_trans.duration)                               6.13736
# STD(temp_hist_trans.amount_month_ratio)                   0.0281872
# MAX(temp_hist_trans.installments)                                 1
# MAX(temp_hist_trans.month_lag)                                    0
# MAX(temp_hist_trans.purchase_amount)                         2.2716
# MAX(temp_hist_trans.purchased_on_weekday)                         1
# MAX(temp_hist_trans.month_diff)                                  15
# MAX(temp_hist_trans.purchase_date_successive_diff)      1.73702e+06
# MAX(temp_hist_trans.duration)                                34.074
# MAX(temp_hist_trans.amount_month_ratio)                     0.15144
# SKEW(temp_hist_trans.installments)                          5.56579
# SKEW(temp_hist_trans.month_lag)                           -0.158893
# SKEW(temp_hist_trans.purchase_amount)                       5.23007
# SKEW(temp_hist_trans.purchased_on_weekday)                -0.551787
# SKEW(temp_hist_trans.month_diff)                          -0.137202
# SKEW(temp_hist_trans.purchase_date_successive_d...          4.40674
# SKEW(temp_hist_trans.duration)                              5.31526
# SKEW(temp_hist_trans.amount_month_ratio)                    5.09217
# MIN(temp_hist_trans.installments)                                 0
# MIN(temp_hist_trans.month_lag)                                   -5
# MIN(temp_hist_trans.purchase_amount)                      -0.740942
# MIN(temp_hist_trans.purchased_on_weekday)                         0
# MIN(temp_hist_trans.month_diff)                                  14
# MIN(temp_hist_trans.purchase_date_successive_diff)                0
# MIN(temp_hist_trans.duration)                              -11.0909
# MIN(temp_hist_trans.amount_month_ratio)                  -0.0529244
# MEAN(temp_hist_trans.installments)                        0.0300752
# MEAN(temp_hist_trans.month_lag)                            -2.31579
# MEAN(temp_hist_trans.purchase_amount)                     -0.562989
# MEAN(temp_hist_trans.purchased_on_weekday)                 0.631579
# MEAN(temp_hist_trans.month_diff)                            14.5338
# MEAN(temp_hist_trans.purchase_date_successive_d...           109344
# MEAN(temp_hist_trans.duration)                             -8.16095
# MEAN(temp_hist_trans.amount_month_ratio)                 -0.0388844
# COUNT(temp_hist_trans)                                          133
# MEDIAN(temp_hist_trans.installments)                              0
# MEDIAN(temp_hist_trans.month_lag)                                -2
# MEDIAN(temp_hist_trans.purchase_amount)                   -0.701828
# MEDIAN(temp_hist_trans.purchased_on_weekday)                      1
# MEDIAN(temp_hist_trans.month_diff)                               15
# MEDIAN(temp_hist_trans.purchase_date_successive...            29646
# MEDIAN(temp_hist_trans.duration)                           -9.95182
# MEDIAN(temp_hist_trans.amount_month_ratio)               -0.0469106
# NUM_UNIQUE(temp_hist_trans.authorized_flag)                       2
# NUM_UNIQUE(temp_hist_trans.city_id)                               3
# NUM_UNIQUE(temp_hist_trans.category_1)                            1
# NUM_UNIQUE(temp_hist_trans.category_3)                            2
# NUM_UNIQUE(temp_hist_trans.merchant_category_id)                 27
# NUM_UNIQUE(temp_hist_trans.merchant_id)                          74
# NUM_UNIQUE(temp_hist_trans.category_2)                            2
# NUM_UNIQUE(temp_hist_trans.state_id)                              2
# NUM_UNIQUE(temp_hist_trans.subsector_id)                         18
# NUM_UNIQUE(temp_hist_trans.purchased_on_weekend)                  2
# MODE(temp_hist_trans.authorized_flag)                             1
# MODE(temp_hist_trans.city_id)                                    87
# MODE(temp_hist_trans.category_1)                                  0
# ...
# MAX(temp_new_trans.PERCENTILE(purchase_date_suc...         0.978723
# MAX(temp_new_trans.PERCENTILE(duration))                          1
# MAX(temp_new_trans.PERCENTILE(amount_month_ratio))                1
# SKEW(temp_new_trans.DAYS_SINCE(purchase_date))            -0.217544
# SKEW(temp_new_trans.PERCENTILE(installments))                     0
# SKEW(temp_new_trans.PERCENTILE(month_lag))                 0.755148
# SKEW(temp_new_trans.PERCENTILE(purchase_amount))          0.0557786
# SKEW(temp_new_trans.PERCENTILE(purchased_on_wee...                0
# SKEW(temp_new_trans.PERCENTILE(month_diff))                 1.23315
# SKEW(temp_new_trans.PERCENTILE(purchase_date_su...         0.147175
# SKEW(temp_new_trans.PERCENTILE(duration))                  0.719544
# SKEW(temp_new_trans.PERCENTILE(amount_month_rat...        -0.153612
# MIN(temp_new_trans.DAYS_SINCE(purchase_date))                   374
# MIN(temp_new_trans.PERCENTILE(installments))               0.510638
# MIN(temp_new_trans.PERCENTILE(month_lag))                  0.308511
# MIN(temp_new_trans.PERCENTILE(purchase_amount))           0.0212766
# MIN(temp_new_trans.PERCENTILE(purchased_on_week...         0.202128
# MIN(temp_new_trans.PERCENTILE(month_diff))                 0.691489
# MIN(temp_new_trans.PERCENTILE(purchase_date_suc...        0.0319149
# MIN(temp_new_trans.PERCENTILE(duration))                  0.0212766
# MIN(temp_new_trans.PERCENTILE(amount_month_ratio))         0.255319
# MEAN(temp_new_trans.installments WHERE purchase...                0
# MEAN(temp_new_trans.month_lag WHERE purchased_o...          1.16667
# MEAN(temp_new_trans.purchase_amount WHERE purch...        -0.382904
# MEAN(temp_new_trans.purchased_on_weekday WHERE ...                0
# MEAN(temp_new_trans.month_diff WHERE purchased_...            14.25
# MEAN(temp_new_trans.purchase_date_successive_di...           154306
# MEAN(temp_new_trans.duration WHERE purchased_on...         -5.48752
# MEAN(temp_new_trans.amount_month_ratio WHERE pu...       -0.0267462
# MEAN(temp_new_trans.DAYS_SINCE(purchase_date))              404.292
# MEAN(temp_new_trans.DAYS_SINCE(purchase_date) W...           408.75
# MEAN(temp_new_trans.PERCENTILE(installments))              0.510638
# MEAN(temp_new_trans.PERCENTILE(installments) WH...         0.510638
# MEAN(temp_new_trans.PERCENTILE(month_lag))                 0.475177
# MEAN(temp_new_trans.PERCENTILE(month_lag) WHERE...         0.391844
# MEAN(temp_new_trans.PERCENTILE(purchase_amount))           0.515514
# MEAN(temp_new_trans.PERCENTILE(purchase_amount)...          0.45922
# MEAN(temp_new_trans.PERCENTILE(purchased_on_wee...         0.452128
# MEAN(temp_new_trans.PERCENTILE(purchased_on_wee...         0.202128
# MEAN(temp_new_trans.PERCENTILE(month_diff))                0.755319
# MEAN(temp_new_trans.PERCENTILE(month_diff) WHER...         0.755319
# MEAN(temp_new_trans.PERCENTILE(purchase_date_su...         0.485372
# MEAN(temp_new_trans.PERCENTILE(purchase_date_su...         0.408688
# MEAN(temp_new_trans.PERCENTILE(duration))                  0.399823
# MEAN(temp_new_trans.PERCENTILE(duration) WHERE ...         0.361702
# MEAN(temp_new_trans.PERCENTILE(amount_month_rat...         0.632979
# MEAN(temp_new_trans.PERCENTILE(amount_month_rat...          0.58156
# MEDIAN(temp_new_trans.DAYS_SINCE(purchase_date))                407
# MEDIAN(temp_new_trans.PERCENTILE(installments))            0.510638
# MEDIAN(temp_new_trans.PERCENTILE(month_lag))               0.308511
# MEDIAN(temp_new_trans.PERCENTILE(purchase_amount))         0.484043
# MEDIAN(temp_new_trans.PERCENTILE(purchased_on_w...         0.452128
# MEDIAN(temp_new_trans.PERCENTILE(month_diff))              0.691489
# MEDIAN(temp_new_trans.PERCENTILE(purchase_date_...         0.468085
# MEDIAN(temp_new_trans.PERCENTILE(duration))                0.287234
# MEDIAN(temp_new_trans.PERCENTILE(amount_month_r...         0.680851
# NUM_UNIQUE(temp_new_trans.DAY(purchase_date))                    17
# NUM_UNIQUE(temp_new_trans.MONTH(purchase_date))                   2
# NUM_UNIQUE(temp_new_trans.WEEKDAY(purchase_date))                 7
# NUM_UNIQUE(temp_new_trans.HOUR(purchase_date))                   13
# MODE(temp_new_trans.DAY(purchase_date))                          24
# MODE(temp_new_trans.MONTH(purchase_date))                        12
# MODE(temp_new_trans.WEEKDAY(purchase_date))                       5
# MODE(temp_new_trans.HOUR(purchase_date))                         11
# TREND(temp_new_trans.PERCENTILE(purchased_on_we...      6.36819e-08
# TREND(temp_new_trans.PERCENTILE(duration), purc...      5.40778e-09
# TREND(temp_new_trans.PERCENTILE(month_diff), pu...     -1.98171e-08
# TREND(temp_new_trans.PERCENTILE(amount_month_ra...       2.4331e-08
# TREND(temp_new_trans.PERCENTILE(installments), ...                0
# TREND(temp_new_trans.DAYS_SINCE(purchase_date),...     -1.15842e-05
# TREND(temp_new_trans.PERCENTILE(purchase_amount...      1.73688e-08
# TREND(temp_new_trans.PERCENTILE(month_lag), pur...      1.63584e-07
# TREND(temp_new_trans.PERCENTILE(purchase_date_s...      8.74523e-08
# PERCENTILE(SUM(temp_hist_trans.installments))                  0.75
# PERCENTILE(SUM(temp_hist_trans.month_lag))                        1
# PERCENTILE(SUM(temp_hist_trans.purchase_amount))                  1
# PERCENTILE(SUM(temp_hist_trans.purchased_on_wee...              0.5
# PERCENTILE(SUM(temp_hist_trans.month_diff))                     0.5
# PERCENTILE(SUM(temp_hist_trans.purchase_date_su...              0.5
# PERCENTILE(SUM(temp_hist_trans.duration))                         1
# PERCENTILE(SUM(temp_hist_trans.amount_month_rat...                1
# PERCENTILE(STD(temp_hist_trans.installments))                     1
# PERCENTILE(STD(temp_hist_trans.month_lag))                      0.5
# PERCENTILE(STD(temp_hist_trans.purchase_amount))                  1
# PERCENTILE(STD(temp_hist_trans.purchased_on_wee...                1
# PERCENTILE(STD(temp_hist_trans.month_diff))                       1
# PERCENTILE(STD(temp_hist_trans.purchase_date_su...                1
# PERCENTILE(STD(temp_hist_trans.duration))                         1
# PERCENTILE(STD(temp_hist_trans.amount_month_rat...                1
# PERCENTILE(MAX(temp_hist_trans.installments))                  0.75
# PERCENTILE(MAX(temp_hist_trans.month_lag))                     0.75
# PERCENTILE(MAX(temp_hist_trans.purchase_amount))                  1
# PERCENTILE(MAX(temp_hist_trans.purchased_on_wee...             0.75
# PERCENTILE(MAX(temp_hist_trans.month_diff))                       1
# PERCENTILE(MAX(temp_hist_trans.purchase_date_su...                1
# PERCENTILE(MAX(temp_hist_trans.duration))                         1
# PERCENTILE(MAX(temp_hist_trans.amount_month_rat...              0.5
# PERCENTILE(SKEW(temp_hist_trans.installments))                  0.5
# PERCENTILE(SKEW(temp_hist_trans.month_lag))                     0.5
# PERCENTILE(SKEW(temp_hist_trans.purchase_amount))               0.5
# PERCENTILE(SKEW(temp_hist_trans.purchased_on_we...                1
# PERCENTILE(SKEW(temp_hist_trans.month_diff))                    0.5
# PERCENTILE(SKEW(temp_hist_trans.purchase_date_s...                1
# PERCENTILE(SKEW(temp_hist_trans.duration))                      0.5
# PERCENTILE(SKEW(temp_hist_trans.amount_month_ra...              0.5
# PERCENTILE(MIN(temp_hist_trans.installments))                  0.75
# PERCENTILE(MIN(temp_hist_trans.month_lag))                        1
# PERCENTILE(MIN(temp_hist_trans.purchase_amount))                0.5
# PERCENTILE(MIN(temp_hist_trans.purchased_on_wee...             0.75
# PERCENTILE(MIN(temp_hist_trans.month_diff))                       1
# PERCENTILE(MIN(temp_hist_trans.purchase_date_su...             0.75
# PERCENTILE(MIN(temp_hist_trans.duration))                       0.5
# PERCENTILE(MIN(temp_hist_trans.amount_month_rat...                1
# PERCENTILE(MEAN(temp_hist_trans.installments))                    1
# PERCENTILE(MEAN(temp_hist_trans.month_lag))                       1
# PERCENTILE(MEAN(temp_hist_trans.purchase_amount))                 1
# PERCENTILE(MEAN(temp_hist_trans.purchased_on_we...              0.5
# PERCENTILE(MEAN(temp_hist_trans.month_diff))                      1
# PERCENTILE(MEAN(temp_hist_trans.purchase_date_s...                1
# PERCENTILE(MEAN(temp_hist_trans.duration))                      0.5
# PERCENTILE(MEAN(temp_hist_trans.amount_month_ra...                1
# PERCENTILE(COUNT(temp_hist_trans))                              0.5
# PERCENTILE(MEDIAN(temp_hist_trans.installments))               0.75
# PERCENTILE(MEDIAN(temp_hist_trans.month_lag))                     1
# PERCENTILE(MEDIAN(temp_hist_trans.purchase_amou...              0.5
# PERCENTILE(MEDIAN(temp_hist_trans.purchased_on_...             0.75
# PERCENTILE(MEDIAN(temp_hist_trans.month_diff))                    1
# PERCENTILE(MEDIAN(temp_hist_trans.purchase_date...              0.5
# PERCENTILE(MEDIAN(temp_hist_trans.duration))                    0.5
# PERCENTILE(MEDIAN(temp_hist_trans.amount_month_...                1
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.authorize...             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.city_id))                 0.5
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.category_1))             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.category_3))             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.merchant_...              0.5
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.merchant_...              0.5
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.category_2))             0.75
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.state_id))                0.5
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.subsector...              0.5
# PERCENTILE(NUM_UNIQUE(temp_hist_trans.purchased...             0.75
# PERCENTILE(AVG_TIME_BETWEEN(temp_hist_trans.pur...                1
# PERCENTILE(TIME_SINCE_LAST(temp_hist_trans.purc...                1
# PERCENTILE(TREND(temp_hist_trans.month_diff, pu...              0.5
# PERCENTILE(TREND(temp_hist_trans.installments, ...                1
# PERCENTILE(TREND(temp_hist_trans.amount_month_r...              0.5
# PERCENTILE(TREND(temp_hist_trans.purchase_amoun...              0.5
# PERCENTILE(TREND(temp_hist_trans.purchase_date_...                1
# PERCENTILE(TREND(temp_hist_trans.duration, purc...              0.5
# PERCENTILE(TREND(temp_hist_trans.month_lag, pur...              0.5
# PERCENTILE(TREND(temp_hist_trans.purchased_on_w...                1
# PERCENTILE(SUM(temp_new_trans.installments))                   0.75
# PERCENTILE(SUM(temp_new_trans.month_lag))                       0.5
# PERCENTILE(SUM(temp_new_trans.purchase_amount))                   1
# PERCENTILE(SUM(temp_new_trans.purchased_on_week...              0.5
# PERCENTILE(SUM(temp_new_trans.month_diff))                        1
# PERCENTILE(SUM(temp_new_trans.purchase_date_suc...              0.5
# PERCENTILE(SUM(temp_new_trans.duration))                          1
# PERCENTILE(SUM(temp_new_trans.amount_month_ratio))                1
# PERCENTILE(STD(temp_new_trans.installments))                   0.75
# PERCENTILE(STD(temp_new_trans.month_lag))                       0.5
# PERCENTILE(STD(temp_new_trans.purchase_amount))                   1
# PERCENTILE(STD(temp_new_trans.purchased_on_week...                1
# PERCENTILE(STD(temp_new_trans.month_diff))                      0.5
# PERCENTILE(STD(temp_new_trans.purchase_date_suc...                1
# PERCENTILE(STD(temp_new_trans.duration))                          1
# PERCENTILE(STD(temp_new_trans.amount_month_ratio))                1
# PERCENTILE(MAX(temp_new_trans.installments))                   0.75
# PERCENTILE(MAX(temp_new_trans.month_lag))                      0.75
# PERCENTILE(MAX(temp_new_trans.purchase_amount))                   1
# PERCENTILE(MAX(temp_new_trans.purchased_on_week...             0.75
# PERCENTILE(MAX(temp_new_trans.month_diff))                        1
# PERCENTILE(MAX(temp_new_trans.purchase_date_suc...              0.5
# PERCENTILE(MAX(temp_new_trans.duration))                          1
# PERCENTILE(MAX(temp_new_trans.amount_month_ratio))                1
# PERCENTILE(SKEW(temp_new_trans.installments))                  0.75
# PERCENTILE(SKEW(temp_new_trans.month_lag))                        1
# PERCENTILE(SKEW(temp_new_trans.purchase_amount))                  1
# PERCENTILE(SKEW(temp_new_trans.purchased_on_wee...                1
# PERCENTILE(SKEW(temp_new_trans.month_diff))                       1
# PERCENTILE(SKEW(temp_new_trans.purchase_date_su...              0.5
# PERCENTILE(SKEW(temp_new_trans.duration))                         1
# PERCENTILE(SKEW(temp_new_trans.amount_month_rat...                1
# PERCENTILE(MIN(temp_new_trans.installments))                   0.75
# PERCENTILE(MIN(temp_new_trans.month_lag))                      0.75
# PERCENTILE(MIN(temp_new_trans.purchase_amount))                 0.5
# PERCENTILE(MIN(temp_new_trans.purchased_on_week...             0.75
# PERCENTILE(MIN(temp_new_trans.month_diff))                        1
# PERCENTILE(MIN(temp_new_trans.purchase_date_suc...             0.75
# PERCENTILE(MIN(temp_new_trans.duration))                        0.5
# PERCENTILE(MIN(temp_new_trans.amount_month_ratio))                1
# PERCENTILE(MEAN(temp_new_trans.installments))                  0.75
# PERCENTILE(MEAN(temp_new_trans.month_lag))                      0.5
# PERCENTILE(MEAN(temp_new_trans.purchase_amount))                  1
# PERCENTILE(MEAN(temp_new_trans.purchased_on_wee...              0.5
# PERCENTILE(MEAN(temp_new_trans.month_diff))                       1
# PERCENTILE(MEAN(temp_new_trans.purchase_date_su...              0.5
# PERCENTILE(MEAN(temp_new_trans.duration))                         1
# PERCENTILE(MEAN(temp_new_trans.amount_month_rat...                1
# PERCENTILE(COUNT(temp_new_trans))                                 1
# PERCENTILE(MEDIAN(temp_new_trans.installments))                0.75
# PERCENTILE(MEDIAN(temp_new_trans.month_lag))                   0.75
# PERCENTILE(MEDIAN(temp_new_trans.purchase_amount))              0.5
# PERCENTILE(MEDIAN(temp_new_trans.purchased_on_w...              0.5
# PERCENTILE(MEDIAN(temp_new_trans.month_diff))                     1
# PERCENTILE(MEDIAN(temp_new_trans.purchase_date_...              0.5
# PERCENTILE(MEDIAN(temp_new_trans.duration))                     0.5
# PERCENTILE(MEDIAN(temp_new_trans.amount_month_r...                1
# PERCENTILE(NUM_UNIQUE(temp_new_trans.authorized...             0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.city_id))                    1
# PERCENTILE(NUM_UNIQUE(temp_new_trans.category_1))              0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.category_3))              0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.merchant_c...             0.75
# PERCENTILE(NUM_UNIQUE(temp_new_trans.merchant_id))                1
# PERCENTILE(NUM_UNIQUE(temp_new_trans.category_2))                 1
# PERCENTILE(NUM_UNIQUE(temp_new_trans.state_id))                   1
# PERCENTILE(NUM_UNIQUE(temp_new_trans.subsector_...                1
# PERCENTILE(NUM_UNIQUE(temp_new_trans.purchased_...             0.75
# PERCENTILE(AVG_TIME_BETWEEN(temp_new_trans.purc...              0.5
# PERCENTILE(TIME_SINCE_LAST(temp_new_trans.purch...                1
# PERCENTILE(TREND(temp_new_trans.installments, p...             0.75
# PERCENTILE(TREND(temp_new_trans.amount_month_ra...              0.5
# PERCENTILE(TREND(temp_new_trans.purchase_amount...              0.5
# PERCENTILE(TREND(temp_new_trans.purchase_date_s...                1
# PERCENTILE(TREND(temp_new_trans.duration, purch...              0.5
# PERCENTILE(TREND(temp_new_trans.purchased_on_we...                1
# PERCENTILE(TREND(temp_new_trans.month_diff, pur...                1
# PERCENTILE(TREND(temp_new_trans.month_lag, purc...                1
# PERCENTILE(DAYS_SINCE(first_active_month))                     0.75

# %%
feature_matrix.target
# Out:
# card_id
# C_ID_92a2005557   -0.820283
# C_ID_ae86f7d5fb   -0.563362
# Name: target, dtype: float64

# %%
def additional_feats2(hist_df):
    hist_df['price'] = hist_df['purchase_amount'] / hist_df['installments']
    #Christmas : December 25 2017
    hist_df['Christmas_Day_2017']=(pd.to_datetime('2017-12-25')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Mothers Day: May 14 2017
    hist_df['Mothers_Day_2017']=(pd.to_datetime('2017-06-04')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #fathers day: August 13 2017
    hist_df['fathers_day_2017']=(pd.to_datetime('2017-08-13')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Childrens day: October 12 2017
    hist_df['Children_day_2017']=(pd.to_datetime('2017-10-12')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Valentine's Day : 12th June, 2017
    hist_df['Valentine_Day_2017']=(pd.to_datetime('2017-06-12')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Black Friday : 24th November 2017
    hist_df['Black_Friday_2017']=(pd.to_datetime('2017-11-24') - hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #2018
    #Mothers Day: May 13 2018
    hist_df['Mothers_Day_2018']=(pd.to_datetime('2018-05-13')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    return hist_df

# %%
temp_hist_trans.head()
# Out:
#       index  authorized_flag          card_id  city_id  category_1  \
# 9935      0                1  C_ID_2223b33279      344           0
# 9936      1                1  C_ID_2223b33279      344           0
# 9937      2                1  C_ID_2223b33279      101           0
# 9938      3                1  C_ID_2223b33279      107           0
# 9939      4                1  C_ID_2223b33279      344           0
#
#       installments  category_3  merchant_category_id      merchant_id  \
# 9935           0.0           0                   415  M_ID_d5b5d05087
# 9936           0.0           0                   574  M_ID_59ddc41791
# 9937           0.0           0                   307  M_ID_54718748ed
# 9938           0.0           0                   307  M_ID_5b87a162da
# 9939           0.0           0                   574  M_ID_59ddc41791
#
#       month_lag  purchase_amount       purchase_date  category_2  state_id  \
# 9935        -10        -0.716855 2017-01-28 19:45:48         2.0        18
# 9936         -8        -0.731881 2017-03-16 16:42:42         2.0        18
# 9937         -4        -0.626696 2017-07-18 10:06:57         4.0         4
# 9938         -4        -0.596643 2017-07-26 19:16:39         4.0         4
# 9939         -2        -0.496416 2017-09-19 16:39:37         2.0        18
#
#       subsector_id  purchased_on_weekend  purchased_on_weekday  month_diff  \
# 9935            18                     1                     0          14
# 9936            22                     0                     1          14
# 9937            19                     0                     1          14
# 9938            19                     0                     1          14
# 9939            22                     0                     1          14
#
#       purchase_date_successive_diff   duration  amount_month_ratio
# 9935                        17478.0 -10.035967           -0.051204
# 9936                        87040.0 -10.246338           -0.052277
# 9937                         1470.0  -8.773740           -0.044764
# 9938                         2686.0  -8.352998           -0.042617
# 9939                       247222.0  -6.949822           -0.035458

# %%
hist_trans2, new_hist_trans2 = [additional_feats2(df) for df in [temp_hist_trans, temp_new_trans]]

# %%
dfs2 = [hist_trans2, new_hist_trans2]

# %%
def aggregate_by_card_id(df):
    aggs = {}
    aggs['Christmas_Day_2017'] = ['mean']
    aggs['Mothers_Day_2017'] = ['mean']
    aggs['fathers_day_2017'] = ['mean']
    aggs['Children_day_2017'] = ['mean']
    aggs['Valentine_Day_2017'] = ['mean']
    aggs['Black_Friday_2017'] = ['mean']
    aggs['Mothers_Day_2018'] = ['mean']
    aggs['price'] = ['sum','mean','max','min','var', 'skew']
    aggs['purchase_date'] = ['max','min']
    aggs['card_id'] = ['size']
    aggs['category_1'] = ['sum', 'mean']
    aggs['category_2'] = ['mean']
    aggs['category_3'] = ['mean']
    new_df = df.groupby(['card_id']).agg(aggs)
    new_df.columns = ['_'.join(col).strip() for col in new_df.columns.values]
    new_df.reset_index(inplace=True)
    for col in ['category_2','category_3', 'subsector_id', 'state_id']:
        df[col+'_mean'] = df.groupby([col])['purchase_amount'].transform('mean')
        df[col+'_min'] = df.groupby([col])['purchase_amount'].transform('min')
        df[col+'_max'] = df.groupby([col])['purchase_amount'].transform('max')
        df[col+'_sum'] = df.groupby([col])['purchase_amount'].transform('sum')
        aggs[col+'_mean'] = ['mean']

    other_df = (df.groupby('card_id')
          .size()
          .reset_index(name='transactions_count'))
    
    new_df = pd.merge(other_df, new_df, on='card_id', how='left')

    new_df['purchase_date_diff'] = (new_df['purchase_date_max'] - new_df['purchase_date_min']).dt.days
    new_df['purchase_date_average'] = new_df['purchase_date_diff']/new_df['card_id_size']
    new_df['purchase_date_uptonow'] = (datetime.datetime.today() - new_df['purchase_date_max']).dt.days
    new_df['purchase_date_uptomin'] = (datetime.datetime.today() - new_df['purchase_date_min']).dt.days
    new_df['inverse_avg_transactions_per_day'] = new_df['purchase_date_diff']/new_df['card_id_size']
    new_df['days_since_last_transaction'] = (datetime.datetime.today() - new_df['purchase_date_max']).dt.days
    return new_df

# %%
gc.collect()
# Out:
# 14

# %%
# %time hist_trans_agg, new_hist_trans_agg = [aggregate_by_card_id(df) for df in dfs2]
# Out:
# CPU times: user 72.9 ms, sys: 0 ns, total: 72.9 ms
# Wall time: 73.2 ms

# %%
hist_trans_agg.shape, new_hist_trans_agg.shape
# Out:
# ((3, 28), (3, 28))

# %%
feature_matrix.shape
# Out:
# (2, 601)

# %%
new_hist_trans_agg
# Out:
#            card_id  transactions_count  Christmas_Day_2017_mean  \
# 0  C_ID_2223b33279                  21                12.761905
# 1  C_ID_92a2005557                  23                 0.000000
# 2  C_ID_ae86f7d5fb                  24                 4.250000
#
#    Mothers_Day_2017_mean  fathers_day_2017_mean  Children_day_2017_mean  \
# 0                      0                      0                       0
# 1                      0                      0                       0
# 2                      0                      0                       0
#
#    Valentine_Day_2017_mean  Black_Friday_2017_mean  Mothers_Day_2018_mean  \
# 0                        0                       0                0.00000
# 1                        0                       0               41.73913
# 2                        0                       0                0.00000
#
#    price_sum  price_mean  price_max  price_min  price_var  price_skew  \
# 0       -inf        -inf       -inf       -inf        NaN         NaN
# 1       -inf        -inf       -inf       -inf        NaN         NaN
# 2        NaN         NaN        inf       -inf        NaN         NaN
#
#     purchase_date_max   purchase_date_min  card_id_size  category_1_sum  \
# 0 2018-01-25 12:23:25 2017-12-01 12:03:54            21               0
# 1 2018-04-29 11:23:05 2018-03-05 14:04:36            23               0
# 2 2018-01-26 10:02:57 2017-12-02 16:32:02            24               0
#
#    category_1_mean  category_2_mean  category_3_mean  purchase_date_diff  \
# 0                0         1.809524                0                  55
# 1                0         1.000000                0                  54
# 2                0         2.833333                0                  54
#
#    purchase_date_average  purchase_date_uptonow  purchase_date_uptomin  \
# 0               2.619048                    377                    432
# 1               2.347826                    283                    338
# 2               2.250000                    376                    431
#
#    inverse_avg_transactions_per_day  days_since_last_transaction
# 0                          2.619048                          377
# 1                          2.347826                          283
# 2                          2.250000                          376

# %%
def add_extra_cols_on_agg(df):
    df['repurchase_merchant_rate_hist'] = df['COUNT(temp_hist_trans)']/df['NUM_UNIQUE(temp_hist_trans.merchant_id)']
    df['repurchase_merchant_rate_new'] = df['COUNT(temp_new_trans)']/df['NUM_UNIQUE(temp_new_trans.merchant_id)']

    df['merchant_category_repurchase_new'] = df['NUM_UNIQUE(temp_new_trans.merchant_category_id)']/df['NUM_UNIQUE(temp_new_trans.merchant_id)']
    df['merchant_category_repurchase_hist'] = df['NUM_UNIQUE(temp_hist_trans.merchant_category_id)']/df['NUM_UNIQUE(temp_hist_trans.merchant_id)']

    df['avg_spend_per_merchant_hist'] = df['SUM(temp_hist_trans.purchase_amount)']/df['NUM_UNIQUE(temp_hist_trans.merchant_id)']
    df['avg_spend_per_merchant_new'] = df['SUM(temp_new_trans.purchase_amount)']/df['NUM_UNIQUE(temp_new_trans.merchant_id)']

    df['avg_trans_per_merchant_new'] = df['COUNT(temp_new_trans)']/df['NUM_UNIQUE(temp_new_trans.merchant_id)']
    df['avg_trans_per_merchant_hist'] = df['COUNT(temp_hist_trans)']/df['NUM_UNIQUE(temp_hist_trans.merchant_id)']

    df['avg_spend_per_transaction_hist'] = df['SUM(temp_hist_trans.purchase_amount)']/df['COUNT(temp_hist_trans)']
    df['avg_spend_per_transaction_new'] = df['SUM(temp_new_trans.purchase_amount)']/df['COUNT(temp_new_trans)']
    return df

# %%
df_fm = add_extra_cols_on_agg(feature_matrix)

# %%
df_fm.shape
# Out:
# (2, 611)

# %% [markdown]
# ### Interactions in test&train dfs

# %%
l_es = ft.EntitySet()

# %%
 test['feature_3'] = test['feature_3'].map({0:1, 1:2})

# %%
test.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3
# 0            2017-04  C_ID_0ab67a22ab          3          3          2
# 1            2017-01  C_ID_130fd0cbdd          2          3          1
# 2            2017-08  C_ID_b709037bc5          5          1          2
# 3            2017-12  C_ID_d27d835a9f          2          1          1
# 4            2015-12  C_ID_2b5e3df5c2          5          1          2

# %%
# lala_cols = {}
# lala_cols['feature_3'] = ft.variable_types.variable.Boolean

# %%
# lala_cols
# Out:
# {'feature_3': featuretools.variable_types.variable.Boolean}

# %%
lala_es = l_es.entity_from_dataframe('train', temp_train, 'card_id', time_index='first_active_month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-badd42e630bd> in <module>
# ----> 1 lala_es = l_es.entity_from_dataframe('train', temp_train, 'card_id', time_index='first_active_month')
#
# NameError: name 'temp_train' is not defined

# %%
test.shape
# Out:
# (123623, 5)

# %%
lala_es = l_es.entity_from_dataframe('test', test, 'card_id', time_index='first_active_month')

# %%
lala_es['test']
# Out:
# Entity: test
#   Variables:
#     card_id (dtype: index)
#     first_active_month (dtype: datetime_time_index)
#     feature_1 (dtype: numeric)
#     feature_2 (dtype: numeric)
#     feature_3 (dtype: numeric)
#   Shape:
#     (Rows: 123623, Columns: 5)

# %%
# lala_es['test']['feature_3'].interesting_values = [1]

# %%
lala_feature_matrix, lala_feature_names = ft.dfs(entityset = lala_es, target_entity = 'test',
                                       trans_primitives = default_trans_primitives,
                                       agg_primitives=default_agg_primitives,
                                       where_primitives = ['mean', 'sum'],
                                        max_depth = 3, features_only=False, verbose = True)
# Out:
# Built 1426 features
# Elapsed: 00:18 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 11/11 chunks

# %%
DataFrameSummary(test).summary()
# Out:
#              first_active_month card_id feature_1 feature_2 feature_3
# count                       NaN     NaN    123623    123623    123623
# mean                        NaN     NaN   3.10926    1.7418   1.56438
# std                         NaN     NaN   1.18911  0.749195   0.49584
# min                         NaN     NaN         1         1         1
# 25%                         NaN     NaN         2         1         1
# 50%                         NaN     NaN         3         2         2
# 75%                         NaN     NaN         4         2         2
# max                         NaN     NaN         5         3         2
# counts                   123622  123623    123623    123623    123623
# uniques                      75  123623         5         3         2
# missing                       1       0         0         0         0
# missing_perc              0.00%      0%        0%        0%        0%
# types                      date  unique   numeric   numeric      bool

# %%
lala_feature_matrix.head()
# Out:
#                  feature_1  feature_2  feature_3  \
# card_id
# C_ID_0001238066        4.0        1.0        1.0
# C_ID_0001793786        5.0        2.0        2.0
# C_ID_00024e244b        2.0        2.0        1.0
# C_ID_0002709b5a        5.0        1.0        2.0
# C_ID_000298032a        2.0        2.0        1.0
#
#                  DAYS_SINCE(first_active_month)  feature_1 + feature_3  \
# card_id
# C_ID_0001238066                           522.0                    5.0
# C_ID_0001793786                           765.0                    7.0
# C_ID_00024e244b                           918.0                    3.0
# C_ID_0002709b5a                          1284.0                    7.0
# C_ID_000298032a                           796.0                    3.0
#
#                  feature_1 + feature_2  feature_2 + feature_3  \
# card_id
# C_ID_0001238066                    5.0                    2.0
# C_ID_0001793786                    7.0                    4.0
# C_ID_00024e244b                    4.0                    3.0
# C_ID_0002709b5a                    6.0                    3.0
# C_ID_000298032a                    4.0                    3.0
#
#                  feature_3 % feature_1  feature_3 % feature_2  \
# card_id
# C_ID_0001238066                    1.0                    0.0
# C_ID_0001793786                    2.0                    0.0
# C_ID_00024e244b                    1.0                    1.0
# C_ID_0002709b5a                    2.0                    0.0
# C_ID_000298032a                    1.0                    1.0
#
#                  feature_1 % feature_3  \
# card_id
# C_ID_0001238066                    0.0
# C_ID_0001793786                    1.0
# C_ID_00024e244b                    0.0
# C_ID_0002709b5a                    1.0
# C_ID_000298032a                    0.0
#
#                                                             ...                                              \
# card_id                                                     ...
# C_ID_0001238066                                             ...
# C_ID_0001793786                                             ...
# C_ID_00024e244b                                             ...
# C_ID_0002709b5a                                             ...
# C_ID_000298032a                                             ...
#
#                  feature_1 % feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                4.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                6.0
# C_ID_000298032a                                                0.0
#
#                  feature_2 + feature_3 % feature_1 + feature_3 * feature_3 % feature_1 + feature_3  \
# card_id
# C_ID_0001238066                                                2.0
# C_ID_0001793786                                                8.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                6.0
# C_ID_000298032a                                                0.0
#
#                  DAYS_SINCE(first_active_month) % feature_1 * feature_3 % DAYS_SINCE(first_active_month)  \
# card_id
# C_ID_0001238066                                                2.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                8.0
# C_ID_000298032a                                                0.0
#
#                  DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3  \
# card_id
# C_ID_0001238066                                                4.0
# C_ID_0001793786                                                8.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                9.0
# C_ID_000298032a                                                0.0
#
#                  feature_1 % DAYS_SINCE(first_active_month) * feature_1 % feature_2  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                5.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                0.0
#
#                  feature_2 + feature_3 % feature_1 + feature_3 * feature_3  \
# card_id
# C_ID_0001238066                                                2.0
# C_ID_0001793786                                                8.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                6.0
# C_ID_000298032a                                                0.0
#
#                  feature_2 % feature_2 + feature_3 * feature_3 % feature_2 + feature_3  \
# card_id
# C_ID_0001238066                                                1.0
# C_ID_0001793786                                                4.0
# C_ID_00024e244b                                                2.0
# C_ID_0002709b5a                                                2.0
# C_ID_000298032a                                                2.0
#
#                  feature_2 % feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)  \
# card_id
# C_ID_0001238066                                                1.0
# C_ID_0001793786                                                4.0
# C_ID_00024e244b                                                2.0
# C_ID_0002709b5a                                                2.0
# C_ID_000298032a                                                2.0
#
#                  feature_1 % feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3  \
# card_id
# C_ID_0001238066                                                8.0
# C_ID_0001793786                                               20.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                               15.0
# C_ID_000298032a                                                0.0
#
#                  DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_3 % feature_1 + feature_3
# card_id
# C_ID_0001238066                                                2.0
# C_ID_0001793786                                                4.0
# C_ID_00024e244b                                                2.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                0.0
#
# [5 rows x 1426 columns]

# %%
default_agg_primitives =  ["sum", "std", "max", "skew", "min", "mean", "count", "median",
                           "percent_true", "num_unique", "mode", "avg_time_between", "time_since_last",
                           "percent_true", "trend"]
default_trans_primitives =  ["days_since", "add", "mod", "multiply"]

# %%
ft.list_primitives()
# Out:
#                    name         type  \
# 0                   all  aggregation
# 1                   any  aggregation
# 2                  mode  aggregation
# 3                  last  aggregation
# 4                  mean  aggregation
# 5                   std  aggregation
# 6              num_true  aggregation
# 7                   sum  aggregation
# 8                  skew  aggregation
# 9      avg_time_between  aggregation
# 10        n_most_common  aggregation
# 11           num_unique  aggregation
# 12                count  aggregation
# 13               median  aggregation
# 14                  max  aggregation
# 15         percent_true  aggregation
# 16      time_since_last  aggregation
# 17                trend  aggregation
# 18                  min  aggregation
# 19            cum_count    transform
# 20             multiply    transform
# 21           characters    transform
# 22              cum_sum    transform
# 23                  add    transform
# 24  time_since_previous    transform
# 25               months    transform
# 26              weekend    transform
# 27                  and    transform
# 28            longitude    transform
# 29                weeks    transform
# 30              minutes    transform
# 31           percentile    transform
# 32                 diff    transform
# 33              seconds    transform
# 34               negate    transform
# 35                hours    transform
# 36           days_since    transform
# 37              cum_max    transform
# 38               divide    transform
# 39                  day    transform
# 40                 days    transform
# 41              is_null    transform
# 42             numwords    transform
# 43             cum_mean    transform
# 44             subtract    transform
# 45                 year    transform
# 46              weekday    transform
# 47                   or    transform
# 48             absolute    transform
# 49            haversine    transform
# 50                month    transform
# 51             latitude    transform
# 52                 week    transform
# 53               minute    transform
# 54                  not    transform
# 55           time_since    transform
# 56                 isin    transform
# 57               second    transform
# 58              cum_min    transform
# 59                  mod    transform
# 60                years    transform
# 61                 hour    transform
#
#                                           description
# 0                      Test if all values are 'True'.
# 1                        Test if any value is 'True'.
# 2   Finds the most common element in a categorical...
# 3                             Returns the last value.
# 4    Computes the average value of a numeric feature.
# 5   Finds the standard deviation of a numeric feat...
# 6     Finds the number of 'True' values in a boolean.
# 7      Sums elements of a numeric or boolean feature.
# 8                Computes the skewness of a data set.
# 9   Computes the average time between consecutive ...
# 10  Finds the N most common elements in a categori...
# 11  Returns the number of unique categorical varia...
# 12              Counts the number of non null values.
# 13  Finds the median value of any feature with wel...
# 14  Finds the maximum non-null value of a numeric ...
# 15  Finds the percent of 'True' values in a boolea...
# 16                  Time since last related instance.
# 17  Calculates the slope of the linear trend of va...
# 18  Finds the minimum non-null value of a numeric ...
# 19  Calculates the number of previous values of an...
# 20  Creates a transform feature that multplies two...
# 21           Return the characters in a given string.
# 22  Calculates the sum of previous values of an in...
# 23  Creates a transform feature that adds two feat...
# 24      Compute the time since the previous instance.
# 25  Transform a Timedelta feature into the number ...
# 26  Transform Datetime feature into the boolean of...
# 27  For two boolean values, determine if both valu...
# 28  Returns the second value on the tuple base fea...
# 29  Transform a Timedelta feature into the number ...
# 30  Transform a Timedelta feature into the number ...
# 31  For each value of the base feature, determines...
# 32  Compute the difference between the value of a ...
# 33  Transform a Timedelta feature into the number ...
# 34  Creates a transform feature that negates a fea...
# 35  Transform a Timedelta feature into the number ...
# 36  For each value of the base feature, compute th...
# 37  Calculates the max of previous values of an in...
# 38  Creates a transform feature that divides two f...
# 39         Transform a Datetime feature into the day.
# 40  Transform a Timedelta feature into the number ...
# 41  For each value of base feature, return 'True' ...
# 42  Returns the words in a given string by countin...
# 43  Calculates the mean of previous values of an i...
# 44  Creates a transform feature that subtracts two...
# 45        Transform a Datetime feature into the year.
# 46  Transform Datetime feature into the boolean of...
# 47  For two boolean values, determine if one value...
# 48                    Absolute value of base feature.
# 49  Calculate the approximate haversine distance i...
# 50       Transform a Datetime feature into the month.
# 51  Returns the first value of the tuple base feat...
# 52        Transform a Datetime feature into the week.
# 53      Transform a Datetime feature into the minute.
# 54  For each value of the base feature, negates th...
# 55             Calculates time since the cutoff time.
# 56  For each value of the base feature, checks whe...
# 57      Transform a Datetime feature into the second.
# 58  Calculates the min of previous values of an in...
# 59  Creates a transform feature that divides two f...
# 60  Transform a Timedelta feature into the number ...
# 61        Transform a Datetime feature into the hour.

# %%
from featuretools import selection

# Remove features with only one unique value
feature_matrix2 = selection.remove_low_information_features(lala_feature_matrix)

print('Removed %d features' % (lala_feature_matrix.shape[1]- feature_matrix2.shape[1]))
# Out:
# Removed 0 features

# %%
feature_matrix2.shape
# Out:
# (123623, 1426)

# %%
df_train_columns = lala_feature_matrix.columns.values

# %%
from scipy.stats import ks_2samp
list_p_value =[]

for i in tqdm(df_train_columns):
    list_p_value.append(ks_2samp(lala_feature_matrix[i] , lala_feature_matrix[i])[1])

Se = pd.Series(list_p_value, index = df_train_columns).sort_values() 
list_discarded = list(Se[Se < .1].index)
# Out:
# 100%|██████████| 1426/1426 [00:23<00:00, 59.95it/s]

# %%
list_discarded
# Out:
# []

# %%
correlation = lala_feature_matrix.corr()

# %%
correlation.to_feather('correlation')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-ab4cfa107305> in <module>
# ----> 1 correlation.to_feather('correlation')
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in to_feather(self, fname)
#    1890         """
#    1891         from pandas.io.feather_format import to_feather
# -> 1892         to_feather(self, fname)
#    1893
#    1894     def to_parquet(self, fname, engine='auto', compression='snappy',
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/io/feather_format.py in to_feather(df, path)
#      62                          "for the index; you can .reset_index()"
#      63                          "to make the index into column(s)".format(
# ---> 64                              type(df.index)))
#      65
#      66     if not df.index.equals(RangeIndex.from_range(range(len(df)))):
#
# ValueError: feather does not support serializing <class 'pandas.core.indexes.base.Index'> for the index; you can .reset_index()to make the index into column(s)

# %%
correlation.head()
# Out:
#                                 feature_1  feature_2  feature_3  \
# feature_1                        1.000000  -0.132061   0.582790
# feature_2                       -0.132061   1.000000   0.065344
# feature_3                        0.582790   0.065344   1.000000
# DAYS_SINCE(first_active_month)   0.113843   0.155899   0.195187
# feature_2 + feature_3            0.205430   0.844932   0.588942
#
#                                 DAYS_SINCE(first_active_month)  \
# feature_1                                             0.113843
# feature_2                                             0.155899
# feature_3                                             0.195187
# DAYS_SINCE(first_active_month)                        1.000000
# feature_2 + feature_3                                 0.230888
#
#                                 feature_2 + feature_3  feature_1 + feature_2  \
# feature_1                                    0.205430               0.826459
# feature_2                                    0.844932               0.448923
# feature_3                                    0.588942               0.562479
# DAYS_SINCE(first_active_month)               0.230888               0.191172
# feature_2 + feature_3                        1.000000               0.665085
#
#                                 feature_1 + feature_3  feature_1 % feature_3  \
# feature_1                                    0.964794               0.582790
# feature_2                                   -0.081353               0.065344
# feature_3                                    0.775998               1.000000
# DAYS_SINCE(first_active_month)               0.151535               0.195187
# feature_2 + feature_3                        0.350062               0.588942
#
#                                 feature_1 % feature_2  feature_3 % feature_2  \
# feature_1                                    0.038619              -0.250381
# feature_2                                    0.448912               0.816185
# feature_3                                    0.094626              -0.078709
# DAYS_SINCE(first_active_month)              -0.194043               0.279974
# feature_2 + feature_3                        0.414298               0.618844
#
#                                                           ...                              \
# feature_1                                                 ...
# feature_2                                                 ...
# feature_3                                                 ...
# DAYS_SINCE(first_active_month)                            ...
# feature_2 + feature_3                                     ...
#
#                                 feature_1 + feature_2 % feature_1 + feature_3 * feature_2 % feature_2 + feature_3  \
# feature_1                                                                0.339106
# feature_2                                                                0.018942
# feature_3                                                                0.288448
# DAYS_SINCE(first_active_month)                                           0.188276
# feature_2 + feature_3                                                    0.169955
#
#                                 feature_1 + feature_2 % feature_3 * feature_2 + feature_3 % feature_1 + feature_2  \
# feature_1                                                                0.291089
# feature_2                                                                0.173283
# feature_3                                                                0.441731
# DAYS_SINCE(first_active_month)                                          -0.105140
# feature_2 + feature_3                                                    0.377119
#
#                                 feature_2 + feature_3 % feature_1 + feature_2 * feature_3  \
# feature_1                                                                0.487026
# feature_2                                                                0.447172
# feature_3                                                                0.883610
# DAYS_SINCE(first_active_month)                                           0.243634
# feature_2 + feature_3                                                    0.835800
#
#                                 feature_1 + feature_2 % feature_1 * feature_3 % feature_2 + feature_3  \
# feature_1                                                                0.565775
# feature_2                                                               -0.136113
# feature_3                                                                0.529470
# DAYS_SINCE(first_active_month)                                          -0.140469
# feature_2 + feature_3                                                    0.173567
#
#                                 DAYS_SINCE(first_active_month) % feature_3 * feature_2 + feature_3 % feature_1 + feature_2  \
# feature_1                                                                0.262945
# feature_2                                                                0.162768
# feature_3                                                                0.519518
# DAYS_SINCE(first_active_month)                                           0.141321
# feature_2 + feature_3                                                    0.410299
#
#                                 feature_1 % feature_1 + feature_2 * feature_1 + feature_2 % feature_1  \
# feature_1                                                                0.731561
# feature_2                                                               -0.088647
# feature_3                                                                0.330609
# DAYS_SINCE(first_active_month)                                          -0.123425
# feature_2 + feature_3                                                    0.105418
#
#                                 feature_1 + feature_2 % feature_2 + feature_3 * feature_1 + feature_3 % feature_1  \
# feature_1                                                                0.341292
# feature_2                                                                0.289003
# feature_3                                                                0.413546
# DAYS_SINCE(first_active_month)                                          -0.035912
# feature_2 + feature_3                                                    0.455734
#
#                                 feature_1 + feature_2 % feature_2 + feature_3 * feature_2 % feature_3  \
# feature_1                                                               -0.051689
# feature_2                                                                0.196103
# feature_3                                                                0.494299
# DAYS_SINCE(first_active_month)                                           0.219171
# feature_2 + feature_3                                                    0.423779
#
#                                 feature_2 + feature_3 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2  \
# feature_1                                                                0.097805
# feature_2                                                                0.282098
# feature_3                                                               -0.328349
# DAYS_SINCE(first_active_month)                                          -0.053573
# feature_2 + feature_3                                                    0.052471
#
#                                 feature_2 % feature_1 + feature_3 * feature_2 + feature_3
# feature_1                                                                0.137869
# feature_2                                                                0.759679
# feature_3                                                                0.423931
# DAYS_SINCE(first_active_month)                                           0.270002
# feature_2 + feature_3                                                    0.842504
#
# [5 rows x 1426 columns]

# %%
correlation.index.name = 'Variable'

# %%
correlation.head()
# Out:
#                                 feature_1  feature_2  feature_3  \
# Variable
# feature_1                        1.000000  -0.132061   0.582790
# feature_2                       -0.132061   1.000000   0.065344
# feature_3                        0.582790   0.065344   1.000000
# DAYS_SINCE(first_active_month)   0.113843   0.155899   0.195187
# feature_2 + feature_3            0.205430   0.844932   0.588942
#
#                                 DAYS_SINCE(first_active_month)  \
# Variable
# feature_1                                             0.113843
# feature_2                                             0.155899
# feature_3                                             0.195187
# DAYS_SINCE(first_active_month)                        1.000000
# feature_2 + feature_3                                 0.230888
#
#                                 feature_2 + feature_3  feature_1 + feature_2  \
# Variable
# feature_1                                    0.205430               0.826459
# feature_2                                    0.844932               0.448923
# feature_3                                    0.588942               0.562479
# DAYS_SINCE(first_active_month)               0.230888               0.191172
# feature_2 + feature_3                        1.000000               0.665085
#
#                                 feature_1 + feature_3  feature_1 % feature_3  \
# Variable
# feature_1                                    0.964794               0.582790
# feature_2                                   -0.081353               0.065344
# feature_3                                    0.775998               1.000000
# DAYS_SINCE(first_active_month)               0.151535               0.195187
# feature_2 + feature_3                        0.350062               0.588942
#
#                                 feature_1 % feature_2  feature_3 % feature_2  \
# Variable
# feature_1                                    0.038619              -0.250381
# feature_2                                    0.448912               0.816185
# feature_3                                    0.094626              -0.078709
# DAYS_SINCE(first_active_month)              -0.194043               0.279974
# feature_2 + feature_3                        0.414298               0.618844
#
#                                                           ...                              \
# Variable                                                  ...
# feature_1                                                 ...
# feature_2                                                 ...
# feature_3                                                 ...
# DAYS_SINCE(first_active_month)                            ...
# feature_2 + feature_3                                     ...
#
#                                 feature_1 + feature_2 % feature_1 + feature_3 * feature_2 % feature_2 + feature_3  \
# Variable
# feature_1                                                                0.339106
# feature_2                                                                0.018942
# feature_3                                                                0.288448
# DAYS_SINCE(first_active_month)                                           0.188276
# feature_2 + feature_3                                                    0.169955
#
#                                 feature_1 + feature_2 % feature_3 * feature_2 + feature_3 % feature_1 + feature_2  \
# Variable
# feature_1                                                                0.291089
# feature_2                                                                0.173283
# feature_3                                                                0.441731
# DAYS_SINCE(first_active_month)                                          -0.105140
# feature_2 + feature_3                                                    0.377119
#
#                                 feature_2 + feature_3 % feature_1 + feature_2 * feature_3  \
# Variable
# feature_1                                                                0.487026
# feature_2                                                                0.447172
# feature_3                                                                0.883610
# DAYS_SINCE(first_active_month)                                           0.243634
# feature_2 + feature_3                                                    0.835800
#
#                                 feature_1 + feature_2 % feature_1 * feature_3 % feature_2 + feature_3  \
# Variable
# feature_1                                                                0.565775
# feature_2                                                               -0.136113
# feature_3                                                                0.529470
# DAYS_SINCE(first_active_month)                                          -0.140469
# feature_2 + feature_3                                                    0.173567
#
#                                 DAYS_SINCE(first_active_month) % feature_3 * feature_2 + feature_3 % feature_1 + feature_2  \
# Variable
# feature_1                                                                0.262945
# feature_2                                                                0.162768
# feature_3                                                                0.519518
# DAYS_SINCE(first_active_month)                                           0.141321
# feature_2 + feature_3                                                    0.410299
#
#                                 feature_1 % feature_1 + feature_2 * feature_1 + feature_2 % feature_1  \
# Variable
# feature_1                                                                0.731561
# feature_2                                                               -0.088647
# feature_3                                                                0.330609
# DAYS_SINCE(first_active_month)                                          -0.123425
# feature_2 + feature_3                                                    0.105418
#
#                                 feature_1 + feature_2 % feature_2 + feature_3 * feature_1 + feature_3 % feature_1  \
# Variable
# feature_1                                                                0.341292
# feature_2                                                                0.289003
# feature_3                                                                0.413546
# DAYS_SINCE(first_active_month)                                          -0.035912
# feature_2 + feature_3                                                    0.455734
#
#                                 feature_1 + feature_2 % feature_2 + feature_3 * feature_2 % feature_3  \
# Variable
# feature_1                                                               -0.051689
# feature_2                                                                0.196103
# feature_3                                                                0.494299
# DAYS_SINCE(first_active_month)                                           0.219171
# feature_2 + feature_3                                                    0.423779
#
#                                 feature_2 + feature_3 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2  \
# Variable
# feature_1                                                                0.097805
# feature_2                                                                0.282098
# feature_3                                                               -0.328349
# DAYS_SINCE(first_active_month)                                          -0.053573
# feature_2 + feature_3                                                    0.052471
#
#                                 feature_2 % feature_1 + feature_3 * feature_2 + feature_3
# Variable
# feature_1                                                                0.137869
# feature_2                                                                0.759679
# feature_3                                                                0.423931
# DAYS_SINCE(first_active_month)                                           0.270002
# feature_2 + feature_3                                                    0.842504
#
# [5 rows x 1426 columns]

# %%
correlation.reset_index().to_feather('correlation')

# %%
threshold = 0.9

correlated_pairs = {}

# Iterate through the columns
for col in correlation:
    # Find correlations above the threshold
    above_threshold_vars = [x for x in list(correlation.index[correlation[col] > threshold]) if x != col]
    correlated_pairs[col] = above_threshold_vars

# %%
correlation['feature_1'].sort_values(ascending=True)[:100]
# Out:
# Variable
# DAYS_SINCE(first_active_month) + feature_1 % DAYS_SINCE(first_active_month) + feature_2         -0.322750
# DAYS_SINCE(first_active_month) + feature_3 % DAYS_SINCE(first_active_month) + feature_2         -0.280467
# feature_3 % feature_2                                                                           -0.250381
# feature_2 + feature_3 % feature_2                                                               -0.250381
# feature_1 % feature_2 * feature_3 % feature_2                                                   -0.236594
# feature_1 + feature_2 % feature_2 * feature_3 % feature_2                                       -0.236594
# feature_1 + feature_2 % feature_2 * feature_2 + feature_3 % feature_2                           -0.236594
# feature_1 % feature_2 * feature_2 + feature_3 % feature_2                                       -0.236594
# feature_1 + feature_2 % feature_1 + feature_3 * feature_3 % feature_2                           -0.220574
# feature_1 + feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2               -0.220574
# feature_2 * feature_2 + feature_3 % feature_2                                                   -0.206110
# feature_2 * feature_3 % feature_2                                                               -0.206110
# feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % feature_2                           -0.206110
# feature_2 % feature_1 + feature_2 * feature_3 % feature_2                                       -0.206110
# feature_2 % feature_2 + feature_3 * feature_3 % feature_2                                       -0.206110
# feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_2                              -0.206110
# feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2                  -0.206110
# feature_2 % feature_1 + feature_2 * feature_2 + feature_3 % feature_2                           -0.206110
# feature_1 % feature_2 + feature_3 * feature_2 + feature_3 % feature_2                           -0.193307
# feature_1 % feature_2 + feature_3 * feature_3 % feature_2                                       -0.193307
# feature_2 + feature_3 * feature_3 % feature_2                                                   -0.186529
# feature_2 + feature_3 * feature_2 + feature_3 % feature_2                                       -0.186529
# feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2                  -0.186529
# feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2      -0.186529
# DAYS_SINCE(first_active_month) + feature_2 * feature_3 % feature_2                              -0.185294
# DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3 % feature_2                  -0.185294
# DAYS_SINCE(first_active_month) * feature_3 % feature_2                                          -0.185178
# DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2                              -0.185178
# DAYS_SINCE(first_active_month) + feature_3 * feature_2 + feature_3 % feature_2                  -0.185161
# DAYS_SINCE(first_active_month) + feature_3 * feature_3 % feature_2                              -0.185161
#                                                                                                    ...
# feature_1 + feature_3 * feature_2 + feature_3 % feature_2                                       -0.134350
# feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2                  -0.134350
# feature_1 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_2               -0.134350
# feature_1 + feature_3 % feature_1 + feature_2 * feature_3 % feature_2                           -0.134350
# feature_1 + feature_3 * feature_3 % feature_2                                                   -0.134350
# DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_2 % feature_1 + feature_3      -0.134263
# feature_2 % feature_1 + feature_2                                                               -0.132061
# feature_2 % feature_2 + feature_3                                                               -0.132061
# DAYS_SINCE(first_active_month) + feature_2 % DAYS_SINCE(first_active_month)                     -0.132061
# feature_2 % DAYS_SINCE(first_active_month) + feature_2                                          -0.132061
# feature_2 % DAYS_SINCE(first_active_month) + feature_1                                          -0.132061
# feature_2 % DAYS_SINCE(first_active_month)                                                      -0.132061
# feature_2 % DAYS_SINCE(first_active_month) + feature_3                                          -0.132061
# feature_2                                                                                       -0.132061
# feature_1 % feature_2 + feature_3 * feature_1 + feature_3 % feature_1 + feature_2               -0.125470
# DAYS_SINCE(first_active_month) % feature_2 * feature_3 % feature_2                              -0.123493
# DAYS_SINCE(first_active_month) % feature_2 * feature_2 + feature_3 % feature_2                  -0.123493
# feature_1 % DAYS_SINCE(first_active_month) * feature_3 % feature_2                              -0.120095
# feature_1 % feature_1 + feature_3 * feature_3 % feature_2                                       -0.120095
# feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2                  -0.120095
# feature_1 % feature_1 + feature_2 * feature_2 + feature_3 % feature_2                           -0.120095
# feature_1 % feature_1 + feature_2 * feature_3 % feature_2                                       -0.120095
# feature_1 * feature_2 + feature_3 % feature_2                                                   -0.120095
# feature_1 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2                           -0.120095
# feature_1 * feature_3 % feature_2                                                               -0.120095
# DAYS_SINCE(first_active_month) % feature_2 * feature_1 % feature_2 + feature_3                  -0.117696
# feature_1 + feature_2 % feature_2 + feature_3 * feature_1 + feature_3 % feature_1 + feature_2   -0.116820
# feature_2 + feature_3 % feature_2 * feature_3 % feature_1                                       -0.116203
# feature_3 % feature_1 * feature_3 % feature_2                                                   -0.116203
# feature_1 + feature_3 % feature_1 * feature_3 % feature_2                                       -0.116203
# Name: feature_1, Length: 100, dtype: float64

# %%
corr_matrix = correlation.abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
len(to_drop)
# Out:
# 1189

# %%
to_drop
# Out:
# ['feature_1 + feature_3',
#  'feature_1 % feature_3',
#  'feature_1 * feature_3',
#  'feature_2 * feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1',
#  'DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2',
#  'feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_2',
#  'feature_3 % feature_2 + feature_3',
#  'feature_1 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_3',
#  'feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3',
#  'feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_3',
#  'feature_3 % feature_1 + feature_3',
#  'feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_1',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_3 * feature_3 % feature_1',
#  'feature_2 % feature_1 * feature_2 + feature_3',
#  'feature_1 % feature_3 * feature_1 + feature_3',
#  'feature_1 + feature_3 * feature_3',
#  'feature_2 + feature_3 * feature_3 % feature_2',
#  'feature_2 * feature_2 + feature_3',
#  'feature_1 % feature_3 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_3',
#  'feature_1 % feature_3 * feature_2',
#  'feature_2 * feature_3 % feature_1',
#  'feature_2 + feature_3 * feature_3 % feature_1',
#  'feature_1 * feature_1 % feature_3',
#  'feature_1 * feature_1 + feature_3',
#  'feature_1 % feature_3 * feature_3',
#  'feature_1 + feature_3 * feature_3 % feature_2',
#  'feature_1 + feature_3 * feature_2 % feature_1',
#  'feature_2 + feature_3 * feature_3',
#  'feature_1 % feature_2 * feature_1 % feature_3',
#  'feature_1 + feature_3 * feature_2',
#  'feature_1 % feature_2 * feature_2',
#  'feature_1 % feature_3 * feature_2 % feature_3',
#  'feature_1 + feature_3 * feature_2 % feature_3',
#  'feature_1 + feature_2 * feature_2 % feature_3',
#  'feature_1 * feature_3 % feature_2',
#  'feature_1 + feature_3 * feature_3 % feature_1',
#  'feature_1 % feature_3 * feature_3 % feature_1',
#  'feature_1 % feature_2 * feature_1 + feature_3',
#  'feature_1 * feature_3 % feature_1',
#  'feature_1 + feature_2 * feature_1 + feature_3',
#  'feature_2 * feature_3 % feature_2',
#  'feature_1 % feature_2 * feature_3',
#  'feature_3 * feature_3 % feature_2',
#  'feature_1 + feature_2 * feature_3 % feature_1',
#  'feature_1 % feature_2 * feature_3 % feature_1',
#  'feature_1 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_1',
#  'feature_2 % feature_3 * feature_3',
#  'feature_2 * feature_2 % feature_1',
#  'feature_1 + feature_2 * feature_2 + feature_3',
#  'feature_1 + feature_2 * feature_2 % feature_1',
#  'feature_2 % feature_3 * feature_3 % feature_2',
#  'feature_1 * feature_1 + feature_2',
#  'feature_1 * feature_1 % feature_2',
#  'DAYS_SINCE(first_active_month) * feature_1 % feature_2',
#  'feature_1 * feature_2 % feature_3',
#  'feature_2 % feature_1 * feature_3 % feature_1',
#  'feature_1 + feature_2 * feature_3',
#  'feature_1 % feature_2 * feature_2 + feature_3',
#  'feature_1 + feature_2 * feature_3 % feature_2',
#  'feature_2 % feature_3 * feature_2 + feature_3',
#  'feature_3 * feature_3 % feature_1',
#  'feature_1 + feature_3 * feature_2 + feature_3',
#  'feature_1 % feature_3 * feature_1 + feature_2',
#  'feature_3 % feature_1 * feature_3 % feature_2',
#  'feature_1 % feature_2 * feature_1 + feature_2',
#  'feature_3 % DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 % feature_3',
#  'feature_3 % DAYS_SINCE(first_active_month) + feature_1',
#  'feature_3 % DAYS_SINCE(first_active_month) + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % DAYS_SINCE(first_active_month) + feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 % feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month) + feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) + feature_2',
#  'feature_2 % DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month) + feature_2',
#  'feature_2 % DAYS_SINCE(first_active_month) + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) + feature_1',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) + feature_1',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) + feature_2',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) + feature_3',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) % DAYS_SINCE(first_active_month) + feature_1',
#  'DAYS_SINCE(first_active_month) + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_1 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_3 % feature_1',
#  'feature_1 % feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_1',
#  'feature_1 % feature_1 + feature_3 * feature_3 % feature_1',
#  'feature_1 + feature_3 % feature_1 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_3 % feature_1 + feature_3',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 % feature_1 + feature_3',
#  'feature_2 + feature_3 % feature_1 + feature_3 * feature_3 % feature_1',
#  'feature_1 + feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_3',
#  'feature_1 % feature_3 * feature_2 % feature_1 + feature_3',
#  'feature_2 % feature_1 + feature_3 * feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 + feature_2 * feature_3',
#  'feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 * feature_2 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_3',
#  'feature_1 + feature_3 % feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 % feature_1 + feature_2',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_3 * feature_2 % feature_2 + feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_2 * feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_3 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_3 % feature_1 + feature_2 * feature_3 % feature_2',
#  'feature_1 + feature_2 * feature_1 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_2 % feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_2 % feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 + feature_2 * feature_2 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_2',
#  'feature_1 + feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_3 * feature_1 + feature_2 % feature_2',
#  'DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_1 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_2',
#  'feature_1 + feature_2 % feature_1 * feature_2 % feature_1',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_2 + feature_3 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 * feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_1 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_3 * feature_3',
#  'feature_1 % feature_2 * feature_1 + feature_2 % feature_2',
#  'feature_1 + feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 % feature_2 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 * feature_1 + feature_2 % feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_2 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 + feature_3 * feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 % feature_2',
#  'feature_2 + feature_3 % feature_2 * feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_3 * feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 * feature_2 % feature_1 + feature_3',
#  'feature_2 + feature_3 * feature_2 + feature_3 % feature_1',
#  'feature_1 % feature_2 + feature_3 * feature_3 % feature_1 + feature_3',
#  'feature_2 + feature_3 % feature_2 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_3 * feature_1 + feature_3 % feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_2 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 % feature_1 + feature_2',
#  'feature_1 % feature_2 + feature_3 * feature_2',
#  'feature_1 + feature_2 % feature_3 * feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_2 * DAYS_SINCE(first_active_month) + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_1 % feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_3 % feature_1',
#  'feature_2 + feature_3 % feature_1 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_3 % feature_2 + feature_3',
#  'feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_2 * feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_1 * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_1 * feature_3 % feature_2 + feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_3',
#  'feature_2 % feature_2 + feature_3 * feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_3 * feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_2 % feature_2 + feature_3 * feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_2 % feature_1',
#  'feature_1 % feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 + feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_3',
#  'feature_1 + feature_3 * feature_1 + feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_2 % feature_1 + feature_3',
#  'feature_2 + feature_3 % feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 * feature_2 % feature_3',
#  'feature_1 + feature_2 % feature_1 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_2 + feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 % feature_3',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_2 * feature_1 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_1 + feature_3 % feature_1',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 * feature_2 % feature_2 + feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_2 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3',
#  'feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_3 * feature_1 + feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * DAYS_SINCE(first_active_month) + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_1 * feature_1 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_3',
#  'feature_2 % feature_1 * feature_2 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_2 % feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_1 % feature_1 + feature_3',
#  'feature_1 * feature_1 + feature_2 % feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_2 % feature_2 + feature_3',
#  'feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_1 * feature_2',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_3',
#  'feature_1 % feature_2 + feature_3 * feature_2 % feature_1 + feature_2',
#  'feature_1 * feature_1 % feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 % feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_3 % feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_2 % feature_1 + feature_2',
#  'feature_2 + feature_3 % feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_3 * feature_2 % feature_1',
#  'feature_2 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_2',
#  'feature_1 + feature_2 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1 % feature_3',
#  'feature_1 + feature_3 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_1 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_2',
#  'feature_1 * feature_3 % feature_1 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_2',
#  'feature_1 * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_1 * feature_1 + feature_2 % feature_3',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_3 % feature_1',
#  'feature_1 % feature_3 * feature_1 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1',
#  'feature_1 + feature_3 % feature_2 * feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1',
#  'feature_1 + feature_3 % feature_1 * feature_3 % feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 + feature_3 % feature_1',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 % feature_1',
#  'feature_2 % feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_2 * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 + feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_1 * feature_2 % feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_1 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 % feature_2',
#  'feature_2 * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1',
#  'feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_2 + feature_3 % feature_3 * feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_3 * feature_2 % feature_2 + feature_3',
#  'feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_1 % feature_3',
#  'feature_1 + feature_2 * feature_1 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_2 % feature_1',
#  'feature_1 + feature_2 % feature_1 * feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 % feature_3',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_2',
#  'feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_3 * feature_2 + feature_3',
#  'feature_1 % feature_2 + feature_3 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_3 % feature_3 * feature_2 % feature_1 + feature_3',
#  'feature_1 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * DAYS_SINCE(first_active_month) + feature_2',
#  'feature_1 * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_2 * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3 % feature_2',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 % feature_1',
#  'feature_1 % feature_1 + feature_3 * feature_2 % feature_3',
#  'feature_1 * feature_1 + feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 % feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 + feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_2 * feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_2 + feature_3',
#  'feature_1 + feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_1 % feature_3 * feature_2 + feature_3 % feature_3',
#  'feature_1 % feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1 + feature_3',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 + feature_3 * feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_1 * feature_1 + feature_2 % feature_3',
#  'feature_1 * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_3 * feature_1 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_2 % feature_2 + feature_3',
#  'feature_1 % feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_1 + feature_2 % feature_2',
#  'feature_1 % feature_3 * feature_1 + feature_2 % feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 + feature_3 * feature_2 % feature_3',
#  'feature_2 % feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 + feature_3 % feature_1',
#  'feature_1 % feature_2 + feature_3 * feature_2 % feature_1 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 % feature_2',
#  'feature_1 % feature_2 * feature_1 + feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_3 % feature_1 + feature_2 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1 + feature_3 % feature_1',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 * feature_2 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * DAYS_SINCE(first_active_month) + feature_2',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 % feature_3',
#  'feature_1 * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_3 % feature_1',
#  'feature_3 % feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_3 * feature_1 + feature_3 % feature_2 + feature_3',
#  'feature_2 + feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3 % feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 % feature_1 + feature_2',
#  'feature_1 % feature_2 + feature_3 * feature_2 % feature_1',
#  'feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1',
#  'feature_2 % feature_1 + feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_2 % feature_1 + feature_2',
#  'feature_1 * feature_1 + feature_3 % feature_1',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_2 % feature_1 + feature_3',
#  'feature_1 % feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_3',
#  'feature_2 % feature_2 + feature_3 * feature_2 % feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_2 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) % feature_3',
#  'feature_2 % feature_1 + feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_1 * feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 + feature_3',
#  'feature_2 % feature_1 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_3 % feature_3',
#  'feature_2 + feature_3 % feature_3 * feature_3 % feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_2 % feature_1',
#  'feature_1 + feature_2 % feature_3 * feature_2 + feature_3 % feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_3',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_2 + feature_3',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 % feature_1 + feature_2',
#  'feature_2 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) * feature_1 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_1 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * DAYS_SINCE(first_active_month) + feature_3',
#  'feature_1 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_1 + feature_3 % feature_2',
#  'feature_2 + feature_3 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_3 % feature_2',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2 + feature_3',
#  'feature_2 % feature_1 + feature_3 * feature_3 % feature_1',
#  'feature_2 + feature_3 % feature_3 * feature_3 % feature_1',
#  'feature_1 % feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_1 * feature_2 + feature_3',
#  'feature_2 + feature_3 % feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 % feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_3 * feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_3 % feature_1 + feature_3',
#  'feature_1 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_2 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_2',
#  'feature_2 + feature_3 % feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 * feature_2 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_3 * DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_3 % feature_1',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1',
#  'feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_1 * feature_1 + feature_3 % feature_2',
#  'feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 + feature_3 % feature_1',
#  'feature_2 % feature_1 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_2 * feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3',
#  'feature_1 % feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) * feature_2 % feature_2 + feature_3',
#  'feature_1 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 + feature_2 * feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_3 % feature_1',
#  'feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_2 * feature_2 + feature_3 % feature_2',
#  'feature_1 % feature_2 + feature_3 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_3 * feature_2 % feature_1 + feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_2',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 * feature_2 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_2 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_2 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 % feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2',
#  'feature_1 + feature_2 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) + feature_3',
#  'feature_1 + feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_2 % feature_1 + feature_2 * feature_3 % feature_2',
#  'feature_3 % feature_1 + feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_3 % feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 % feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1',
#  'feature_2 % feature_1 + feature_2 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_2 % feature_3',
#  'feature_1 + feature_2 % feature_1 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 % feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_2 % feature_3',
#  'feature_2 + feature_3 % feature_1 + feature_3 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1',
#  'feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_2 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_2 * feature_2 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_2 % feature_1',
#  'feature_1 + feature_2 % feature_1 * feature_1 + feature_2 % feature_2',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_3 * feature_2 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_3',
#  'feature_2 + feature_3 % feature_2 * feature_3 % feature_2',
#  'feature_1 + feature_3 % feature_1 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_2 % feature_1',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 * feature_3 % feature_2',
#  'feature_1 + feature_2 * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 + feature_2',
#  'feature_3 % feature_1 * feature_3 % feature_2 + feature_3',
#  'feature_2 % feature_1 + feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_1 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 % feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_2',
#  'feature_2 % feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
# ...
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_3 * DAYS_SINCE(first_active_month) + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 + feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_2 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_1 % feature_1 + feature_2',
#  'feature_1 % feature_3 * feature_1 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_2 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_1 % feature_2 + feature_3 * feature_1 + feature_2 % feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 % feature_1 + feature_2',
#  'feature_1 % feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 * feature_2 % feature_1 + feature_2',
#  'feature_2 % feature_1 + feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_2 + feature_3 % feature_1 * feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_2 % feature_1 * feature_1 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_3 % feature_2',
#  'feature_1 * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_2 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_1 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_2',
#  'feature_2 % feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_3',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) % feature_1',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_2 * feature_1 + feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_3 % feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2',
#  'feature_2 % feature_1 * feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_2 % feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 + feature_3 % feature_2 * feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_2 % feature_2',
#  'feature_2 + feature_3 % feature_2 * feature_2 + feature_3 % feature_3',
#  'feature_1 % feature_2 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_2 % feature_1 + feature_2 * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_1 % feature_2 + feature_3',
#  'feature_1 + feature_2 * feature_2 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_2 % feature_3 * feature_2 + feature_3 % feature_1',
#  'feature_1 % feature_1 + feature_3 * feature_2',
#  'feature_1 + feature_3 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_1 + feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_3 % feature_1',
#  'feature_2 % feature_1 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_1 + feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_1 + feature_2 % feature_3',
#  'feature_1 % feature_2 * feature_1 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_1',
#  'feature_1 + feature_3 * feature_2 + feature_3 % feature_2',
#  'feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_2 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 % feature_2 + feature_3',
#  'feature_2 + feature_3 % feature_1 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 % feature_2 + feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 * feature_1 + feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_2 + feature_3 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_3 % feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_3 * feature_2 % feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_1 + feature_2 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_2 * DAYS_SINCE(first_active_month) + feature_1',
#  'feature_1 + feature_3 % feature_2 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_3',
#  'feature_2 + feature_3 % feature_1 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_3 % feature_1 * feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_2',
#  'feature_2 % feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_1 + feature_2 * feature_2',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) % feature_2',
#  'feature_1 + feature_3 % DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_2 * feature_1 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_1 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_3',
#  'feature_2 % feature_1 * feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_2 * feature_1 + feature_3 % feature_1',
#  'feature_1 % feature_2 + feature_3 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_3 % feature_1',
#  'feature_1 % feature_2 * feature_2 + feature_3 % feature_2',
#  'feature_1 % feature_1 + feature_2 * feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * feature_3 % feature_1 + feature_3',
#  'feature_1 * feature_1 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_2',
#  'feature_3 % feature_1 + feature_2 * feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_2 + feature_3 % feature_1 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_2',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_2 + feature_3 % DAYS_SINCE(first_active_month) * feature_3 % feature_1 + feature_3',
#  'feature_1 % feature_1 + feature_2 * feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) * feature_2 + feature_3 % feature_3',
#  'DAYS_SINCE(first_active_month) % feature_1 * feature_1 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_1 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_3 * feature_2 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_2 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 + feature_3 * feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_2 + feature_3 * feature_1 % feature_3',
#  'feature_1 + feature_3 * feature_1 + feature_3 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'DAYS_SINCE(first_active_month) + feature_3 * feature_1 + feature_3 % feature_1',
#  'feature_1 + feature_2 % feature_2 * feature_1 + feature_3 % feature_2 + feature_3',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 % feature_3',
#  'feature_1 + feature_3 % feature_1 * feature_2 % feature_1',
#  'DAYS_SINCE(first_active_month) % feature_3 * feature_1 + feature_3 % feature_3',
#  'feature_1 % feature_2 * feature_1 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_2 + feature_3 * feature_2 + feature_3',
#  'feature_2 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_2 % DAYS_SINCE(first_active_month) * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_2 % feature_1 + feature_3 * feature_3 % feature_2 + feature_3',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_2 % feature_1 + feature_3',
#  'feature_1 + feature_2 % feature_2 + feature_3 * feature_1 + feature_3',
#  'DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 % feature_3',
#  'feature_1 + feature_2 % feature_3 * feature_2 % feature_1',
#  'feature_1 % feature_2 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_3 * feature_2 + feature_3 % feature_1',
#  'feature_1 + feature_3 % feature_1 * feature_3 % feature_1',
#  'DAYS_SINCE(first_active_month) * DAYS_SINCE(first_active_month) + feature_2',
#  'feature_2 + feature_3 % feature_2 * feature_3 % feature_2 + feature_3',
#  'DAYS_SINCE(first_active_month) + feature_1 * DAYS_SINCE(first_active_month) + feature_2',
#  'feature_1 % feature_2 * feature_1 + feature_2 % feature_2 + feature_3',
#  'feature_1 + feature_2 * feature_2 % feature_2 + feature_3',
#  'feature_1 % feature_1 + feature_3 * feature_1 + feature_2 % feature_2',
#  'DAYS_SINCE(first_active_month) % feature_1 + feature_3 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 % feature_2 + feature_3 * feature_3 % feature_1 + feature_2',
#  'feature_1 * feature_2 + feature_3 % feature_1 + feature_2',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_2 % feature_3 * feature_2 + feature_3 % feature_3',
#  'feature_1 + feature_3 % feature_2 + feature_3 * feature_2 % feature_1 + feature_2',
#  'feature_1 % DAYS_SINCE(first_active_month) * feature_1 + feature_2 % feature_2 + feature_3',
#  'feature_2 * feature_2 + feature_3 % DAYS_SINCE(first_active_month)',
#  'feature_1 % feature_1 + feature_2 * feature_3 % feature_2',
#  'feature_1 + feature_2 % DAYS_SINCE(first_active_month) * feature_1 + feature_3 % feature_1',
#  'feature_2 * feature_2 % DAYS_SINCE(first_active_month)',
#  'feature_1 + feature_3 % feature_3 * feature_3 % feature_1 + feature_2',
#  ...]

# %%
pruned = lala_feature_matrix.drop(to_drop, axis=1)

# %%
pruned.shape
# Out:
# (123623, 237)

# %%
pruned.head()
# Out:
#                  feature_1  feature_2  feature_3  \
# card_id
# C_ID_0001238066        4.0        1.0        1.0
# C_ID_0001793786        5.0        2.0        2.0
# C_ID_00024e244b        2.0        2.0        1.0
# C_ID_0002709b5a        5.0        1.0        2.0
# C_ID_000298032a        2.0        2.0        1.0
#
#                  DAYS_SINCE(first_active_month)  feature_2 + feature_3  \
# card_id
# C_ID_0001238066                           522.0                    2.0
# C_ID_0001793786                           765.0                    4.0
# C_ID_00024e244b                           918.0                    3.0
# C_ID_0002709b5a                          1284.0                    3.0
# C_ID_000298032a                           796.0                    3.0
#
#                  feature_1 + feature_2  feature_1 % feature_2  \
# card_id
# C_ID_0001238066                    5.0                    0.0
# C_ID_0001793786                    7.0                    1.0
# C_ID_00024e244b                    4.0                    0.0
# C_ID_0002709b5a                    6.0                    0.0
# C_ID_000298032a                    4.0                    0.0
#
#                  feature_3 % feature_2  feature_3 % feature_1  \
# card_id
# C_ID_0001238066                    0.0                    1.0
# C_ID_0001793786                    0.0                    2.0
# C_ID_00024e244b                    1.0                    1.0
# C_ID_0002709b5a                    0.0                    2.0
# C_ID_000298032a                    1.0                    1.0
#
#                  feature_2 % feature_1  \
# card_id
# C_ID_0001238066                    1.0
# C_ID_0001793786                    2.0
# C_ID_00024e244b                    0.0
# C_ID_0002709b5a                    1.0
# C_ID_000298032a                    0.0
#
#                                                        ...                                          \
# card_id                                                ...
# C_ID_0001238066                                        ...
# C_ID_0001793786                                        ...
# C_ID_00024e244b                                        ...
# C_ID_0002709b5a                                        ...
# C_ID_000298032a                                        ...
#
#                  DAYS_SINCE(first_active_month) % feature_1 * feature_1 + feature_2 % feature_2 + feature_3  \
# card_id
# C_ID_0001238066                                                2.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                0.0
#
#                  feature_1 + feature_3 % feature_1 + feature_2 * feature_2 + feature_3 % feature_1  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                3.0
# C_ID_0002709b5a                                                3.0
# C_ID_000298032a                                                3.0
#
#                  DAYS_SINCE(first_active_month) % feature_1 * feature_2 + feature_3 % feature_1  \
# card_id
# C_ID_0001238066                                                4.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                               12.0
# C_ID_000298032a                                                0.0
#
#                  DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_1 % feature_2 + feature_3  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                1.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                2.0
#
#                  feature_1 + feature_2 % feature_3 * feature_1 + feature_3 % feature_1 + feature_2  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                0.0
#
#                  DAYS_SINCE(first_active_month) % feature_2 * DAYS_SINCE(first_active_month) % feature_3  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                1.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                0.0
#
#                  feature_1 + feature_2 % feature_1 + feature_3 * feature_1 + feature_3 % feature_1 + feature_2  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                3.0
# C_ID_0002709b5a                                                6.0
# C_ID_000298032a                                                3.0
#
#                  DAYS_SINCE(first_active_month) % feature_2 + feature_3 * feature_2 + feature_3 % feature_1  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                4.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                1.0
#
#                  DAYS_SINCE(first_active_month) % feature_1 * feature_1 + feature_2 % feature_3  \
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                0.0
# C_ID_0002709b5a                                                0.0
# C_ID_000298032a                                                0.0
#
#                  feature_1 + feature_2 % feature_1 + feature_3 * feature_2 % feature_1 + feature_3
# card_id
# C_ID_0001238066                                                0.0
# C_ID_0001793786                                                0.0
# C_ID_00024e244b                                                2.0
# C_ID_0002709b5a                                                6.0
# C_ID_000298032a                                                2.0
#
# [5 rows x 237 columns]

# %% [markdown]
# ### Merge automated & manual aggs

# %%
add_datepart(temp_train, 'first_active_month', drop=False)
add_datepart(temp_test, 'first_active_month', drop=False)

# %%
new_hist_trans_agg.columns
# Out:
# Index(['card_id', 'transactions_count', 'Christmas_Day_2017_mean',
#        'Mothers_Day_2017_mean', 'fathers_day_2017_mean',
#        'Children_day_2017_mean', 'Valentine_Day_2017_mean',
#        'Black_Friday_2017_mean', 'Mothers_Day_2018_mean', 'price_sum',
#        'price_mean', 'price_max', 'price_min', 'price_var', 'price_skew',
#        'purchase_date_max', 'purchase_date_min', 'card_id_size',
#        'category_1_sum', 'category_1_mean', 'category_2_mean',
#        'category_3_mean', 'purchase_date_diff', 'purchase_date_average',
#        'purchase_date_uptonow', 'purchase_date_uptomin',
#        'inverse_avg_transactions_per_day', 'days_since_last_transaction'],
#       dtype='object')

# %%
def add_additional_aggs3(df):
    df['purchase_amount_ptp_new'] = df['MAX(temp_new_trans.purchase_amount)'] - df['MIN(temp_new_trans.purchase_amount)']
    df['purchase_amount_ptp_hist'] = df['MAX(temp_hist_trans.purchase_amount)'] - df['MIN(temp_hist_trans.purchase_amount)']
    df['card_id_total'] = df['COUNT(temp_hist_trans)'] + df['COUNT(temp_new_trans)']
    df['card_id_count_ratio'] = df['COUNT(temp_hist_trans)'] / df['COUNT(temp_new_trans)']
    df['purchase_amount_total'] = df['SUM(temp_new_trans.purchase_amount)']+df['SUM(temp_hist_trans.purchase_amount)']
    df['purchase_amount_ratio'] = df['SUM(temp_hist_trans.purchase_amount)'] / df['SUM(temp_new_trans.purchase_amount)']
    df['purchase_amount_mean_total'] = df['MEAN(temp_new_trans.purchase_amount)']+df['MEAN(temp_hist_trans.purchase_amount)']
    # redo with actual min & max
    df['purchase_amount_max_total'] = df['MAX(temp_new_trans.purchase_amount)']+df['MAX(temp_hist_trans.purchase_amount)']
    df['purchase_amount_min_total'] = df['MIN(temp_new_trans.purchase_amount)']+df['MIN(temp_hist_trans.purchase_amount)']
    df['avg_spend_per_transaction'] = df['purchase_amount_total']/df['card_id_total']
    df['month_diff_mean_total'] = df['MEAN(temp_new_trans.month_diff)']+df['MEAN(temp_hist_trans.month_diff)']
    df['month_diff_mean_ratio'] = df['MEAN(temp_hist_trans.month_diff)'] / df['MEAN(temp_new_trans.month_diff)']

    df['month_lag_ratio'] = df['SUM(temp_hist_trans.month_lag)'] / df['SUM(temp_new_trans.month_lag)']
    df['month_lag_sum'] = df['SUM(temp_hist_trans.month_lag)'] + df['SUM(temp_new_trans.month_lag)']
    df['month_lag_mean_total'] = df['MEAN(temp_new_trans.month_lag)']+df['MEAN(temp_hist_trans.month_lag)']
    # redo with actual min & max
    df['month_lag_max_total'] = df['MAX(temp_new_trans.month_lag)']+df['MAX(temp_hist_trans.month_lag)']
    df['month_lag_min_total'] = df['MIN(temp_new_trans.month_lag)']+df['MIN(temp_hist_trans.month_lag)']
    
    df['installments_ratio'] = df['SUM(temp_hist_trans.installments)'] / df['SUM(temp_new_trans.installments)']
    df['installments_sum'] = df['SUM(temp_hist_trans.installments)'] + df['SUM(temp_new_trans.installments)']
    df['installments_mean_total'] = df['MEAN(temp_new_trans.installments)']+df['MEAN(temp_hist_trans.installments)']
    # redo with actual min & max
    df['installments_max_total'] = df['MAX(temp_new_trans.installments)']+df['MAX(temp_hist_trans.installments)']
    df['installments_min_total'] = df['MIN(temp_new_trans.installments)']+df['MIN(temp_hist_trans.installments)']
    
    df['duration_sum_ratio'] = df['SUM(temp_hist_trans.duration)'] / df['SUM(temp_new_trans.duration)']
    df['duration_mean_total'] = df['MEAN(temp_new_trans.duration)']+df['MEAN(temp_hist_trans.duration)']
    # redo with actual min & max
    df['duration_max_total'] = df['MAX(temp_new_trans.duration)']+df['MAX(temp_hist_trans.duration)']
    df['duration_min_total'] = df['MIN(temp_new_trans.duration)']+df['MIN(temp_hist_trans.duration)']
    
    df['amount_month_ratio_sum_ratio'] = df['SUM(temp_hist_trans.amount_month_ratio)'] / df['SUM(temp_new_trans.amount_month_ratio)']
    df['amount_month_ratio_mean_total'] = df['MEAN(temp_new_trans.amount_month_ratio)']+df['MEAN(temp_hist_trans.amount_month_ratio)']
    # redo with actual min & max
    df['amount_month_ratio_max_total'] = df['MAX(temp_new_trans.amount_month_ratio)']+df['MAX(temp_hist_trans.amount_month_ratio)']
    df['amount_month_ratio_min_total'] = df['MIN(temp_new_trans.amount_month_ratio)']+df['MIN(temp_hist_trans.amount_month_ratio)']
    
    df['category_1_mean'] = df['category_1_mean']+df['category_1_mean_old']
    df['price_total'] = df['purchase_amount_total'] / df['installments_sum']
    df['price_mean'] = df['purchase_amount_mean_total'] / df['installments_mean_total']
    df['price_max'] = df['purchase_amount_max_total'] / df['installments_max_total']

    df['CLV_new'] = df['COUNT(temp_new_trans)'] * df['SUM(temp_new_trans.purchase_amount)'] / df['MEAN(temp_new_trans.month_diff)']
    df['CLV_hist'] = df['COUNT(temp_hist_trans)'] * df['SUM(temp_hist_trans.purchase_amount)'] / df['MEAN(temp_hist_trans.month_diff)']
    
    df['CLV_ratio'] = df['CLV_hist'] / df['CLV_new']
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days

    df['hist_first_buy'] = (df['purchase_date_min_old'] - df['first_active_month']).dt.days
    df['new_first_buy'] = (df['purchase_date_min'] - df['first_active_month']).dt.days
    df['hist_last_buy'] = (df['purchase_date_max_old'] - df['first_active_month']).dt.days
    df['new_last_buy'] = (df['purchase_date_max'] - df['first_active_month']).dt.days
    df['purchased_before_issue'] = df['hist_first_buy'] < 0
    return df

# %%
def join_dfs(left, right, left_on, right_on=None, suffix='_old'):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, suffixes=("", suffix))

# %%
train_df = join_dfs(temp_train, new_hist_trans_agg, left_on='card_id')

# %%
train_df = join_dfs(train_df, hist_trans_agg, left_on='card_id', suffix='_old')

# %%
train_df = join_dfs(train_df, feature_matrix, left_on='card_id')

# %%
train_df.shape
# Out:
# (2, 684)

# %%
def add_days_feature_interaction(df):
    # to datetime
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])

    # datetime features
    df['quarter'] = df['first_active_month'].dt.quarter
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days

    df['days_feature1'] = df['elapsed_time'] * df['feature_1']
    df['days_feature2'] = df['elapsed_time'] * df['feature_2']
    df['days_feature3'] = df['elapsed_time'] * df['feature_3']

    df['days_feature1_ratio'] = df['feature_1'] / df['elapsed_time']
    df['days_feature2_ratio'] = df['feature_2'] / df['elapsed_time']
    df['days_feature3_ratio'] = df['feature_3'] / df['elapsed_time']
    df['feature_sum'] = df['feature_1'] + df['feature_2'] + df['feature_3']
    df['feature_mean'] = df['feature_sum']/3
    df['feature_max'] = df[['feature_1', 'feature_2', 'feature_3']].max(axis=1)
    df['feature_min'] = df[['feature_1', 'feature_2', 'feature_3']].min(axis=1)
    df['feature_var'] = df[['feature_1', 'feature_2', 'feature_3']].std(axis=1)
    return df

# %%
train_df = add_additional_aggs3(train_df)

# %%
train_df.shape
# Out:
# (2, 724)

# %%
train_df = add_days_feature_interaction(train_df)

# %%
train_df.shape
# Out:
# (2, 736)

# %%
test_df = join_dfs(temp_test, new_hist_trans_agg, left_on='card_id')
test_df = join_dfs(test_df, hist_trans_agg, left_on='card_id', suffix='_old')
test_df = join_dfs(test_df, feature_matrix, left_on='card_id')
test_df = add_additional_aggs3(test_df)
test_df = add_days_feature_interaction(test_df)

# %%
test_df.shape
# Out:
# (1, 735)

# %%
train_df['outliers'] = 0
train_df.loc[train_df['target'] < -30, 'outliers'] = 1
train_df['outliers'].value_counts()
# Out:
# 0    2
# Name: outliers, dtype: int64

# %%
for f in ['feature_1','feature_2','feature_3']:
    order_label = train_df.groupby([f])['outliers'].mean()
    train_df[f] = train_df[f].map(order_label)
    test_df[f] = test_df[f].map(order_label)
