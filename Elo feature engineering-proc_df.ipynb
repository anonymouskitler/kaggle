# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-dependencies" data-toc-modified-id="Load-dependencies-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load dependencies</a></span></li><li><span><a href="#Read-csv-files-to-DFs" data-toc-modified-id="Read-csv-files-to-DFs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Read csv files to DFs</a></span></li><li><span><a href="#Add-date-part" data-toc-modified-id="Add-date-part-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Add date part</a></span></li><li><span><a href="#Train-cats-for-the-DFs" data-toc-modified-id="Train-cats-for-the-DFs-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train cats for the DFs</a></span></li><li><span><a href="#Add-extra-columns-(purchased-on-weekend,-monthend,-month_diff-etc." data-toc-modified-id="Add-extra-columns-(purchased-on-weekend,-monthend,-month_diff-etc.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Add extra columns (purchased on weekend, monthend, month_diff etc.</a></span></li><li><span><a href="#proc_df-to-fill-nas,-one-hot-encode-cats" data-toc-modified-id="proc_df-to-fill-nas,-one-hot-encode-cats-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>proc_df to fill nas, one hot encode cats</a></span></li><li><span><a href="#Mark-as-categorical-variables-(not-required)" data-toc-modified-id="Mark-as-categorical-variables-(not-required)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Mark as categorical variables (not required)</a></span></li><li><span><a href="#One-hot-encoding-categories-(not-required)" data-toc-modified-id="One-hot-encoding-categories-(not-required)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>One hot encoding categories (not required)</a></span></li><li><span><a href="#Aggregate-by-card_id" data-toc-modified-id="Aggregate-by-card_id-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Aggregate by card_id</a></span></li><li><span><a href="#Add-exta-interpreted-columns-on-aggregates" data-toc-modified-id="Add-exta-interpreted-columns-on-aggregates-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Add exta interpreted columns on aggregates</a></span></li><li><span><a href="#Load-test-&amp;-train-DFs" data-toc-modified-id="Load-test-&amp;-train-DFs-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Load test &amp; train DFs</a></span></li><li><span><a href="#Add-date-part-to-test-&amp;-train-dfs" data-toc-modified-id="Add-date-part-to-test-&amp;-train-dfs-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Add date part to test &amp; train dfs</a></span></li><li><span><a href="#Merge-train-&amp;-test-with-new-&amp;-old-transactions-history" data-toc-modified-id="Merge-train-&amp;-test-with-new-&amp;-old-transactions-history-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Merge train &amp; test with new &amp; old transactions history</a></span></li><li><span><a href="#Add-extra-columns-like-age,-total-transactions,-installments,-purchase-amount,-first-buy-etc" data-toc-modified-id="Add-extra-columns-like-age,-total-transactions,-installments,-purchase-amount,-first-buy-etc-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Add extra columns like age, total transactions, installments, purchase amount, first buy etc</a></span></li><li><span><a href="#Mark-the-outliers" data-toc-modified-id="Mark-the-outliers-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Mark the outliers</a></span></li><li><span><a href="#Target-encode-the-outliers" data-toc-modified-id="Target-encode-the-outliers-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Target encode the outliers</a></span></li></ul></div>

# %% [markdown]
# 1. Load dependencies
# 2. Read csv files to dataframes
# 3. Fill missing values
# 4. Add date part
# 5. Add extra columns (purchased on weekend, monthend, month_diff etc.
# 6. Aggregate by card_id
# 7. Aggregate by categories
# 8. Mark categorical columns
# 9. Add exta interpreted columns on aggregates
# 10. Load test & train csvs to dfs
# 11. Add date part to test & train dfs
# 12. Merge train & test with new & old transactions history
# 13. Add extra columns like age, total transactions, installments, purchase amount, first buy etc
# 14. Mark the outliers
# 15. Target encode the outliers
# 16. Save to feather

# %% [markdown]
# ### Load dependencies

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather

# %% [markdown]
# ### Read csv files to DFs

# %%
PATH = '../data/elo/'

# %%
files = ['historical_transactions', 'new_merchant_transactions']

# %%
hist_trans, new_hist_trans = [pd.read_csv(f'{PATH}{c}.csv') for c in files]

# %% [markdown]
# ### Add date part

# %%
add_datepart(hist_trans, 'purchase_date', drop=False)
add_datepart(new_hist_trans, 'purchase_date', drop=False)

# %% [markdown]
# ### Train cats for the DFs

# %%
train_cats(hist_trans)
train_cats(new_hist_trans)

# %% [markdown]
# ### Add extra columns (purchased on weekend, monthend, month_diff etc.

# %%
dfs = [hist_trans, new_hist_trans]

# %%
def add_extra_cols(df):
    df['purchased_on_weekend'] = (df.purchase_Dayofweek >=5).astype(int)
    df['month_diff'] = ((datetime.datetime.today() - df['purchase_date']).dt.days)//30
    df['month_diff'] += df['month_lag']
    return df

# %%
hist_trans, new_hist_trans = [add_extra_cols(df) for df in dfs]

# %%
hist_trans.shape, new_hist_trans.shape
# Out:
# ((29112361, 29), (1963031, 29))

# %% [markdown]
# ### proc_df to fill nas, one hot encode cats

# %%
# %time hist_trans_proc, y_hist, nas = proc_df(hist_trans, max_n_cat=7,ignore_flds=['purchase_date','card_id', 'merchant_id'])
# Out:
# CPU times: user 48.6 s, sys: 9.59 s, total: 58.2 s
# Wall time: 12.8 s

# %%
# %time new_trans_proc, y_new, nas_new = proc_df(new_hist_trans, max_n_cat=7,ignore_flds=['purchase_date','card_id', 'merchant_id'])
# Out:
# CPU times: user 3.82 s, sys: 0 ns, total: 3.82 s
# Wall time: 697 ms

# %%
hist_trans_proc.shape, new_trans_proc.shape
# Out:
# ((29112361, 37), (1963031, 36))

# %%
hist_trans_proc.columns.values, new_trans_proc.columns.values
# Out:
# (array(['purchase_date', 'card_id', 'merchant_id', 'city_id', 'installments', 'merchant_category_id',
#         'month_lag', 'purchase_amount', 'category_2', 'state_id', 'subsector_id', 'purchase_Year',
#         'purchase_Month', 'purchase_Week', 'purchase_Day', 'purchase_Dayofweek', 'purchase_Dayofyear',
#         'purchase_Is_month_end', 'purchase_Is_month_start', 'purchase_Is_quarter_end',
#         'purchase_Is_quarter_start', 'purchase_Is_year_end', 'purchase_Is_year_start', 'purchase_Elapsed',
#         'purchased_on_weekend', 'month_diff', 'category_2_na', 'authorized_flag_N', 'authorized_flag_Y',
#         'authorized_flag_nan', 'category_1_N', 'category_1_Y', 'category_1_nan', 'category_3_A',
#         'category_3_B', 'category_3_C', 'category_3_nan'], dtype=object),
#  array(['purchase_date', 'card_id', 'merchant_id', 'city_id', 'installments', 'merchant_category_id',
#         'month_lag', 'purchase_amount', 'category_2', 'state_id', 'subsector_id', 'purchase_Year',
#         'purchase_Month', 'purchase_Week', 'purchase_Day', 'purchase_Dayofweek', 'purchase_Dayofyear',
#         'purchase_Is_month_end', 'purchase_Is_month_start', 'purchase_Is_quarter_end',
#         'purchase_Is_quarter_start', 'purchase_Is_year_end', 'purchase_Is_year_start', 'purchase_Elapsed',
#         'purchased_on_weekend', 'month_diff', 'category_2_na', 'authorized_flag_Y', 'authorized_flag_nan',
#         'category_1_N', 'category_1_Y', 'category_1_nan', 'category_3_A', 'category_3_B', 'category_3_C',
#         'category_3_nan'], dtype=object))

# %%
import gc

# %%
gc.collect()
# Out:
# 77

# %% [markdown]
# ### Mark as categorical variables (not required)

# %%
def mark_categorical_cols_for_transactions(df):
    categorical_cols = ['authorized_flag', 'card_id', 'city_id',
       'merchant_category_id', 'merchant_id',
       'state_id', 'subsector_id', 'purchase_Year', 'purchase_Month']
    for c in categorical_cols:
        df[c] = df[c].astype('category').cat.as_ordered()
    for col in ['authorized_flag', 'category_1']:
        df[col] = df[col].map({'Y':1, 'N':0})
    return df

# %%
hist_trans_c, new_hist_trans_c = [mark_categorical_cols_for_transactions(df) for df in dfs]

# %%
hist_trans.shape, new_hist_trans.shape
# Out:
# ((29112361, 29), (1963031, 29))

# %%
hist_trans.to_feather('hist_trans')
new_hist_trans.to_feather('new_hist_trans')

# %%
hist_trans = feather.read_dataframe('hist_trans')

# %%
new_hist_trans = feather.read_dataframe('new_hist_trans')

# %% [markdown]
# ### One hot encoding categories (not required)

# %%
DataFrameSummary(new_hist_trans_c).summary()
# Out:
#              authorized_flag      card_id      city_id   category_1  \
# count            1.96303e+06          NaN          NaN  1.96303e+06
# mean                       1          NaN          NaN    0.0321421
# std                        0          NaN          NaN     0.176378
# min                        1          NaN          NaN            0
# 25%                        1          NaN          NaN            0
# 50%                        1          NaN          NaN            0
# 75%                        1          NaN          NaN            0
# max                        1          NaN          NaN            1
# counts               1963031      1963031      1963031      1963031
# uniques                    1       290001          308            2
# missing                    0            0            0            0
# missing_perc              0%           0%           0%           0%
# types               constant  categorical  categorical         bool
#
#              installments   category_3 merchant_category_id  merchant_id  \
# count         1.96303e+06          NaN                  NaN          NaN
# mean             0.682964          NaN                  NaN          NaN
# std               1.58407          NaN                  NaN          NaN
# min                    -1          NaN                  NaN          NaN
# 25%                     0          NaN                  NaN          NaN
# 50%                     1          NaN                  NaN          NaN
# 75%                     1          NaN                  NaN          NaN
# max                   999          NaN                  NaN          NaN
# counts            1963031      1963031              1963031      1963031
# uniques                15            3                  314       226129
# missing                 0            0                    0            0
# missing_perc           0%           0%                   0%           0%
# types             numeric  categorical          categorical  categorical
#
#                 month_lag purchase_amount     ...      purchase_Dayofyear  \
# count         1.96303e+06     1.96303e+06     ...             1.96303e+06
# mean              1.47652       -0.550969     ...                 109.884
# std              0.499448        0.694004     ...                 75.1097
# min                     1       -0.746893     ...                       1
# 25%                     1       -0.716629     ...                      71
# 50%                     1       -0.674841     ...                      90
# 75%                     2       -0.581616     ...                     112
# max                     2         263.157     ...                     365
# counts            1963031         1963031     ...                 1963031
# uniques                 2           75190     ...                     365
# missing                 0               0     ...                       0
# missing_perc           0%              0%     ...                      0%
# types                bool         numeric     ...                 numeric
#
#              purchase_Is_month_end purchase_Is_month_start  \
# count                          NaN                     NaN
# mean                           NaN                     NaN
# std                            NaN                     NaN
# min                            NaN                     NaN
# 25%                            NaN                     NaN
# 50%                            NaN                     NaN
# 75%                            NaN                     NaN
# max                            NaN                     NaN
# counts                     1963031                 1963031
# uniques                          2                       2
# missing                          0                       0
# missing_perc                    0%                      0%
# types                         bool                    bool
#
#              purchase_Is_quarter_end purchase_Is_quarter_start  \
# count                            NaN                       NaN
# mean                             NaN                       NaN
# std                              NaN                       NaN
# min                              NaN                       NaN
# 25%                              NaN                       NaN
# 50%                              NaN                       NaN
# 75%                              NaN                       NaN
# max                              NaN                       NaN
# counts                       1963031                   1963031
# uniques                            2                         2
# missing                            0                         0
# missing_perc                      0%                        0%
# types                           bool                      bool
#
#              purchase_Is_year_end purchase_Is_year_start purchase_Elapsed  \
# count                         NaN                    NaN      1.96303e+06
# mean                          NaN                    NaN      1.51935e+09
# std                           NaN                    NaN       6.6753e+06
# min                           NaN                    NaN      1.48834e+09
# 25%                           NaN                    NaN      1.51967e+09
# 50%                           NaN                    NaN      1.52146e+09
# 75%                           NaN                    NaN      1.52322e+09
# max                           NaN                    NaN      1.52513e+09
# counts                    1963031                1963031          1963031
# uniques                         2                      2          1667025
# missing                         0                      0                0
# missing_perc                   0%                     0%               0%
# types                        bool                   bool          numeric
#
#              purchased_on_weekend   month_diff
# count                 1.96303e+06  1.96303e+06
# mean                     0.307438       11.772
# std                      0.461433      2.55921
# min                             0           10
# 25%                             0           10
# 50%                             0           11
# 75%                             1           12
# max                             1           23
# counts                    1963031      1963031
# uniques                         2           14
# missing                         0            0
# missing_perc                   0%           0%
# types                        bool      numeric
#
# [13 rows x 29 columns]

# %%
def one_hot_encode_dfs(df):
    return pd.get_dummies(df, columns=['category_2', 'category_3'])

# %%
hist_trans_c.shape, new_hist_trans_c.shape
# Out:
# ((29112361, 29), (1963031, 29))

# %%
hist_trans_c_e, new_hist_trans_c_e = [one_hot_encode_dfs(df) for df in dfs]

# %%
hist_trans_c_e.shape, new_hist_trans_c_e.shape
# Out:
# ((29112361, 35), (1963031, 35))

# %%
new_hist_trans_c_e.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'merchant_category_id', 'merchant_id', 'month_lag', 'purchase_amount',
#        'purchase_date', 'state_id', 'subsector_id', 'purchase_Year',
#        'purchase_Month', 'purchase_Week', 'purchase_Day', 'purchase_Dayofweek',
#        'purchase_Dayofyear', 'purchase_Is_month_end',
#        'purchase_Is_month_start', 'purchase_Is_quarter_end',
#        'purchase_Is_quarter_start', 'purchase_Is_year_end',
#        'purchase_Is_year_start', 'purchase_Elapsed', 'purchased_on_weekend',
#        'month_diff', 'category_2_1.0', 'category_2_2.0', 'category_2_3.0',
#        'category_2_4.0', 'category_2_5.0', 'category_3_A', 'category_3_B',
#        'category_3_C'],
#       dtype='object')

# %%
## Not working
def aggregate_by_category(df):
    features = ['category_2_1.0', 'category_2_2.0', 'category_2_3.0',
       'category_2_4.0', 'category_2_5.0', 'category_3_A', 'category_3_B',
       'category_3_C']
    cat_agg = {"purchase_amount": ["sum", "mean"], "installments": ["sum", "mean"]}
    other_df = pd.DataFrame()
    for fe in features:
        g = df.groupby(['card_id', fe]).agg(cat_agg)
        g.columns = ['_'+fe+'_'.join(c).strip() for c in g.columns.values]
        g.reset_index(inplace=True)
        if other_df.empty:
            other_df = g
        else:
            other_df = pd.merge(other_df, g, on='card_id', how='left')
    return other_df

# %% [markdown]
# ### Aggregate by card_id

# %%
new_trans_proc['authorized_flag_N'] = 0

# %%
new_trans_proc.shape, hist_trans_proc.shape
# Out:
# ((1963031, 37), (29112361, 37))

# %%
# DataFrameSummary(new_trans_proc).summary().T

# %%
# new_trans_proc.head().T

# %%
def aggregate_by_card_id(df):
    unique_cols = ['city_id', 'merchant_category_id', 'merchant_id', 'state_id', 
                   'subsector_id']
    aggs = {}
    for c in unique_cols:
        aggs[c] = ['nunique'] 
    aggs['authorized_flag_Y'] = ['mean', 'sum']
    aggs['authorized_flag_N'] = ['mean', 'sum']
    aggs['purchase_amount'] = ['sum', 'max', 'min', 'mean', 'std', 'median']
    aggs['installments'] = ['sum', 'max', 'mean', 'std', 'median']
    aggs['month_lag'] = ['sum', 'max', 'min', 'mean', 'std', 'median']
    aggs['purchase_date'] = [np.min, np.max, np.ptp]
    aggs['card_id'] = ['size']
    aggs['purchased_on_weekend'] = ['sum', 'mean']
    aggs['month_diff'] = ['mean', 'std', 'var']
    aggs['category_1_N'] = ['sum', 'mean']
    aggs['category_1_Y'] = ['sum', 'mean']
    aggs['category_2'] = ['mean', 'sum']
    aggs['category_2_na'] = ['mean', 'sum']
    aggs['category_3_A'] = ['mean', 'sum']
    aggs['category_3_B' ] = ['mean', 'sum']
    aggs['category_3_C' ] = ['mean', 'sum']
    
    for col in ['category_2','category_2_na','category_3_nan', 'category_3_A', 'category_3_B', 'category_3_C']:
        df[col+'_mean2'] = df.groupby([col])['purchase_amount'].transform('mean')
        aggs[col+'_mean2'] = ['mean']    

    new_df = df.groupby(['card_id']).agg(aggs)
    new_df.columns = ['_'.join(col).strip() for col in new_df.columns.values]
    new_df.reset_index(inplace=True)
    other_df = (df.groupby('card_id')
          .size()
          .reset_index(name='transactions_count'))
    
    new_df = pd.merge(other_df, new_df, on='card_id', how='left')
    new_df["purchase_date_ptp"] = new_df["purchase_date_ptp"].dt.days    
    return new_df

# %%
dfs_e = [hist_trans_proc, new_trans_proc]

# %%
# %time hist_trans_agg, new_hist_trans_agg = [aggregate_by_card_id(df) for df in dfs_e]
# Out:
# CPU times: user 2min 56s, sys: 12.2 s, total: 3min 8s
# Wall time: 1min 54s

# %% [markdown]
# ### Add exta interpreted columns on aggregates

# %%
def add_extra_cols_on_agg(df):
    df['inverse_avg_transactions_per_day'] = df['purchase_date_ptp']/df['card_id_size']
    df['days_since_last_transaction'] = (datetime.datetime.today() - df['purchase_date_amax']).dt.days
    return df

# %%
[hist_trans_agg, new_hist_trans_agg] = [add_extra_cols_on_agg(df) for df in [hist_trans_agg, 
                                                                             new_hist_trans_agg]]

# %%
hist_trans_agg.to_feather('hist_trans_agg_proc')
new_hist_trans_agg.to_feather('new_trans_agg_proc')

# %%
hist_trans_agg_proc = feather.read_dataframe('hist_trans_agg_proc')
new_trans_agg_proc = feather.read_dataframe('new_trans_agg_proc')

# %%
hist_trans_agg_proc.shape, new_trans_agg_proc.shape
# Out:
# ((325540, 59), (290001, 59))

# %% [markdown]
# ### Load test & train DFs

# %%
PATH = 'data/elo/'

# %%
train, test = [pd.read_csv(f'{PATH}{c}') for c in ['train.csv', 'test.csv']]

# %% [markdown]
# ### Add date part to test & train dfs

# %%
add_datepart(train, 'first_active_month', drop=False)
add_datepart(test, 'first_active_month', drop=False)

# %% [markdown]
# ### Merge train & test with new & old transactions history

# %%
def join_dfs(left, right, left_on, right_on=None, suffix='_old'):
    if right_on is None: right_on = left_on
    return left.merge(right, how='left', left_on=left_on, right_on=right_on, suffixes=("", suffix))

# %%
hist_trans_agg.head().T
# Out:
#                                                     0                    1  \
# card_id                               C_ID_00007093c1      C_ID_0001238066
# transactions_count                                149                  123
# city_id_nunique                                     4                   18
# merchant_category_id_nunique                       18                   29
# merchant_id_nunique                                29                   65
# state_id_nunique                                    3                    6
# subsector_id_nunique                               13                   17
# authorized_flag_Y_mean                       0.765101              0.97561
# authorized_flag_Y_sum                             114                  120
# authorized_flag_N_mean                       0.234899            0.0243902
# authorized_flag_N_sum                              35                    3
# purchase_amount_sum                           -76.845             -72.4472
# purchase_amount_max                           1.50707             0.768095
# purchase_amount_min                         -0.728876            -0.734887
# purchase_amount_mean                        -0.515739            -0.589002
# purchase_amount_std                          0.298141             0.190235
# purchase_amount_median                      -0.587627            -0.648184
# installments_sum                                  192                  198
# installments_max                                    6                   10
# installments_mean                             1.28859              1.60976
# installments_std                               0.7649              1.48564
# installments_median                                 1                    1
# month_lag_sum                                    -872                 -223
# month_lag_max                                       0                    0
# month_lag_min                                     -12                   -5
# month_lag_mean                               -5.85235             -1.81301
# month_lag_std                                 3.45311              1.28898
# month_lag_median                                   -6                   -2
# purchase_date_amin                2017-02-14 14:00:43  2017-09-28 22:25:14
# purchase_date_amax                2018-02-27 05:14:57  2018-02-27 16:18:59
# purchase_date_ptp                                 377                  151
# card_id_size                                      149                  123
# purchased_on_weekend_sum                           25                   52
# purchased_on_weekend_mean                    0.167785             0.422764
# month_diff_mean                               10.8121              10.5528
# month_diff_std                               0.391965             0.499233
# month_diff_var                               0.153637             0.249234
# category_1_N_sum                                  121                  121
# category_1_N_mean                            0.812081              0.98374
# category_1_Y_sum                                   28                    2
# category_1_Y_mean                            0.187919            0.0162602
# category_2_mean                               2.63758              1.65041
# category_2_sum                                    393                  203
# category_2_na_mean                           0.187919            0.0650407
# category_2_na_sum                                  28                    8
# category_3_A_mean                                   0                    0
# category_3_A_sum                                    0                    0
# category_3_B_mean                            0.838926             0.715447
# category_3_B_sum                                  125                   88
# category_3_C_mean                            0.161074             0.260163
# category_3_C_sum                                   24                   32
# category_2_mean2_mean                         0.15858            0.0454582
# category_2_na_mean2_mean                  -0.00523215            0.0476203
# category_3_nan_mean2_mean                   0.0362652            0.0368062
# category_3_A_mean2_mean                     -0.329781            -0.329781
# category_3_B_mean2_mean                     -0.285957            -0.195039
# category_3_C_mean2_mean                     0.0436633            0.0510288
# inverse_avg_transactions_per_day               2.5302              1.22764
# days_since_last_transaction                       321                  321
#
#                                                     2                    3  \
# card_id                               C_ID_0001506ef0      C_ID_0001793786
# transactions_count                                 66                  216
# city_id_nunique                                     3                   10
# merchant_category_id_nunique                       19                   48
# merchant_id_nunique                                28                  119
# state_id_nunique                                    2                    4
# subsector_id_nunique                               12                   24
# authorized_flag_Y_mean                       0.939394                0.875
# authorized_flag_Y_sum                              62                  189
# authorized_flag_N_mean                      0.0606061                0.125
# authorized_flag_N_sum                               4                   27
# purchase_amount_sum                          -34.6019              -36.786
# purchase_amount_max                           1.49355              4.55415
# purchase_amount_min                         -0.740491            -0.745405
# purchase_amount_mean                        -0.524271            -0.170306
# purchase_amount_std                          0.472284             0.836046
# purchase_amount_median                      -0.703707            -0.487911
# installments_sum                                    1                    5
# installments_max                                    1                    1
# installments_mean                           0.0151515            0.0231481
# installments_std                             0.123091             0.150723
# installments_median                                 0                    0
# month_lag_sum                                    -319                 -719
# month_lag_max                                       0                    0
# month_lag_min                                     -13                   -9
# month_lag_mean                               -4.83333              -3.3287
# month_lag_std                                  4.2375              2.30637
# month_lag_median                                   -3                   -3
# purchase_date_amin                2017-01-14 16:16:01  2017-01-21 10:15:21
# purchase_date_amax                2018-02-17 12:33:56  2017-10-31 20:20:18
# purchase_date_ptp                                 398                  283
# card_id_size                                       66                  216
# purchased_on_weekend_sum                           32                   37
# purchased_on_weekend_mean                    0.484848             0.171296
# month_diff_mean                               10.8788              14.7778
# month_diff_std                               0.328875             0.416705
# month_diff_var                               0.108159             0.173643
# category_1_N_sum                                   66                  214
# category_1_N_mean                                   1             0.990741
# category_1_Y_sum                                    0                    2
# category_1_Y_mean                                   0           0.00925926
# category_2_mean                               2.93939              1.49074
# category_2_sum                                    194                  322
# category_2_na_mean                                  0             0.527778
# category_2_na_sum                                   0                  114
# category_3_A_mean                            0.984848             0.976852
# category_3_A_sum                                   65                  211
# category_3_B_mean                           0.0151515            0.0231481
# category_3_B_sum                                    1                    5
# category_3_C_mean                                   0                    0
# category_3_C_sum                                    0                    0
# category_2_mean2_mean                        0.177169          -0.00261963
# category_2_na_mean2_mean                    0.0755954            -0.151411
# category_3_nan_mean2_mean                   0.0362652            0.0362652
# category_3_A_mean2_mean                      0.351446             0.345914
# category_3_B_mean2_mean                      0.320589             0.314702
# category_3_C_mean2_mean                     0.0316902            0.0316902
# inverse_avg_transactions_per_day               6.0303              1.31019
# days_since_last_transaction                       331                  439
#
#                                                     4
# card_id                               C_ID_000183fdda
# transactions_count                                144
# city_id_nunique                                     9
# merchant_category_id_nunique                       36
# merchant_id_nunique                                73
# state_id_nunique                                    7
# subsector_id_nunique                               21
# authorized_flag_Y_mean                       0.951389
# authorized_flag_Y_sum                             137
# authorized_flag_N_mean                      0.0486111
# authorized_flag_N_sum                               7
# purchase_amount_sum                          -68.8379
# purchase_amount_max                           2.76479
# purchase_amount_min                         -0.737892
# purchase_amount_mean                        -0.478041
# purchase_amount_std                          0.524948
# purchase_amount_median                      -0.661294
# installments_sum                                  264
# installments_max                                   10
# installments_mean                             1.83333
# installments_std                              2.11885
# installments_median                                 1
# month_lag_sum                                    -353
# month_lag_max                                       0
# month_lag_min                                      -6
# month_lag_mean                               -2.45139
# month_lag_std                                 1.89526
# month_lag_median                                   -2
# purchase_date_amin                2017-08-07 09:49:14
# purchase_date_amax                2018-02-25 20:57:08
# purchase_date_ptp                                 202
# card_id_size                                      144
# purchased_on_weekend_sum                           33
# purchased_on_weekend_mean                    0.229167
# month_diff_mean                               10.7292
# month_diff_std                               0.445941
# month_diff_var                               0.198864
# category_1_N_sum                                  140
# category_1_N_mean                            0.972222
# category_1_Y_sum                                    4
# category_1_Y_mean                           0.0277778
# category_2_mean                               2.85417
# category_2_sum                                    411
# category_2_na_mean                          0.0277778
# category_2_na_sum                                   4
# category_3_A_mean                                   0
# category_3_A_sum                                    0
# category_3_B_mean                            0.715278
# category_3_B_sum                                  103
# category_3_C_mean                            0.256944
# category_3_C_sum                                   37
# category_2_mean2_mean                        0.167912
# category_2_na_mean2_mean                    0.0636477
# category_3_nan_mean2_mean                   0.0368813
# category_3_A_mean2_mean                     -0.329781
# category_3_B_mean2_mean                     -0.194915
# category_3_C_mean2_mean                     0.0507896
# inverse_avg_transactions_per_day              1.40278
# days_since_last_transaction                       322

# %%
new_trans_agg_proc.head().T
# Out:
#                                                     0                    1  \
# card_id                               C_ID_00007093c1      C_ID_0001238066
# transactions_count                                  2                   26
# city_id_nunique                                     2                    8
# merchant_category_id_nunique                        2                   15
# merchant_id_nunique                                 2                   25
# state_id_nunique                                    2                    4
# subsector_id_nunique                                2                    9
# authorized_flag_Y_mean                              1                    1
# authorized_flag_Y_sum                               2                   26
# authorized_flag_N_mean                              0                    0
# authorized_flag_N_sum                               0                    0
# purchase_amount_sum                          -1.32852             -14.8501
# purchase_amount_max                         -0.656749           -0.0783182
# purchase_amount_min                         -0.671775            -0.740897
# purchase_amount_mean                        -0.664262            -0.571156
# purchase_amount_std                         0.0106254             0.173436
# purchase_amount_median                      -0.664262            -0.649235
# installments_sum                                    2                   42
# installments_max                                    1                   10
# installments_mean                                   1              1.61538
# installments_std                                    0              2.07994
# installments_median                                 1                    1
# month_lag_sum                                       4                   35
# month_lag_max                                       2                    2
# month_lag_min                                       2                    1
# month_lag_mean                                      2              1.34615
# month_lag_std                                       0             0.485165
# month_lag_median                                    2                    1
# purchase_date_amin                2018-04-03 11:13:35  2018-03-01 16:48:27
# purchase_date_amax                2018-04-09 16:23:59  2018-04-30 19:57:30
# purchase_date_ptp                                   6                   60
# card_id_size                                        2                   26
# purchased_on_weekend_sum                            0                   12
# purchased_on_weekend_mean                           0             0.461538
# month_diff_mean                                    11                 10.5
# month_diff_std                                      0             0.509902
# month_diff_var                                      0                 0.26
# category_1_N_sum                                    2                   24
# category_1_N_mean                                   1             0.923077
# category_1_Y_sum                                    0                    2
# category_1_Y_mean                                   0            0.0769231
# category_2_mean                                     2              1.46154
# category_2_sum                                      4                   38
# category_2_na_mean                                  0             0.115385
# category_2_na_sum                                   0                    3
# category_3_A_mean                                   0                    0
# category_3_A_sum                                    0                    0
# category_3_B_mean                                   1             0.807692
# category_3_B_sum                                    2                   21
# category_3_C_mean                                   0             0.153846
# category_3_C_sum                                    0                    4
# category_2_mean2_mean                       -0.550506            -0.550028
# category_2_na_mean2_mean                    -0.561925            -0.539717
# category_3_nan_mean2_mean                   -0.568123            -0.544963
# category_3_A_mean2_mean                     -0.480041            -0.480041
# category_3_B_mean2_mean                     -0.606486            -0.587887
# category_3_C_mean2_mean                     -0.599212            -0.501224
# inverse_avg_transactions_per_day                    3              2.30769
# days_since_last_transaction                       280                  258
#
#                                                     2                    3  \
# card_id                               C_ID_0001506ef0      C_ID_0001793786
# transactions_count                                  2                   31
# city_id_nunique                                     1                    7
# merchant_category_id_nunique                        2                   21
# merchant_id_nunique                                 1                   31
# state_id_nunique                                    1                    5
# subsector_id_nunique                                2                   14
# authorized_flag_Y_mean                              1                    1
# authorized_flag_Y_sum                               2                   31
# authorized_flag_N_mean                              0                    0
# authorized_flag_N_sum                               0                    0
# purchase_amount_sum                          -1.44735             -0.22962
# purchase_amount_max                         -0.715352              3.12993
# purchase_amount_min                         -0.732001            -0.737892
# purchase_amount_mean                        -0.723677           -0.0074071
# purchase_amount_std                         0.0117729             0.947223
# purchase_amount_median                      -0.723677            -0.372748
# installments_sum                                    0                    0
# installments_max                                    0                    0
# installments_mean                                   0                    0
# installments_std                                    0                    0
# installments_median                                 0                    0
# month_lag_sum                                       2                   41
# month_lag_max                                       1                    2
# month_lag_min                                       1                    1
# month_lag_mean                                      1              1.32258
# month_lag_std                                       0             0.475191
# month_lag_median                                    1                    1
# purchase_date_amin                2018-03-16 22:21:58  2017-11-15 15:44:20
# purchase_date_amax                2018-03-22 09:14:30  2017-12-31 17:35:56
# purchase_date_ptp                                   5                   46
# card_id_size                                        2                   31
# purchased_on_weekend_sum                            0                   14
# purchased_on_weekend_mean                           0             0.451613
# month_diff_mean                                  10.5              14.2903
# month_diff_std                               0.707107             0.461414
# month_diff_var                                    0.5             0.212903
# category_1_N_sum                                    2                   31
# category_1_N_mean                                   1                    1
# category_1_Y_sum                                    0                    0
# category_1_Y_mean                                   0                    0
# category_2_mean                                     3              1.70968
# category_2_sum                                      6                   53
# category_2_na_mean                                  0            0.0645161
# category_2_na_sum                                   0                    2
# category_3_A_mean                                   1                    1
# category_3_A_sum                                    2                   31
# category_3_B_mean                                   0                    0
# category_3_B_sum                                    0                    0
# category_3_C_mean                                   0                    0
# category_3_C_sum                                    0                    0
# category_2_mean2_mean                       -0.550852            -0.551649
# category_2_na_mean2_mean                    -0.561925            -0.549508
# category_3_nan_mean2_mean                   -0.568123            -0.568123
# category_3_A_mean2_mean                     -0.631014            -0.631014
# category_3_B_mean2_mean                     -0.509773            -0.509773
# category_3_C_mean2_mean                     -0.599212            -0.599212
# inverse_avg_transactions_per_day                  2.5              1.48387
# days_since_last_transaction                       298                  379
#
#                                                     4
# card_id                               C_ID_000183fdda
# transactions_count                                 11
# city_id_nunique                                     2
# merchant_category_id_nunique                        9
# merchant_id_nunique                                11
# state_id_nunique                                    2
# subsector_id_nunique                                6
# authorized_flag_Y_mean                              1
# authorized_flag_Y_sum                              11
# authorized_flag_N_mean                              0
# authorized_flag_N_sum                               0
# purchase_amount_sum                          -6.59078
# purchase_amount_max                          -0.10768
# purchase_amount_min                         -0.732332
# purchase_amount_mean                        -0.599162
# purchase_amount_std                          0.182877
# purchase_amount_median                      -0.665765
# installments_sum                                   16
# installments_max                                    4
# installments_mean                             1.45455
# installments_std                              1.29334
# installments_median                                 1
# month_lag_sum                                      14
# month_lag_max                                       2
# month_lag_min                                       1
# month_lag_mean                                1.27273
# month_lag_std                                0.467099
# month_lag_median                                    1
# purchase_date_amin                2018-03-02 12:26:26
# purchase_date_amax                2018-04-30 14:59:53
# purchase_date_ptp                                  59
# card_id_size                                       11
# purchased_on_weekend_sum                            2
# purchased_on_weekend_mean                    0.181818
# month_diff_mean                               10.7273
# month_diff_std                               0.467099
# month_diff_var                               0.218182
# category_1_N_sum                                   11
# category_1_N_mean                                   1
# category_1_Y_sum                                    0
# category_1_Y_mean                                   0
# category_2_mean                                     3
# category_2_sum                                     33
# category_2_na_mean                                  0
# category_2_na_sum                                   0
# category_3_A_mean                                   0
# category_3_A_sum                                    0
# category_3_B_mean                            0.545455
# category_3_B_sum                                    6
# category_3_C_mean                            0.363636
# category_3_C_sum                                    4
# category_2_mean2_mean                       -0.550852
# category_2_na_mean2_mean                    -0.561925
# category_3_nan_mean2_mean                   -0.513382
# category_3_A_mean2_mean                     -0.480041
# category_3_B_mean2_mean                     -0.562525
# category_3_C_mean2_mean                     -0.367604
# inverse_avg_transactions_per_day              5.36364
# days_since_last_transaction                       259

# %%
train_df = join_dfs(train, new_trans_agg_proc, left_on='card_id')

# %%
train_df = join_dfs(train_df, hist_trans_agg, left_on='card_id', suffix='_old')

# %%
test_df = join_dfs(test, new_hist_trans_agg, left_on='card_id')
test_df = join_dfs(test_df, hist_trans_agg, left_on='card_id', suffix='_old')

# %%
test_df.shape, train_df.shape
# Out:
# ((123623, 134), (201917, 135))

# %%
train_df.head().T
# Out:
#                                                         0  \
# first_active_month                    2017-06-01 00:00:00
# card_id                                   C_ID_92a2005557
# feature_1                                               5
# feature_2                                               2
# feature_3                                               1
# target                                          -0.820283
# first_active_monthYear                               2017
# first_active_monthMonth                                 6
# first_active_monthWeek                                 22
# first_active_monthDay                                   1
# first_active_monthDayofweek                             3
# first_active_monthDayofyear                           152
# first_active_monthIs_month_end                      False
# first_active_monthIs_month_start                     True
# first_active_monthIs_quarter_end                    False
# first_active_monthIs_quarter_start                  False
# first_active_monthIs_year_end                       False
# first_active_monthIs_year_start                     False
# first_active_monthElapsed                      1496275200
# transactions_count                                     23
# city_id_nunique                                         3
# merchant_category_id_nunique                           14
# merchant_id_nunique                                    23
# state_id_nunique                                        1
# subsector_id_nunique                                   10
# authorized_flag_Y_mean                                  1
# authorized_flag_Y_sum                                  23
# authorized_flag_N_mean                                  0
# authorized_flag_N_sum                                   0
# purchase_amount_sum                              -13.2442
# ...                                                   ...
# purchase_date_amax_old                2018-02-25 09:31:15
# purchase_date_ptp_old                                 242
# card_id_size_old                                      260
# purchased_on_weekend_sum_old                           90
# purchased_on_weekend_mean_old                    0.346154
# month_diff_mean_old                               10.7231
# month_diff_std_old                               0.448341
# month_diff_var_old                                0.20101
# category_1_N_sum_old                                  260
# category_1_N_mean_old                                   1
# category_1_Y_sum_old                                    0
# category_1_Y_mean_old                                   0
# category_2_mean_old                               1.04615
# category_2_sum_old                                    272
# category_2_na_mean_old                                  0
# category_2_na_sum_old                                   0
# category_3_A_mean_old                            0.984615
# category_3_A_sum_old                                  256
# category_3_B_mean_old                           0.0153846
# category_3_B_sum_old                                    4
# category_3_C_mean_old                                   0
# category_3_C_sum_old                                    0
# category_2_mean2_mean_old                       0.0725022
# category_2_na_mean2_mean_old                    0.0755954
# category_3_nan_mean2_mean_old                   0.0362652
# category_3_A_mean2_mean_old                      0.351284
# category_3_B_mean2_mean_old                      0.320418
# category_3_C_mean2_mean_old                     0.0316902
# inverse_avg_transactions_per_day_old             0.930769
# days_since_last_transaction_old                       323
#
#                                                         1  \
# first_active_month                    2017-01-01 00:00:00
# card_id                                   C_ID_3d0044924f
# feature_1                                               4
# feature_2                                               1
# feature_3                                               0
# target                                           0.392913
# first_active_monthYear                               2017
# first_active_monthMonth                                 1
# first_active_monthWeek                                 52
# first_active_monthDay                                   1
# first_active_monthDayofweek                             6
# first_active_monthDayofyear                             1
# first_active_monthIs_month_end                      False
# first_active_monthIs_month_start                     True
# first_active_monthIs_quarter_end                    False
# first_active_monthIs_quarter_start                   True
# first_active_monthIs_year_end                       False
# first_active_monthIs_year_start                      True
# first_active_monthElapsed                      1483228800
# transactions_count                                      6
# city_id_nunique                                         1
# merchant_category_id_nunique                            5
# merchant_id_nunique                                     6
# state_id_nunique                                        1
# subsector_id_nunique                                    4
# authorized_flag_Y_mean                                  1
# authorized_flag_Y_sum                                   6
# authorized_flag_N_mean                                  0
# authorized_flag_N_sum                                   0
# purchase_amount_sum                              -4.35573
# ...                                                   ...
# purchase_date_amax_old                2018-01-31 22:31:09
# purchase_date_ptp_old                                 390
# card_id_size_old                                      350
# purchased_on_weekend_sum_old                          132
# purchased_on_weekend_mean_old                    0.377143
# month_diff_mean_old                               11.6771
# month_diff_std_old                               0.468238
# month_diff_var_old                               0.219247
# category_1_N_sum_old                                  319
# category_1_N_mean_old                            0.911429
# category_1_Y_sum_old                                   31
# category_1_Y_mean_old                           0.0885714
# category_2_mean_old                                     1
# category_2_sum_old                                    350
# category_2_na_mean_old                          0.0885714
# category_2_na_sum_old                                  31
# category_3_A_mean_old                                   0
# category_3_A_sum_old                                    0
# category_3_B_mean_old                            0.788571
# category_3_B_sum_old                                  276
# category_3_C_mean_old                            0.205714
# category_3_C_sum_old                                   72
# category_2_mean2_mean_old                       0.0745679
# category_2_na_mean2_mean_old                    0.0374992
# category_3_nan_mean2_mean_old                   0.0363919
# category_3_A_mean2_mean_old                     -0.329781
# category_3_B_mean2_mean_old                     -0.248881
# category_3_C_mean2_mean_old                     0.0469815
# inverse_avg_transactions_per_day_old              1.11429
# days_since_last_transaction_old                       347
#
#                                                         2  \
# first_active_month                    2016-08-01 00:00:00
# card_id                                   C_ID_d639edf6cd
# feature_1                                               2
# feature_2                                               2
# feature_3                                               0
# target                                           0.688056
# first_active_monthYear                               2016
# first_active_monthMonth                                 8
# first_active_monthWeek                                 31
# first_active_monthDay                                   1
# first_active_monthDayofweek                             0
# first_active_monthDayofyear                           214
# first_active_monthIs_month_end                      False
# first_active_monthIs_month_start                     True
# first_active_monthIs_quarter_end                    False
# first_active_monthIs_quarter_start                  False
# first_active_monthIs_year_end                       False
# first_active_monthIs_year_start                     False
# first_active_monthElapsed                      1470009600
# transactions_count                                      1
# city_id_nunique                                         1
# merchant_category_id_nunique                            1
# merchant_id_nunique                                     1
# state_id_nunique                                        1
# subsector_id_nunique                                    1
# authorized_flag_Y_mean                                  1
# authorized_flag_Y_sum                                   1
# authorized_flag_N_mean                                  0
# authorized_flag_N_sum                                   0
# purchase_amount_sum                             -0.700326
# ...                                                   ...
# purchase_date_amax_old                2018-02-27 19:08:25
# purchase_date_ptp_old                                 412
# card_id_size_old                                       43
# purchased_on_weekend_sum_old                           11
# purchased_on_weekend_mean_old                    0.255814
# month_diff_mean_old                               10.6279
# month_diff_std_old                               0.489083
# month_diff_var_old                               0.239203
# category_1_N_sum_old                                   43
# category_1_N_mean_old                                   1
# category_1_Y_sum_old                                    0
# category_1_Y_mean_old                                   0
# category_2_mean_old                               4.62791
# category_2_sum_old                                    199
# category_2_na_mean_old                                  0
# category_2_na_sum_old                                   0
# category_3_A_mean_old                                   1
# category_3_A_sum_old                                   43
# category_3_B_mean_old                                   0
# category_3_B_sum_old                                    0
# category_3_C_mean_old                                   0
# category_3_C_sum_old                                    0
# category_2_mean2_mean_old                      -0.0878033
# category_2_na_mean2_mean_old                    0.0755954
# category_3_nan_mean2_mean_old                   0.0362652
# category_3_A_mean2_mean_old                      0.361926
# category_3_B_mean2_mean_old                      0.331746
# category_3_C_mean2_mean_old                     0.0316902
# inverse_avg_transactions_per_day_old               9.5814
# days_since_last_transaction_old                       320
#
#                                                         3                    4
# first_active_month                    2017-09-01 00:00:00  2017-11-01 00:00:00
# card_id                                   C_ID_186d6a6901      C_ID_cdbd2c0db2
# feature_1                                               4                    1
# feature_2                                               3                    3
# feature_3                                               0                    0
# target                                           0.142495            -0.159749
# first_active_monthYear                               2017                 2017
# first_active_monthMonth                                 9                   11
# first_active_monthWeek                                 35                   44
# first_active_monthDay                                   1                    1
# first_active_monthDayofweek                             4                    2
# first_active_monthDayofyear                           244                  305
# first_active_monthIs_month_end                      False                False
# first_active_monthIs_month_start                     True                 True
# first_active_monthIs_quarter_end                    False                False
# first_active_monthIs_quarter_start                  False                False
# first_active_monthIs_year_end                       False                False
# first_active_monthIs_year_start                     False                False
# first_active_monthElapsed                      1504224000           1509494400
# transactions_count                                      7                   36
# city_id_nunique                                         2                    5
# merchant_category_id_nunique                            6                   17
# merchant_id_nunique                                     7                   36
# state_id_nunique                                        2                    5
# subsector_id_nunique                                    5                   10
# authorized_flag_Y_mean                                  1                    1
# authorized_flag_Y_sum                                   7                   36
# authorized_flag_N_mean                                  0                    0
# authorized_flag_N_sum                                   0                    0
# purchase_amount_sum                              -4.65437             -19.9262
# ...                                                   ...                  ...
# purchase_date_amax_old                2018-02-28 11:44:40  2018-02-28 20:40:41
# purchase_date_ptp_old                                 154                  108
# card_id_size_old                                       77                  133
# purchased_on_weekend_sum_old                           11                   42
# purchased_on_weekend_mean_old                    0.142857             0.315789
# month_diff_mean_old                               10.6104              10.5714
# month_diff_std_old                                0.49086             0.496743
# month_diff_var_old                               0.240943             0.246753
# category_1_N_sum_old                                   65                  118
# category_1_N_mean_old                            0.844156             0.887218
# category_1_Y_sum_old                                   12                   15
# category_1_Y_mean_old                            0.155844             0.112782
# category_2_mean_old                               3.06494              3.44361
# category_2_sum_old                                    236                  458
# category_2_na_mean_old                           0.155844             0.112782
# category_2_na_sum_old                                  12                   15
# category_3_A_mean_old                                   0                    0
# category_3_A_sum_old                                    0                    0
# category_3_B_mean_old                            0.883117             0.947368
# category_3_B_sum_old                                   68                  126
# category_3_C_mean_old                           0.0909091            0.0526316
# category_3_C_sum_old                                    7                    7
# category_2_mean2_mean_old                      -0.0861658            -0.114647
# category_2_na_mean2_mean_old                   0.00856402            0.0270859
# category_3_nan_mean2_mean_old                   0.0368413            0.0362652
# category_3_A_mean2_mean_old                     -0.329781            -0.329781
# category_3_B_mean2_mean_old                     -0.318495            -0.365803
# category_3_C_mean2_mean_old                     0.0384477            0.0356025
# inverse_avg_transactions_per_day_old                    2              0.81203
# days_since_last_transaction_old                       320                  319
#
# [135 rows x 5 columns]

# %% [markdown]
# ### Add extra columns like age, total transactions, installments, purchase amount, first buy etc

# %%
display(train_df.columns.values)
# Out:
# array(['first_active_month', 'card_id', 'feature_1', 'feature_2', 'feature_3', 'target',
#        'first_active_monthYear', 'first_active_monthMonth', 'first_active_monthWeek',
#        'first_active_monthDay', 'first_active_monthDayofweek', 'first_active_monthDayofyear',
#        'first_active_monthIs_month_end', 'first_active_monthIs_month_start',
#        'first_active_monthIs_quarter_end', 'first_active_monthIs_quarter_start',
#        'first_active_monthIs_year_end', 'first_active_monthIs_year_start', 'first_active_monthElapsed',
#        'transactions_count', 'city_id_nunique', 'merchant_category_id_nunique', 'merchant_id_nunique',
#        'state_id_nunique', 'subsector_id_nunique', 'authorized_flag_Y_mean', 'authorized_flag_Y_sum',
#        'authorized_flag_N_mean', 'authorized_flag_N_sum', 'purchase_amount_sum', 'purchase_amount_max',
#        'purchase_amount_min', 'purchase_amount_mean', 'purchase_amount_std', 'purchase_amount_median',
#        'installments_sum', 'installments_max', 'installments_mean', 'installments_std',
#        'installments_median', 'month_lag_sum', 'month_lag_max', 'month_lag_min', 'month_lag_mean',
#        'month_lag_std', 'month_lag_median', 'purchase_date_amin', 'purchase_date_amax', 'purchase_date_ptp',
#        'card_id_size', 'purchased_on_weekend_sum', 'purchased_on_weekend_mean', 'month_diff_mean',
#        'month_diff_std', 'month_diff_var', 'category_1_N_sum', 'category_1_N_mean', 'category_1_Y_sum',
#        'category_1_Y_mean', 'category_2_mean', 'category_2_sum', 'category_2_na_mean', 'category_2_na_sum',
#        'category_3_A_mean', 'category_3_A_sum', 'category_3_B_mean', 'category_3_B_sum', 'category_3_C_mean',
#        'category_3_C_sum', 'category_2_mean2_mean', 'category_2_na_mean2_mean', 'category_3_nan_mean2_mean',
#        'category_3_A_mean2_mean', 'category_3_B_mean2_mean', 'category_3_C_mean2_mean',
#        'inverse_avg_transactions_per_day', 'days_since_last_transaction', 'transactions_count_old',
#        'city_id_nunique_old', 'merchant_category_id_nunique_old', 'merchant_id_nunique_old',
#        'state_id_nunique_old', 'subsector_id_nunique_old', 'authorized_flag_Y_mean_old',
#        'authorized_flag_Y_sum_old', 'authorized_flag_N_mean_old', 'authorized_flag_N_sum_old',
#        'purchase_amount_sum_old', 'purchase_amount_max_old', 'purchase_amount_min_old',
#        'purchase_amount_mean_old', 'purchase_amount_std_old', 'purchase_amount_median_old',
#        'installments_sum_old', 'installments_max_old', 'installments_mean_old', 'installments_std_old',
#        'installments_median_old', 'month_lag_sum_old', 'month_lag_max_old', 'month_lag_min_old',
#        'month_lag_mean_old', 'month_lag_std_old', 'month_lag_median_old', 'purchase_date_amin_old',
#        'purchase_date_amax_old', 'purchase_date_ptp_old', 'card_id_size_old', 'purchased_on_weekend_sum_old',
#        'purchased_on_weekend_mean_old', 'month_diff_mean_old', 'month_diff_std_old', 'month_diff_var_old',
#        'category_1_N_sum_old', 'category_1_N_mean_old', 'category_1_Y_sum_old', 'category_1_Y_mean_old',
#        'category_2_mean_old', 'category_2_sum_old', 'category_2_na_mean_old', 'category_2_na_sum_old',
#        'category_3_A_mean_old', 'category_3_A_sum_old', 'category_3_B_mean_old', 'category_3_B_sum_old',
#        'category_3_C_mean_old', 'category_3_C_sum_old', 'category_2_mean2_mean_old',
#        'category_2_na_mean2_mean_old', 'category_3_nan_mean2_mean_old', 'category_3_A_mean2_mean_old',
#        'category_3_B_mean2_mean_old', 'category_3_C_mean2_mean_old', 'inverse_avg_transactions_per_day_old',
#        'days_since_last_transaction_old'], dtype=object)

# %%
for df in [train_df, test_df]:
    df['elapsed_time'] = (datetime.datetime.today() - df['first_active_month']).dt.days
    df['card_id_total'] = df['card_id_size']+df['card_id_size_old']
    df["authorized_flag_Y_mean_total"]= df["authorized_flag_Y_mean_old"]+ df["authorized_flag_Y_mean"]
    df["authorized_flag_Y_sum_total"]= df["authorized_flag_Y_sum_old"]+ df["authorized_flag_Y_sum"]
    df["authorized_flag_N_mean_total"]= df["authorized_flag_N_mean_old"]+ df["authorized_flag_N_mean"]
    df["authorized_flag_N_sum_total"]= df["authorized_flag_N_sum_old"]+ df["authorized_flag_N_sum"]
    df["month_lag_sum_total"]= df["month_lag_sum_old"]+ df["month_lag_sum"]
    df['purchase_amount_total'] = df['purchase_amount_sum']+df['purchase_amount_sum_old']
    df['installments_total'] = df['installments_sum'] + df['installments_sum_old']
    df["category_1_Y_sum_total"] = df["category_1_Y_sum_old"]+ df["category_1_Y_sum"]
    df["category_2_sum_total"]= df["category_2_sum_old"]+ df["category_2_sum"]
    df["category_3_A_total"]= df["category_3_A_sum"]+ df["category_3_A_sum_old"]
    df["category_3_B_total"]= df["category_3_B_sum"]+ df["category_3_B_sum_old"]
    df["category_3_C_total"]= df["category_3_C_sum"]+ df["category_3_C_sum_old"]
    df['hist_first_buy'] = (df['purchase_date_amin_old'] - df['first_active_month']).dt.days
    df['new_first_buy'] = (df['purchase_date_amin'] - df['first_active_month']).dt.days

# %% [markdown]
# ### Mark the outliers

# %%
train_df['outliers'] = 0
train_df.loc[train_df['target'] < -30, 'outliers'] = 1
train_df['outliers'].value_counts()
# Out:
# 0    199710
# 1      2207
# Name: outliers, dtype: int64

# %% [markdown]
# ### Target encode the outliers

# %%
for f in ['feature_1','feature_2','feature_3']:
    order_label = train_df.groupby([f])['outliers'].mean()
    train_df[f] = train_df[f].map(order_label)
    test_df[f] = test_df[f].map(order_label)

# %%
train_df.to_feather('train_df_proc')
test_df.to_feather('test_df_proc')
