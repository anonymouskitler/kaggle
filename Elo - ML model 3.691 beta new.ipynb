# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-imports-and-dfs" data-toc-modified-id="Load-imports-and-dfs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load imports and dfs</a></span></li><li><span><a href="#Blend" data-toc-modified-id="Blend-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Blend</a></span></li></ul></div>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# ### Load imports and dfs

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import warnings
import gc

# %%
train_df2 = feather.read_dataframe('train_df_3691')
test_df2 = feather.read_dataframe('test_df_3691')

# %%
for df in [train_df2, test_df2]:
    for f in ['purchase_date_max','purchase_date_min','purchase_date_max_old',\
                     'purchase_date_min_old']:
        df[f] = df[f].astype(np.int64) * 1e-9

# %%
cols_excluded = ['purchase_date_max', 'purchase_date_max_old', 'card_id', 'first_active_month',
                 'target','outliers','card_id_size', 'card_id_size_old', 
                 'purchase_date_min', 'purchase_date_min_old','first_active_monthYear',
                 'first_active_monthMonth',
                 'first_active_monthWeek',
                 'first_active_monthDay',
                 'first_active_monthDayofweek',
                 'first_active_monthDayofyear',
                 'first_active_monthIs_month_end',
                 'first_active_monthIs_month_start',
                 'first_active_monthIs_quarter_end',
                 'first_active_monthIs_quarter_start',
                 'first_active_monthIs_year_end',
                 'first_active_monthIs_year_start']

# %%
df_train_columns = [c for c in train_df2.columns if c not in cols_excluded]
target = train_df2['target']

# %%
train_df2.shape, test_df2.shape
# Out:
# ((201917, 203), (123623, 201))

# %%
target.shape
# Out:
# (201917,)

# %%
del train_df2['target']

# %%
len(df_train_columns)
# Out:
# 181

# %%
df_train_columns
# Out:
# ['feature_1',
#  'feature_2',
#  'feature_3',
#  'first_active_monthElapsed',
#  'transactions_count',
#  'subsector_id_nunique',
#  'merchant_id_nunique',
#  'merchant_category_id_nunique',
#  'purchase_Month_mean',
#  'purchase_Month_min',
#  'purchase_Month_max',
#  'purchase_Week_nunique',
#  'purchase_Week_mean',
#  'purchase_Week_min',
#  'purchase_Week_max',
#  'purchase_Dayofweek_mean',
#  'purchase_Dayofweek_min',
#  'purchase_Dayofweek_max',
#  'purchase_Day_nunique',
#  'purchase_Day_mean',
#  'purchase_Day_min',
#  'purchase_Day_max',
#  'purchase_Hour_nunique',
#  'purchase_Hour_mean',
#  'purchase_Hour_min',
#  'purchase_Hour_max',
#  'purchase_amount_sum',
#  'purchase_amount_max',
#  'purchase_amount_min',
#  'purchase_amount_mean',
#  'purchase_amount_var',
#  'purchase_amount_skew',
#  'installments_sum',
#  'installments_max',
#  'installments_mean',
#  'installments_var',
#  'installments_skew',
#  'month_lag_max',
#  'month_lag_min',
#  'month_lag_mean',
#  'month_lag_var',
#  'month_lag_skew',
#  'month_diff_mean',
#  'month_diff_var',
#  'month_diff_skew',
#  'purchased_on_weekend_mean',
#  'category_1_mean',
#  'category_2_mean',
#  'category_3_mean',
#  'card_id_count',
#  'price_mean',
#  'price_max',
#  'price_min',
#  'price_var',
#  'Christmas_Day_2017_mean',
#  'Children_day_2017_mean',
#  'Black_Friday_2017_mean',
#  'Mothers_Day_2018_mean',
#  'duration_mean',
#  'duration_min',
#  'duration_max',
#  'duration_var',
#  'duration_skew',
#  'amount_month_ratio_mean',
#  'amount_month_ratio_min',
#  'amount_month_ratio_max',
#  'amount_month_ratio_var',
#  'amount_month_ratio_skew',
#  'category_2_mean_mean',
#  'category_3_mean_mean',
#  'purchase_date_diff',
#  'purchase_date_average',
#  'purchase_date_uptonow',
#  'purchase_date_uptomin',
#  'transactions_count_old',
#  'subsector_id_nunique_old',
#  'merchant_id_nunique_old',
#  'merchant_category_id_nunique_old',
#  'purchase_Month_nunique',
#  'purchase_Month_mean_old',
#  'purchase_Month_min_old',
#  'purchase_Month_max_old',
#  'purchase_Week_nunique_old',
#  'purchase_Week_mean_old',
#  'purchase_Week_min_old',
#  'purchase_Week_max_old',
#  'purchase_Dayofweek_mean_old',
#  'purchase_Day_nunique_old',
#  'purchase_Day_mean_old',
#  'purchase_Day_min_old',
#  'purchase_Hour_nunique_old',
#  'purchase_Hour_mean_old',
#  'purchase_Hour_min_old',
#  'purchase_Hour_max_old',
#  'purchase_amount_sum_old',
#  'purchase_amount_max_old',
#  'purchase_amount_min_old',
#  'purchase_amount_mean_old',
#  'purchase_amount_var_old',
#  'purchase_amount_skew_old',
#  'installments_sum_old',
#  'installments_max_old',
#  'installments_mean_old',
#  'installments_var_old',
#  'installments_skew_old',
#  'month_lag_max_old',
#  'month_lag_min_old',
#  'month_lag_mean_old',
#  'month_lag_var_old',
#  'month_lag_skew_old',
#  'month_diff_max',
#  'month_diff_min',
#  'month_diff_mean_old',
#  'month_diff_var_old',
#  'month_diff_skew_old',
#  'authorized_flag_mean',
#  'purchased_on_weekend_mean_old',
#  'category_1_mean_old',
#  'category_2_mean_old',
#  'category_3_mean_old',
#  'card_id_count_old',
#  'price_sum',
#  'price_mean_old',
#  'price_max_old',
#  'price_min_old',
#  'price_var_old',
#  'Christmas_Day_2017_mean_old',
#  'Mothers_Day_2017_mean',
#  'fathers_day_2017_mean',
#  'Children_day_2017_mean_old',
#  'Valentine_Day_2017_mean',
#  'Black_Friday_2017_mean_old',
#  'Mothers_Day_2018_mean_old',
#  'duration_mean_old',
#  'duration_min_old',
#  'duration_max_old',
#  'duration_var_old',
#  'duration_skew_old',
#  'amount_month_ratio_mean_old',
#  'amount_month_ratio_min_old',
#  'amount_month_ratio_max_old',
#  'amount_month_ratio_var_old',
#  'amount_month_ratio_skew_old',
#  'category_2_mean_mean_old',
#  'category_3_mean_mean_old',
#  'purchase_date_diff_old',
#  'purchase_date_average_old',
#  'purchase_date_uptonow_old',
#  'purchase_date_uptomin_old',
#  'card_id_total',
#  'card_id_count_total',
#  'card_id_count_ratio',
#  'purchase_amount_total',
#  'purchase_amount_total_mean',
#  'purchase_amount_total_max',
#  'purchase_amount_total_min',
#  'purchase_amount_sum_ratio',
#  'hist_first_buy',
#  'new_first_buy',
#  'hist_last_buy',
#  'new_last_buy',
#  'month_diff_ratio',
#  'installments_total',
#  'installments_ratio',
#  'price_total',
#  'CLV',
#  'CLV_old',
#  'CLV_ratio',
#  'quarter',
#  'elapsed_time',
#  'days_feature1',
#  'days_feature2',
#  'days_feature3',
#  'days_feature1_ratio',
#  'days_feature2_ratio',
#  'days_feature3_ratio',
#  'feature_sum',
#  'feature_mean',
#  'feature_max',
#  'feature_min',
#  'feature_var']

# %%
n_fold =5

# %%
param = {
        'task': 'train',
        'boosting': 'goss',
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.01,
        'subsample': 0.9855232997390695,
        'max_depth': 7,
        'top_rate': 0.9064148448434349,
        'num_leaves': 123,
        'min_child_weight': 41.9612869171337,
        'other_rate': 0.0721768246018207,
        'reg_alpha': 9.677537745007898,
        'colsample_bytree': 0.5665320670155495,
        'min_split_gain': 9.820197773625843,
        'reg_lambda': 8.2532317400459,
        'min_data_in_leaf': 21,
        'verbose': -1,
        'seed':int(2**n_fold),
        'bagging_seed':int(2**n_fold),
        'drop_seed':int(2**n_fold)
        }
folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=4590)
oof = np.zeros(len(train_df2))
predictions = np.zeros(len(test_df2))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df2,train_df2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(train_df2.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df2.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(train_df2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test_df2[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.64895	valid_1's rmse: 3.71321
# [200]	training's rmse: 3.56154	valid_1's rmse: 3.6754
# [300]	training's rmse: 3.50825	valid_1's rmse: 3.66249
# [400]	training's rmse: 3.47226	valid_1's rmse: 3.65733
# [500]	training's rmse: 3.44095	valid_1's rmse: 3.65516
# [600]	training's rmse: 3.41556	valid_1's rmse: 3.65344
# [700]	training's rmse: 3.39453	valid_1's rmse: 3.65281
# [800]	training's rmse: 3.37522	valid_1's rmse: 3.65213
# [900]	training's rmse: 3.35713	valid_1's rmse: 3.65221
# [1000]	training's rmse: 3.33981	valid_1's rmse: 3.65217
# [1100]	training's rmse: 3.32304	valid_1's rmse: 3.65241
# Early stopping, best iteration is:
# [950]	training's rmse: 3.34887	valid_1's rmse: 3.65192
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.64968	valid_1's rmse: 3.70194
# [200]	training's rmse: 3.56091	valid_1's rmse: 3.6661
# [300]	training's rmse: 3.50831	valid_1's rmse: 3.65502
# [400]	training's rmse: 3.47091	valid_1's rmse: 3.65197
# [500]	training's rmse: 3.44058	valid_1's rmse: 3.65009
# [600]	training's rmse: 3.41717	valid_1's rmse: 3.64919
# [700]	training's rmse: 3.39471	valid_1's rmse: 3.64835
# [800]	training's rmse: 3.37616	valid_1's rmse: 3.64787
# [900]	training's rmse: 3.3565	valid_1's rmse: 3.64781
# [1000]	training's rmse: 3.33843	valid_1's rmse: 3.64774
# Early stopping, best iteration is:
# [837]	training's rmse: 3.36924	valid_1's rmse: 3.64769
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.64754	valid_1's rmse: 3.71021
# [200]	training's rmse: 3.56003	valid_1's rmse: 3.6756
# [300]	training's rmse: 3.50751	valid_1's rmse: 3.66394
# [400]	training's rmse: 3.47076	valid_1's rmse: 3.6599
# [500]	training's rmse: 3.44446	valid_1's rmse: 3.65775
# [600]	training's rmse: 3.42151	valid_1's rmse: 3.65652
# [700]	training's rmse: 3.4002	valid_1's rmse: 3.65655
# [800]	training's rmse: 3.38096	valid_1's rmse: 3.65614
# [900]	training's rmse: 3.36334	valid_1's rmse: 3.65621
# [1000]	training's rmse: 3.34672	valid_1's rmse: 3.65608
# [1100]	training's rmse: 3.3299	valid_1's rmse: 3.65588
# [1200]	training's rmse: 3.31387	valid_1's rmse: 3.656
# [1300]	training's rmse: 3.29648	valid_1's rmse: 3.6565
# Early stopping, best iteration is:
# [1125]	training's rmse: 3.32589	valid_1's rmse: 3.65576
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.64444	valid_1's rmse: 3.70686
# [200]	training's rmse: 3.55389	valid_1's rmse: 3.67757
# [300]	training's rmse: 3.50113	valid_1's rmse: 3.66871
# [400]	training's rmse: 3.46471	valid_1's rmse: 3.665
# [500]	training's rmse: 3.43864	valid_1's rmse: 3.66231
# [600]	training's rmse: 3.41603	valid_1's rmse: 3.66128
# [700]	training's rmse: 3.39468	valid_1's rmse: 3.66034
# [800]	training's rmse: 3.37722	valid_1's rmse: 3.65968
# [900]	training's rmse: 3.35925	valid_1's rmse: 3.65949
# [1000]	training's rmse: 3.33931	valid_1's rmse: 3.65959
# [1100]	training's rmse: 3.32071	valid_1's rmse: 3.65939
# [1200]	training's rmse: 3.30318	valid_1's rmse: 3.6593
# [1300]	training's rmse: 3.28416	valid_1's rmse: 3.65903
# [1400]	training's rmse: 3.26872	valid_1's rmse: 3.65933
# Early stopping, best iteration is:
# [1261]	training's rmse: 3.29134	valid_1's rmse: 3.65897
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.64738	valid_1's rmse: 3.69663
# [200]	training's rmse: 3.55756	valid_1's rmse: 3.66832
# [300]	training's rmse: 3.50193	valid_1's rmse: 3.65911
# [400]	training's rmse: 3.46394	valid_1's rmse: 3.65567
# [500]	training's rmse: 3.4384	valid_1's rmse: 3.65411
# [600]	training's rmse: 3.41551	valid_1's rmse: 3.65299
# [700]	training's rmse: 3.39547	valid_1's rmse: 3.65297
# [800]	training's rmse: 3.3759	valid_1's rmse: 3.6529
# [900]	training's rmse: 3.35626	valid_1's rmse: 3.65295
# Early stopping, best iteration is:
# [769]	training's rmse: 3.38146	valid_1's rmse: 3.65271
# 3.653410894233743

# %% [markdown]
# 1. Base feats - f1,f2,f3 - 3.8421399267932315
# 2. 3.6552368169417204, 3.692
# 3. 3.654460362787254, 3.692
# 4. 3.6538177315106624, 3.691 - 13th Feb
# 5. 3.654063570445142 - 15th Feb
# 6. 3.653410894233743 - 16th Feb

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
len(best_features.sort_values(by='importance', ascending=False)[:800]['Feature'].unique())
# Out:
# 168

# %%
best_features.head(5)
# Out:
#                     Feature  importance  fold
# 0       purchase_amount_max        1003     1
# 1          duration_min_old         779     1
# 2  authorized_flag_mean_old         865     1
# 3        purchase_Week_mean         608     1
# 4       month_diff_mean_old         637     1

# %%
picked_feats = best_features.sort_values(by='importance', ascending=False)[:800]['Feature'].unique()

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import gc

# %%
def kfold_lightgbm(train_df, test_df, num_folds, stratified = False, debug= False):
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))

    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=326)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=326)

    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in cols_excluded]

    # k-fold
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['outliers'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['target'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['target'].iloc[valid_idx]

        # set data structure
        lgb_train = lgb.Dataset(train_x,
                                label=train_y,
                                free_raw_data=False)
        lgb_test = lgb.Dataset(valid_x,
                               label=valid_y,
                               free_raw_data=False)

        # params optimized by optuna
        params ={
                'task': 'train',
                'boosting': 'goss',
                'objective': 'regression',
                'metric': 'rmse',
                'learning_rate': 0.01,
                'subsample': 0.9855232997390695,
                'max_depth': 7,
                'top_rate': 0.9064148448434349,
                'num_leaves': 63,
                'min_child_weight': 41.9612869171337,
                'other_rate': 0.0721768246018207,
                'reg_alpha': 9.677537745007898,
                'colsample_bytree': 0.5665320670155495,
                'min_split_gain': 9.820197773625843,
                'reg_lambda': 8.2532317400459,
                'min_data_in_leaf': 21,
                'verbose': -1,
                'seed':int(2**n_fold),
                'bagging_seed':int(2**n_fold),
                'drop_seed':int(2**n_fold)
                }

        reg = lgb.train(
                        params,
                        lgb_train,
                        valid_sets=[lgb_train, lgb_test],
                        valid_names=['train', 'test'],
                        num_boost_round=10000,
                        early_stopping_rounds= 200,
                        verbose_eval=100
                        )

        oof_preds[valid_idx] = reg.predict(valid_x, num_iteration=reg.best_iteration)
        sub_preds += reg.predict(test_df[feats], num_iteration=reg.best_iteration) / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = np.log1p(reg.feature_importance(importance_type='gain', iteration=reg.best_iteration))
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d RMSE : %.6f' % (n_fold + 1, rmse(valid_y, oof_preds[valid_idx])))
        del reg, train_x, train_y, valid_x, valid_y
        gc.collect()

    # display importances
    display_importances(feature_importance_df)

    if not debug:
        # save submission file
        submission_name = pd.to_datetime("today")
        sub_df = pd.DataFrame({"card_id":test_df2["card_id"].values})
        sub_df["target"] = sub_preds
        sub_df.to_csv(f'submission_kfold-{submission_name}.csv', index=False)
#         test_df.loc[:,'target'] = sub_preds
#         test_df = test_df.reset_index()
#         test_df[['card_id', 'target']].to_csv(submission_name, index=False)

# %%
# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]

    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances.png')

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
gc.collect()
# Out:
# 33488

# %%
kfold_lightgbm(train_df2, test_df2, num_folds=11, stratified=False, debug=False)

# %%
submission_name = pd.to_datetime("today")

# %%
sub_df = pd.DataFrame({"card_id":test_df2["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv(f'submission-{submission_name}.csv', index=False)

# %%
# !ls
# Out:
# 'Blend with df outliers.ipynb'
# 'Blending submissions.ipynb'
# 'Elo - ML model - 3.693.ipynb'
# 'Elo - ML model - 3.695 beta.ipynb'
# 'Elo - ML model - 3.695.ipynb'
# 'Elo - ML model - 3.696.ipynb'
# 'Elo - ML model - alpha.ipynb'
# 'Elo - ML model - cat aggregates.ipynb'
# 'Elo - ML model 3.691 beta new.ipynb'
# 'Elo - ML model 3.691.ipynb'
# 'Elo - ML model clean.ipynb'
# 'Elo - ML model proc_df.ipynb'
# 'Elo - ML model-RF copy.ipynb'
# 'Elo - ML model-backup.ipynb'
# 'Elo - ML model-new.ipynb'
# 'Elo RF- New.ipynb'
# 'Elo RF.ipynb'
# 'Elo end 2 end.ipynb'
# 'Elo feature engineering - 3.691 - beta.ipynb'
# 'Elo feature engineering - 3.691.ipynb'
# 'Elo feature engineering - 3.696.ipynb'
# 'Elo feature engineering 3.693 .ipynb'
# 'Elo feature engineering 3.695 beta.ipynb'
# 'Elo feature engineering 3.695.ipynb'
# 'Elo feature engineering alpha.ipynb'
# 'Elo feature engineering using agg.ipynb'
# 'Elo feature engineering-backup.ipynb'
# 'Elo feature engineering-proc_df - new-Copy1.ipynb'
# 'Elo feature engineering-proc_df - new.ipynb'
# 'Elo feature engineering-proc_df-OLD.ipynb'
# 'Elo feature engineering-proc_df.ipynb'
# 'Elo merchant category reco - using RF.ipynb'
# 'Elo outlier predictions & blending .ipynb'
# 'Feature selection using Boruta.ipynb'
# 'Feature selection.ipynb'
# 'Null importances - beta.ipynb'
# 'Outlier classification using Autoencoder.ipynb'
#  README.md
# 'Scrap pad.ipynb'
# 'Scrap pad.py'
# 'TS Fresh.ipynb'
# 'TS Fresh.py'
# 'Train & test clean.ipynb'
# 'Using DL-Copy1.ipynb'
# 'Using DL.ipynb'
# 'Using Feature tools - old.ipynb'
# 'Using feature tools-Copy1.ipynb'
# 'Using feature tools.ipynb'
#  actual_importances_ditribution_rf.csv
#  adf
#  alla.pkl
#  authorised_trans_proc_agg
# 'blend-2019-02-02 23:24:52.864854.csv'
#  blend-{submission_name}
#  blend_kfol_st.csv
#  chandu_mean1.csv
#  cols_keep.npy
#  comb_15.csv
# 'combined_submission-2019-02-15 15:07:09.944221.csv'
# 'combined_submission-2019-02-15 15:09:20.708055.csv'
#  combining_submission.csv
#  corr_scores_null_importances.csv
#  correlation
#  data
#  df_auth
#  df_hot_dropped_all
#  df_hot_ext
#  df_hot_test
#  df_hot_test_ext
#  df_new
#  df_non_auth
#  df_proc_dfed
#  df_test_n_o
#  df_xo
#  fastai
#  fm_new_hist
#  hist_trans
#  hist_trans_3_696
#  hist_trans_agg
#  hist_trans_agg_3_696
#  hist_trans_agg_beta
#  hist_trans_agg_cat
#  hist_trans_agg_month
#  hist_trans_agg_n
#  hist_trans_agg_proc
#  hist_trans_beta
# 'kfold lightgbm.ipynb'
#  latent_representation.png
#  lgbm_importances.png
#  lla
#  new_hist_prc
#  new_hist_trans
#  new_hist_trans_3_696
#  new_hist_trans_agg
#  new_hist_trans_agg_3_696
#  new_hist_trans_agg_beta
#  new_hist_trans_agg_cat
#  new_hist_trans_agg_month
#  new_hist_trans_agg_n
#  new_hist_trans_beta
#  new_trans_agg_proc
#  new_trans_proc_agg
#  non_authorised_trans_proc
#  non_authorised_trans_proc_agg
#  null_importances_distribution_rf.csv
#  oof_lgb_3.npy
#  oof_xgb_3.npy
#  original.png
#  predictions_lgb_3.npy
#  predictions_xgb_3.npy
# 'scrap pad 2.ipynb'
# 'submission-2019-01-11 09:49:53.716164.csv'
# 'submission-2019-01-11 10:18:09.909061.csv'
# 'submission-2019-01-12 13:53:27.215115.csv'
# 'submission-2019-01-12 16:27:31.239044.csv'
# 'submission-2019-01-12 17:25:56.678553.csv'
# 'submission-2019-01-12 17:33:29.475835.csv'
# 'submission-2019-01-12 17:42:01.350278.csv'
# 'submission-2019-01-12 22:12:59.947458.csv'
# 'submission-2019-01-13 15:59:45.792347.csv'
# 'submission-2019-01-13 18:24:51.237991.csv'
# 'submission-2019-01-14 19:04:33.028609.csv'
# 'submission-2019-01-14 19:56:09.906235.csv'
# 'submission-2019-01-15 22:18:34.294443.csv'
# 'submission-2019-01-15 22:24:38.071972.csv'
# 'submission-2019-01-15 22:29:20.144417.csv'
# 'submission-2019-01-16 00:35:46.490517.csv'
# 'submission-2019-01-16 00:36:26.004443.csv'
# 'submission-2019-01-16 12:20:00.957329.csv'
# 'submission-2019-01-16 21:37:16.421927.csv'
# 'submission-2019-01-17 10:20:06.724992.csv'
# 'submission-2019-01-17 11:09:17.495216.csv'
# 'submission-2019-01-17 23:23:57.743505.csv'
# 'submission-2019-01-18 01:18:08.182115.csv'
# 'submission-2019-01-18 01:42:20.587834.csv'
# 'submission-2019-01-18 01:47:04.024727.csv'
# 'submission-2019-01-18 16:16:45.475456.csv'
# 'submission-2019-01-18 16:27:58.560480.csv'
# 'submission-2019-01-18 17:22:46.188675.csv'
# 'submission-2019-01-20 00:30:10.643280.csv'
# 'submission-2019-01-20 01:28:12.077657.csv'
# 'submission-2019-01-20 01:46:39.187580.csv'
# 'submission-2019-01-20 02:32:16.439302.csv'
# 'submission-2019-01-20 17:01:54.207459.csv'
# 'submission-2019-01-20 17:27:46.797180.csv'
# 'submission-2019-01-20 18:29:37.773532.csv'
# 'submission-2019-01-20 19:11:58.593189.csv'
# 'submission-2019-01-20 19:35:24.892043.csv'
# 'submission-2019-01-20 20:47:32.743729.csv'
# 'submission-2019-01-22 09:33:02.341491.csv'
# 'submission-2019-01-22 10:35:57.465665.csv'
# 'submission-2019-01-31 22:00:10.810901.csv'
# 'submission-2019-01-31 22:04:41.815902.csv'
# 'submission-2019-02-02 23:13:59.670630.csv'
# 'submission-2019-02-02 23:24:52.864854.csv'
# 'submission-2019-02-03 14:42:22.636262.csv'
# 'submission-2019-02-03 14:43:29.797523.csv'
# 'submission-2019-02-10 14:58:45.312994.csv'
# 'submission-2019-02-10 17:36:17.986042.csv'
# 'submission-2019-02-10 18:01:58.093819.csv'
# 'submission-2019-02-12 22:57:39.862967.csv'
# 'submission-2019-02-13 00:42:12.274968.csv'
# 'submission-2019-02-13 01:51:25.440947.csv'
# 'submission-2019-02-13 22:48:45.005871.csv'
# 'submission-2019-02-15 14:22:06.881490.csv'
# 'submission-2019-02-15 14:45:36.932530.csv'
# 'submission-2019-02-15 18:08:33.904515.csv'
# 'submission-2019-02-16 13:14:48.321120.csv'
# 'submission-2019-02-16 13:22:43.779348.csv'
# 'submission_kfold-2019-02-13 00:55:25.132146.csv'
# 'submission_kfold-2019-02-13 01:29:28.856630.csv'
# 'submission_kfold-2019-02-13 01:59:08.971995.csv'
# 'submission_kfold-2019-02-13 23:21:24.051900.csv'
#  submissions
#  target_all
#  target_outliers_removed
#  test_clean.csv
#  test_clean.csv.zip
#  test_df
#  test_df_3.695
#  test_df_3691
#  test_df_3_696
#  test_df_beta
#  test_df_proc
#  test_df_proc_new
#  test_df_proc_new_m
#  train_clean.csv
#  train_clean.csv.zip
#  train_clean0
#  train_df
#  train_df_3691
#  train_df_3_696
#  train_df_beta
#  train_df_proc
#  train_df_proc_new
#  train_df_proc_new_m

# %%
FileLink(f'submission-{submission_name}.csv')
# Out:
# /home/chandrasekhar/private/kaggle/submission-2019-02-13 22:48:45.005871.csv

# %% [markdown]
# ### Blend

# %%
p1 = pd.read_csv(f'submission-{submission_name}.csv')
p2 = pd.read_csv('submission-2019-02-02 23:13:59.670630.csv')

# %%
p1.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.960024
# 1  C_ID_130fd0cbdd -0.421305
# 2  C_ID_b709037bc5 -1.011111
# 3  C_ID_d27d835a9f -0.141994
# 4  C_ID_2b5e3df5c2 -1.270823

# %%
p2.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.072875
# 1  C_ID_130fd0cbdd -0.348145
# 2  C_ID_b709037bc5 -0.949767
# 3  C_ID_d27d835a9f -0.149493
# 4  C_ID_2b5e3df5c2 -1.212316

# %%
p3 = p1.copy()

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.960024
# 1  C_ID_130fd0cbdd -0.421305
# 2  C_ID_b709037bc5 -1.011111
# 3  C_ID_d27d835a9f -0.141994
# 4  C_ID_2b5e3df5c2 -1.270823

# %%
p3 = pd.DataFrame({"card_id":test_df2["card_id"].values})
p3["target"] = p1['target']*.5 + p2['target']*.5

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.016449
# 1  C_ID_130fd0cbdd -0.384725
# 2  C_ID_b709037bc5 -0.980439
# 3  C_ID_d27d835a9f -0.145743
# 4  C_ID_2b5e3df5c2 -1.241569

# %%
p3.to_csv('blend_kfol_st.csv',index=False)

# %%
message = 'using blend kfold + stratified, purchase amount trimmed'

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.016449
# 1  C_ID_130fd0cbdd -0.384725
# 2  C_ID_b709037bc5 -0.980439
# 3  C_ID_d27d835a9f -0.145743
# 4  C_ID_2b5e3df5c2 -1.241569

# %%
filename = f'submission-{submission_name}.csv'

# %%
filename
# Out:
# 'submission-2019-02-16 13:14:48.321120.csv'

# %%
# !kaggle competitions submit elo-merchant-category-recommendation -f 'submission-2019-02-16 13:14:48.321120.csv' -m 'lc'
# Out:
# 100%|#######################################| 4.24M/4.24M [00:21<00:00, 203kB/s]
# Successfully submitted to Elo Merchant Category Recommendation

# %%
train = train_df2.copy()
train['rounded_target'] = train['target'].round(0)
train = train.sort_values('rounded_target').reset_index(drop=True)
vc = train['rounded_target'].value_counts()
vc = dict(sorted(vc.items()))
df = pd.DataFrame()
train['indexcol'],i = 0,1
for k,v in vc.items():
    step = train.shape[0]/v
    indent = train.shape[0]/(v+1)
    df2 = train[train['rounded_target'] == k].sample(v, random_state=120).reset_index(drop=True)
    for j in range(0, v):
        df2.at[j, 'indexcol'] = indent + j*step + 0.000001*i
    df = pd.concat([df2,df])
    i+=1

# %%
train = df.sort_values('indexcol', ascending=True).reset_index(drop=True)

# %%
train.head().T
# Out:
#                                                       0                    1  \
# first_active_month                  2017-12-01 00:00:00  2016-12-01 00:00:00
# card_id                                 C_ID_176ecc65bd      C_ID_6082929d3a
# feature_1                                     0.0131446            0.0107116
# feature_2                                     0.0113848            0.0113848
# feature_3                                     0.0114275            0.0102828
# target                                        -0.279039            -0.926039
# first_active_monthYear                             2017                 2016
# first_active_monthMonth                              12                   12
# first_active_monthWeek                               48                   48
# first_active_monthDay                                 1                    1
# first_active_monthDayofweek                           4                    3
# first_active_monthDayofyear                         335                  336
# first_active_monthIs_month_end                    False                False
# first_active_monthIs_month_start                   True                 True
# first_active_monthIs_quarter_end                  False                False
# first_active_monthIs_quarter_start                False                False
# first_active_monthIs_year_end                     False                False
# first_active_monthIs_year_start                   False                False
# first_active_monthElapsed                    1512086400           1480550400
# transactions_count                                   10                   46
# city_id_nunique                                       5                   15
# merchant_category_id_nunique                          7                   20
# merchant_id_nunique                                  10                   46
# state_id_nunique                                      2                    8
# subsector_id_nunique                                  7                   13
# purchase_Year_nunique                                 1                    1
# purchase_Month_nunique                                2                    2
# purchase_Week_nunique                                 5                    9
# purchase_Day_nunique                                  7                   17
# purchase_amount_sum                           -0.450675             -22.5638
# ...                                                 ...                  ...
# purchase_amount_sum_sum                         7.36008             -390.031
# purchase_amount_sum_ptp                         23.4604              358.046
# purchase_amount_sum_max                         15.4103            -0.619333
# purchase_amount_max_mean                        9.49366              2.61874
# purchase_amount_max_sum                         18.9873              7.85621
# purchase_amount_max_ptp                         14.2301              8.07011
# purchase_amount_max_max                         16.6087              7.45078
# purchase_amount_mean_mean                      -0.04237            -0.593192
# purchase_amount_mean_sum                       -0.08474             -1.77958
# purchase_amount_mean_ptp                       0.490273            0.0499709
# purchase_amount_mean_max                       0.202767            -0.569362
# elapsed_time                                        426                  791
# card_id_total                                       114                  708
# card_id_count_total                                 114                  708
# purchase_amount_total                            6.9094             -412.594
# purchase_amount_total_mean                    0.0257024             -1.07969
# installments_total                                  124                  742
# hist_first_buy                                        4                   31
# new_first_buy                                        90                  465
# hist_last_buy                                        89                  454
# new_last_buy                                        132                  515
# purchase_amount_max_total                       3.01714             0.574974
# purchased_before_issue                            False                False
# outliers                                              0                    0
# days                                                 62                  427
# days_feature1                                       310                 1708
# days_feature2                                        62                  427
# days_feature3                                        62                    0
# rounded_target                                       -0                   -1
# indexcol                                              2                    5
#
#                                                       2                    3  \
# first_active_month                  2016-09-01 00:00:00  2017-11-01 00:00:00
# card_id                                 C_ID_a87bbd85a7      C_ID_92e4809531
# feature_1                                     0.0104794           0.00805849
# feature_2                                     0.0113848            0.0113848
# feature_3                                     0.0114275            0.0102828
# target                                         0.475326             0.516026
# first_active_monthYear                             2016                 2017
# first_active_monthMonth                               9                   11
# first_active_monthWeek                               35                   44
# first_active_monthDay                                 1                    1
# first_active_monthDayofweek                           3                    2
# first_active_monthDayofyear                         245                  305
# first_active_monthIs_month_end                    False                False
# first_active_monthIs_month_start                   True                 True
# first_active_monthIs_quarter_end                  False                False
# first_active_monthIs_quarter_start                False                False
# first_active_monthIs_year_end                     False                False
# first_active_monthIs_year_start                   False                False
# first_active_monthElapsed                    1472688000           1509494400
# transactions_count                                   22                    6
# city_id_nunique                                       3                    5
# merchant_category_id_nunique                         17                    4
# merchant_id_nunique                                  22                    6
# state_id_nunique                                      1                    3
# subsector_id_nunique                                 11                    4
# purchase_Year_nunique                                 1                    1
# purchase_Month_nunique                                2                    2
# purchase_Week_nunique                                 5                    5
# purchase_Day_nunique                                 13                    6
# purchase_amount_sum                            -15.5147              -3.1597
# ...                                                 ...                  ...
# purchase_amount_sum_sum                         -322.03             -14.6139
# purchase_amount_sum_ptp                          284.74              12.2301
# purchase_amount_sum_max                        -18.6449              -1.1919
# purchase_amount_max_mean                      -0.588055              1.90307
# purchase_amount_max_sum                        -1.17611              3.80614
# purchase_amount_max_ptp                        0.129754              1.82123
# purchase_amount_max_max                       -0.523178              2.81368
# purchase_amount_mean_mean                     -0.712977            -0.280704
# purchase_amount_mean_sum                       -1.42595            -0.561408
# purchase_amount_mean_ptp                     0.00826695             0.164107
# purchase_amount_mean_max                      -0.708844             -0.19865
# elapsed_time                                        882                  456
# card_id_total                                       476                   49
# card_id_count_total                                 476                   49
# purchase_amount_total                          -337.545             -17.7736
# purchase_amount_total_mean                     -1.41453            -0.866476
# installments_total                                    0                   74
# hist_first_buy                                      125                    6
# new_first_buy                                       551                  121
# hist_last_buy                                       540                  117
# new_last_buy                                        598                  172
# purchase_amount_max_total                      -1.31004            -0.932425
# purchased_before_issue                            False                False
# outliers                                              0                    0
# days                                                518                   92
# days_feature1                                      1554                   92
# days_feature2                                       518                   92
# days_feature3                                       518                    0
# rounded_target                                        0                    1
# indexcol                                              5                    5
#
#                                                       4
# first_active_month                  2017-11-01 00:00:00
# card_id                                 C_ID_d2dd6bbf9a
# feature_1                                     0.0107116
# feature_2                                     0.0113848
# feature_3                                     0.0102828
# target                                        -0.100927
# first_active_monthYear                             2017
# first_active_monthMonth                              11
# first_active_monthWeek                               44
# first_active_monthDay                                 1
# first_active_monthDayofweek                           2
# first_active_monthDayofyear                         305
# first_active_monthIs_month_end                    False
# first_active_monthIs_month_start                   True
# first_active_monthIs_quarter_end                  False
# first_active_monthIs_quarter_start                False
# first_active_monthIs_year_end                     False
# first_active_monthIs_year_start                   False
# first_active_monthElapsed                    1509494400
# transactions_count                                   16
# city_id_nunique                                       6
# merchant_category_id_nunique                         13
# merchant_id_nunique                                  16
# state_id_nunique                                      3
# subsector_id_nunique                                  8
# purchase_Year_nunique                                 1
# purchase_Month_nunique                                2
# purchase_Week_nunique                                 6
# purchase_Day_nunique                                  9
# purchase_amount_sum                            -4.21238
# ...                                                 ...
# purchase_amount_sum_sum                        -14.7675
# purchase_amount_sum_ptp                         1.36254
# purchase_amount_sum_max                        -6.70246
# purchase_amount_max_mean                        3.17877
# purchase_amount_max_sum                         6.35754
# purchase_amount_max_ptp                         4.16685
# purchase_amount_max_max                         5.26219
# purchase_amount_mean_mean                     -0.284128
# purchase_amount_mean_sum                      -0.568255
# purchase_amount_mean_ptp                       0.269552
# purchase_amount_mean_max                      -0.149352
# elapsed_time                                        456
# card_id_total                                        86
# card_id_count_total                                  86
# purchase_amount_total                          -18.9798
# purchase_amount_total_mean                    -0.474238
# installments_total                                  180
# hist_first_buy                                      -62
# new_first_buy                                       140
# hist_last_buy                                       116
# new_last_buy                                        180
# purchase_amount_max_total                      0.144826
# purchased_before_issue                             True
# outliers                                              0
# days                                                 92
# days_feature1                                       368
# days_feature2                                        92
# days_feature3                                         0
# rounded_target                                       -0
# indexcol                                              8
#
# [170 rows x 5 columns]

# %%
df_180 = ['feature_1',
         'feature_2',
         'feature_3',
         'transactions_count',
         'subsector_id_nunique',
         'merchant_id_nunique',
         'merchant_category_id_nunique',
         'purchase_Month_mean',
         'purchase_Month_min',
         'purchase_Month_max',
         'purchase_Week_nunique',
         'purchase_Week_mean',
         'purchase_Week_min',
         'purchase_Week_max',
         'purchase_Dayofweek_mean',
         'purchase_Dayofweek_min',
         'purchase_Dayofweek_max',
         'purchase_Day_nunique',
         'purchase_Day_mean',
         'purchase_Day_min',
         'purchase_Day_max',
         'purchase_Hour_nunique',
         'purchase_Hour_mean',
         'purchase_Hour_min',
         'purchase_Hour_max',
         'purchase_amount_sum',
         'purchase_amount_max',
         'purchase_amount_min',
         'purchase_amount_mean',
         'purchase_amount_var',
         'purchase_amount_skew',
         'installments_sum',
         'installments_max',
         'installments_mean',
         'installments_var',
         'installments_skew',
         'month_lag_max',
         'month_lag_min',
         'month_lag_mean',
         'month_lag_var',
         'month_lag_skew',
         'month_diff_mean',
         'month_diff_var',
         'month_diff_skew',
         'purchased_on_weekend_mean',
         'category_1_mean',
         'category_2_mean',
         'category_3_mean',
         'card_id_count',
         'price_mean',
         'price_max',
         'price_min',
         'price_var',
         'Christmas_Day_2017_mean',
         'Children_day_2017_mean',
         'Black_Friday_2017_mean',
         'Mothers_Day_2018_mean',
         'duration_mean',
         'duration_min',
         'duration_max',
         'duration_var',
         'duration_skew',
         'amount_month_ratio_mean',
         'amount_month_ratio_min',
         'amount_month_ratio_max',
         'amount_month_ratio_var',
         'amount_month_ratio_skew',
         'category_2_mean_mean',
         'category_3_mean_mean',
         'purchase_date_diff',
         'purchase_date_average',
         'purchase_date_uptonow',
         'purchase_date_uptomin',
         'transactions_count_old',
         'subsector_id_nunique_old',
         'merchant_id_nunique_old',
         'merchant_category_id_nunique_old',
         'purchase_Month_nunique',
         'purchase_Month_mean_old',
         'purchase_Month_min_old',
         'purchase_Month_max_old',
         'purchase_Week_nunique_old',
         'purchase_Week_mean_old',
         'purchase_Week_min_old',
         'purchase_Week_max_old',
         'purchase_Dayofweek_mean_old',
         'purchase_Day_nunique_old',
         'purchase_Day_mean_old',
         'purchase_Day_min_old',
         'purchase_Hour_nunique_old',
         'purchase_Hour_mean_old',
         'purchase_Hour_min_old',
         'purchase_Hour_max_old',
         'purchase_amount_sum_old',
         'purchase_amount_max_old',
         'purchase_amount_min_old',
         'purchase_amount_mean_old',
         'purchase_amount_var_old',
         'purchase_amount_skew_old',
         'installments_sum_old',
         'installments_max_old',
         'installments_mean_old',
         'installments_var_old',
         'installments_skew_old',
         'month_lag_max_old',
         'month_lag_min_old',
         'month_lag_mean_old',
         'month_lag_var_old',
         'month_lag_skew_old',
         'month_diff_max',
         'month_diff_min',
         'month_diff_mean_old',
         'month_diff_var_old',
         'month_diff_skew_old',
         'authorized_flag_mean',
         'purchased_on_weekend_mean_old',
         'category_1_mean_old',
         'category_2_mean_old',
         'category_3_mean_old',
         'card_id_count_old',
         'price_sum',
         'price_mean_old',
         'price_max_old',
         'price_min_old',
         'price_var_old',
         'Christmas_Day_2017_mean_old',
         'Mothers_Day_2017_mean',
         'fathers_day_2017_mean',
         'Children_day_2017_mean_old',
         'Valentine_Day_2017_mean',
         'Black_Friday_2017_mean_old',
         'Mothers_Day_2018_mean_old',
         'duration_mean_old',
         'duration_min_old',
         'duration_max_old',
         'duration_var_old',
         'duration_skew_old',
         'amount_month_ratio_mean_old',
         'amount_month_ratio_min_old',
         'amount_month_ratio_max_old',
         'amount_month_ratio_var_old',
         'amount_month_ratio_skew_old',
         'category_2_mean_mean_old',
         'category_3_mean_mean_old',
         'purchase_date_diff_old',
         'purchase_date_average_old',
         'purchase_date_uptonow_old',
         'purchase_date_uptomin_old',
         'quarter',
         'elapsed_time',
         'days_feature1',
         'days_feature2',
         'days_feature3',
         'days_feature1_ratio',
         'days_feature2_ratio',
         'days_feature3_ratio',
         'feature_sum',
         'feature_mean',
         'feature_max',
         'feature_min',
         'feature_var',
         'card_id_total',
         'card_id_count_total',
         'card_id_count_ratio',
         'purchase_amount_total',
         'purchase_amount_total_mean',
         'purchase_amount_total_max',
         'purchase_amount_total_min',
         'purchase_amount_sum_ratio',
         'hist_first_buy',
         'new_first_buy',
         'hist_last_buy',
         'new_last_buy',
         'month_diff_ratio',
         'installments_total',
         'installments_ratio',
         'price_total',
         'CLV',
         'CLV_old',
         'CLV_ratio']

# %%
df_181 = ['feature_1',
 'feature_2',
 'feature_3',
 'first_active_monthElapsed',
 'transactions_count',
 'subsector_id_nunique',
 'merchant_id_nunique',
 'merchant_category_id_nunique',
 'purchase_Month_mean',
 'purchase_Month_min',
 'purchase_Month_max',
 'purchase_Week_nunique',
 'purchase_Week_mean',
 'purchase_Week_min',
 'purchase_Week_max',
 'purchase_Dayofweek_mean',
 'purchase_Dayofweek_min',
 'purchase_Dayofweek_max',
 'purchase_Day_nunique',
 'purchase_Day_mean',
 'purchase_Day_min',
 'purchase_Day_max',
 'purchase_Hour_nunique',
 'purchase_Hour_mean',
 'purchase_Hour_min',
 'purchase_Hour_max',
 'purchase_amount_sum',
 'purchase_amount_max',
 'purchase_amount_min',
 'purchase_amount_mean',
 'purchase_amount_var',
 'purchase_amount_skew',
 'installments_sum',
 'installments_max',
 'installments_mean',
 'installments_var',
 'installments_skew',
 'month_lag_max',
 'month_lag_min',
 'month_lag_mean',
 'month_lag_var',
 'month_lag_skew',
 'month_diff_mean',
 'month_diff_var',
 'month_diff_skew',
 'purchased_on_weekend_mean',
 'category_1_mean',
 'category_2_mean',
 'category_3_mean',
 'card_id_count',
 'price_mean',
 'price_max',
 'price_min',
 'price_var',
 'Christmas_Day_2017_mean',
 'Children_day_2017_mean',
 'Black_Friday_2017_mean',
 'Mothers_Day_2018_mean',
 'duration_mean',
 'duration_min',
 'duration_max',
 'duration_var',
 'duration_skew',
 'amount_month_ratio_mean',
 'amount_month_ratio_min',
 'amount_month_ratio_max',
 'amount_month_ratio_var',
 'amount_month_ratio_skew',
 'category_2_mean_mean',
 'category_3_mean_mean',
 'purchase_date_diff',
 'purchase_date_average',
 'purchase_date_uptonow',
 'purchase_date_uptomin',
 'transactions_count_old',
 'subsector_id_nunique_old',
 'merchant_id_nunique_old',
 'merchant_category_id_nunique_old',
 'purchase_Month_nunique',
 'purchase_Month_mean_old',
 'purchase_Month_min_old',
 'purchase_Month_max_old',
 'purchase_Week_nunique_old',
 'purchase_Week_mean_old',
 'purchase_Week_min_old',
 'purchase_Week_max_old',
 'purchase_Dayofweek_mean_old',
 'purchase_Day_nunique_old',
 'purchase_Day_mean_old',
 'purchase_Day_min_old',
 'purchase_Hour_nunique_old',
 'purchase_Hour_mean_old',
 'purchase_Hour_min_old',
 'purchase_Hour_max_old',
 'purchase_amount_sum_old',
 'purchase_amount_max_old',
 'purchase_amount_min_old',
 'purchase_amount_mean_old',
 'purchase_amount_var_old',
 'purchase_amount_skew_old',
 'installments_sum_old',
 'installments_max_old',
 'installments_mean_old',
 'installments_var_old',
 'installments_skew_old',
 'month_lag_max_old',
 'month_lag_min_old',
 'month_lag_mean_old',
 'month_lag_var_old',
 'month_lag_skew_old',
 'month_diff_max',
 'month_diff_min',
 'month_diff_mean_old',
 'month_diff_var_old',
 'month_diff_skew_old',
 'authorized_flag_mean',
 'purchased_on_weekend_mean_old',
 'category_1_mean_old',
 'category_2_mean_old',
 'category_3_mean_old',
 'card_id_count_old',
 'price_sum',
 'price_mean_old',
 'price_max_old',
 'price_min_old',
 'price_var_old',
 'Christmas_Day_2017_mean_old',
 'Mothers_Day_2017_mean',
 'fathers_day_2017_mean',
 'Children_day_2017_mean_old',
 'Valentine_Day_2017_mean',
 'Black_Friday_2017_mean_old',
 'Mothers_Day_2018_mean_old',
 'duration_mean_old',
 'duration_min_old',
 'duration_max_old',
 'duration_var_old',
 'duration_skew_old',
 'amount_month_ratio_mean_old',
 'amount_month_ratio_min_old',
 'amount_month_ratio_max_old',
 'amount_month_ratio_var_old',
 'amount_month_ratio_skew_old',
 'category_2_mean_mean_old',
 'category_3_mean_mean_old',
 'purchase_date_diff_old',
 'purchase_date_average_old',
 'purchase_date_uptonow_old',
 'purchase_date_uptomin_old',
 'card_id_total',
 'card_id_count_total',
 'card_id_count_ratio',
 'purchase_amount_total',
 'purchase_amount_total_mean',
 'purchase_amount_total_max',
 'purchase_amount_total_min',
 'purchase_amount_sum_ratio',
 'hist_first_buy',
 'new_first_buy',
 'hist_last_buy',
 'new_last_buy',
 'month_diff_ratio',
 'installments_total',
 'installments_ratio',
 'price_total',
 'CLV',
 'CLV_old',
 'CLV_ratio',
 'quarter',
 'elapsed_time',
 'days_feature1',
 'days_feature2',
 'days_feature3',
 'days_feature1_ratio',
 'days_feature2_ratio',
 'days_feature3_ratio',
 'feature_sum',
 'feature_mean',
 'feature_max',
 'feature_min',
 'feature_var']

# %%
[c for c in df_181 if c not in df_180]
# Out:
# ['first_active_monthElapsed']
