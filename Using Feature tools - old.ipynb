# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Manual" data-toc-modified-id="Manual-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Manual</a></span></li><li><span><a href="#Automated" data-toc-modified-id="Automated-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Automated</a></span></li></ul></div>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather
import gc

# %%
gc.collect()
# Out:
# 7

# %%
hist_trans = feather.read_dataframe('hist_trans')
new_hist_trans = feather.read_dataframe('new_hist_trans')

# %% [markdown]
# ### Manual

# %%
def aggregate_by_card_id(df):
    unique_cols = ['city_id', 'merchant_category_id', 'merchant_id', 'state_id', 
                   'subsector_id']
    aggs = {}
    for c in unique_cols:
        aggs[c] = ['nunique'] 
    aggs['purchase_amount'] = ['sum','max','min','mean','var']
    aggs['installments'] = ['sum','max','min','mean','var']
    aggs['purchase_date'] = ['max','min', np.ptp]
    aggs['month_lag'] = ['max','min','mean','var']
    aggs['month_diff'] = ['mean', 'std', 'var']
    aggs['authorized_flag'] = ['sum', 'mean']
    aggs['purchased_on_weekend'] = ['sum', 'mean']
    aggs['category_1'] = ['sum', 'mean']
    aggs['card_id'] = ['size']
    cols_vals = df.columns.values
    for col in ['category_2','category_3', 'authorized_flag']:
        if col in cols_vals:
            df[col+'_amount_mean'] = df.groupby([col])['purchase_amount'].transform('mean')
            df[col+'_amount_sum'] = df.groupby([col])['purchase_amount'].transform('sum')
            aggs[col+'_amount_mean'] = ['mean']
            aggs[col+'_amount_sum'] = ['sum']

    new_df = df.groupby(['card_id']).agg(aggs)
    new_df.columns = ['_'.join(col).strip() for col in new_df.columns.values]
    new_df.reset_index(inplace=True)
    other_df = (df.groupby('card_id')
          .size()
          .reset_index(name='transactions_count'))
    
    new_df = pd.merge(other_df, new_df, on='card_id', how='left')
    new_df["purchase_date_ptp"] = new_df["purchase_date_ptp"].dt.days
    new_df['purchase_date_diff'] = (new_df['purchase_date_max'] - new_df['purchase_date_min']).dt.days
    new_df['purchase_date_average'] = new_df['purchase_date_diff']/new_df['card_id_size']
    new_df['purchase_date_uptonow'] = (datetime.datetime.today() - new_df['purchase_date_max']).dt.days
    return new_df

# %%
aggregate_by_card_id(temp).T
# Out:
#                                                     0
# card_id                               C_ID_92a2005557
# transactions_count                                260
# city_id_nunique                                     7
# merchant_category_id_nunique                       41
# merchant_id_nunique                                94
# state_id_nunique                                    3
# subsector_id_nunique                               21
# purchase_amount_sum                          -165.969
# purchase_amount_max                           2.25839
# purchase_amount_min                         -0.739395
# purchase_amount_mean                        -0.638341
# purchase_amount_var                         0.0450031
# installments_sum                                    4
# installments_max                                    1
# installments_min                                    0
# installments_mean                           0.0153846
# installments_var                            0.0152064
# purchase_date_max                 2018-02-25 09:31:15
# purchase_date_min                 2017-06-27 14:18:08
# purchase_date_ptp                                 242
# month_lag_max                                       0
# month_lag_min                                      -8
# month_lag_mean                               -3.91154
# month_lag_var                                  5.7489
# month_diff_mean                                  10.8
# month_diff_std                               0.400771
# month_diff_var                               0.160618
# authorized_flag_sum                               247
# authorized_flag_mean                             0.95
# purchased_on_weekend_sum                           90
# purchased_on_weekend_mean                    0.346154
# category_1_sum                                      0
# category_1_mean                                     0
# card_id_size                                      260
# category_2_amount_mean_mean                 -0.638341
# category_2_amount_sum_sum                    -42175.5
# category_3_amount_mean_mean                 -0.638341
# category_3_amount_sum_sum                    -41811.6
# authorized_flag_amount_mean_mean            -0.638341
# authorized_flag_amount_sum_sum               -38988.5
# purchase_date_diff                                242
# purchase_date_average                        0.930769
# purchase_date_uptonow                             328

# %%
hist_trans['category_2'].value_counts()
# Out:
# 1.0    17830063
# 3.0     3911795
# 5.0     3725915
# 4.0     2618053
# 2.0     1026535
# Name: category_2, dtype: int64

# %%
new_hist_trans['category_2'].value_counts()
# Out:
# 1.0    1169987
# 3.0     289525
# 5.0     259266
# 4.0     178590
# 2.0      65663
# Name: category_2, dtype: int64

# %%
hist_trans['category_3'].value_counts()
# Out:
# A    15589906
# B    11677522
# C     1844933
# Name: category_3, dtype: int64

# %%
hist_trans['category_1'].value_counts()
# Out:
# 0    27028332
# 1     2084029
# Name: category_1, dtype: int64

# %%
new_hist_trans['category_1'].value_counts()
# Out:
# 0    1899935
# 1      63096
# Name: category_1, dtype: int64

# %%
temp1 = hist_trans.loc[hist_trans['card_id'].isin(['C_ID_05042ebd55', 'C_ID_5c240d6e3c'])]

# %%
temp1.T
# Out:
#                                       29112043             29112044  \
# authorized_flag                              0                    1
# card_id                        C_ID_05042ebd55      C_ID_05042ebd55
# city_id                                     -1                   20
# category_1                                   0                    0
# installments                                 0                    0
# category_3                                   A                    A
# merchant_category_id                       437                  422
# merchant_id                    M_ID_ce1e7a7a85      M_ID_0de7fd2bef
# month_lag                                   -4                   -1
# purchase_amount                      -0.643976            -0.692948
# purchase_date              2017-10-28 15:16:46  2018-01-14 21:22:48
# category_2                                   1                    3
# state_id                                    -1                   19
# subsector_id                                15                   27
# purchase_Year                             2017                 2018
# purchase_Month                              10                    1
# purchase_Week                               43                    2
# purchase_Day                                28                   14
# purchase_Dayofweek                           5                    6
# purchase_Dayofyear                         301                   14
# purchase_Is_month_end                    False                False
# purchase_Is_month_start                  False                False
# purchase_Is_quarter_end                  False                False
# purchase_Is_quarter_start                False                False
# purchase_Is_year_end                     False                False
# purchase_Is_year_start                   False                False
# purchase_Elapsed                    1509203806           1515964968
# purchased_on_weekend                         1                    1
# month_diff                                  10                   11
#
#                                       29112045             29112046  \
# authorized_flag                              1                    1
# card_id                        C_ID_05042ebd55      C_ID_05042ebd55
# city_id                                     -1                   -1
# category_1                                   0                    0
# installments                                 0                    0
# category_3                                   A                    A
# merchant_category_id                       703                   80
# merchant_id                    M_ID_051eacb2a3      M_ID_9ecff0beda
# month_lag                                   -2                    0
# purchase_amount                      -0.716855            -0.705585
# purchase_date              2017-12-31 16:27:35  2018-02-07 12:34:06
# category_2                                   1                    1
# state_id                                    -1                   -1
# subsector_id                                29                   37
# purchase_Year                             2017                 2018
# purchase_Month                              12                    2
# purchase_Week                               52                    6
# purchase_Day                                31                    7
# purchase_Dayofweek                           6                    2
# purchase_Dayofyear                         365                   38
# purchase_Is_month_end                     True                False
# purchase_Is_month_start                  False                False
# purchase_Is_quarter_end                   True                False
# purchase_Is_quarter_start                False                False
# purchase_Is_year_end                      True                False
# purchase_Is_year_start                   False                False
# purchase_Elapsed                    1514737655           1518006846
# purchased_on_weekend                         1                    0
# month_diff                                  10                   11
#
#                                       29112047             29112048  \
# authorized_flag                              0                    1
# card_id                        C_ID_05042ebd55      C_ID_05042ebd55
# city_id                                     -1                   -1
# category_1                                   0                    0
# installments                                 0                    0
# category_3                                   A                    A
# merchant_category_id                        80                  278
# merchant_id                    M_ID_9ecff0beda      M_ID_814793f74b
# month_lag                                    0                    0
# purchase_amount                      -0.705134            -0.725871
# purchase_date              2018-02-07 12:33:36  2018-02-09 15:04:41
# category_2                                   1                    1
# state_id                                    -1                   -1
# subsector_id                                37                   37
# purchase_Year                             2018                 2018
# purchase_Month                               2                    2
# purchase_Week                                6                    6
# purchase_Day                                 7                    9
# purchase_Dayofweek                           2                    4
# purchase_Dayofyear                          38                   40
# purchase_Is_month_end                    False                False
# purchase_Is_month_start                  False                False
# purchase_Is_quarter_end                  False                False
# purchase_Is_quarter_start                False                False
# purchase_Is_year_end                     False                False
# purchase_Is_year_start                   False                False
# purchase_Elapsed                    1518006816           1518188681
# purchased_on_weekend                         0                    0
# month_diff                                  11                   11
#
#                                       29112358             29112359  \
# authorized_flag                              1                    1
# card_id                        C_ID_5c240d6e3c      C_ID_5c240d6e3c
# city_id                                      3                  331
# category_1                                   0                    0
# installments                                 0                    0
# category_3                                   A                    A
# merchant_category_id                       278                  514
# merchant_id                    M_ID_9cdcfe8673      M_ID_1a75f94f92
# month_lag                                    0                   -1
# purchase_amount                       -0.65774              0.77062
# purchase_date              2017-12-26 18:37:51  2017-11-24 14:18:15
# category_2                                   1                    1
# state_id                                    16                   16
# subsector_id                                37                    9
# purchase_Year                             2017                 2017
# purchase_Month                              12                   11
# purchase_Week                               52                   47
# purchase_Day                                26                   24
# purchase_Dayofweek                           1                    4
# purchase_Dayofyear                         360                  328
# purchase_Is_month_end                    False                False
# purchase_Is_month_start                  False                False
# purchase_Is_quarter_end                  False                False
# purchase_Is_quarter_start                False                False
# purchase_Is_year_end                     False                False
# purchase_Is_year_start                   False                False
# purchase_Elapsed                    1514313471           1511533095
# purchased_on_weekend                         0                    0
# month_diff                                  12                   13
#
#                                       29112360
# authorized_flag                              1
# card_id                        C_ID_5c240d6e3c
# city_id                                    331
# category_1                                   0
# installments                                 0
# category_3                                   A
# merchant_category_id                       514
# merchant_id                    M_ID_1a75f94f92
# month_lag                                   -2
# purchase_amount                        1.13441
# purchase_date              2017-10-26 14:09:40
# category_2                                   1
# state_id                                    16
# subsector_id                                 9
# purchase_Year                             2017
# purchase_Month                              10
# purchase_Week                               43
# purchase_Day                                26
# purchase_Dayofweek                           3
# purchase_Dayofyear                         299
# purchase_Is_month_end                    False
# purchase_Is_month_start                  False
# purchase_Is_quarter_end                  False
# purchase_Is_quarter_start                False
# purchase_Is_year_end                     False
# purchase_Is_year_start                   False
# purchase_Elapsed                    1509026980
# purchased_on_weekend                         0
# month_diff                                  12

# %%
temp1[['category_2','category_3', 'category_1', 'authorized_flag']].apply(pd.value_counts)
# Out:
#      category_2  category_3  category_1  authorized_flag
# 1.0         8.0         NaN         NaN              7.0
# 3.0         1.0         NaN         NaN              NaN
# A           NaN         9.0         NaN              NaN
# 0           NaN         NaN         9.0              2.0

# %%
k =temp1.groupby(['card_id', 'category_2']).agg({"purchase_amount":'sum'})

# %%
k
# Out:
#                             purchase_amount
# card_id         category_2
# C_ID_05042ebd55 1.0               -3.497421
#                 3.0               -0.692948
# C_ID_5c240d6e3c 1.0                1.247291

# %%
['_'.join(c) for c in k.columns.values]
# Out:
# ['p_u_r_c_h_a_s_e___a_m_o_u_n_t']

# %%
k.columns.values
# Out:
# array(['purchase_amount'], dtype=object)

# %%
k.columns
# Out:
# Index(['purchase_amount'], dtype='object')

# %%
l = temp1.pivot_table(index='card_id',columns='category_2',aggfunc={"purchase_amount": ['sum']})

# %%
l.columns = ['cat_2_{0[2]}_{0[0]}_{0[1]}'.format(col) if col[2] else col[2] for col in l.columns.tolist()]

# %%
l.reset_index()
# Out:
#            card_id  cat_2_1.0_purchase_amount_sum  \
# 0  C_ID_05042ebd55                      -3.497421
# 1  C_ID_5c240d6e3c                       1.247291
#
#    cat_2_3.0_purchase_amount_sum
# 0                      -0.692948
# 1                            NaN

# %%
p = temp1.pivot_table(index='card_id',columns='category_2' ,aggfunc={"purchase_amount": ['sum', 'mean']})

# %%
p
# Out:
#                 purchase_amount
#                            mean                 sum
# category_2                  1.0       3.0       1.0       3.0
# card_id
# C_ID_05042ebd55       -0.699484 -0.692948 -3.497421 -0.692948
# C_ID_5c240d6e3c        0.415764       NaN  1.247291       NaN

# %%
['cat_2_{0[2]}_{0[0]}_{0[1]}'.format(col) if col[2] else col[2] for col in p.columns.tolist()]
# Out:
# ['cat_2_1.0_purchase_amount_mean',
#  'cat_2_3.0_purchase_amount_mean',
#  'cat_2_1.0_purchase_amount_sum',
#  'cat_2_3.0_purchase_amount_sum']

# %%
aggregate_by_card_id(temp1).T
# Out:
#                                                     0                    1
# card_id                               C_ID_05042ebd55      C_ID_5c240d6e3c
# transactions_count                                  6                    3
# city_id_nunique                                     2                    2
# merchant_category_id_nunique                        5                    2
# merchant_id_nunique                                 5                    2
# state_id_nunique                                    2                    1
# subsector_id_nunique                                4                    2
# purchase_amount_sum                          -4.19037              1.24729
# purchase_amount_max                         -0.643976              1.13441
# purchase_amount_min                         -0.725871             -0.65774
# purchase_amount_mean                        -0.698395             0.415764
# purchase_amount_var                       0.000836773             0.897394
# installments_sum                                    0                    0
# installments_max                                    0                    0
# installments_min                                    0                    0
# installments_mean                                   0                    0
# installments_var                                    0                    0
# purchase_date_max                 2018-02-09 15:04:41  2017-12-26 18:37:51
# purchase_date_min                 2017-10-28 15:16:46  2017-10-26 14:09:40
# purchase_date_ptp                                 103                   61
# month_lag_max                                       0                    0
# month_lag_min                                      -4                   -2
# month_lag_mean                               -1.16667                   -1
# month_lag_var                                 2.56667                    1
# month_diff_mean                               10.6667              12.3333
# month_diff_std                               0.516398              0.57735
# month_diff_var                               0.266667             0.333333
# authorized_flag_sum                                 4                    3
# authorized_flag_mean                         0.666667                    1
# purchased_on_weekend_sum                            3                    0
# purchased_on_weekend_mean                         0.5                    0
# category_1_sum                                      0                    0
# category_1_mean                                     0                    0
# card_id_size                                        6                    3
# category_2_amount_mean_mean                  -0.34988            -0.281266
# category_2_amount_sum_sum                    -11.9436             -6.75039
# category_3_amount_mean_mean                 -0.327009            -0.327009
# category_3_amount_sum_sum                    -17.6585             -8.82923
# authorized_flag_amount_mean_mean            -0.376658             -0.22771
# authorized_flag_amount_sum_sum               -9.07409              -4.7819
# purchase_date_diff                                103                   61
# purchase_date_average                         17.1667              20.3333
# purchase_date_uptonow                             344                  389

# %%
temp1.pivot_table(index='card_id',columns='authorized_flag' ,aggfunc={"purchase_amount": ['sum', 'mean']})
# Out:
#                 purchase_amount
#                            mean                sum
# authorized_flag               0         1        0         1
# card_id
# C_ID_05042ebd55       -0.674555 -0.710314 -1.34911 -2.841258
# C_ID_5c240d6e3c             NaN  0.415764      NaN  1.247291

# %%
temp1['authorized_flag'].value_counts()
# Out:
# 1    7
# 0    2
# Name: authorized_flag, dtype: int64

# %%
def agg_on_cat(df, category, feature):
    temp_df = df.pivot_table(index='card_id', columns=category, aggfunc={feature: ['sum', 'mean']})
    cols = [category + '_{0[2]}_{0[0]}_{0[1]}'.format(col) for col in temp_df.columns.tolist()]
    temp_df.columns = cols
    return temp_df

# %%
agg_on_cat(temp1, 'category_2', 'purchase_amount')
# Out:
#                  category_2_1.0_purchase_amount_mean  \
# card_id
# C_ID_05042ebd55                            -0.699484
# C_ID_5c240d6e3c                             0.415764
#
#                  category_2_3.0_purchase_amount_mean  \
# card_id
# C_ID_05042ebd55                            -0.692948
# C_ID_5c240d6e3c                                  NaN
#
#                  category_2_1.0_purchase_amount_sum  \
# card_id
# C_ID_05042ebd55                           -3.497421
# C_ID_5c240d6e3c                            1.247291
#
#                  category_2_3.0_purchase_amount_sum
# card_id
# C_ID_05042ebd55                           -0.692948
# C_ID_5c240d6e3c                                 NaN

# %%
agg_on_cat(temp1, 'category_3', 'purchase_amount')
# Out:
#                  category_3_A_purchase_amount_mean  \
# card_id
# C_ID_05042ebd55                          -0.698395
# C_ID_5c240d6e3c                           0.415764
#
#                  category_3_A_purchase_amount_sum
# card_id
# C_ID_05042ebd55                         -4.190368
# C_ID_5c240d6e3c                          1.247291

# %%
agg_on_cat(temp1, 'authorized_flag', 'purchase_amount')
# Out:
#                  authorized_flag_0_purchase_amount_mean  \
# card_id
# C_ID_05042ebd55                               -0.674555
# C_ID_5c240d6e3c                                     NaN
#
#                  authorized_flag_1_purchase_amount_mean  \
# card_id
# C_ID_05042ebd55                               -0.710314
# C_ID_5c240d6e3c                                0.415764
#
#                  authorized_flag_0_purchase_amount_sum  \
# card_id
# C_ID_05042ebd55                               -1.34911
# C_ID_5c240d6e3c                                    NaN
#
#                  authorized_flag_1_purchase_amount_sum
# card_id
# C_ID_05042ebd55                              -2.841258
# C_ID_5c240d6e3c                               1.247291

# %%
new_hist_trans = feather.read_dataframe('new_hist_trans')

# %%
agg_on_cat(new_hist_trans, 'category_2', 'purchase_amount')
# Out:
#                  category_2_1.0_purchase_amount_mean  \
# card_id
# C_ID_00007093c1                            -0.656749
# C_ID_0001238066                            -0.580966
# C_ID_0001506ef0                                  NaN
# C_ID_0001793786                             0.139747
# C_ID_000183fdda                                  NaN
# C_ID_0002709b5a                            -0.680791
# C_ID_000298032a                            -0.641872
# C_ID_0002ba3c2e                                  NaN
# C_ID_0002c7c2c1                            -0.654908
# C_ID_00032df08f                            -0.348942
# C_ID_0003754056                            -0.709342
# C_ID_000377f6a0                                  NaN
# C_ID_0003be3c83                            -0.573552
# C_ID_0003f41435                            -0.732820
# C_ID_00042d509c                            -0.467264
# C_ID_0004587331                                  NaN
# C_ID_0004725b87                            -0.619197
# C_ID_0004888ddd                                  NaN
# C_ID_0004b68c49                            -0.611451
# C_ID_0004c2a5ab                            -0.589558
# C_ID_00057b99fe                            -0.701828
# C_ID_000599daf9                                  NaN
# C_ID_0005f16cc8                            -0.607161
# C_ID_0006152db8                                  NaN
# C_ID_000616f4a8                            -0.454958
# C_ID_000664aa02                            -0.530032
# C_ID_00079fec55                            -0.326466
# C_ID_0007a60a33                                  NaN
# C_ID_0007fe3157                            -0.671598
# C_ID_000844d8f1                            -0.708820
# ...                                              ...
# C_ID_fffaed41f0                            -0.687328
# C_ID_fffb79fb56                            -0.671775
# C_ID_fffba72dc5                            -0.435108
# C_ID_fffbdf036b                            -0.660645
# C_ID_fffbee5c24                                  NaN
# C_ID_fffc96bf24                                  NaN
# C_ID_fffcb74f49                            -0.649010
# C_ID_fffcf66e12                                  NaN
# C_ID_fffd070e0e                             1.795077
# C_ID_fffd1207a8                            -0.679125
# C_ID_fffd24dcf3                            -0.351734
# C_ID_fffd337484                                  NaN
# C_ID_fffd345048                            -0.667013
# C_ID_fffd351e7f                            -0.612987
# C_ID_fffd93c8bf                                  NaN
# C_ID_fffd943b91                            -0.637790
# C_ID_fffdad8aa0                            -0.697920
# C_ID_fffde15ab6                            -0.706486
# C_ID_fffdf34798                                  NaN
# C_ID_fffe29a04a                            -0.697245
# C_ID_fffe78b232                            -0.556576
# C_ID_fffe866457                            -0.542865
# C_ID_fffea6de74                                  NaN
# C_ID_fffeced303                            -0.717456
# C_ID_fffeed3a89                            -0.038712
# C_ID_ffff1d9928                            -0.728876
# C_ID_ffff579d3a                            -0.664262
# C_ID_ffff756266                             0.378578
# C_ID_ffff828181                            -0.622448
# C_ID_fffffd5772                                  NaN
#
#                  category_2_2.0_purchase_amount_mean  \
# card_id
# C_ID_00007093c1                                  NaN
# C_ID_0001238066                                  NaN
# C_ID_0001506ef0                                  NaN
# C_ID_0001793786                            -0.344766
# C_ID_000183fdda                                  NaN
# C_ID_0002709b5a                            -0.726367
# C_ID_000298032a                                  NaN
# C_ID_0002ba3c2e                            -0.690353
# C_ID_0002c7c2c1                                  NaN
# C_ID_00032df08f                                  NaN
# C_ID_0003754056                                  NaN
# C_ID_000377f6a0                                  NaN
# C_ID_0003be3c83                                  NaN
# C_ID_0003f41435                                  NaN
# C_ID_00042d509c                                  NaN
# C_ID_0004587331                                  NaN
# C_ID_0004725b87                                  NaN
# C_ID_0004888ddd                                  NaN
# C_ID_0004b68c49                                  NaN
# C_ID_0004c2a5ab                                  NaN
# C_ID_00057b99fe                                  NaN
# C_ID_000599daf9                                  NaN
# C_ID_0005f16cc8                                  NaN
# C_ID_0006152db8                                  NaN
# C_ID_000616f4a8                                  NaN
# C_ID_000664aa02                                  NaN
# C_ID_00079fec55                                  NaN
# C_ID_0007a60a33                                  NaN
# C_ID_0007fe3157                                  NaN
# C_ID_000844d8f1                                  NaN
# ...                                              ...
# C_ID_fffaed41f0                                  NaN
# C_ID_fffb79fb56                                  NaN
# C_ID_fffba72dc5                                  NaN
# C_ID_fffbdf036b                                  NaN
# C_ID_fffbee5c24                            -0.571759
# C_ID_fffc96bf24                                  NaN
# C_ID_fffcb74f49                                  NaN
# C_ID_fffcf66e12                                  NaN
# C_ID_fffd070e0e                                  NaN
# C_ID_fffd1207a8                                  NaN
# C_ID_fffd24dcf3                                  NaN
# C_ID_fffd337484                                  NaN
# C_ID_fffd345048                                  NaN
# C_ID_fffd351e7f                            -0.296212
# C_ID_fffd93c8bf                                  NaN
# C_ID_fffd943b91                                  NaN
# C_ID_fffdad8aa0                                  NaN
# C_ID_fffde15ab6                                  NaN
# C_ID_fffdf34798                            -0.691915
# C_ID_fffe29a04a                                  NaN
# C_ID_fffe78b232                                  NaN
# C_ID_fffe866457                                  NaN
# C_ID_fffea6de74                                  NaN
# C_ID_fffeced303                                  NaN
# C_ID_fffeed3a89                                  NaN
# C_ID_ffff1d9928                                  NaN
# C_ID_ffff579d3a                                  NaN
# C_ID_ffff756266                                  NaN
# C_ID_ffff828181                            -0.679659
# C_ID_fffffd5772                                  NaN
#
#                  category_2_3.0_purchase_amount_mean  \
# card_id
# C_ID_00007093c1                            -0.671775
# C_ID_0001238066                                  NaN
# C_ID_0001506ef0                            -0.723677
# C_ID_0001793786                             0.102887
# C_ID_000183fdda                            -0.599162
# C_ID_0002709b5a                                  NaN
# C_ID_000298032a                                  NaN
# C_ID_0002ba3c2e                                  NaN
# C_ID_0002c7c2c1                                  NaN
# C_ID_00032df08f                                  NaN
# C_ID_0003754056                                  NaN
# C_ID_000377f6a0                            -0.613172
# C_ID_0003be3c83                                  NaN
# C_ID_0003f41435                                  NaN
# C_ID_00042d509c                            -0.720687
# C_ID_0004587331                            -0.734271
# C_ID_0004725b87                                  NaN
# C_ID_0004888ddd                            -0.693113
# C_ID_0004b68c49                                  NaN
# C_ID_0004c2a5ab                                  NaN
# C_ID_00057b99fe                                  NaN
# C_ID_000599daf9                            -0.581434
# C_ID_0005f16cc8                            -0.575666
# C_ID_0006152db8                                  NaN
# C_ID_000616f4a8                                  NaN
# C_ID_000664aa02                                  NaN
# C_ID_00079fec55                                  NaN
# C_ID_0007a60a33                                  NaN
# C_ID_0007fe3157                                  NaN
# C_ID_000844d8f1                                  NaN
# ...                                              ...
# C_ID_fffaed41f0                                  NaN
# C_ID_fffb79fb56                                  NaN
# C_ID_fffba72dc5                                  NaN
# C_ID_fffbdf036b                                  NaN
# C_ID_fffbee5c24                                  NaN
# C_ID_fffc96bf24                                  NaN
# C_ID_fffcb74f49                                  NaN
# C_ID_fffcf66e12                                  NaN
# C_ID_fffd070e0e                                  NaN
# C_ID_fffd1207a8                                  NaN
# C_ID_fffd24dcf3                                  NaN
# C_ID_fffd337484                            -0.387184
# C_ID_fffd345048                                  NaN
# C_ID_fffd351e7f                            -0.687668
# C_ID_fffd93c8bf                            -0.661382
# C_ID_fffd943b91                                  NaN
# C_ID_fffdad8aa0                                  NaN
# C_ID_fffde15ab6                                  NaN
# C_ID_fffdf34798                                  NaN
# C_ID_fffe29a04a                                  NaN
# C_ID_fffe78b232                                  NaN
# C_ID_fffe866457                                  NaN
# C_ID_fffea6de74                            -0.674931
# C_ID_fffeced303                                  NaN
# C_ID_fffeed3a89                            -0.730401
# C_ID_ffff1d9928                                  NaN
# C_ID_ffff579d3a                                  NaN
# C_ID_ffff756266                                  NaN
# C_ID_ffff828181                                  NaN
# C_ID_fffffd5772                            -0.708490
#
#                  category_2_4.0_purchase_amount_mean  \
# card_id
# C_ID_00007093c1                                  NaN
# C_ID_0001238066                                  NaN
# C_ID_0001506ef0                                  NaN
# C_ID_0001793786                                  NaN
# C_ID_000183fdda                                  NaN
# C_ID_0002709b5a                                  NaN
# C_ID_000298032a                                  NaN
# C_ID_0002ba3c2e                                  NaN
# C_ID_0002c7c2c1                                  NaN
# C_ID_00032df08f                                  NaN
# C_ID_0003754056                                  NaN
# C_ID_000377f6a0                                  NaN
# C_ID_0003be3c83                                  NaN
# C_ID_0003f41435                                  NaN
# C_ID_00042d509c                                  NaN
# C_ID_0004587331                                  NaN
# C_ID_0004725b87                                  NaN
# C_ID_0004888ddd                                  NaN
# C_ID_0004b68c49                                  NaN
# C_ID_0004c2a5ab                                  NaN
# C_ID_00057b99fe                                  NaN
# C_ID_000599daf9                                  NaN
# C_ID_0005f16cc8                                  NaN
# C_ID_0006152db8                            -0.533231
# C_ID_000616f4a8                                  NaN
# C_ID_000664aa02                                  NaN
# C_ID_00079fec55                                  NaN
# C_ID_0007a60a33                                  NaN
# C_ID_0007fe3157                                  NaN
# C_ID_000844d8f1                                  NaN
# ...                                              ...
# C_ID_fffaed41f0                                  NaN
# C_ID_fffb79fb56                                  NaN
# C_ID_fffba72dc5                                  NaN
# C_ID_fffbdf036b                                  NaN
# C_ID_fffbee5c24                                  NaN
# C_ID_fffc96bf24                             0.264016
# C_ID_fffcb74f49                                  NaN
# C_ID_fffcf66e12                                  NaN
# C_ID_fffd070e0e                                  NaN
# C_ID_fffd1207a8                                  NaN
# C_ID_fffd24dcf3                                  NaN
# C_ID_fffd337484                                  NaN
# C_ID_fffd345048                                  NaN
# C_ID_fffd351e7f                            -0.695066
# C_ID_fffd93c8bf                            -0.562809
# C_ID_fffd943b91                                  NaN
# C_ID_fffdad8aa0                                  NaN
# C_ID_fffde15ab6                                  NaN
# C_ID_fffdf34798                                  NaN
# C_ID_fffe29a04a                                  NaN
# C_ID_fffe78b232                                  NaN
# C_ID_fffe866457                                  NaN
# C_ID_fffea6de74                                  NaN
# C_ID_fffeced303                                  NaN
# C_ID_fffeed3a89                            -0.564688
# C_ID_ffff1d9928                            -0.577158
# C_ID_ffff579d3a                                  NaN
# C_ID_ffff756266                                  NaN
# C_ID_ffff828181                            -0.528941
# C_ID_fffffd5772                                  NaN
#
#                  category_2_5.0_purchase_amount_mean  \
# card_id
# C_ID_00007093c1                                  NaN
# C_ID_0001238066                            -0.495945
# C_ID_0001506ef0                                  NaN
# C_ID_0001793786                            -0.361628
# C_ID_000183fdda                                  NaN
# C_ID_0002709b5a                            -0.611669
# C_ID_000298032a                                  NaN
# C_ID_0002ba3c2e                                  NaN
# C_ID_0002c7c2c1                                  NaN
# C_ID_00032df08f                                  NaN
# C_ID_0003754056                                  NaN
# C_ID_000377f6a0                                  NaN
# C_ID_0003be3c83                                  NaN
# C_ID_0003f41435                                  NaN
# C_ID_00042d509c                                  NaN
# C_ID_0004587331                                  NaN
# C_ID_0004725b87                                  NaN
# C_ID_0004888ddd                                  NaN
# C_ID_0004b68c49                                  NaN
# C_ID_0004c2a5ab                                  NaN
# C_ID_00057b99fe                                  NaN
# C_ID_000599daf9                                  NaN
# C_ID_0005f16cc8                                  NaN
# C_ID_0006152db8                                  NaN
# C_ID_000616f4a8                                  NaN
# C_ID_000664aa02                                  NaN
# C_ID_00079fec55                                  NaN
# C_ID_0007a60a33                            -0.737892
# C_ID_0007fe3157                                  NaN
# C_ID_000844d8f1                            -0.731881
# ...                                              ...
# C_ID_fffaed41f0                            -0.646389
# C_ID_fffb79fb56                                  NaN
# C_ID_fffba72dc5                                  NaN
# C_ID_fffbdf036b                                  NaN
# C_ID_fffbee5c24                                  NaN
# C_ID_fffc96bf24                                  NaN
# C_ID_fffcb74f49                                  NaN
# C_ID_fffcf66e12                            -0.685825
# C_ID_fffd070e0e                                  NaN
# C_ID_fffd1207a8                                  NaN
# C_ID_fffd24dcf3                                  NaN
# C_ID_fffd337484                                  NaN
# C_ID_fffd345048                                  NaN
# C_ID_fffd351e7f                                  NaN
# C_ID_fffd93c8bf                                  NaN
# C_ID_fffd943b91                                  NaN
# C_ID_fffdad8aa0                                  NaN
# C_ID_fffde15ab6                                  NaN
# C_ID_fffdf34798                            -0.684398
# C_ID_fffe29a04a                                  NaN
# C_ID_fffe78b232                                  NaN
# C_ID_fffe866457                                  NaN
# C_ID_fffea6de74                            -0.709342
# C_ID_fffeced303                                  NaN
# C_ID_fffeed3a89                            -0.601828
# C_ID_ffff1d9928                                  NaN
# C_ID_ffff579d3a                                  NaN
# C_ID_ffff756266                                  NaN
# C_ID_ffff828181                                  NaN
# C_ID_fffffd5772                                  NaN
#
#                  category_2_1.0_purchase_amount_sum  \
# card_id
# C_ID_00007093c1                           -0.656749
# C_ID_0001238066                          -13.362220
# C_ID_0001506ef0                                 NaN
# C_ID_0001793786                            2.375707
# C_ID_000183fdda                                 NaN
# C_ID_0002709b5a                           -0.680791
# C_ID_000298032a                           -0.641872
# C_ID_0002ba3c2e                                 NaN
# C_ID_0002c7c2c1                           -3.929448
# C_ID_00032df08f                           -2.791535
# C_ID_0003754056                           -0.709342
# C_ID_000377f6a0                                 NaN
# C_ID_0003be3c83                           -3.441312
# C_ID_0003f41435                           -1.465641
# C_ID_00042d509c                           -0.467264
# C_ID_0004587331                                 NaN
# C_ID_0004725b87                           -1.238395
# C_ID_0004888ddd                                 NaN
# C_ID_0004b68c49                           -1.222903
# C_ID_0004c2a5ab                           -1.179115
# C_ID_00057b99fe                           -0.701828
# C_ID_000599daf9                                 NaN
# C_ID_0005f16cc8                           -0.607161
# C_ID_0006152db8                                 NaN
# C_ID_000616f4a8                           -2.274788
# C_ID_000664aa02                           -4.240256
# C_ID_00079fec55                           -0.326466
# C_ID_0007a60a33                                 NaN
# C_ID_0007fe3157                           -6.044384
# C_ID_000844d8f1                           -9.923478
# ...                                             ...
# C_ID_fffaed41f0                           -1.374655
# C_ID_fffb79fb56                           -0.671775
# C_ID_fffba72dc5                           -0.870215
# C_ID_fffbdf036b                          -13.873543
# C_ID_fffbee5c24                                 NaN
# C_ID_fffc96bf24                                 NaN
# C_ID_fffcb74f49                           -1.947030
# C_ID_fffcf66e12                                 NaN
# C_ID_fffd070e0e                            5.385231
# C_ID_fffd1207a8                           -6.791247
# C_ID_fffd24dcf3                           -3.165605
# C_ID_fffd337484                                 NaN
# C_ID_fffd345048                          -11.339216
# C_ID_fffd351e7f                           -6.129870
# C_ID_fffd93c8bf                                 NaN
# C_ID_fffd943b91                           -1.913371
# C_ID_fffdad8aa0                           -9.770884
# C_ID_fffde15ab6                           -0.706486
# C_ID_fffdf34798                                 NaN
# C_ID_fffe29a04a                           -2.788981
# C_ID_fffe78b232                           -4.452611
# C_ID_fffe866457                           -4.342917
# C_ID_fffea6de74                                 NaN
# C_ID_fffeced303                           -1.434912
# C_ID_fffeed3a89                           -0.154848
# C_ID_ffff1d9928                           -0.728876
# C_ID_ffff579d3a                           -0.664262
# C_ID_ffff756266                            0.378578
# C_ID_ffff828181                           -1.867345
# C_ID_fffffd5772                                 NaN
#
#                  category_2_2.0_purchase_amount_sum  \
# card_id
# C_ID_00007093c1                                 NaN
# C_ID_0001238066                                 NaN
# C_ID_0001506ef0                                 NaN
# C_ID_0001793786                           -2.758131
# C_ID_000183fdda                                 NaN
# C_ID_0002709b5a                           -0.726367
# C_ID_000298032a                                 NaN
# C_ID_0002ba3c2e                           -2.071059
# C_ID_0002c7c2c1                                 NaN
# C_ID_00032df08f                                 NaN
# C_ID_0003754056                                 NaN
# C_ID_000377f6a0                                 NaN
# C_ID_0003be3c83                                 NaN
# C_ID_0003f41435                                 NaN
# C_ID_00042d509c                                 NaN
# C_ID_0004587331                                 NaN
# C_ID_0004725b87                                 NaN
# C_ID_0004888ddd                                 NaN
# C_ID_0004b68c49                                 NaN
# C_ID_0004c2a5ab                                 NaN
# C_ID_00057b99fe                                 NaN
# C_ID_000599daf9                                 NaN
# C_ID_0005f16cc8                                 NaN
# C_ID_0006152db8                                 NaN
# C_ID_000616f4a8                                 NaN
# C_ID_000664aa02                                 NaN
# C_ID_00079fec55                                 NaN
# C_ID_0007a60a33                                 NaN
# C_ID_0007fe3157                                 NaN
# C_ID_000844d8f1                                 NaN
# ...                                             ...
# C_ID_fffaed41f0                                 NaN
# C_ID_fffb79fb56                                 NaN
# C_ID_fffba72dc5                                 NaN
# C_ID_fffbdf036b                                 NaN
# C_ID_fffbee5c24                           -2.858794
# C_ID_fffc96bf24                                 NaN
# C_ID_fffcb74f49                                 NaN
# C_ID_fffcf66e12                                 NaN
# C_ID_fffd070e0e                                 NaN
# C_ID_fffd1207a8                                 NaN
# C_ID_fffd24dcf3                                 NaN
# C_ID_fffd337484                                 NaN
# C_ID_fffd345048                                 NaN
# C_ID_fffd351e7f                           -2.962116
# C_ID_fffd93c8bf                                 NaN
# C_ID_fffd943b91                                 NaN
# C_ID_fffdad8aa0                                 NaN
# C_ID_fffde15ab6                                 NaN
# C_ID_fffdf34798                           -2.767658
# C_ID_fffe29a04a                                 NaN
# C_ID_fffe78b232                                 NaN
# C_ID_fffe866457                                 NaN
# C_ID_fffea6de74                                 NaN
# C_ID_fffeced303                                 NaN
# C_ID_fffeed3a89                                 NaN
# C_ID_ffff1d9928                                 NaN
# C_ID_ffff579d3a                                 NaN
# C_ID_ffff756266                                 NaN
# C_ID_ffff828181                           -2.038977
# C_ID_fffffd5772                                 NaN
#
#                  category_2_3.0_purchase_amount_sum  \
# card_id
# C_ID_00007093c1                           -0.671775
# C_ID_0001238066                                 NaN
# C_ID_0001506ef0                           -1.447354
# C_ID_0001793786                            0.514433
# C_ID_000183fdda                           -6.590778
# C_ID_0002709b5a                                 NaN
# C_ID_000298032a                                 NaN
# C_ID_0002ba3c2e                                 NaN
# C_ID_0002c7c2c1                                 NaN
# C_ID_00032df08f                                 NaN
# C_ID_0003754056                                 NaN
# C_ID_000377f6a0                           -0.613172
# C_ID_0003be3c83                                 NaN
# C_ID_0003f41435                                 NaN
# C_ID_00042d509c                           -0.720687
# C_ID_0004587331                           -1.468541
# C_ID_0004725b87                                 NaN
# C_ID_0004888ddd                           -1.386226
# C_ID_0004b68c49                                 NaN
# C_ID_0004c2a5ab                                 NaN
# C_ID_00057b99fe                                 NaN
# C_ID_000599daf9                           -5.232908
# C_ID_0005f16cc8                           -1.151331
# C_ID_0006152db8                                 NaN
# C_ID_000616f4a8                                 NaN
# C_ID_000664aa02                                 NaN
# C_ID_00079fec55                                 NaN
# C_ID_0007a60a33                                 NaN
# C_ID_0007fe3157                                 NaN
# C_ID_000844d8f1                                 NaN
# ...                                             ...
# C_ID_fffaed41f0                                 NaN
# C_ID_fffb79fb56                                 NaN
# C_ID_fffba72dc5                                 NaN
# C_ID_fffbdf036b                                 NaN
# C_ID_fffbee5c24                                 NaN
# C_ID_fffc96bf24                                 NaN
# C_ID_fffcb74f49                                 NaN
# C_ID_fffcf66e12                                 NaN
# C_ID_fffd070e0e                                 NaN
# C_ID_fffd1207a8                                 NaN
# C_ID_fffd24dcf3                                 NaN
# C_ID_fffd337484                           -1.548737
# C_ID_fffd345048                                 NaN
# C_ID_fffd351e7f                           -4.126010
# C_ID_fffd93c8bf                           -3.968291
# C_ID_fffd943b91                                 NaN
# C_ID_fffdad8aa0                                 NaN
# C_ID_fffde15ab6                                 NaN
# C_ID_fffdf34798                                 NaN
# C_ID_fffe29a04a                                 NaN
# C_ID_fffe78b232                                 NaN
# C_ID_fffe866457                                 NaN
# C_ID_fffea6de74                           -7.424239
# C_ID_fffeced303                                 NaN
# C_ID_fffeed3a89                           -1.460802
# C_ID_ffff1d9928                                 NaN
# C_ID_ffff579d3a                                 NaN
# C_ID_ffff756266                                 NaN
# C_ID_ffff828181                                 NaN
# C_ID_fffffd5772                           -2.125470
#
#                  category_2_4.0_purchase_amount_sum  \
# card_id
# C_ID_00007093c1                                 NaN
# C_ID_0001238066                                 NaN
# C_ID_0001506ef0                                 NaN
# C_ID_0001793786                                 NaN
# C_ID_000183fdda                                 NaN
# C_ID_0002709b5a                                 NaN
# C_ID_000298032a                                 NaN
# C_ID_0002ba3c2e                                 NaN
# C_ID_0002c7c2c1                                 NaN
# C_ID_00032df08f                                 NaN
# C_ID_0003754056                                 NaN
# C_ID_000377f6a0                                 NaN
# C_ID_0003be3c83                                 NaN
# C_ID_0003f41435                                 NaN
# C_ID_00042d509c                                 NaN
# C_ID_0004587331                                 NaN
# C_ID_0004725b87                                 NaN
# C_ID_0004888ddd                                 NaN
# C_ID_0004b68c49                                 NaN
# C_ID_0004c2a5ab                                 NaN
# C_ID_00057b99fe                                 NaN
# C_ID_000599daf9                                 NaN
# C_ID_0005f16cc8                                 NaN
# C_ID_0006152db8                           -1.066462
# C_ID_000616f4a8                                 NaN
# C_ID_000664aa02                                 NaN
# C_ID_00079fec55                                 NaN
# C_ID_0007a60a33                                 NaN
# C_ID_0007fe3157                                 NaN
# C_ID_000844d8f1                                 NaN
# ...                                             ...
# C_ID_fffaed41f0                                 NaN
# C_ID_fffb79fb56                                 NaN
# C_ID_fffba72dc5                                 NaN
# C_ID_fffbdf036b                                 NaN
# C_ID_fffbee5c24                                 NaN
# C_ID_fffc96bf24                            0.792047
# C_ID_fffcb74f49                                 NaN
# C_ID_fffcf66e12                                 NaN
# C_ID_fffd070e0e                                 NaN
# C_ID_fffd1207a8                                 NaN
# C_ID_fffd24dcf3                                 NaN
# C_ID_fffd337484                                 NaN
# C_ID_fffd345048                                 NaN
# C_ID_fffd351e7f                           -2.780265
# C_ID_fffd93c8bf                           -3.939666
# C_ID_fffd943b91                                 NaN
# C_ID_fffdad8aa0                                 NaN
# C_ID_fffde15ab6                                 NaN
# C_ID_fffdf34798                                 NaN
# C_ID_fffe29a04a                                 NaN
# C_ID_fffe78b232                                 NaN
# C_ID_fffe866457                                 NaN
# C_ID_fffea6de74                                 NaN
# C_ID_fffeced303                                 NaN
# C_ID_fffeed3a89                           -3.952814
# C_ID_ffff1d9928                           -1.731475
# C_ID_ffff579d3a                                 NaN
# C_ID_ffff756266                                 NaN
# C_ID_ffff828181                           -1.057881
# C_ID_fffffd5772                                 NaN
#
#                  category_2_5.0_purchase_amount_sum
# card_id
# C_ID_00007093c1                                 NaN
# C_ID_0001238066                           -1.487835
# C_ID_0001506ef0                                 NaN
# C_ID_0001793786                           -0.361628
# C_ID_000183fdda                                 NaN
# C_ID_0002709b5a                           -0.611669
# C_ID_000298032a                                 NaN
# C_ID_0002ba3c2e                                 NaN
# C_ID_0002c7c2c1                                 NaN
# C_ID_00032df08f                                 NaN
# C_ID_0003754056                                 NaN
# C_ID_000377f6a0                                 NaN
# C_ID_0003be3c83                                 NaN
# C_ID_0003f41435                                 NaN
# C_ID_00042d509c                                 NaN
# C_ID_0004587331                                 NaN
# C_ID_0004725b87                                 NaN
# C_ID_0004888ddd                                 NaN
# C_ID_0004b68c49                                 NaN
# C_ID_0004c2a5ab                                 NaN
# C_ID_00057b99fe                                 NaN
# C_ID_000599daf9                                 NaN
# C_ID_0005f16cc8                                 NaN
# C_ID_0006152db8                                 NaN
# C_ID_000616f4a8                                 NaN
# C_ID_000664aa02                                 NaN
# C_ID_00079fec55                                 NaN
# C_ID_0007a60a33                           -0.737892
# C_ID_0007fe3157                                 NaN
# C_ID_000844d8f1                           -0.731881
# ...                                             ...
# C_ID_fffaed41f0                          -10.342222
# C_ID_fffb79fb56                                 NaN
# C_ID_fffba72dc5                                 NaN
# C_ID_fffbdf036b                                 NaN
# C_ID_fffbee5c24                                 NaN
# C_ID_fffc96bf24                                 NaN
# C_ID_fffcb74f49                                 NaN
# C_ID_fffcf66e12                           -0.685825
# C_ID_fffd070e0e                                 NaN
# C_ID_fffd1207a8                                 NaN
# C_ID_fffd24dcf3                                 NaN
# C_ID_fffd337484                                 NaN
# C_ID_fffd345048                                 NaN
# C_ID_fffd351e7f                                 NaN
# C_ID_fffd93c8bf                                 NaN
# C_ID_fffd943b91                                 NaN
# C_ID_fffdad8aa0                                 NaN
# C_ID_fffde15ab6                                 NaN
# C_ID_fffdf34798                           -0.684398
# C_ID_fffe29a04a                                 NaN
# C_ID_fffe78b232                                 NaN
# C_ID_fffe866457                                 NaN
# C_ID_fffea6de74                           -0.709342
# C_ID_fffeced303                                 NaN
# C_ID_fffeed3a89                          -22.869479
# C_ID_ffff1d9928                                 NaN
# C_ID_ffff579d3a                                 NaN
# C_ID_ffff756266                                 NaN
# C_ID_ffff828181                                 NaN
# C_ID_fffffd5772                                 NaN
#
# [290001 rows x 10 columns]

# %%
p
# Out:
#                 purchase_amount
#                            mean                 sum
# category_2                  1.0       3.0       1.0       3.0
# card_id
# C_ID_05042ebd55       -0.699484 -0.692948 -3.497421 -0.692948
# C_ID_5c240d6e3c        0.415764       NaN  1.247291       NaN

# %%
temp1.groupby(['card_id','category_2'])['purchase_amount'].agg(['sum']).groupby('card_id').sum()
# Out:
#                       sum
# card_id
# C_ID_05042ebd55 -4.190368
# C_ID_5c240d6e3c  1.247291

# %%
temp1.groupby('card_id').agg({'category_2': 'count'})
# Out:
#                  category_2
# card_id
# C_ID_05042ebd55           6
# C_ID_5c240d6e3c           3

# %% [markdown]
# ### Automated

# %%
# DataFrameSummary(new_hist_trans).summary().T

# %%
 import featuretools as ft

# %%
PATH = 'data/elo/'

# %%
train, test = [pd.read_csv(f'{PATH}{c}') for c in ['train.csv', 'test.csv']]

# %%
train.head().T
# Out:
#                                   0                1                2  \
# first_active_month          2017-06          2017-01          2016-08
# card_id             C_ID_92a2005557  C_ID_3d0044924f  C_ID_d639edf6cd
# feature_1                         5                4                2
# feature_2                         2                1                2
# feature_3                         1                0                0
# target                    -0.820283         0.392913         0.688056
#
#                                   3                4
# first_active_month          2017-09          2017-11
# card_id             C_ID_186d6a6901  C_ID_cdbd2c0db2
# feature_1                         4                1
# feature_2                         3                3
# feature_3                         0                0
# target                     0.142495        -0.159749

# %%
def additional_feats(hist_df):
    hist_df['price'] = hist_df['purchase_amount'] / hist_df['installments']
    #Christmas : December 25 2017
    hist_df['Christmas_Day_2017']=(pd.to_datetime('2017-12-25')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Mothers Day: May 14 2017
    hist_df['Mothers_Day_2017']=(pd.to_datetime('2017-06-04')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #fathers day: August 13 2017
    hist_df['fathers_day_2017']=(pd.to_datetime('2017-08-13')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Childrens day: October 12 2017
    hist_df['Children_day_2017']=(pd.to_datetime('2017-10-12')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Valentine's Day : 12th June, 2017
    hist_df['Valentine_Day_2017']=(pd.to_datetime('2017-06-12')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #Black Friday : 24th November 2017
    hist_df['Black_Friday_2017']=(pd.to_datetime('2017-11-24') - hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    #2018
    #Mothers Day: May 13 2018
    hist_df['Mothers_Day_2018']=(pd.to_datetime('2018-05-13')-hist_df['purchase_date']).dt.days.apply(lambda x: x if x > 0 and x < 100 else 0)
    hist_df['duration'] = hist_df['purchase_amount']*hist_df['month_diff']
    hist_df['amount_month_ratio'] = hist_df['purchase_amount']/hist_df['month_diff']
    return hist_df

# %%
dfs = [hist_trans, new_hist_trans]

# %%
hist_trans, new_hist_trans = [additional_feats(df) for df in dfs]

# %%
hist_trans.head().T
# Out:
#                                                  0                    1  \
# authorized_flag                                  1                    1
# card_id                            C_ID_4e6213e9bc      C_ID_4e6213e9bc
# city_id                                         88                   88
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  367
# merchant_id                        M_ID_e020e9b302      M_ID_86ec983688
# month_lag                                       -8                   -7
# purchase_amount                          -0.703331            -0.733128
# purchase_date                  2017-06-25 15:33:07  2017-07-15 12:10:45
# category_2                                       1                    1
# state_id                                        16                   16
# subsector_id                                    37                   16
# purchase_Year                                 2017                 2017
# purchase_Month                                   6                    7
# purchase_Week                                   25                   28
# purchase_Day                                    25                   15
# purchase_Dayofweek                               6                    5
# purchase_Dayofyear                             176                  196
# purchase_Is_month_end                        False                False
# purchase_Is_month_start                      False                False
# purchase_Is_quarter_end                      False                False
# purchase_Is_quarter_start                    False                False
# purchase_Is_year_end                         False                False
# purchase_Is_year_start                       False                False
# purchase_Elapsed                        1498404787           1500120645
# purchased_on_weekend                             1                    1
# month_diff                                      11                   11
# purchase_date_successive_diff               150590                50683
# price                                         -inf                 -inf
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                48                   28
# Children_day_2017                                0                   88
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
# duration                                  -7.73664             -8.06441
# amount_month_ratio                      -0.0639392            -0.066648
#
#                                                  2                    3  \
# authorized_flag                                  1                    1
# card_id                            C_ID_4e6213e9bc      C_ID_4e6213e9bc
# city_id                                         88                   88
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  560
# merchant_id                        M_ID_979ed661fc      M_ID_e6d5ae8ea6
# month_lag                                       -6                   -5
# purchase_amount                          -0.720386            -0.735352
# purchase_date                  2017-08-09 22:04:29  2017-09-02 10:06:26
# category_2                                       1                    1
# state_id                                        16                   16
# subsector_id                                    37                   34
# purchase_Year                                 2017                 2017
# purchase_Month                                   8                    9
# purchase_Week                                   32                   35
# purchase_Day                                     9                    2
# purchase_Dayofweek                               2                    5
# purchase_Dayofyear                             221                  245
# purchase_Is_month_end                        False                False
# purchase_Is_month_start                      False                False
# purchase_Is_quarter_end                      False                False
# purchase_Is_quarter_start                    False                False
# purchase_Is_year_end                         False                False
# purchase_Is_year_start                       False                False
# purchase_Elapsed                        1502316269           1504346786
# purchased_on_weekend                             0                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                32504                66123
# price                                         -inf                 -inf
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 3                    0
# Children_day_2017                               63                   39
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                   82
# Mothers_Day_2018                                 0                    0
# duration                                  -7.92425             -8.08888
# amount_month_ratio                      -0.0654896           -0.0668502
#
#                                                  4
# authorized_flag                                  1
# card_id                            C_ID_4e6213e9bc
# city_id                                         88
# category_1                                       0
# installments                                     0
# category_3                                       0
# merchant_category_id                            80
# merchant_id                        M_ID_e020e9b302
# month_lag                                      -11
# purchase_amount                          -0.722865
# purchase_date                  2017-03-10 01:14:19
# category_2                                       1
# state_id                                        16
# subsector_id                                    37
# purchase_Year                                 2017
# purchase_Month                                   3
# purchase_Week                                   10
# purchase_Day                                    10
# purchase_Dayofweek                               4
# purchase_Dayofyear                              69
# purchase_Is_month_end                        False
# purchase_Is_month_start                      False
# purchase_Is_quarter_end                      False
# purchase_Is_quarter_start                    False
# purchase_Is_year_end                         False
# purchase_Is_year_start                       False
# purchase_Elapsed                        1489108459
# purchased_on_weekend                             0
# month_diff                                      11
# purchase_date_successive_diff                33917
# price                                         -inf
# Christmas_Day_2017                               0
# Mothers_Day_2017                                85
# fathers_day_2017                                 0
# Children_day_2017                                0
# Valentine_Day_2017                              93
# Black_Friday_2017                                0
# Mothers_Day_2018                                 0
# duration                                  -7.95152
# amount_month_ratio                       -0.065715

# %%
temp = hist_trans.loc[hist_trans['card_id'].isin(['C_ID_92a2005557'])]

# %%
temp.columns.values
# Out:
# array(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments', 'category_3',
#        'merchant_category_id', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2',
#        'state_id', 'subsector_id', 'purchase_Year', 'purchase_Month', 'purchase_Week', 'purchase_Day',
#        'purchase_Dayofweek', 'purchase_Dayofyear', 'purchase_Is_month_end', 'purchase_Is_month_start',
#        'purchase_Is_quarter_end', 'purchase_Is_quarter_start', 'purchase_Is_year_end',
#        'purchase_Is_year_start', 'purchase_Elapsed', 'purchased_on_weekend', 'month_diff',
#        'purchase_date_successive_diff', 'price', 'Christmas_Day_2017', 'Mothers_Day_2017',
#        'fathers_day_2017', 'Children_day_2017', 'Valentine_Day_2017', 'Black_Friday_2017',
#        'Mothers_Day_2018', 'duration', 'amount_month_ratio'], dtype=object)

# %%
temp.drop(['purchase_Year', 'purchase_Month', 'purchase_Week', 'purchase_Day',
       'purchase_Dayofweek', 'purchase_Dayofyear', 'purchase_Is_month_end', 'purchase_Is_month_start',
       'purchase_Is_quarter_end', 'purchase_Is_quarter_start', 'purchase_Is_year_end',
       'purchase_Is_year_start', 'purchase_Elapsed'], axis=1, inplace=True)

# %%
temp.columns.values
# Out:
# array(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments', 'category_3',
#        'merchant_category_id', 'merchant_id', 'month_lag', 'purchase_amount', 'purchase_date', 'category_2',
#        'state_id', 'subsector_id', 'purchased_on_weekend', 'month_diff', 'purchase_date_successive_diff',
#        'price', 'Christmas_Day_2017', 'Mothers_Day_2017', 'fathers_day_2017', 'Children_day_2017',
#        'Valentine_Day_2017', 'Black_Friday_2017', 'Mothers_Day_2018', 'duration', 'amount_month_ratio'],
#       dtype=object)

# %%
cat_cols = ['authorized_flag', 'card_id', 'city_id', 'category_1', 'category_3',
       'merchant_category_id', 'merchant_id', 'category_2',
       'state_id', 'subsector_id', 'purchased_on_weekend']

# %%
cat_dict = {c:ft.variable_types.Categorical for c in cat_cols}

# %%
cat_dict
# Out:
# {'authorized_flag': featuretools.variable_types.variable.Categorical,
#  'card_id': featuretools.variable_types.variable.Categorical,
#  'city_id': featuretools.variable_types.variable.Categorical,
#  'category_1': featuretools.variable_types.variable.Categorical,
#  'category_3': featuretools.variable_types.variable.Categorical,
#  'merchant_category_id': featuretools.variable_types.variable.Categorical,
#  'merchant_id': featuretools.variable_types.variable.Categorical,
#  'category_2': featuretools.variable_types.variable.Categorical,
#  'state_id': featuretools.variable_types.variable.Categorical,
#  'subsector_id': featuretools.variable_types.variable.Categorical,
#  'purchased_on_weekend': featuretools.variable_types.variable.Categorical}

# %%
es = ft.EntitySet()

# %%
new_trans_es = es.entity_from_dataframe('new_trans', temp, 'index', time_index='purchase_date',
                                        variable_types=cat_dict)
# Out:
# 2019-02-03 16:12:31,782 featuretools.entityset - WARNING    index index not found in dataframe, creating new integer column

# %%
new_trans_es
# Out:
# Entityset: None
#   Entities:
#     new_trans [Rows: 260, Columns: 28]
#   Relationships:
#     No relationships

# %%
new_trans_es['new_trans']
# Out:
# Entity: new_trans
#   Variables:
#     index (dtype: index)
#     installments (dtype: numeric)
#     month_lag (dtype: numeric)
#     purchase_amount (dtype: numeric)
#     purchase_date (dtype: datetime_time_index)
#     month_diff (dtype: numeric)
#     purchase_date_successive_diff (dtype: numeric)
#     price (dtype: numeric)
#     Christmas_Day_2017 (dtype: numeric)
#     Mothers_Day_2017 (dtype: numeric)
#     fathers_day_2017 (dtype: numeric)
#     Children_day_2017 (dtype: numeric)
#     Valentine_Day_2017 (dtype: numeric)
#     Black_Friday_2017 (dtype: numeric)
#     Mothers_Day_2018 (dtype: numeric)
#     duration (dtype: numeric)
#     amount_month_ratio (dtype: numeric)
#     authorized_flag (dtype: categorical)
#     card_id (dtype: categorical)
#     city_id (dtype: categorical)
#     category_1 (dtype: categorical)
#     category_3 (dtype: categorical)
#     merchant_category_id (dtype: categorical)
#     merchant_id (dtype: categorical)
#     category_2 (dtype: categorical)
#     state_id (dtype: categorical)
#     subsector_id (dtype: categorical)
#     purchased_on_weekend (dtype: categorical)
#   Shape:
#     (Rows: 260, Columns: 28)

# %%
train_temp = train[train['card_id'].isin(['C_ID_92a2005557'])]

# %%
train_temp.columns.values
# Out:
# array(['first_active_month', 'card_id', 'feature_1', 'feature_2', 'feature_3', 'target'], dtype=object)

# %%
train_cat_cols = ['feature_1', 'feature_2', 'feature_3']

# %%
train_cat_cols = {c:ft.variable_types.Ordinal for c in train_cat_cols}

# %%
new_trans_es = es.entity_from_dataframe('train', train_temp, 'card_id', time_index='first_active_month',
                                        variable_types=train_cat_cols)

# %%
new_trans_es
# Out:
# Entityset: None
#   Entities:
#     new_trans [Rows: 260, Columns: 28]
#     train [Rows: 1, Columns: 6]
#   Relationships:
#     No relationships

# %%
new_r = ft.Relationship( new_trans_es['train']['card_id'],new_trans_es['new_trans']['card_id'])

# %%
new_trans_es = new_trans_es.add_relationship(new_r)

# %%
new_trans_es
# Out:
# Entityset: None
#   Entities:
#     new_trans [Rows: 260, Columns: 28]
#     train [Rows: 1, Columns: 6]
#   Relationships:
#     new_trans.card_id -> train.card_id

# %%
fm, fd = ft.dfs(entityset=new_trans_es, target_entity='train')

# %%
fm.T
# Out:
# card_id                                       C_ID_92a2005557
# target                                              -0.820283
# feature_1                                                   5
# feature_2                                                   2
# feature_3                                                   1
# SUM(new_trans.installments)                                 4
# SUM(new_trans.month_lag)                                -1017
# SUM(new_trans.purchase_amount)                       -165.969
# SUM(new_trans.month_diff)                                2819
# SUM(new_trans.purchase_date_successive_diff)       2.0978e+07
# SUM(new_trans.price)                                        0
# SUM(new_trans.Christmas_Day_2017)                        3412
# SUM(new_trans.Mothers_Day_2017)                             0
# SUM(new_trans.fathers_day_2017)                          1629
# SUM(new_trans.Children_day_2017)                         6959
# SUM(new_trans.Valentine_Day_2017)                           0
# SUM(new_trans.Black_Friday_2017)                         4281
# SUM(new_trans.Mothers_Day_2018)                          2016
# SUM(new_trans.duration)                              -1798.81
# SUM(new_trans.amount_month_ratio)                    -15.3321
# STD(new_trans.installments)                          0.123314
# STD(new_trans.month_lag)                              2.39769
# STD(new_trans.purchase_amount)                       0.212139
# STD(new_trans.month_diff)                            0.365155
# STD(new_trans.purchase_date_successive_diff)           107376
# STD(new_trans.price)                                      NaN
# STD(new_trans.Christmas_Day_2017)                     25.2463
# STD(new_trans.Mothers_Day_2017)                             0
# STD(new_trans.fathers_day_2017)                       12.5145
# STD(new_trans.Children_day_2017)                      34.8648
# STD(new_trans.Valentine_Day_2017)                           0
# ...                                                       ...
# NUM_UNIQUE(new_trans.category_1)                            1
# NUM_UNIQUE(new_trans.category_3)                            2
# NUM_UNIQUE(new_trans.merchant_category_id)                 41
# NUM_UNIQUE(new_trans.merchant_id)                          94
# NUM_UNIQUE(new_trans.category_2)                            2
# NUM_UNIQUE(new_trans.state_id)                              3
# NUM_UNIQUE(new_trans.subsector_id)                         21
# NUM_UNIQUE(new_trans.purchased_on_weekend)                  2
# MODE(new_trans.authorized_flag)                             1
# MODE(new_trans.city_id)                                    69
# MODE(new_trans.category_1)                                  0
# MODE(new_trans.category_3)                                  0
# MODE(new_trans.merchant_category_id)                      560
# MODE(new_trans.merchant_id)                   M_ID_1a81c358a3
# MODE(new_trans.category_2)                                  1
# MODE(new_trans.state_id)                                    9
# MODE(new_trans.subsector_id)                               34
# MODE(new_trans.purchased_on_weekend)                        0
# DAY(first_active_month)                                     1
# YEAR(first_active_month)                                 2017
# MONTH(first_active_month)                                   6
# WEEKDAY(first_active_month)                                 3
# NUM_UNIQUE(new_trans.DAY(purchase_date))                   31
# NUM_UNIQUE(new_trans.YEAR(purchase_date))                   2
# NUM_UNIQUE(new_trans.MONTH(purchase_date))                  9
# NUM_UNIQUE(new_trans.WEEKDAY(purchase_date))                7
# MODE(new_trans.DAY(purchase_date))                         11
# MODE(new_trans.YEAR(purchase_date))                      2017
# MODE(new_trans.MONTH(purchase_date))                       12
# MODE(new_trans.WEEKDAY(purchase_date))                      5
#
# [127 rows x 1 columns]

# %%
# DataFrameSummary(temp).summary().T

# %%
primitives = ft.list_primitives()
pd.options.display.max_colwidth = 100
primitives[primitives['type'] == 'aggregation']
# Out:
#                 name         type  \
# 0                all  aggregation
# 1                min  aggregation
# 2              count  aggregation
# 3                any  aggregation
# 4              trend  aggregation
# 5         num_unique  aggregation
# 6               last  aggregation
# 7       percent_true  aggregation
# 8                std  aggregation
# 9             median  aggregation
# 10              mode  aggregation
# 11     n_most_common  aggregation
# 12          num_true  aggregation
# 13              skew  aggregation
# 14  avg_time_between  aggregation
# 15              mean  aggregation
# 16   time_since_last  aggregation
# 17               max  aggregation
# 18               sum  aggregation
#
#                                                                 description
# 0                                            Test if all values are 'True'.
# 1                    Finds the minimum non-null value of a numeric feature.
# 2                                     Counts the number of non null values.
# 3                                              Test if any value is 'True'.
# 4            Calculates the slope of the linear trend of variable overtime.
# 5                       Returns the number of unique categorical variables.
# 6                                                   Returns the last value.
# 7                  Finds the percent of 'True' values in a boolean feature.
# 8   Finds the standard deviation of a numeric feature ignoring null values.
# 9           Finds the median value of any feature with well-ordered values.
# 10                  Finds the most common element in a categorical feature.
# 11               Finds the N most common elements in a categorical feature.
# 12                          Finds the number of 'True' values in a boolean.
# 13                                     Computes the skewness of a data set.
# 14                    Computes the average time between consecutive events.
# 15                         Computes the average value of a numeric feature.
# 16                                        Time since last related instance.
# 17                   Finds the maximum non-null value of a numeric feature.
# 18                           Sums elements of a numeric or boolean feature.

# %%
primitives[primitives['type'] == 'transform']
# Out:
#                    name       type  \
# 19           days_since  transform
# 20                hours  transform
# 21               divide  transform
# 22              cum_min  transform
# 23                 days  transform
# 24             numwords  transform
# 25              seconds  transform
# 26             subtract  transform
# 27            cum_count  transform
# 28                 year  transform
# 29              weekday  transform
# 30              cum_sum  transform
# 31            haversine  transform
# 32                month  transform
# 33  time_since_previous  transform
# 34                  and  transform
# 35             latitude  transform
# 36                 week  transform
# 37               minute  transform
# 38                  not  transform
# 39                 isin  transform
# 40               second  transform
# 41              is_null  transform
# 42                  mod  transform
# 43                 hour  transform
# 44           time_since  transform
# 45             multiply  transform
# 46              cum_max  transform
# 47                  day  transform
# 48           characters  transform
# 49                  add  transform
# 50             cum_mean  transform
# 51               months  transform
# 52              weekend  transform
# 53                   or  transform
# 54            longitude  transform
# 55             absolute  transform
# 56                weeks  transform
# 57              minutes  transform
# 58           percentile  transform
# 59                 diff  transform
# 60                years  transform
# 61               negate  transform
#
#                                                                                            description
# 19                           For each value of the base feature, compute the number of days between it
# 20                                             Transform a Timedelta feature into the number of hours.
# 21                                              Creates a transform feature that divides two features.
# 22     Calculates the min of previous values of an instance for each value in a time-dependent entity.
# 23                                              Transform a Timedelta feature into the number of days.
# 24                                         Returns the words in a given string by counting the spaces.
# 25                                           Transform a Timedelta feature into the number of seconds.
# 26                                            Creates a transform feature that subtracts two features.
# 27  Calculates the number of previous values of an instance for each value in a time-dependent entity.
# 28                                                         Transform a Datetime feature into the year.
# 29                                             Transform Datetime feature into the boolean of Weekday.
# 30     Calculates the sum of previous values of an instance for each value in a time-dependent entity.
# 31           Calculate the approximate haversine distance in miles between two LatLong variable types.
# 32                                                        Transform a Datetime feature into the month.
# 33                                                       Compute the time since the previous instance.
# 34                                        For two boolean values, determine if both values are 'True'.
# 35                                                  Returns the first value of the tuple base feature.
# 36                                                         Transform a Datetime feature into the week.
# 37                                                       Transform a Datetime feature into the minute.
# 38                                      For each value of the base feature, negates the boolean value.
# 39                        For each value of the base feature, checks whether it is in a provided list.
# 40                                                       Transform a Datetime feature into the second.
# 41                                     For each value of base feature, return 'True' if value is null.
# 42                                              Creates a transform feature that divides two features.
# 43                                                         Transform a Datetime feature into the hour.
# 44                                                              Calculates time since the cutoff time.
# 45                                            Creates a transform feature that multplies two features.
# 46     Calculates the max of previous values of an instance for each value in a time-dependent entity.
# 47                                                          Transform a Datetime feature into the day.
# 48                                                            Return the characters in a given string.
# 49                                                 Creates a transform feature that adds two features.
# 50    Calculates the mean of previous values of an instance for each value in a time-dependent entity.
# 51                                            Transform a Timedelta feature into the number of months.
# 52                                             Transform Datetime feature into the boolean of Weekend.
# 53                                           For two boolean values, determine if one value is 'True'.
# 54                                                 Returns the second value on the tuple base feature.
# 55                                                                     Absolute value of base feature.
# 56                                             Transform a Timedelta feature into the number of weeks.
# 57                                           Transform a Timedelta feature into the number of minutes.
# 58                           For each value of the base feature, determines the percentile in relation
# 59                  Compute the difference between the value of a base feature and the previous value.
# 60                                             Transform a Timedelta feature into the number of years.
# 61                                                 Creates a transform feature that negates a feature.

# %%
default_agg_primitives =  ["sum", "std", "max", "skew", "min", "mean", "count", "percent_true", "num_unique", "mode"]
default_trans_primitives =  ["day", "add", "month","weekday","days_since","time_since_previous", "percentile"]

# %%
feature_names = ft.dfs(entityset = new_trans_es, target_entity = 'train',
                       max_depth = 4, features_only=True)

print('%d Total Features' % len(feature_names))
# Out:
# 128 Total Features

# %%
feature_matrix, feature_names = ft.dfs(entityset = new_trans_es, target_entity = 'train',
                                       trans_primitives = default_trans_primitives,
                                       agg_primitives=default_agg_primitives, 
                                        max_depth = 2, features_only=False, verbose = True)

pd.options.display.max_columns = 1700
# Out:
# Built 6106 features
#
#
#
#
#
#
#
# Elapsed: 00:00 | Remaining: ? | Progress:   0%|          | Calculated: 0/1 chunks
#
#
#
#
#
#
# Elapsed: 00:04 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 1/1 chunks

# %%
feature_names
# Out:
# [<Feature: target>,
#  <Feature: feature_1>,
#  <Feature: feature_2>,
#  <Feature: feature_3>,
#  <Feature: SUM(new_trans.installments)>,
#  <Feature: SUM(new_trans.month_lag)>,
#  <Feature: SUM(new_trans.purchase_amount)>,
#  <Feature: SUM(new_trans.month_diff)>,
#  <Feature: SUM(new_trans.purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.price)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017)>,
#  <Feature: SUM(new_trans.Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.fathers_day_2017)>,
#  <Feature: SUM(new_trans.Children_day_2017)>,
#  <Feature: SUM(new_trans.Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.Black_Friday_2017)>,
#  <Feature: SUM(new_trans.Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.duration)>,
#  <Feature: SUM(new_trans.amount_month_ratio)>,
#  <Feature: STD(new_trans.installments)>,
#  <Feature: STD(new_trans.month_lag)>,
#  <Feature: STD(new_trans.purchase_amount)>,
#  <Feature: STD(new_trans.month_diff)>,
#  <Feature: STD(new_trans.purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.price)>,
#  <Feature: STD(new_trans.Christmas_Day_2017)>,
#  <Feature: STD(new_trans.Mothers_Day_2017)>,
#  <Feature: STD(new_trans.fathers_day_2017)>,
#  <Feature: STD(new_trans.Children_day_2017)>,
#  <Feature: STD(new_trans.Valentine_Day_2017)>,
#  <Feature: STD(new_trans.Black_Friday_2017)>,
#  <Feature: STD(new_trans.Mothers_Day_2018)>,
#  <Feature: STD(new_trans.duration)>,
#  <Feature: STD(new_trans.amount_month_ratio)>,
#  <Feature: MAX(new_trans.installments)>,
#  <Feature: MAX(new_trans.month_lag)>,
#  <Feature: MAX(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.month_diff)>,
#  <Feature: MAX(new_trans.purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.price)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.fathers_day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017)>,
#  <Feature: MAX(new_trans.Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Black_Friday_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.duration)>,
#  <Feature: MAX(new_trans.amount_month_ratio)>,
#  <Feature: SKEW(new_trans.installments)>,
#  <Feature: SKEW(new_trans.month_lag)>,
#  <Feature: SKEW(new_trans.purchase_amount)>,
#  <Feature: SKEW(new_trans.month_diff)>,
#  <Feature: SKEW(new_trans.purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.price)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.fathers_day_2017)>,
#  <Feature: SKEW(new_trans.Children_day_2017)>,
#  <Feature: SKEW(new_trans.Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.duration)>,
#  <Feature: SKEW(new_trans.amount_month_ratio)>,
#  <Feature: MIN(new_trans.installments)>,
#  <Feature: MIN(new_trans.month_lag)>,
#  <Feature: MIN(new_trans.purchase_amount)>,
#  <Feature: MIN(new_trans.month_diff)>,
#  <Feature: MIN(new_trans.purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.price)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.fathers_day_2017)>,
#  <Feature: MIN(new_trans.Children_day_2017)>,
#  <Feature: MIN(new_trans.Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.Black_Friday_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.duration)>,
#  <Feature: MIN(new_trans.amount_month_ratio)>,
#  <Feature: MEAN(new_trans.installments)>,
#  <Feature: MEAN(new_trans.month_lag)>,
#  <Feature: MEAN(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.month_diff)>,
#  <Feature: MEAN(new_trans.purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.price)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.fathers_day_2017)>,
#  <Feature: MEAN(new_trans.Children_day_2017)>,
#  <Feature: MEAN(new_trans.Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.duration)>,
#  <Feature: MEAN(new_trans.amount_month_ratio)>,
#  <Feature: COUNT(new_trans)>,
#  <Feature: NUM_UNIQUE(new_trans.authorized_flag)>,
#  <Feature: NUM_UNIQUE(new_trans.city_id)>,
#  <Feature: NUM_UNIQUE(new_trans.category_1)>,
#  <Feature: NUM_UNIQUE(new_trans.category_3)>,
#  <Feature: NUM_UNIQUE(new_trans.merchant_category_id)>,
#  <Feature: NUM_UNIQUE(new_trans.merchant_id)>,
#  <Feature: NUM_UNIQUE(new_trans.category_2)>,
#  <Feature: NUM_UNIQUE(new_trans.state_id)>,
#  <Feature: NUM_UNIQUE(new_trans.subsector_id)>,
#  <Feature: NUM_UNIQUE(new_trans.purchased_on_weekend)>,
#  <Feature: MODE(new_trans.authorized_flag)>,
#  <Feature: MODE(new_trans.city_id)>,
#  <Feature: MODE(new_trans.category_1)>,
#  <Feature: MODE(new_trans.category_3)>,
#  <Feature: MODE(new_trans.merchant_category_id)>,
#  <Feature: MODE(new_trans.merchant_id)>,
#  <Feature: MODE(new_trans.category_2)>,
#  <Feature: MODE(new_trans.state_id)>,
#  <Feature: MODE(new_trans.subsector_id)>,
#  <Feature: MODE(new_trans.purchased_on_weekend)>,
#  <Feature: DAY(first_active_month)>,
#  <Feature: MONTH(first_active_month)>,
#  <Feature: WEEKDAY(first_active_month)>,
#  <Feature: DAYS_SINCE(first_active_month)>,
#  <Feature: PERCENTILE(target)>,
#  <Feature: SUM(new_trans.duration + month_lag)>,
#  <Feature: SUM(new_trans.Mothers_Day_2017 + purchase_amount)>,
#  <Feature: SUM(new_trans.month_lag + purchase_amount)>,
#  <Feature: SUM(new_trans.Children_day_2017 + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.installments + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.amount_month_ratio + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.price + purchase_amount)>,
#  <Feature: SUM(new_trans.purchase_amount + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + installments)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.duration + fathers_day_2017)>,
#  <Feature: SUM(new_trans.installments + month_diff)>,
#  <Feature: SUM(new_trans.month_diff + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.amount_month_ratio + month_lag)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + purchase_amount)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + fathers_day_2017)>,
#  <Feature: SUM(new_trans.Mothers_Day_2018 + purchase_amount)>,
#  <Feature: SUM(new_trans.amount_month_ratio + purchase_amount)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + purchase_amount)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + month_lag)>,
#  <Feature: SUM(new_trans.price + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.Mothers_Day_2018 + price)>,
#  <Feature: SUM(new_trans.duration + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Children_day_2017 + purchase_amount)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + purchase_amount)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Mothers_Day_2018 + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + price)>,
#  <Feature: SUM(new_trans.duration + month_diff)>,
#  <Feature: SUM(new_trans.Children_day_2017 + Christmas_Day_2017)>,
#  <Feature: SUM(new_trans.amount_month_ratio + Black_Friday_2017)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.installments + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.amount_month_ratio + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + duration)>,
#  <Feature: SUM(new_trans.Children_day_2017 + fathers_day_2017)>,
#  <Feature: SUM(new_trans.Mothers_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.installments + price)>,
#  <Feature: SUM(new_trans.Mothers_Day_2018 + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.installments + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + price)>,
#  <Feature: SUM(new_trans.installments + month_lag)>,
#  <Feature: SUM(new_trans.amount_month_ratio + installments)>,
#  <Feature: SUM(new_trans.amount_month_ratio + Children_day_2017)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Children_day_2017 + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.amount_month_ratio + Christmas_Day_2017)>,
#  <Feature: SUM(new_trans.Children_day_2017 + month_lag)>,
#  <Feature: SUM(new_trans.month_diff + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.installments + purchase_amount)>,
#  <Feature: SUM(new_trans.duration + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + month_diff)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + month_lag)>,
#  <Feature: SUM(new_trans.duration + installments)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + price)>,
#  <Feature: SUM(new_trans.Children_day_2017 + price)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.Children_day_2017 + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.amount_month_ratio + duration)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.amount_month_ratio + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + month_diff)>,
#  <Feature: SUM(new_trans.amount_month_ratio + price)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + month_lag)>,
#  <Feature: SUM(new_trans.Mothers_Day_2017 + price)>,
#  <Feature: SUM(new_trans.duration + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.month_diff + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.amount_month_ratio + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.Children_day_2017 + month_diff)>,
#  <Feature: SUM(new_trans.Mothers_Day_2017 + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + installments)>,
#  <Feature: SUM(new_trans.month_lag + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.month_diff + price)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.month_lag + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.month_lag + price)>,
#  <Feature: SUM(new_trans.purchase_amount + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.month_lag + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.Children_day_2017 + installments)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.amount_month_ratio + fathers_day_2017)>,
#  <Feature: SUM(new_trans.month_lag + Mothers_Day_2017)>,
#  <Feature: SUM(new_trans.Mothers_Day_2017 + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.amount_month_ratio + month_diff)>,
#  <Feature: SUM(new_trans.purchase_date_successive_diff + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.Christmas_Day_2017 + duration)>,
#  <Feature: SUM(new_trans.duration + Mothers_Day_2018)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + month_diff)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + Christmas_Day_2017)>,
#  <Feature: SUM(new_trans.price + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.duration + price)>,
#  <Feature: SUM(new_trans.installments + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.duration + purchase_amount)>,
#  <Feature: SUM(new_trans.month_diff + month_lag)>,
#  <Feature: SUM(new_trans.Children_day_2017 + duration)>,
#  <Feature: SUM(new_trans.fathers_day_2017 + installments)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + fathers_day_2017)>,
#  <Feature: SUM(new_trans.Children_day_2017 + Valentine_Day_2017)>,
#  <Feature: SUM(new_trans.Black_Friday_2017 + Children_day_2017)>,
#  <Feature: SUM(new_trans.month_diff + purchase_date_successive_diff)>,
#  <Feature: SUM(new_trans.month_diff + purchase_amount)>,
#  <Feature: SUM(new_trans.DAYS_SINCE(purchase_date))>,
#  <Feature: SUM(new_trans.PERCENTILE(installments))>,
#  <Feature: SUM(new_trans.PERCENTILE(month_lag))>,
#  <Feature: SUM(new_trans.PERCENTILE(purchase_amount))>,
#  <Feature: SUM(new_trans.PERCENTILE(month_diff))>,
#  <Feature: SUM(new_trans.PERCENTILE(purchase_date_successive_diff))>,
#  <Feature: SUM(new_trans.PERCENTILE(price))>,
#  <Feature: SUM(new_trans.PERCENTILE(Christmas_Day_2017))>,
#  <Feature: SUM(new_trans.PERCENTILE(Mothers_Day_2017))>,
#  <Feature: SUM(new_trans.PERCENTILE(fathers_day_2017))>,
#  <Feature: SUM(new_trans.PERCENTILE(Children_day_2017))>,
#  <Feature: SUM(new_trans.PERCENTILE(Valentine_Day_2017))>,
#  <Feature: SUM(new_trans.PERCENTILE(Black_Friday_2017))>,
#  <Feature: SUM(new_trans.PERCENTILE(Mothers_Day_2018))>,
#  <Feature: SUM(new_trans.PERCENTILE(duration))>,
#  <Feature: SUM(new_trans.PERCENTILE(amount_month_ratio))>,
#  <Feature: STD(new_trans.duration + month_lag)>,
#  <Feature: STD(new_trans.Mothers_Day_2017 + purchase_amount)>,
#  <Feature: STD(new_trans.month_lag + purchase_amount)>,
#  <Feature: STD(new_trans.Children_day_2017 + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.installments + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.amount_month_ratio + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.price + purchase_amount)>,
#  <Feature: STD(new_trans.purchase_amount + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + installments)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.duration + fathers_day_2017)>,
#  <Feature: STD(new_trans.installments + month_diff)>,
#  <Feature: STD(new_trans.month_diff + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.amount_month_ratio + month_lag)>,
#  <Feature: STD(new_trans.fathers_day_2017 + purchase_amount)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + fathers_day_2017)>,
#  <Feature: STD(new_trans.Mothers_Day_2018 + purchase_amount)>,
#  <Feature: STD(new_trans.amount_month_ratio + purchase_amount)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + purchase_amount)>,
#  <Feature: STD(new_trans.fathers_day_2017 + month_lag)>,
#  <Feature: STD(new_trans.price + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.Mothers_Day_2018 + price)>,
#  <Feature: STD(new_trans.duration + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Children_day_2017 + purchase_amount)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + purchase_amount)>,
#  <Feature: STD(new_trans.fathers_day_2017 + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Mothers_Day_2018 + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.fathers_day_2017 + price)>,
#  <Feature: STD(new_trans.duration + month_diff)>,
#  <Feature: STD(new_trans.Children_day_2017 + Christmas_Day_2017)>,
#  <Feature: STD(new_trans.amount_month_ratio + Black_Friday_2017)>,
#  <Feature: STD(new_trans.fathers_day_2017 + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.installments + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.amount_month_ratio + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + duration)>,
#  <Feature: STD(new_trans.Children_day_2017 + fathers_day_2017)>,
#  <Feature: STD(new_trans.Mothers_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.installments + price)>,
#  <Feature: STD(new_trans.Mothers_Day_2018 + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.installments + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + price)>,
#  <Feature: STD(new_trans.installments + month_lag)>,
#  <Feature: STD(new_trans.amount_month_ratio + installments)>,
#  <Feature: STD(new_trans.amount_month_ratio + Children_day_2017)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Children_day_2017 + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.amount_month_ratio + Christmas_Day_2017)>,
#  <Feature: STD(new_trans.Children_day_2017 + month_lag)>,
#  <Feature: STD(new_trans.month_diff + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.installments + purchase_amount)>,
#  <Feature: STD(new_trans.duration + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.fathers_day_2017 + month_diff)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + month_lag)>,
#  <Feature: STD(new_trans.duration + installments)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + price)>,
#  <Feature: STD(new_trans.Children_day_2017 + price)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.Children_day_2017 + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.amount_month_ratio + duration)>,
#  <Feature: STD(new_trans.fathers_day_2017 + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.amount_month_ratio + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + month_diff)>,
#  <Feature: STD(new_trans.amount_month_ratio + price)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + month_lag)>,
#  <Feature: STD(new_trans.Mothers_Day_2017 + price)>,
#  <Feature: STD(new_trans.duration + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.month_diff + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.amount_month_ratio + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.Children_day_2017 + month_diff)>,
#  <Feature: STD(new_trans.Mothers_Day_2017 + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + installments)>,
#  <Feature: STD(new_trans.month_lag + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.month_diff + price)>,
#  <Feature: STD(new_trans.fathers_day_2017 + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.month_lag + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.month_lag + price)>,
#  <Feature: STD(new_trans.purchase_amount + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.month_lag + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.Children_day_2017 + installments)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.amount_month_ratio + fathers_day_2017)>,
#  <Feature: STD(new_trans.month_lag + Mothers_Day_2017)>,
#  <Feature: STD(new_trans.Mothers_Day_2017 + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.amount_month_ratio + month_diff)>,
#  <Feature: STD(new_trans.purchase_date_successive_diff + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.Christmas_Day_2017 + duration)>,
#  <Feature: STD(new_trans.duration + Mothers_Day_2018)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + month_diff)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + Christmas_Day_2017)>,
#  <Feature: STD(new_trans.price + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.duration + price)>,
#  <Feature: STD(new_trans.installments + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.duration + purchase_amount)>,
#  <Feature: STD(new_trans.month_diff + month_lag)>,
#  <Feature: STD(new_trans.Children_day_2017 + duration)>,
#  <Feature: STD(new_trans.fathers_day_2017 + installments)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + fathers_day_2017)>,
#  <Feature: STD(new_trans.Children_day_2017 + Valentine_Day_2017)>,
#  <Feature: STD(new_trans.Black_Friday_2017 + Children_day_2017)>,
#  <Feature: STD(new_trans.month_diff + purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.month_diff + purchase_amount)>,
#  <Feature: STD(new_trans.DAYS_SINCE(purchase_date))>,
#  <Feature: STD(new_trans.PERCENTILE(installments))>,
#  <Feature: STD(new_trans.PERCENTILE(month_lag))>,
#  <Feature: STD(new_trans.PERCENTILE(purchase_amount))>,
#  <Feature: STD(new_trans.PERCENTILE(month_diff))>,
#  <Feature: STD(new_trans.PERCENTILE(purchase_date_successive_diff))>,
#  <Feature: STD(new_trans.PERCENTILE(price))>,
#  <Feature: STD(new_trans.PERCENTILE(Christmas_Day_2017))>,
#  <Feature: STD(new_trans.PERCENTILE(Mothers_Day_2017))>,
#  <Feature: STD(new_trans.PERCENTILE(fathers_day_2017))>,
#  <Feature: STD(new_trans.PERCENTILE(Children_day_2017))>,
#  <Feature: STD(new_trans.PERCENTILE(Valentine_Day_2017))>,
#  <Feature: STD(new_trans.PERCENTILE(Black_Friday_2017))>,
#  <Feature: STD(new_trans.PERCENTILE(Mothers_Day_2018))>,
#  <Feature: STD(new_trans.PERCENTILE(duration))>,
#  <Feature: STD(new_trans.PERCENTILE(amount_month_ratio))>,
#  <Feature: MAX(new_trans.duration + month_lag)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017 + purchase_amount)>,
#  <Feature: MAX(new_trans.month_lag + purchase_amount)>,
#  <Feature: MAX(new_trans.Children_day_2017 + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.installments + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.amount_month_ratio + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.price + purchase_amount)>,
#  <Feature: MAX(new_trans.purchase_amount + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + installments)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.duration + fathers_day_2017)>,
#  <Feature: MAX(new_trans.installments + month_diff)>,
#  <Feature: MAX(new_trans.month_diff + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio + month_lag)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + purchase_amount)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + fathers_day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018 + purchase_amount)>,
#  <Feature: MAX(new_trans.amount_month_ratio + purchase_amount)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + purchase_amount)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + month_lag)>,
#  <Feature: MAX(new_trans.price + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018 + price)>,
#  <Feature: MAX(new_trans.duration + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017 + purchase_amount)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + purchase_amount)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018 + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + price)>,
#  <Feature: MAX(new_trans.duration + month_diff)>,
#  <Feature: MAX(new_trans.Children_day_2017 + Christmas_Day_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio + Black_Friday_2017)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.installments + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.amount_month_ratio + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + duration)>,
#  <Feature: MAX(new_trans.Children_day_2017 + fathers_day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.installments + price)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018 + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.installments + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + price)>,
#  <Feature: MAX(new_trans.installments + month_lag)>,
#  <Feature: MAX(new_trans.amount_month_ratio + installments)>,
#  <Feature: MAX(new_trans.amount_month_ratio + Children_day_2017)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017 + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.amount_month_ratio + Christmas_Day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017 + month_lag)>,
#  <Feature: MAX(new_trans.month_diff + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.installments + purchase_amount)>,
#  <Feature: MAX(new_trans.duration + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + month_diff)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + month_lag)>,
#  <Feature: MAX(new_trans.duration + installments)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + price)>,
#  <Feature: MAX(new_trans.Children_day_2017 + price)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.Children_day_2017 + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.amount_month_ratio + duration)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.amount_month_ratio + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + month_diff)>,
#  <Feature: MAX(new_trans.amount_month_ratio + price)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + month_lag)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017 + price)>,
#  <Feature: MAX(new_trans.duration + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.month_diff + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017 + month_diff)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017 + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + installments)>,
#  <Feature: MAX(new_trans.month_lag + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.month_diff + price)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.month_lag + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.month_lag + price)>,
#  <Feature: MAX(new_trans.purchase_amount + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.month_lag + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.Children_day_2017 + installments)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio + fathers_day_2017)>,
#  <Feature: MAX(new_trans.month_lag + Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017 + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.amount_month_ratio + month_diff)>,
#  <Feature: MAX(new_trans.purchase_date_successive_diff + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017 + duration)>,
#  <Feature: MAX(new_trans.duration + Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + month_diff)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + Christmas_Day_2017)>,
#  <Feature: MAX(new_trans.price + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.duration + price)>,
#  <Feature: MAX(new_trans.installments + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.duration + purchase_amount)>,
#  <Feature: MAX(new_trans.month_diff + month_lag)>,
#  <Feature: MAX(new_trans.Children_day_2017 + duration)>,
#  <Feature: MAX(new_trans.fathers_day_2017 + installments)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + fathers_day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017 + Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Black_Friday_2017 + Children_day_2017)>,
#  <Feature: MAX(new_trans.month_diff + purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.month_diff + purchase_amount)>,
#  <Feature: MAX(new_trans.DAYS_SINCE(purchase_date))>,
#  <Feature: MAX(new_trans.PERCENTILE(installments))>,
#  <Feature: MAX(new_trans.PERCENTILE(month_lag))>,
#  <Feature: MAX(new_trans.PERCENTILE(purchase_amount))>,
#  <Feature: MAX(new_trans.PERCENTILE(month_diff))>,
#  <Feature: MAX(new_trans.PERCENTILE(purchase_date_successive_diff))>,
#  <Feature: MAX(new_trans.PERCENTILE(price))>,
#  <Feature: MAX(new_trans.PERCENTILE(Christmas_Day_2017))>,
#  <Feature: MAX(new_trans.PERCENTILE(Mothers_Day_2017))>,
#  <Feature: MAX(new_trans.PERCENTILE(fathers_day_2017))>,
#  <Feature: MAX(new_trans.PERCENTILE(Children_day_2017))>,
#  <Feature: MAX(new_trans.PERCENTILE(Valentine_Day_2017))>,
#  <Feature: MAX(new_trans.PERCENTILE(Black_Friday_2017))>,
#  <Feature: MAX(new_trans.PERCENTILE(Mothers_Day_2018))>,
#  <Feature: MAX(new_trans.PERCENTILE(duration))>,
#  <Feature: MAX(new_trans.PERCENTILE(amount_month_ratio))>,
#  <Feature: SKEW(new_trans.duration + month_lag)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2017 + purchase_amount)>,
#  <Feature: SKEW(new_trans.month_lag + purchase_amount)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.installments + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.price + purchase_amount)>,
#  <Feature: SKEW(new_trans.purchase_amount + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + installments)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.duration + fathers_day_2017)>,
#  <Feature: SKEW(new_trans.installments + month_diff)>,
#  <Feature: SKEW(new_trans.month_diff + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + month_lag)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + purchase_amount)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + fathers_day_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2018 + purchase_amount)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + purchase_amount)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + purchase_amount)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + month_lag)>,
#  <Feature: SKEW(new_trans.price + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2018 + price)>,
#  <Feature: SKEW(new_trans.duration + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + purchase_amount)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + purchase_amount)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2018 + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + price)>,
#  <Feature: SKEW(new_trans.duration + month_diff)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + Christmas_Day_2017)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + Black_Friday_2017)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.installments + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + duration)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + fathers_day_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.installments + price)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2018 + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.installments + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + price)>,
#  <Feature: SKEW(new_trans.installments + month_lag)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + installments)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + Children_day_2017)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + Christmas_Day_2017)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + month_lag)>,
#  <Feature: SKEW(new_trans.month_diff + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.installments + purchase_amount)>,
#  <Feature: SKEW(new_trans.duration + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + month_diff)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + month_lag)>,
#  <Feature: SKEW(new_trans.duration + installments)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + price)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + price)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + duration)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + month_diff)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + price)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + month_lag)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2017 + price)>,
#  <Feature: SKEW(new_trans.duration + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.month_diff + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + month_diff)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2017 + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + installments)>,
#  <Feature: SKEW(new_trans.month_lag + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.month_diff + price)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.month_lag + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.month_lag + price)>,
#  <Feature: SKEW(new_trans.purchase_amount + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.month_lag + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + installments)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + fathers_day_2017)>,
#  <Feature: SKEW(new_trans.month_lag + Mothers_Day_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2017 + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.amount_month_ratio + month_diff)>,
#  <Feature: SKEW(new_trans.purchase_date_successive_diff + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017 + duration)>,
#  <Feature: SKEW(new_trans.duration + Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + month_diff)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + Christmas_Day_2017)>,
#  <Feature: SKEW(new_trans.price + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.duration + price)>,
#  <Feature: SKEW(new_trans.installments + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.duration + purchase_amount)>,
#  <Feature: SKEW(new_trans.month_diff + month_lag)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + duration)>,
#  <Feature: SKEW(new_trans.fathers_day_2017 + installments)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + fathers_day_2017)>,
#  <Feature: SKEW(new_trans.Children_day_2017 + Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.Black_Friday_2017 + Children_day_2017)>,
#  <Feature: SKEW(new_trans.month_diff + purchase_date_successive_diff)>,
#  <Feature: SKEW(new_trans.month_diff + purchase_amount)>,
#  <Feature: SKEW(new_trans.DAYS_SINCE(purchase_date))>,
#  <Feature: SKEW(new_trans.PERCENTILE(installments))>,
#  <Feature: SKEW(new_trans.PERCENTILE(month_lag))>,
#  <Feature: SKEW(new_trans.PERCENTILE(purchase_amount))>,
#  <Feature: SKEW(new_trans.PERCENTILE(month_diff))>,
#  <Feature: SKEW(new_trans.PERCENTILE(purchase_date_successive_diff))>,
#  <Feature: SKEW(new_trans.PERCENTILE(price))>,
#  <Feature: SKEW(new_trans.PERCENTILE(Christmas_Day_2017))>,
#  <Feature: SKEW(new_trans.PERCENTILE(Mothers_Day_2017))>,
#  <Feature: SKEW(new_trans.PERCENTILE(fathers_day_2017))>,
#  <Feature: SKEW(new_trans.PERCENTILE(Children_day_2017))>,
#  <Feature: SKEW(new_trans.PERCENTILE(Valentine_Day_2017))>,
#  <Feature: SKEW(new_trans.PERCENTILE(Black_Friday_2017))>,
#  <Feature: SKEW(new_trans.PERCENTILE(Mothers_Day_2018))>,
#  <Feature: SKEW(new_trans.PERCENTILE(duration))>,
#  <Feature: SKEW(new_trans.PERCENTILE(amount_month_ratio))>,
#  <Feature: MIN(new_trans.duration + month_lag)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017 + purchase_amount)>,
#  <Feature: MIN(new_trans.month_lag + purchase_amount)>,
#  <Feature: MIN(new_trans.Children_day_2017 + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.installments + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.amount_month_ratio + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.price + purchase_amount)>,
#  <Feature: MIN(new_trans.purchase_amount + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + installments)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.duration + fathers_day_2017)>,
#  <Feature: MIN(new_trans.installments + month_diff)>,
#  <Feature: MIN(new_trans.month_diff + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.amount_month_ratio + month_lag)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + purchase_amount)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + fathers_day_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018 + purchase_amount)>,
#  <Feature: MIN(new_trans.amount_month_ratio + purchase_amount)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + purchase_amount)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + month_lag)>,
#  <Feature: MIN(new_trans.price + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018 + price)>,
#  <Feature: MIN(new_trans.duration + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Children_day_2017 + purchase_amount)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + purchase_amount)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018 + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + price)>,
#  <Feature: MIN(new_trans.duration + month_diff)>,
#  <Feature: MIN(new_trans.Children_day_2017 + Christmas_Day_2017)>,
#  <Feature: MIN(new_trans.amount_month_ratio + Black_Friday_2017)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.installments + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.amount_month_ratio + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + duration)>,
#  <Feature: MIN(new_trans.Children_day_2017 + fathers_day_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.installments + price)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018 + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.installments + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + price)>,
#  <Feature: MIN(new_trans.installments + month_lag)>,
#  <Feature: MIN(new_trans.amount_month_ratio + installments)>,
#  <Feature: MIN(new_trans.amount_month_ratio + Children_day_2017)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Children_day_2017 + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.amount_month_ratio + Christmas_Day_2017)>,
#  <Feature: MIN(new_trans.Children_day_2017 + month_lag)>,
#  <Feature: MIN(new_trans.month_diff + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.installments + purchase_amount)>,
#  <Feature: MIN(new_trans.duration + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + month_diff)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + month_lag)>,
#  <Feature: MIN(new_trans.duration + installments)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + price)>,
#  <Feature: MIN(new_trans.Children_day_2017 + price)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.Children_day_2017 + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.amount_month_ratio + duration)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.amount_month_ratio + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + month_diff)>,
#  <Feature: MIN(new_trans.amount_month_ratio + price)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + month_lag)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017 + price)>,
#  <Feature: MIN(new_trans.duration + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.month_diff + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.amount_month_ratio + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.Children_day_2017 + month_diff)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017 + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + installments)>,
#  <Feature: MIN(new_trans.month_lag + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.month_diff + price)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.month_lag + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.month_lag + price)>,
#  <Feature: MIN(new_trans.purchase_amount + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.month_lag + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.Children_day_2017 + installments)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.amount_month_ratio + fathers_day_2017)>,
#  <Feature: MIN(new_trans.month_lag + Mothers_Day_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017 + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.amount_month_ratio + month_diff)>,
#  <Feature: MIN(new_trans.purchase_date_successive_diff + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017 + duration)>,
#  <Feature: MIN(new_trans.duration + Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + month_diff)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + Christmas_Day_2017)>,
#  <Feature: MIN(new_trans.price + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.duration + price)>,
#  <Feature: MIN(new_trans.installments + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.duration + purchase_amount)>,
#  <Feature: MIN(new_trans.month_diff + month_lag)>,
#  <Feature: MIN(new_trans.Children_day_2017 + duration)>,
#  <Feature: MIN(new_trans.fathers_day_2017 + installments)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + fathers_day_2017)>,
#  <Feature: MIN(new_trans.Children_day_2017 + Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.Black_Friday_2017 + Children_day_2017)>,
#  <Feature: MIN(new_trans.month_diff + purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.month_diff + purchase_amount)>,
#  <Feature: MIN(new_trans.DAYS_SINCE(purchase_date))>,
#  <Feature: MIN(new_trans.PERCENTILE(installments))>,
#  <Feature: MIN(new_trans.PERCENTILE(month_lag))>,
#  <Feature: MIN(new_trans.PERCENTILE(purchase_amount))>,
#  <Feature: MIN(new_trans.PERCENTILE(month_diff))>,
#  <Feature: MIN(new_trans.PERCENTILE(purchase_date_successive_diff))>,
#  <Feature: MIN(new_trans.PERCENTILE(price))>,
#  <Feature: MIN(new_trans.PERCENTILE(Christmas_Day_2017))>,
#  <Feature: MIN(new_trans.PERCENTILE(Mothers_Day_2017))>,
#  <Feature: MIN(new_trans.PERCENTILE(fathers_day_2017))>,
#  <Feature: MIN(new_trans.PERCENTILE(Children_day_2017))>,
#  <Feature: MIN(new_trans.PERCENTILE(Valentine_Day_2017))>,
#  <Feature: MIN(new_trans.PERCENTILE(Black_Friday_2017))>,
#  <Feature: MIN(new_trans.PERCENTILE(Mothers_Day_2018))>,
#  <Feature: MIN(new_trans.PERCENTILE(duration))>,
#  <Feature: MIN(new_trans.PERCENTILE(amount_month_ratio))>,
#  <Feature: MEAN(new_trans.duration + month_lag)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017 + purchase_amount)>,
#  <Feature: MEAN(new_trans.month_lag + purchase_amount)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.installments + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.price + purchase_amount)>,
#  <Feature: MEAN(new_trans.purchase_amount + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + installments)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.duration + fathers_day_2017)>,
#  <Feature: MEAN(new_trans.installments + month_diff)>,
#  <Feature: MEAN(new_trans.month_diff + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + month_lag)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + purchase_amount)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + fathers_day_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2018 + purchase_amount)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + purchase_amount)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + purchase_amount)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + month_lag)>,
#  <Feature: MEAN(new_trans.price + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2018 + price)>,
#  <Feature: MEAN(new_trans.duration + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + purchase_amount)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + purchase_amount)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2018 + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + price)>,
#  <Feature: MEAN(new_trans.duration + month_diff)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + Christmas_Day_2017)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + Black_Friday_2017)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.installments + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + duration)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + fathers_day_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.installments + price)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2018 + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.installments + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + price)>,
#  <Feature: MEAN(new_trans.installments + month_lag)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + installments)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + Children_day_2017)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + Christmas_Day_2017)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + month_lag)>,
#  <Feature: MEAN(new_trans.month_diff + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.installments + purchase_amount)>,
#  <Feature: MEAN(new_trans.duration + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + month_diff)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + month_lag)>,
#  <Feature: MEAN(new_trans.duration + installments)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + price)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + price)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + duration)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + month_diff)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + price)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + month_lag)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017 + price)>,
#  <Feature: MEAN(new_trans.duration + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.month_diff + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + month_diff)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017 + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + installments)>,
#  <Feature: MEAN(new_trans.month_lag + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.month_diff + price)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.month_lag + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.month_lag + price)>,
#  <Feature: MEAN(new_trans.purchase_amount + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.month_lag + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + installments)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + fathers_day_2017)>,
#  <Feature: MEAN(new_trans.month_lag + Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017 + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.amount_month_ratio + month_diff)>,
#  <Feature: MEAN(new_trans.purchase_date_successive_diff + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017 + duration)>,
#  <Feature: MEAN(new_trans.duration + Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + month_diff)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + Christmas_Day_2017)>,
#  <Feature: MEAN(new_trans.price + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.duration + price)>,
#  <Feature: MEAN(new_trans.installments + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.duration + purchase_amount)>,
#  <Feature: MEAN(new_trans.month_diff + month_lag)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + duration)>,
#  <Feature: MEAN(new_trans.fathers_day_2017 + installments)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + fathers_day_2017)>,
#  <Feature: MEAN(new_trans.Children_day_2017 + Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017 + Children_day_2017)>,
#  <Feature: MEAN(new_trans.month_diff + purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.month_diff + purchase_amount)>,
#  <Feature: MEAN(new_trans.DAYS_SINCE(purchase_date))>,
#  <Feature: MEAN(new_trans.PERCENTILE(installments))>,
#  <Feature: MEAN(new_trans.PERCENTILE(month_lag))>,
#  <Feature: MEAN(new_trans.PERCENTILE(purchase_amount))>,
#  <Feature: MEAN(new_trans.PERCENTILE(month_diff))>,
#  <Feature: MEAN(new_trans.PERCENTILE(purchase_date_successive_diff))>,
#  <Feature: MEAN(new_trans.PERCENTILE(price))>,
#  <Feature: MEAN(new_trans.PERCENTILE(Christmas_Day_2017))>,
#  <Feature: MEAN(new_trans.PERCENTILE(Mothers_Day_2017))>,
#  <Feature: MEAN(new_trans.PERCENTILE(fathers_day_2017))>,
#  <Feature: MEAN(new_trans.PERCENTILE(Children_day_2017))>,
#  <Feature: MEAN(new_trans.PERCENTILE(Valentine_Day_2017))>,
#  <Feature: MEAN(new_trans.PERCENTILE(Black_Friday_2017))>,
#  <Feature: MEAN(new_trans.PERCENTILE(Mothers_Day_2018))>,
#  <Feature: MEAN(new_trans.PERCENTILE(duration))>,
#  <Feature: MEAN(new_trans.PERCENTILE(amount_month_ratio))>,
#  <Feature: COUNT(new_trans WHERE authorized_flag = 1)>,
#  <Feature: NUM_UNIQUE(new_trans.DAY(purchase_date))>,
#  <Feature: NUM_UNIQUE(new_trans.MONTH(purchase_date))>,
#  <Feature: NUM_UNIQUE(new_trans.WEEKDAY(purchase_date))>,
#  <Feature: MODE(new_trans.DAY(purchase_date))>,
#  <Feature: MODE(new_trans.MONTH(purchase_date))>,
#  <Feature: MODE(new_trans.WEEKDAY(purchase_date))>,
#  <Feature: SKEW(new_trans.Black_Friday_2017) + SKEW(new_trans.duration)>,
#  <Feature: MAX(new_trans.Children_day_2017) + MEAN(new_trans.Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio) + SKEW(new_trans.Mothers_Day_2018)>,
#  <Feature: MIN(new_trans.Valentine_Day_2017) + NUM_UNIQUE(new_trans.category_2)>,
#  <Feature: MIN(new_trans.Children_day_2017) + SKEW(new_trans.Christmas_Day_2017)>,
#  <Feature: MAX(new_trans.month_diff) + SKEW(new_trans.duration)>,
#  <Feature: MEAN(new_trans.duration) + SKEW(new_trans.price)>,
#  <Feature: MEAN(new_trans.month_diff) + STD(new_trans.month_diff)>,
#  <Feature: MAX(new_trans.month_lag) + NUM_UNIQUE(new_trans.subsector_id)>,
#  <Feature: MIN(new_trans.month_lag) + STD(new_trans.duration)>,
#  <Feature: NUM_UNIQUE(new_trans.category_3) + STD(new_trans.Black_Friday_2017)>,
#  <Feature: MEAN(new_trans.month_diff) + MEAN(new_trans.month_lag)>,
#  <Feature: MEAN(new_trans.fathers_day_2017) + MIN(new_trans.price)>,
#  <Feature: MEAN(new_trans.Children_day_2017) + MEAN(new_trans.month_lag)>,
#  <Feature: MEAN(new_trans.installments) + STD(new_trans.month_lag)>,
#  <Feature: COUNT(new_trans) + NUM_UNIQUE(new_trans.purchased_on_weekend)>,
#  <Feature: SKEW(new_trans.month_lag) + SUM(new_trans.purchase_amount)>,
#  <Feature: SKEW(new_trans.purchase_date_successive_diff) + SUM(new_trans.Mothers_Day_2017)>,
#  <Feature: STD(new_trans.purchase_amount) + SUM(new_trans.purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017) + MEAN(new_trans.purchase_date_successive_diff)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017) + MAX(new_trans.month_lag)>,
#  <Feature: MAX(new_trans.duration) + SUM(new_trans.Children_day_2017)>,
#  <Feature: MAX(new_trans.purchase_amount) + STD(new_trans.month_lag)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017) + NUM_UNIQUE(new_trans.category_1)>,
#  <Feature: MIN(new_trans.price) + SUM(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018) + MEAN(new_trans.amount_month_ratio)>,
#  <Feature: STD(new_trans.Valentine_Day_2017) + SUM(new_trans.purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.amount_month_ratio) + STD(new_trans.installments)>,
#  <Feature: MAX(new_trans.amount_month_ratio) + STD(new_trans.month_diff)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017) + SUM(new_trans.purchase_amount)>,
#  <Feature: MIN(new_trans.Mothers_Day_2017) + NUM_UNIQUE(new_trans.category_3)>,
#  <Feature: MAX(new_trans.month_diff) + SKEW(new_trans.Valentine_Day_2017)>,
#  <Feature: MEAN(new_trans.price) + MIN(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.amount_month_ratio) + NUM_UNIQUE(new_trans.authorized_flag)>,
#  <Feature: SKEW(new_trans.installments) + SKEW(new_trans.price)>,
#  <Feature: NUM_UNIQUE(new_trans.category_2) + SUM(new_trans.installments)>,
#  <Feature: STD(new_trans.fathers_day_2017) + STD(new_trans.installments)>,
#  <Feature: NUM_UNIQUE(new_trans.category_2) + STD(new_trans.price)>,
#  <Feature: MIN(new_trans.installments) + SUM(new_trans.amount_month_ratio)>,
#  <Feature: MIN(new_trans.duration) + STD(new_trans.month_diff)>,
#  <Feature: MAX(new_trans.purchase_date_successive_diff) + MEAN(new_trans.Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.purchase_amount) + SKEW(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017) + MEAN(new_trans.Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.purchase_amount) + MIN(new_trans.month_lag)>,
#  <Feature: MIN(new_trans.Black_Friday_2017) + SUM(new_trans.Children_day_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2017) + MIN(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.purchase_amount) + SKEW(new_trans.Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.installments) + SKEW(new_trans.Mothers_Day_2018)>,
#  <Feature: SKEW(new_trans.Christmas_Day_2017) + SUM(new_trans.Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017) + STD(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.month_diff) + STD(new_trans.Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.Valentine_Day_2017) + STD(new_trans.Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.month_lag) + MEAN(new_trans.duration)>,
#  <Feature: MEAN(new_trans.Children_day_2017) + SUM(new_trans.Children_day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017) + SKEW(new_trans.Black_Friday_2017)>,
#  <Feature: MEAN(new_trans.Mothers_Day_2018) + STD(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.amount_month_ratio) + STD(new_trans.Black_Friday_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio) + STD(new_trans.fathers_day_2017)>,
#  <Feature: MIN(new_trans.month_diff) + SKEW(new_trans.Black_Friday_2017)>,
#  <Feature: MAX(new_trans.amount_month_ratio) + MAX(new_trans.price)>,
#  <Feature: MIN(new_trans.fathers_day_2017) + SKEW(new_trans.Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Children_day_2017) + MIN(new_trans.installments)>,
#  <Feature: MIN(new_trans.Christmas_Day_2017) + SKEW(new_trans.Mothers_Day_2017)>,
#  <Feature: NUM_UNIQUE(new_trans.authorized_flag) + SUM(new_trans.month_lag)>,
#  <Feature: SKEW(new_trans.Children_day_2017) + STD(new_trans.Children_day_2017)>,
#  <Feature: MAX(new_trans.month_diff) + MEAN(new_trans.month_diff)>,
#  <Feature: MEAN(new_trans.purchase_date_successive_diff) + STD(new_trans.fathers_day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018) + SKEW(new_trans.fathers_day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018) + SUM(new_trans.month_lag)>,
#  <Feature: MEAN(new_trans.installments) + SUM(new_trans.price)>,
#  <Feature: MAX(new_trans.price) + SKEW(new_trans.Black_Friday_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017) + SKEW(new_trans.Children_day_2017)>,
#  <Feature: MIN(new_trans.month_lag) + NUM_UNIQUE(new_trans.authorized_flag)>,
#  <Feature: STD(new_trans.month_diff) + SUM(new_trans.Valentine_Day_2017)>,
#  <Feature: SKEW(new_trans.month_diff) + STD(new_trans.month_diff)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018) + STD(new_trans.Children_day_2017)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018) + MIN(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017) + SKEW(new_trans.month_diff)>,
#  <Feature: SKEW(new_trans.Valentine_Day_2017) + STD(new_trans.installments)>,
#  <Feature: COUNT(new_trans) + SUM(new_trans.Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017) + SUM(new_trans.Christmas_Day_2017)>,
#  <Feature: SKEW(new_trans.price) + SUM(new_trans.Children_day_2017)>,
#  <Feature: MIN(new_trans.duration) + STD(new_trans.fathers_day_2017)>,
#  <Feature: MAX(new_trans.purchase_date_successive_diff) + STD(new_trans.amount_month_ratio)>,
#  <Feature: MEAN(new_trans.month_diff) + MEAN(new_trans.Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.amount_month_ratio) + STD(new_trans.purchase_amount)>,
#  <Feature: SUM(new_trans.duration) + SUM(new_trans.fathers_day_2017)>,
#  <Feature: SKEW(new_trans.Mothers_Day_2018) + SUM(new_trans.purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.month_lag) + NUM_UNIQUE(new_trans.purchased_on_weekend)>,
#  <Feature: MAX(new_trans.Black_Friday_2017) + MAX(new_trans.Mothers_Day_2017)>,
#  <Feature: MAX(new_trans.purchase_amount) + SKEW(new_trans.purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.fathers_day_2017) + SKEW(new_trans.amount_month_ratio)>,
#  <Feature: SKEW(new_trans.installments) + SUM(new_trans.month_lag)>,
#  <Feature: MEAN(new_trans.amount_month_ratio) + MEAN(new_trans.Children_day_2017)>,
#  <Feature: MEAN(new_trans.duration) + MIN(new_trans.purchase_date_successive_diff)>,
#  <Feature: STD(new_trans.installments) + SUM(new_trans.duration)>,
#  <Feature: MIN(new_trans.purchase_date_successive_diff) + SUM(new_trans.Black_Friday_2017)>,
#  <Feature: MIN(new_trans.amount_month_ratio) + STD(new_trans.Mothers_Day_2017)>,
#  <Feature: COUNT(new_trans) + MEAN(new_trans.month_diff)>,
#  <Feature: MEAN(new_trans.Black_Friday_2017) + SKEW(new_trans.price)>,
#  <Feature: MAX(new_trans.Valentine_Day_2017) + STD(new_trans.Christmas_Day_2017)>,
#  <Feature: SKEW(new_trans.month_diff) + SKEW(new_trans.Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.duration) + MAX(new_trans.Mothers_Day_2017)>,
#  <Feature: MEAN(new_trans.purchase_date_successive_diff) + STD(new_trans.amount_month_ratio)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017) + SUM(new_trans.Black_Friday_2017)>,
#  <Feature: MAX(new_trans.fathers_day_2017) + MAX(new_trans.installments)>,
#  <Feature: STD(new_trans.Children_day_2017) + STD(new_trans.fathers_day_2017)>,
#  <Feature: COUNT(new_trans) + STD(new_trans.Christmas_Day_2017)>,
#  <Feature: MIN(new_trans.month_lag) + SUM(new_trans.Black_Friday_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018) + MAX(new_trans.Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.price) + MEAN(new_trans.Christmas_Day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017) + MAX(new_trans.purchase_amount)>,
#  <Feature: SUM(new_trans.Mothers_Day_2018) + SUM(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.fathers_day_2017) + MIN(new_trans.Children_day_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017) + MEAN(new_trans.price)>,
#  <Feature: STD(new_trans.Christmas_Day_2017) + SUM(new_trans.month_lag)>,
#  <Feature: MAX(new_trans.purchase_date_successive_diff) + MIN(new_trans.Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.month_diff) + MEAN(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.Black_Friday_2017) + MEAN(new_trans.purchase_amount)>,
#  <Feature: MAX(new_trans.month_diff) + NUM_UNIQUE(new_trans.merchant_category_id)>,
#  <Feature: MEAN(new_trans.amount_month_ratio) + MIN(new_trans.duration)>,
#  <Feature: MEAN(new_trans.installments) + MIN(new_trans.month_diff)>,
#  <Feature: MIN(new_trans.Black_Friday_2017) + MIN(new_trans.price)>,
#  <Feature: MIN(new_trans.Mothers_Day_2018) + NUM_UNIQUE(new_trans.subsector_id)>,
#  <Feature: NUM_UNIQUE(new_trans.city_id) + STD(new_trans.Mothers_Day_2018)>,
#  <Feature: MEAN(new_trans.price) + SUM(new_trans.fathers_day_2017)>,
#  <Feature: MAX(new_trans.Mothers_Day_2018) + SKEW(new_trans.purchase_date_successive_diff)>,
#  <Feature: MEAN(new_trans.purchase_amount) + MIN(new_trans.Valentine_Day_2017)>,
#  <Feature: MIN(new_trans.price) + NUM_UNIQUE(new_trans.city_id)>,
#  <Feature: MAX(new_trans.Mothers_Day_2017) + MAX(new_trans.purchase_date_successive_diff)>,
#  <Feature: MIN(new_trans.purchase_date_successive_diff) + SKEW(new_trans.Children_day_2017)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017) + SKEW(new_trans.Black_Friday_2017)>,
#  <Feature: MAX(new_trans.price) + SKEW(new_trans.month_lag)>,
#  <Feature: MAX(new_trans.duration) + MEAN(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.Christmas_Day_2017) + STD(new_trans.purchase_amount)>,
#  <Feature: MEAN(new_trans.amount_month_ratio) + SKEW(new_trans.amount_month_ratio)>,
#  <Feature: SKEW(new_trans.amount_month_ratio) + SUM(new_trans.duration)>,
#  <Feature: MAX(new_trans.month_diff) + MIN(new_trans.Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.purchase_amount) + MEAN(new_trans.installments)>,
#  <Feature: MAX(new_trans.installments) + MEAN(new_trans.month_diff)>,
#  <Feature: NUM_UNIQUE(new_trans.category_1) + STD(new_trans.installments)>,
#  <Feature: SKEW(new_trans.Valentine_Day_2017) + STD(new_trans.Children_day_2017)>,
#  <Feature: STD(new_trans.installments) + SUM(new_trans.Mothers_Day_2018)>,
#  <Feature: MAX(new_trans.fathers_day_2017) + MEAN(new_trans.duration)>,
#  <Feature: STD(new_trans.installments) + SUM(new_trans.Valentine_Day_2017)>,
#  <Feature: MAX(new_trans.Christmas_Day_2017) + SUM(new_trans.amount_month_ratio)>,
#  <Feature: MIN(new_trans.price) + SKEW(new_trans.Christmas_Day_2017)>,
#  ...]

# %%
feature_matrix.T
# Out:
# card_id                                       C_ID_92a2005557
# target                                              -0.820283
# feature_1                                                   5
# feature_2                                                   2
# feature_3                                                   1
# SUM(new_trans.installments)                                 4
# SUM(new_trans.month_lag)                                -1017
# SUM(new_trans.purchase_amount)                       -165.969
# SUM(new_trans.month_diff)                                2819
# SUM(new_trans.purchase_date_successive_diff)       2.0978e+07
# SUM(new_trans.price)                                        0
# SUM(new_trans.Christmas_Day_2017)                        3412
# SUM(new_trans.Mothers_Day_2017)                             0
# SUM(new_trans.fathers_day_2017)                          1629
# SUM(new_trans.Children_day_2017)                         6959
# SUM(new_trans.Valentine_Day_2017)                           0
# SUM(new_trans.Black_Friday_2017)                         4281
# SUM(new_trans.Mothers_Day_2018)                          2016
# SUM(new_trans.duration)                              -1798.81
# SUM(new_trans.amount_month_ratio)                    -15.3321
# STD(new_trans.installments)                          0.123314
# STD(new_trans.month_lag)                              2.39769
# STD(new_trans.purchase_amount)                       0.212139
# STD(new_trans.month_diff)                            0.365155
# STD(new_trans.purchase_date_successive_diff)           107376
# STD(new_trans.price)                                      NaN
# STD(new_trans.Christmas_Day_2017)                     25.2463
# STD(new_trans.Mothers_Day_2017)                             0
# STD(new_trans.fathers_day_2017)                       12.5145
# STD(new_trans.Children_day_2017)                      34.8648
# STD(new_trans.Valentine_Day_2017)                           0
# ...                                                       ...
# MEAN(new_trans.Mothers_Day_2018)                      7.75385
# MEAN(new_trans.duration)                             -6.91849
# MEAN(new_trans.amount_month_ratio)                 -0.0589698
# COUNT(new_trans)                                          260
# NUM_UNIQUE(new_trans.authorized_flag)                       2
# NUM_UNIQUE(new_trans.city_id)                               7
# NUM_UNIQUE(new_trans.category_1)                            1
# NUM_UNIQUE(new_trans.category_3)                            2
# NUM_UNIQUE(new_trans.merchant_category_id)                 41
# NUM_UNIQUE(new_trans.merchant_id)                          94
# NUM_UNIQUE(new_trans.category_2)                            2
# NUM_UNIQUE(new_trans.state_id)                              3
# NUM_UNIQUE(new_trans.subsector_id)                         21
# NUM_UNIQUE(new_trans.purchased_on_weekend)                  2
# MODE(new_trans.authorized_flag)                             1
# MODE(new_trans.city_id)                                    69
# MODE(new_trans.category_1)                                  0
# MODE(new_trans.category_3)                                  0
# MODE(new_trans.merchant_category_id)                      560
# MODE(new_trans.merchant_id)                   M_ID_1a81c358a3
# MODE(new_trans.category_2)                                  1
# MODE(new_trans.state_id)                                    9
# MODE(new_trans.subsector_id)                               34
# MODE(new_trans.purchased_on_weekend)                        0
# DAY(first_active_month)                                     1
# MONTH(first_active_month)                                   6
# WEEKDAY(first_active_month)                                 3
# DAYS_SINCE(first_active_month)                            612
# PERCENTILE(target)                                          1
# COUNT(new_trans WHERE authorized_flag = 1)                247
#
# [121 rows x 1 columns]

# %%
temp.T
# Out:
#                                           12454872             12454873  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           195                  278
# merchant_id                        M_ID_cc72dac895      M_ID_c9c0f1cb3f
# purchase_date                  2017-11-25 16:37:11  2017-07-16 12:21:00
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   37
# purchased_on_weekend                             1                    1
# month_diff                                      11                   11
# purchase_date_successive_diff               266503                74028
# price                                            0                    0
# Christmas_Day_2017                              29                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   27
# Children_day_2017                                0                   87
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454874             12454875  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           683                  309
# merchant_id                        M_ID_36f9e41993      M_ID_b790230ee9
# purchase_date                  2017-08-10 21:01:16  2017-12-15 12:06:58
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   21
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                  181                83223
# price                                            0                    0
# Christmas_Day_2017                               0                    9
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 2                    0
# Children_day_2017                               62                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454876             12454877  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           278                  560
# merchant_id                        M_ID_ab67f6c982      M_ID_b3c49066d8
# purchase_date                  2017-07-08 15:13:18  2017-08-13 13:43:07
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   34
# purchased_on_weekend                             1                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                26501                88599
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                35                    0
# Children_day_2017                               95                   59
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454878             12454879  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  560
# merchant_id                        M_ID_b3c49066d8      M_ID_b3c49066d8
# purchase_date                  2018-01-27 06:44:29  2017-07-01 09:02:20
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   34
# purchased_on_weekend                             1                    1
# month_diff                                      10                   11
# purchase_date_successive_diff                60224               154274
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   42
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454880             12454881  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  560
# merchant_id                        M_ID_c124c4467a      M_ID_1a81c358a3
# purchase_date                  2017-09-02 23:05:56  2017-07-27 08:17:48
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   34
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                18396                62738
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   16
# Children_day_2017                               39                   76
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               82                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454882             12454883  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  130
# merchant_id                        M_ID_b3c49066d8      M_ID_166984dc8f
# purchase_date                  2018-02-25 09:25:39  2017-12-20 11:55:05
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   41
# purchased_on_weekend                             1                    0
# month_diff                                      10                   11
# purchase_date_successive_diff               252333                 5040
# price                                            0                    0
# Christmas_Day_2017                               0                    4
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                76                    0
#
#                                           12454884             12454885  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           454                  560
# merchant_id                        M_ID_8e24779ad0      M_ID_1a81c358a3
# purchase_date                  2017-09-30 20:06:30  2017-07-07 13:58:08
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    39                   34
# purchased_on_weekend                             1                    0
# month_diff                                      10                   11
# purchase_date_successive_diff                 2771                25149
# price                                            0                    0
# Christmas_Day_2017                              85                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   36
# Children_day_2017                               11                   96
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               54                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454886             12454887  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           637                  526
# merchant_id                        M_ID_800c9d11e3      M_ID_03bb6f5a3b
# purchase_date                  2017-07-12 15:20:45  2017-12-20 18:28:09
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   25
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                12555                13256
# price                                            0                    0
# Christmas_Day_2017                               0                    4
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                31                    0
# Children_day_2017                               91                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454888             12454889  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           108                   80
# merchant_id                        M_ID_0888bdef7e      M_ID_c124c4467a
# purchase_date                  2017-09-07 16:30:10  2017-08-26 21:51:48
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   37
# purchased_on_weekend                             0                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                84708                 6852
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                               34                   46
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               77                   89
# Mothers_Day_2018                                 0                    0
#
#                                           12454890             12454891  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                  231
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           884                  454
# merchant_id                        M_ID_9122ebdd02      M_ID_4b30e99bda
# purchase_date                  2017-09-17 19:48:49  2017-10-09 18:42:12
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    27                   39
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                80999               345206
# price                                            0                    0
# Christmas_Day_2017                              98                   76
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                               24                    2
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               67                   45
# Mothers_Day_2018                                 0                    0
#
#                                           12454892             12454893  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  454
# merchant_id                        M_ID_1a81c358a3      M_ID_6b718b517f
# purchase_date                  2017-07-26 08:08:11  2017-10-04 18:52:58
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   39
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                63121               162675
# price                                            0                    0
# Christmas_Day_2017                               0                   81
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                17                    0
# Children_day_2017                               77                    7
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                   50
# Mothers_Day_2018                                 0                    0
#
#                                           12454894             12454895  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           561                  478
# merchant_id                        M_ID_50f575c681      M_ID_de54dcf09d
# purchase_date                  2017-09-16 01:30:25  2017-10-05 18:48:46
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                     7                    7
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                19883                72999
# price                                            0                    0
# Christmas_Day_2017                              99                   80
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                               25                    6
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               68                   49
# Mothers_Day_2018                                 0                    0
#
#                                           12454896             12454897  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           454                  278
# merchant_id                        M_ID_eb154b339f      M_ID_0ef7af562d
# purchase_date                  2017-12-14 09:56:57  2017-12-11 13:40:13
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    39                   37
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                64556                 7234
# price                                            0                    0
# Christmas_Day_2017                              10                   13
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454898             12454899  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           454                  879
# merchant_id                        M_ID_6b718b517f      M_ID_00a6ca8a8a
# purchase_date                  2018-01-09 10:06:54  2018-02-17 09:39:17
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    39                   29
# purchased_on_weekend                             0                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                68367                75439
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                   84
#
#                                           12454900             12454901  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           454                  195
# merchant_id                        M_ID_800c9d11e3      M_ID_cc72dac895
# purchase_date                  2017-12-13 16:01:01  2018-01-13 14:23:54
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    39                   34
# purchased_on_weekend                             0                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                28927               150582
# price                                            0                    0
# Christmas_Day_2017                              11                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454902             12454903  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                   80
# merchant_id                        M_ID_1a81c358a3      M_ID_5ba019a379
# purchase_date                  2017-08-03 14:28:00  2017-08-11 14:51:19
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   37
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                86250                14271
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 9                    1
# Children_day_2017                               69                   61
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454904             12454905  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  560
# merchant_id                        M_ID_b3c49066d8      M_ID_b3c49066d8
# purchase_date                  2018-01-27 19:04:53  2017-07-20 18:11:47
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   34
# purchased_on_weekend                             1                    0
# month_diff                                      10                   11
# purchase_date_successive_diff                44424                14449
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   23
# Children_day_2017                                0                   83
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454906             12454907  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           278                  454
# merchant_id                        M_ID_295b485138      M_ID_800c9d11e3
# purchase_date                  2017-12-22 14:19:22  2017-12-23 17:13:23
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   39
# purchased_on_weekend                             0                    1
# month_diff                                      11                   11
# purchase_date_successive_diff               157873                12015
# price                                            0                    0
# Christmas_Day_2017                               2                    1
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454908             12454909  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  705
# merchant_id                        M_ID_b3c49066d8      M_ID_82a30d9203
# purchase_date                  2017-08-20 09:40:00  2017-10-01 15:38:43
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   33
# purchased_on_weekend                             1                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                62084                  456
# price                                            0                    0
# Christmas_Day_2017                               0                   84
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                               52                   10
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               95                   53
# Mothers_Day_2018                                 0                    0
#
#                                           12454910             12454911  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  369
# merchant_id                        M_ID_55462d7eb5      M_ID_67d873012e
# purchase_date                  2017-12-31 08:48:42  2017-10-21 14:46:32
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   27
# purchased_on_weekend                             1                    1
# month_diff                                      10                   11
# purchase_date_successive_diff                64399               139592
# price                                            0                    0
# Christmas_Day_2017                               0                   64
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                   33
# Mothers_Day_2018                                 0                    0
#
#                                           12454912             12454913  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                        231                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  560
# merchant_id                        M_ID_2ad4dbe808      M_ID_b3c49066d8
# purchase_date                  2017-08-11 10:53:28  2017-12-01 19:04:25
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   34
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                49357                33555
# price                                            0                    0
# Christmas_Day_2017                               0                   23
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 1                    0
# Children_day_2017                               61                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454914             12454915  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           683                  560
# merchant_id                        M_ID_d2544479be      M_ID_b3c49066d8
# purchase_date                  2017-07-22 13:15:00  2017-07-08 07:51:37
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   34
# purchased_on_weekend                             1                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                11120                64409
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                21                   35
# Children_day_2017                               81                   95
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454916             12454917  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           278                  454
# merchant_id                        M_ID_365f0deb25      M_ID_800c9d11e3
# purchase_date                  2017-12-23 13:53:08  2017-08-16 16:04:30
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   39
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                84826                   42
# price                                            0                    0
# Christmas_Day_2017                               1                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                   56
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                   99
# Mothers_Day_2018                                 0                    0
#
#                                           12454918             12454919  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  278
# merchant_id                        M_ID_5ba019a379      M_ID_1790e57dc1
# purchase_date                  2017-12-29 15:37:01  2017-07-20 19:08:18
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   37
# purchased_on_weekend                             0                    0
# month_diff                                      10                   11
# purchase_date_successive_diff                84018                 3391
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   23
# Children_day_2017                                0                   83
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454920             12454921  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                        131                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           367                  560
# merchant_id                        M_ID_fde710ae59      M_ID_1a81c358a3
# purchase_date                  2017-10-12 00:34:19  2017-06-27 14:18:08
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    16                   34
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                77659                    0
# price                                            0                    0
# Christmas_Day_2017                              73                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   46
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               42                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454922             12454923  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           360                  561
# merchant_id                        M_ID_1337d917d1      M_ID_50f575c681
# purchase_date                  2017-12-11 14:02:25  2018-01-10 13:41:27
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                    7
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                 1332                82521
# price                                            0                    0
# Christmas_Day_2017                              13                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12454924             12454925  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                   80
# merchant_id                        M_ID_1a81c358a3      M_ID_5ba019a379
# purchase_date                  2017-08-04 15:15:39  2017-07-17 14:42:31
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   37
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# ...
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  420
# merchant_id                        M_ID_b3c49066d8      M_ID_bd2f7edfa0
# purchase_date                  2018-02-08 07:33:00  2018-02-02 08:47:57
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                   31
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                62075               247063
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                93                   99
#
#                                           12455116             12455117  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                            80                  560
# merchant_id                        M_ID_8f7abb829d      M_ID_1a81c358a3
# purchase_date                  2017-11-27 16:27:14  2017-07-13 14:57:36
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   34
# purchased_on_weekend                             0                    0
# month_diff                                      10                   11
# purchase_date_successive_diff                59234                20956
# price                                            0                    0
# Christmas_Day_2017                              27                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   30
# Children_day_2017                                0                   90
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455118             12455119  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           367                  454
# merchant_id                        M_ID_820c7b73c8      M_ID_eb154b339f
# purchase_date                  2017-11-25 19:49:01  2017-07-04 14:05:19
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    16                   39
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                11510                  179
# price                                            0                    0
# Christmas_Day_2017                              29                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   39
# Children_day_2017                                0                   99
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455120             12455121  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                        181                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           367                  278
# merchant_id                        M_ID_baffe72349      M_ID_ed31e01703
# purchase_date                  2018-01-05 11:01:06  2018-01-11 20:34:12
# category_2                                       5                    1
# state_id                                         5                    9
# subsector_id                                    16                   37
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                84830                22101
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455122             12455123  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           606                  454
# merchant_id                        M_ID_cd2c0b07e9      M_ID_800c9d11e3
# purchase_date                  2017-10-17 13:21:44  2018-01-23 13:30:58
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    17                   39
# purchased_on_weekend                             0                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                71957                22668
# price                                            0                    0
# Christmas_Day_2017                              68                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                               37                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455124             12455125  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           779                  278
# merchant_id                        M_ID_855512f895      M_ID_35d5f43c28
# purchase_date                  2017-12-30 14:55:23  2017-07-15 14:58:36
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    27                   37
# purchased_on_weekend                             1                    1
# month_diff                                      10                   11
# purchase_date_successive_diff                  565                   26
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                   28
# Children_day_2017                                0                   88
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455126             12455127  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           560                  561
# merchant_id                        M_ID_b3c49066d8      M_ID_50f575c681
# purchase_date                  2017-07-22 10:09:40  2017-12-26 14:14:42
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    34                    7
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                69201                67794
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                21                    0
# Children_day_2017                               81                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455128             12455129  \
# authorized_flag                                  1                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           309                  818
# merchant_id                        M_ID_b790230ee9      M_ID_b66f23e4da
# purchase_date                  2017-12-14 12:59:55  2017-12-24 10:30:34
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    21                   12
# purchased_on_weekend                             0                    1
# month_diff                                      11                   11
# purchase_date_successive_diff                10978                62231
# price                                            0                    0
# Christmas_Day_2017                              10                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                 0                    0
# Children_day_2017                                0                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0
#
#                                           12455130             12455131
# authorized_flag                                  0                    1
# card_id                            C_ID_92a2005557      C_ID_92a2005557
# city_id                                         69                   69
# category_1                                       0                    0
# installments                                     0                    0
# category_3                                       0                    0
# merchant_category_id                           278                  526
# merchant_id                        M_ID_35d5f43c28      M_ID_03bb6f5a3b
# purchase_date                  2017-07-15 14:58:10  2018-01-15 16:33:42
# category_2                                       1                    1
# state_id                                         9                    9
# subsector_id                                    37                   25
# purchased_on_weekend                             1                    0
# month_diff                                      11                   11
# purchase_date_successive_diff                20884               180588
# price                                            0                    0
# Christmas_Day_2017                               0                    0
# Mothers_Day_2017                                 0                    0
# fathers_day_2017                                28                    0
# Children_day_2017                               88                    0
# Valentine_Day_2017                               0                    0
# Black_Friday_2017                                0                    0
# Mothers_Day_2018                                 0                    0

# %%
temp.replace([np.inf, -np.inf], 0, inplace=True)

# %%
time_features, time_feature_names = ft.dfs(entityset = new_trans_es, target_entity = 'new_trans', 
                                           trans_primitives = ['cum_sum', 'time_since_previous'], max_depth = 2,
                                           agg_primitives=['mean'], verbose=True,
                                           features_only = False)
# Out:
# Built 45 features
#
#
#
#
#
#
#
# Elapsed: 00:00 | Remaining: ? | Progress:   0%|          | Calculated: 0/10 chunks
#
#
#
#
#
#
# Elapsed: 00:00 | Remaining: 00:02 | Progress:  10%|█         | Calculated: 1/10 chunks
#
#
#
#
#
#
# Elapsed: 00:00 | Remaining: 00:02 | Progress:  20%|██        | Calculated: 2/10 chunks
#
#
#
#
#
#
# Elapsed: 00:00 | Remaining: 00:02 | Progress:  30%|███       | Calculated: 3/10 chunks
#
#
#
#
#
#
# Elapsed: 00:01 | Remaining: 00:01 | Progress:  40%|████      | Calculated: 4/10 chunks
#
#
#
#
#
#
# Elapsed: 00:01 | Remaining: 00:01 | Progress:  50%|█████     | Calculated: 5/10 chunks
#
#
#
#
#
#
# Elapsed: 00:01 | Remaining: 00:01 | Progress:  60%|██████    | Calculated: 6/10 chunks
#
#
#
#
#
#
# Elapsed: 00:02 | Remaining: 00:00 | Progress:  70%|███████   | Calculated: 7/10 chunks
#
#
#
#
#
#
# Elapsed: 00:02 | Remaining: 00:00 | Progress:  80%|████████  | Calculated: 8/10 chunks
#
#
#
#
#
#
# Elapsed: 00:02 | Remaining: 00:00 | Progress:  90%|█████████ | Calculated: 9/10 chunks
#
#
#
#
#
#
# Elapsed: 00:03 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 10/10 chunks

# %%
time_features.columns.values
# Out:
# array(['installments', 'month_lag', 'purchase_amount', 'month_diff', 'purchase_date_successive_diff',
#        'price', 'Christmas_Day_2017', 'Mothers_Day_2017', 'fathers_day_2017', 'Children_day_2017',
#        'Valentine_Day_2017', 'Black_Friday_2017', 'Mothers_Day_2018', 'duration', 'amount_month_ratio',
#        'authorized_flag', 'card_id', 'city_id', 'category_1', 'category_3', 'merchant_category_id',
#        'merchant_id', 'category_2', 'state_id', 'subsector_id', 'purchased_on_weekend', 'train.target',
#        'train.feature_1', 'train.feature_2', 'train.feature_3', 'train.MEAN(new_trans.installments)',
#        'train.MEAN(new_trans.month_lag)', 'train.MEAN(new_trans.purchase_amount)',
#        'train.MEAN(new_trans.month_diff)', 'train.MEAN(new_trans.purchase_date_successive_diff)',
#        'train.MEAN(new_trans.price)', 'train.MEAN(new_trans.Christmas_Day_2017)',
#        'train.MEAN(new_trans.Mothers_Day_2017)', 'train.MEAN(new_trans.fathers_day_2017)',
#        'train.MEAN(new_trans.Children_day_2017)', 'train.MEAN(new_trans.Valentine_Day_2017)',
#        'train.MEAN(new_trans.Black_Friday_2017)', 'train.MEAN(new_trans.Mothers_Day_2018)',
#        'train.MEAN(new_trans.duration)', 'train.MEAN(new_trans.amount_month_ratio)'], dtype=object)

# %%
time_features.T
# Out:
# card_id                                        C_ID_92a2005557
# target                                               -0.820283
# feature_1                                             5.000000
# feature_2                                             2.000000
# feature_3                                             1.000000
# MEAN(new_trans.installments)                          0.015385
# MEAN(new_trans.month_lag)                            -3.911538
# MEAN(new_trans.purchase_amount)                      -0.638341
# MEAN(new_trans.month_diff)                           10.842308
# MEAN(new_trans.purchase_date_successive_diff)     80684.565385
# MEAN(new_trans.price)                                      NaN
# MEAN(new_trans.Christmas_Day_2017)                   13.123077
# MEAN(new_trans.Mothers_Day_2017)                      0.000000
# MEAN(new_trans.fathers_day_2017)                      6.265385
# MEAN(new_trans.Children_day_2017)                    26.765385
# MEAN(new_trans.Valentine_Day_2017)                    0.000000
# MEAN(new_trans.Black_Friday_2017)                    16.465385
# MEAN(new_trans.Mothers_Day_2018)                      7.753846
# MEAN(new_trans.duration)                             -6.918492
# MEAN(new_trans.amount_month_ratio)                   -0.058970

# %%
new_trans_es
# Out:
# Entityset: None
#   Entities:
#     new_trans [Rows: 260, Columns: 28]
#     train [Rows: 1, Columns: 6]
#   Relationships:
#     new_trans.card_id -> train.card_id

# %%
new_trans_es['new_trans']['authorized_flag'].interesting_values = [1]

# %%
temp.drop(['purchase_amount'], axis=1, inplace=True)

# %%
temp.dropna(inplace=True)

# %%
interesting_features, interesting_feature_names = ft.dfs(entityset=new_trans_es, target_entity='new_trans', max_depth = 2, 
                                                         where_primitives = ['mean', 'mode'], 
                                                         agg_primitives=['trend'],
                                                         trans_primitives=[], features_only = False, verbose = True)
# Out:
# Built 45 features
#
#
#
#
#
#
# Elapsed: 00:00 | Remaining: ? | Progress:   0%|          | Calculated: 0/10 chunks
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/pandas_backend.py in wrap(df)
#     522             else:
# --> 523                 d[f.get_name()] = func(*args)
#     524
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/primitives/standard/aggregation_primitives.py in pd_trend(y, x)
#     352             # consider scipy.stats.linregress for large n cases
# --> 353             coefficients = np.polyfit(x, y, 1)
#     354
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     579     lhs /= scale
# --> 580     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     581     c = (c.T/scale).T  # broadcast scale coefficients
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2155     extobj = get_linalg_error_extobj(_raise_linalgerror_lstsq)
# -> 2156     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2157
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_lstsq(err, flag)
#     100 def _raise_linalgerror_lstsq(err, flag):
# --> 101     raise LinAlgError("SVD did not converge in Linear Least Squares")
#     102
#
# LinAlgError: SVD did not converge in Linear Least Squares
#
# During handling of the above exception, another exception occurred:
#
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-135-9df467e1314b> in <module>
#       2                                                          where_primitives = ['mean', 'mode'],
#       3                                                          agg_primitives=['trend'],
# ----> 4                                                          trans_primitives=[], features_only = False, verbose = True)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/synthesis/dfs.py in dfs(entities, relationships, entityset, target_entity, cutoff_time, instance_ids, agg_primitives, trans_primitives, allowed_paths, max_depth, ignore_entities, ignore_variables, seed_features, drop_contains, drop_exact, where_primitives, max_features, cutoff_time_in_index, save_progress, features_only, training_window, approximate, chunk_size, n_jobs, dask_kwargs, verbose)
#     211                                                   n_jobs=n_jobs,
#     212                                                   dask_kwargs=dask_kwargs,
# --> 213                                                   verbose=verbose)
#     214     return feature_matrix, features
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in calculate_feature_matrix(features, entityset, cutoff_time, instance_ids, entities, relationships, cutoff_time_in_index, training_window, approximate, save_progress, verbose, chunk_size, n_jobs, dask_kwargs, profile)
#     260                                                  cutoff_df_time_var=cutoff_df_time_var,
#     261                                                  target_time=target_time,
# --> 262                                                  pass_columns=pass_columns)
#     263
#     264     feature_matrix = pd.concat(feature_matrix)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in linear_calculate_chunks(chunks, features, approximate, training_window, profile, verbose, save_progress, entityset, no_unapproximated_aggs, cutoff_df_time_var, target_time, pass_columns)
#     523                                           cutoff_df_time_var,
#     524                                           target_time, pass_columns,
# --> 525                                           backend=backend)
#     526         feature_matrix.append(_feature_matrix)
#     527         # Do a manual garbage collection in case objects from calculate_chunk
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in calculate_chunk(chunk, features, approximate, training_window, profile, verbose, save_progress, no_unapproximated_aggs, cutoff_df_time_var, target_time, pass_columns, backend, entityset)
#     344                                            ids,
#     345                                            precalculated_features=precalculated_features,
# --> 346                                            training_window=window)
#     347
#     348             id_name = _feature_matrix.index.name
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/utils.py in wrapped(*args, **kwargs)
#      32         def wrapped(*args, **kwargs):
#      33             if save_progress is None:
# ---> 34                 r = method(*args, **kwargs)
#      35             else:
#      36                 time = args[0].to_pydatetime()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/calculate_feature_matrix.py in calc_results(time_last, ids, precalculated_features, training_window)
#     318                                                     precalculated_features=precalculated_features,
#     319                                                     ignored=all_approx_feature_set,
# --> 320                                                     profile=profile)
#     321             return matrix
#     322
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/pandas_backend.py in calculate_all_features(self, instance_ids, time_last, training_window, profile, precalculated_features, ignored, verbose)
#     191
#     192                     handler = self._feature_type_handler(test_feature)
# --> 193                     result_frame = handler(group, input_frames)
#     194
#     195                     output_frames_type = self.feature_tree.output_frames_type(test_feature)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/pandas_backend.py in _calculate_agg_features(self, features, entity_frames)
#     445                 # the column (in actuality grouping by both index and group would
#     446                 # work)
# --> 447                 to_merge = base_frame.groupby(base_frame[groupby_var], observed=True, sort=False).apply(wrap)
#     448                 frame = pd.merge(left=frame, right=to_merge,
#     449                                  left_index=True,
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/computational_backends/pandas_backend.py in wrap(df)
#     521                 d[f.get_name()] = func(*args, time=time_last)
#     522             else:
# --> 523                 d[f.get_name()] = func(*args)
#     524
#     525         return pd.Series(d)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/featuretools/primitives/standard/aggregation_primitives.py in pd_trend(y, x)
#     351
#     352             # consider scipy.stats.linregress for large n cases
# --> 353             coefficients = np.polyfit(x, y, 1)
#     354
#     355             return coefficients[0]
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     578     scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     579     lhs /= scale
# --> 580     c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     581     c = (c.T/scale).T  # broadcast scale coefficients
#     582
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2154     signature = 'DDd->Ddid' if isComplexType(t) else 'ddd->ddid'
#    2155     extobj = get_linalg_error_extobj(_raise_linalgerror_lstsq)
# -> 2156     x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2157
#    2158     # remove the axis we added
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_lstsq(err, flag)
#      99
#     100 def _raise_linalgerror_lstsq(err, flag):
# --> 101     raise LinAlgError("SVD did not converge in Linear Least Squares")
#     102
#     103 def get_linalg_error_extobj(callback):
#
# LinAlgError: SVD did not converge in Linear Least Squares

# %%
interesting_feature_names
# Out:
# [<Feature: installments>,
#  <Feature: month_lag>,
#  <Feature: purchase_amount>,
#  <Feature: month_diff>,
#  <Feature: purchase_date_successive_diff>,
#  <Feature: price>,
#  <Feature: Christmas_Day_2017>,
#  <Feature: Mothers_Day_2017>,
#  <Feature: fathers_day_2017>,
#  <Feature: Children_day_2017>,
#  <Feature: Valentine_Day_2017>,
#  <Feature: Black_Friday_2017>,
#  <Feature: Mothers_Day_2018>,
#  <Feature: duration>,
#  <Feature: amount_month_ratio>,
#  <Feature: authorized_flag>,
#  <Feature: card_id>,
#  <Feature: city_id>,
#  <Feature: category_1>,
#  <Feature: category_3>,
#  <Feature: merchant_category_id>,
#  <Feature: merchant_id>,
#  <Feature: category_2>,
#  <Feature: state_id>,
#  <Feature: subsector_id>,
#  <Feature: purchased_on_weekend>,
#  <Feature: train.target>,
#  <Feature: train.feature_1>,
#  <Feature: train.feature_2>,
#  <Feature: train.feature_3>]
