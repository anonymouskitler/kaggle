# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather

# %%
from tsfresh import extract_features
from tsfresh import extract_relevant_features

# %%
from tsfresh.examples.robot_execution_failures import download_robot_execution_failures, \
    load_robot_execution_failures
download_robot_execution_failures()
timeseries, y = load_robot_execution_failures()

# %%
new_hist_prc = feather.read_dataframe('new_hist_prc')

# %%
train_cats(new_hist_prc_copy)

# %%
new_hist_prc_copy.dtypes
# Out:
# card_id                        int64
# city_id                        int64
# installments                   int64
# merchant_category_id           int64
# merchant_id                    int64
# month_lag                      int64
# purchase_amount              float64
# category_2                   float64
# state_id                       int64
# subsector_id                   int64
# purchase_Year                  int64
# purchase_Month                 int64
# purchase_Week                  int64
# purchase_Day                   int64
# purchase_Dayofweek             int64
# purchase_Dayofyear             int64
# purchase_Is_month_end           bool
# purchase_Is_month_start         bool
# purchase_Is_quarter_end         bool
# purchase_Is_quarter_start       bool
# purchase_Is_year_end            bool
# purchase_Is_year_start          bool
# purchase_Elapsed               int64
# purchased_on_weekend           int64
# month_diff                     int64
# ...

# %%
new_hist_prc_copy = new_hist_prc[:20].copy()

# %%
new_hist = feather.read_dataframe('new_hist_trans')

# %%
train, test = [pd.read_csv('data/elo/train.csv'), pd.read_csv('data/elo/test.csv')]
# Out:
# 'Elo - ML model-RF copy.ipynb'
# 'Elo - ML model.ipynb'
# 'Elo RF.ipynb'
# 'Elo end 2 end.ipynb'
# 'Elo feature engineering-proc_df.ipynb'
# 'Elo feature engineering.ipynb'
# 'Elo merchant category reco - using RF.ipynb'
# 'Scrap pad.ipynb'
# 'Scrap pad.py'
# 'TS Fresh.ipynb'
# 'TS Fresh.py'
#  adf
#  data
#  df_hot_dropped_all
#  df_hot_ext
#  df_hot_test
#  df_hot_test_ext
#  df_proc_dfed
#  df_test_n_o
#  df_xo
#  fastai
#  hist_trans
#  hist_trans_agg
#  lgbm_importances.png
#  new_hist_prc
#  new_hist_trans
#  new_hist_trans_agg
# 'submission-2019-01-11 09:49:53.716164.csv'
# 'submission-2019-01-11 10:18:09.909061.csv'
# 'submission-2019-01-12 13:53:27.215115.csv'
# 'submission-2019-01-12 16:27:31.239044.csv'
# 'submission-2019-01-12 17:25:56.678553.csv'
# 'submission-2019-01-12 17:33:29.475835.csv'
# 'submission-2019-01-12 17:42:01.350278.csv'
# 'submission-2019-01-12 22:12:59.947458.csv'
# 'submission-2019-01-13 15:59:45.792347.csv'
# ...

# %%
new_hist_prc_copy['merchant_id'] = new_hist_prc_copy['merchant_id'].astype('category')

# %%
new_hist_prc_copy.dtypes
# Out:
# card_id                         int64
# city_id                         int64
# installments                    int64
# merchant_category_id            int64
# merchant_id                  category
# month_lag                       int64
# purchase_amount               float64
# category_2                    float64
# state_id                        int64
# subsector_id                    int64
# purchase_Year                   int64
# purchase_Month                  int64
# purchase_Week                   int64
# purchase_Day                    int64
# purchase_Dayofweek              int64
# purchase_Dayofyear              int64
# purchase_Is_month_end            bool
# purchase_Is_month_start          bool
# purchase_Is_quarter_end          bool
# purchase_Is_quarter_start        bool
# purchase_Is_year_end             bool
# purchase_Is_year_start           bool
# purchase_Elapsed                int64
# purchased_on_weekend            int64
# month_diff                      int64
# ...

# %%
extract_features(new_hist_prc_copy.reset_index(), column_id='card_id', column_sort='purchase_Elapsed',
                column_value='month_diff')
# Out:
# ...
# Feature Extraction: 100%|██████████| 2/2 [00:00<00:00, 36.13it/s]
# variable  month_diff__abs_energy  month_diff__absolute_sum_of_changes  \
# id
# 74151                      463.0                                  1.0
# 271039                    1810.0                                  3.0
#
# variable  month_diff__agg_autocorrelation__f_agg_"mean"  \
# id
# 74151                                         -0.481481
# 271039                                        -0.090362
#
# variable  month_diff__agg_autocorrelation__f_agg_"median"  \
# id
# 74151                                           -0.333333
# 271039                                          -0.066667
#
# variable  month_diff__agg_autocorrelation__f_agg_"var"  \
# id
# 74151                                         0.142661
# 271039                                        0.256152
#
# variable  month_diff__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"  \
# id
# ...

# %%
la = extract_features(new_hist_prc_copy.reset_index(), column_id='card_id', column_sort='purchase_Elapsed',
                column_value='purchase_amount')
# Out:
# ...
# Feature Extraction: 100%|██████████| 2/2 [00:00<00:00,  6.59it/s]

# %%
la.T
# Out:
# id                                                    74151      271039
# variable
# purchase_amount__abs_energy                         1.390436  52.878897
# purchase_amount__absolute_sum_of_changes            0.144901  14.381138
# purchase_amount__agg_autocorrelation__f_agg_"mean" -0.514896  -0.038125
# purchase_amount__agg_autocorrelation__f_agg_"me... -0.184062   0.037112
# purchase_amount__agg_autocorrelation__f_agg_"var"   0.289258   0.053002
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN   5.263697
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN  -1.000000
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN  -5.755755
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN   0.000000
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN        NaN
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN        NaN
# purchase_amount__agg_linear_trend__f_agg_"max"_...       NaN        NaN
# ...

# %%
features_filtered_direct = extract_features(la[['card_id', 'purchase_Elapsed']],
                                                     column_id='card_id', column_sort='purchase_Elapsed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-5cb61f226dd1> in <module>
#       1 features_filtered_direct = extract_features(la[['card_id', 'purchase_Elapsed']],
# ----> 2                                                      column_id='card_id', column_sort='purchase_Elapsed')
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor)
#     135                                                                         column_id=column_id, column_kind=column_kind,
# ...

# %%
features_filtered_direct.to_feather('new_features_filtered_direct')
