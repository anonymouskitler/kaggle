# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-imports-and-dfs" data-toc-modified-id="Load-imports-and-dfs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load imports and dfs</a></span></li><li><span><a href="#Blend" data-toc-modified-id="Blend-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Blend</a></span></li></ul></div>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# 1. Load imports & test, train DFs
# 2. Apply stratified kfold & traing with lgbm and submit to kaggle
# 3. Check for missing data feature engineering parts missed if score > 3.7
# 4. Split the training set to train & validation
# 5. Train over RF to get a benchmark of the dataset
# 6. Drop irrelevant features by sorting on feature importance
# 7. Drop redundant features by plotting a Dendogram and removing the redundancy
# 8. Use a feature interpreter to see which feature is contributing lot to prediction
# 9. Use extrapolation to see if we can remove feature which add bias of training & validation set
# 10. Use partial dependence plot to see outliers/missed features
# 11. Submit to kaggle the RF model and see the score
# 11. Use stratified kfold to train the RF model and submit to kaggle
# 12. Repeat again with LGBM/XGBoost/Adaboost. Stack the model and submit to kaggle

# %% [markdown]
# ### Load imports and dfs

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import warnings

# %%
train_df2 = feather.read_dataframe('train_df_beta')
test_df2 = feather.read_dataframe('test_df_beta')

# %%
for df in [train_df2, test_df2]:
    for f in ['purchase_date_max','purchase_date_min','purchase_date_max_old',\
                     'purchase_date_min_old']:
        df[f] = df[f].astype(np.int64) * 1e-9

# %%
del_cols = ['first_active_monthIs_month_start', 'authorized_flag_1_mean', 'first_active_monthIs_year_start',
       'first_active_monthIs_year_end', 'first_active_monthIs_quarter_end', 'avg_trans_per_merchant',
       'first_active_monthIs_month_end', 'first_active_monthDay', 'card_id_size',
       'authorized_flag_1_amount_mean_mean', 'authorized_flag_1_amount_sum_sum','card_id', 'first_active_month','target','outliers']

# %%
def one_hot_encode_fe(df):
    return pd.get_dummies(df, columns=['feature_1', 'feature_2', 'feature_3'])

# %%
# [train_df2, test_df2] = [one_hot_encode_fe(d) for d in [train_df2, test_df2]]

# %%
df_train_columns = [c for c in train_df2.columns if c not in ['card_id', 'first_active_month','target','outliers']]
target = train_df2['target']

# %%
train_df2.shape, test_df2.shape
# Out:
# ((201917, 244), (123623, 242))

# %%
target.shape
# Out:
# (201917,)

# %%
del train_df2['target']

# %%
len(df_train_columns)
# Out:
# 240

# %%
from scipy.stats import ks_2samp
list_p_value =[]

for i in tqdm(df_train_columns):
    list_p_value.append(ks_2samp(test_df2[i] , train_df2[i])[1])

Se = pd.Series(list_p_value, index = df_train_columns).sort_values() 
list_discarded = list(Se[Se < .1].index)
# Out:
# 100%|██████████| 240/240 [00:06<00:00, 41.05it/s]

# %%
list_discarded
# Out:
# ['purchase_amount_total_max',
#  'duration_max',
#  'amount_month_ratio_max',
#  'price_sum',
#  'category_2_mean_mean',
#  'avg_spend_per_transaction',
#  'price_max_old',
#  'category_2_mean',
#  'avg_spend_per_merchant',
#  'purchase_amount_mean',
#  'category_2_mean_mean_old',
#  'purchase_amount_total_mean',
#  'price_sum_old',
#  'price_mean',
#  'price_mean_old',
#  'purchase_amount_max_old',
#  'price_total',
#  'duration_mean',
#  'state_id_mean_mean',
#  'price_max',
#  'amount_month_ratio_max_old',
#  'category_3_mean_old',
#  'category_3_mean_mean_old',
#  'installments_mean',
#  'installments_mean_old']

# %%
# df_train_columns = [c for c in df_train_columns if c not in list_discarded]?

# %%
len(df_train_columns)
# Out:
# 240

# %%
FEATS_EXCLUDED = ['first_active_month', 'target', 'card_id', 'outliers',
                  'hist_purchase_date_max', 'hist_purchase_date_min', 'hist_card_id_size',
                  'new_purchase_date_max', 'new_purchase_date_min', 'new_card_id_size',
                  'OOF_PRED', 'month_0']

# %%
df_train_columns = [c for c in df_train_columns if c not in FEATS_EXCLUDED]

# %%
n_fold =5

# %%
param = {
        'task': 'train',
        'boosting': 'goss',
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.01,
        'subsample': 0.9855232997390695,
        'max_depth': 7,
        'top_rate': 0.9064148448434349,
        'num_leaves': 63,
        'min_child_weight': 41.9612869171337,
        'other_rate': 0.0721768246018207,
        'reg_alpha': 9.677537745007898,
        'colsample_bytree': 0.5665320670155495,
        'min_split_gain': 9.820197773625843,
        'reg_lambda': 8.2532317400459,
        'min_data_in_leaf': 21,
        'verbose': -1,
        'seed':int(2**n_fold),
        'bagging_seed':int(2**n_fold),
        'drop_seed':int(2**n_fold)
        }
folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=4590)
oof = np.zeros(len(train_df2))
predictions = np.zeros(len(test_df2))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df2,train_df2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(train_df2.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])#, categorical_feature=categorical_feats)
    val_data = lgb.Dataset(train_df2.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])#, categorical_feature=categorical_feats)

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 100)
    oof[val_idx] = clf.predict(train_df2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test_df2[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.65767	valid_1's rmse: 3.71273
# [200]	training's rmse: 3.57691	valid_1's rmse: 3.67559
# [300]	training's rmse: 3.52759	valid_1's rmse: 3.66293
# [400]	training's rmse: 3.4932	valid_1's rmse: 3.65792
# [500]	training's rmse: 3.46444	valid_1's rmse: 3.65576
# [600]	training's rmse: 3.43938	valid_1's rmse: 3.6541
# [700]	training's rmse: 3.41784	valid_1's rmse: 3.65345
# [800]	training's rmse: 3.39895	valid_1's rmse: 3.65277
# [900]	training's rmse: 3.38197	valid_1's rmse: 3.65238
# Early stopping, best iteration is:
# [898]	training's rmse: 3.3824	valid_1's rmse: 3.65237
# fold 1
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.65849	valid_1's rmse: 3.70444
# [200]	training's rmse: 3.57499	valid_1's rmse: 3.66826
# [300]	training's rmse: 3.52428	valid_1's rmse: 3.65732
# [400]	training's rmse: 3.48813	valid_1's rmse: 3.65371
# [500]	training's rmse: 3.4612	valid_1's rmse: 3.65201
# [600]	training's rmse: 3.43737	valid_1's rmse: 3.65123
# [700]	training's rmse: 3.41623	valid_1's rmse: 3.65082
# [800]	training's rmse: 3.39667	valid_1's rmse: 3.65112
# Early stopping, best iteration is:
# [731]	training's rmse: 3.41051	valid_1's rmse: 3.65078
# fold 2
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.65668	valid_1's rmse: 3.71413
# [200]	training's rmse: 3.57605	valid_1's rmse: 3.67978
# [300]	training's rmse: 3.52611	valid_1's rmse: 3.66805
# [400]	training's rmse: 3.4909	valid_1's rmse: 3.6624
# [500]	training's rmse: 3.4626	valid_1's rmse: 3.65899
# [600]	training's rmse: 3.43659	valid_1's rmse: 3.65739
# [700]	training's rmse: 3.41655	valid_1's rmse: 3.6562
# [800]	training's rmse: 3.39823	valid_1's rmse: 3.6556
# [900]	training's rmse: 3.38036	valid_1's rmse: 3.65559
# Early stopping, best iteration is:
# [852]	training's rmse: 3.38863	valid_1's rmse: 3.65544
# fold 3
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.65564	valid_1's rmse: 3.70792
# [200]	training's rmse: 3.57174	valid_1's rmse: 3.67658
# [300]	training's rmse: 3.52091	valid_1's rmse: 3.66567
# [400]	training's rmse: 3.48589	valid_1's rmse: 3.66224
# [500]	training's rmse: 3.4587	valid_1's rmse: 3.66055
# [600]	training's rmse: 3.43609	valid_1's rmse: 3.65953
# [700]	training's rmse: 3.41574	valid_1's rmse: 3.65885
# [800]	training's rmse: 3.39546	valid_1's rmse: 3.65847
# Early stopping, best iteration is:
# [798]	training's rmse: 3.3957	valid_1's rmse: 3.65844
# fold 4
# Training until validation scores don't improve for 100 rounds.
# [100]	training's rmse: 3.65762	valid_1's rmse: 3.69917
# [200]	training's rmse: 3.5735	valid_1's rmse: 3.67111
# [300]	training's rmse: 3.52171	valid_1's rmse: 3.66206
# [400]	training's rmse: 3.48755	valid_1's rmse: 3.65846
# [500]	training's rmse: 3.46286	valid_1's rmse: 3.65627
# [600]	training's rmse: 3.44093	valid_1's rmse: 3.65549
# [700]	training's rmse: 3.42028	valid_1's rmse: 3.65477
# [800]	training's rmse: 3.4014	valid_1's rmse: 3.65481
# Early stopping, best iteration is:
# [745]	training's rmse: 3.41203	valid_1's rmse: 3.65449
# 3.654305490157562

# %% [markdown]
# 1. Score for submission-2019-01-11 10:18:09.909061.csv - 3.6597596743401666, LB - 3.707 (included cat_1)
# 2. Score for submission-2019-01-12 13:53:27.215115.csv - 3.656726211308068, LB - 3.696 (jst refactored)
# 3. No changes what so ever - 3.6627995460091523
# 4. Replaced with kernels code - 3.6623128394907103
# 5. Replaced with kernels code along with cat_2 mean - 3.6609564684554594
# 6. Added extra feature - 3.6559302073797637, LB - 3.696 (No grouping by auth flag and all)
# 7. Added aggs on cat_1, auth - 3.6554801486969906, LB- 3.696
# 8. Removed unnecessary cols - 3.6556548946965446, LB - 3.696
# 9. Removed aggs on cat_1 - 3.654208034404632, LB - 3.697
# 10. Removed unnecessary del_cols - 3.65493381575084, LB - 3.697
# 11. One hot encoded features - 3.6558286566186897
# 12. Added monthly aggregates - 3.653533666238162, LB - 3.716
# 13. Removed some monthly aggregates - 3.654769374794982, LB - 3.707
# 14. reverting to earlier checkpoing - 3.65377489489624
# 15. Benchmarks - LGBM - 3.654910478618945, DL - 3.6971527526968155
# 16. Just ran the whole FE page -submission-2019-01-20 01:46:39.187580.csv - 3.6546249070742816

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
best_features.sort_values(by='importance', ascending=False)[:500]['Feature'].unique()
# Out:
# array(['purchase_amount_max', 'duration_min_old', 'authorized_flag_mean_old', 'category_1_sum_old',
#        'purchase_Week_mean', 'month_diff_mean_old', 'purchase_Month_nunique_old',
#        'repurchase_merchant_rate_old', 'category_1_mean', 'purchase_date_uptonow', 'purchase_Day_mean',
#        'purchase_date_diff', 'fathers_day_2017_mean_old', 'purchase_Week_max', 'month_lag_mean_old',
#        'purchase_Month_mean', 'category_1_mean_old', 'duration_mean_old', 'purchase_date_diff_old',
#        'duration_max_old', 'amount_month_ratio_min_old', 'purchase_date_successive_diff_skew_old',
#        'installments_sum_old', 'purchase_date_uptonow_old', 'purchase_date_successive_diff_var',
#        'purchase_date_successive_diff_max_old', 'Christmas_Day_2017_mean', 'Children_day_2017_mean_old',
#        'avg_spend_per_merchant_old', 'purchase_date_successive_diff_var_old', 'purchase_amount_mean',
#        'purchase_date_max_old', 'month_lag_var_old', 'purchase_amount_max_total', 'card_id_count_ratio',
#        'days_feature1', 'category_1_sum', 'purchase_date_successive_diff_median_old',
#        'Valentine_Day_2017_mean_old', 'purchase_Week_min', 'purchase_date_min_old', 'days_feature2',
#        'purchase_date_max', 'month_lag_mean', 'subsector_id_mean_mean', 'price_var_old', 'hist_last_buy',
#        'month_lag_skew', 'Black_Friday_2017_mean', 'duration_var', 'state_id_mean_mean_old', 'month_lag_max',
#        'price_skew_old', 'month_lag_skew_old', 'duration_min', 'purchase_Week_nunique_old',
#        'days_feature1_ratio', 'merchant_id_nunique_old', 'merchant_category_repurchase_old',
#        'purchase_amount_min', 'Mothers_Day_2017_mean_old', 'purchase_amount_min_old',
#        'Mothers_Day_2018_mean', 'state_id_mean_mean', 'purchased_on_weekend_mean_old', 'days_feature2_ratio',
#        'purchase_date_uptomin', 'purchase_amount_mean_old', 'month_diff_mean', 'purchase_Day_max',
#        'installments_ratio', 'purchase_Day_min', 'hist_first_buy', 'amount_month_ratio_mean_old',
#        'avg_spend_per_merchant', 'purchase_Day_mean_old', 'month_diff_var_old',
#        'days_since_last_transaction', 'month_diff_skew_old', 'subsector_id_mean_mean_old', 'CLV',
#        'purchase_amount_sum', 'purchase_date_successive_diff_skew', 'month_diff_ratio',
#        'category_2_mean_mean_old', 'merchant_category_id_nunique_old', 'installments_var_old',
#        'avg_trans_per_merchant_old', 'month_lag_var', 'new_first_buy', 'duration_var_old',
#        'purchase_date_successive_diff_mean', 'purchase_date_successive_diff_mean_old', 'CLV_ratio',
#        'Children_day_2017_mean', 'price_mean_old', 'days_since_last_transaction_old',
#        'amount_month_ratio_var', 'price_var', 'new_last_buy', 'installments_mean_old',
#        'purchase_amount_skew_old', 'amount_month_ratio_min', 'duration_mean',
#        'purchase_date_successive_diff_max', 'installments_total', 'duration_skew_old',
#        'purchase_amount_total_min', 'price_min', 'purchase_Week_mean_old', 'purchase_amount_var',
#        'installments_mean', 'purchase_amount_sum_ratio', 'purchase_date_successive_diff_median',
#        'days_feature3', 'Black_Friday_2017_mean_old', 'purchase_date_min', 'price_max',
#        'purchase_date_average', 'subsector_id_nunique_old', 'purchased_on_weekday_sum_old',
#        'avg_spend_per_transaction'], dtype=object)

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import gc

# %%
def kfold_lightgbm(train_df, test_df, num_folds, stratified = False, debug= False):
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))

    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=326)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=326)

    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in FEATS_EXCLUDED]

    # k-fold
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['outliers'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['target'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['target'].iloc[valid_idx]

        # set data structure
        lgb_train = lgb.Dataset(train_x,
                                label=train_y,
                                free_raw_data=False)
        lgb_test = lgb.Dataset(valid_x,
                               label=valid_y,
                               free_raw_data=False)

        # params optimized by optuna
        params ={
                'task': 'train',
                'boosting': 'goss',
                'objective': 'regression',
                'metric': 'rmse',
                'learning_rate': 0.01,
                'subsample': 0.9855232997390695,
                'max_depth': 7,
                'top_rate': 0.9064148448434349,
                'num_leaves': 63,
                'min_child_weight': 41.9612869171337,
                'other_rate': 0.0721768246018207,
                'reg_alpha': 9.677537745007898,
                'colsample_bytree': 0.5665320670155495,
                'min_split_gain': 9.820197773625843,
                'reg_lambda': 8.2532317400459,
                'min_data_in_leaf': 21,
                'verbose': -1,
                'seed':int(2**n_fold),
                'bagging_seed':int(2**n_fold),
                'drop_seed':int(2**n_fold)
                }

        reg = lgb.train(
                        params,
                        lgb_train,
                        valid_sets=[lgb_train, lgb_test],
                        valid_names=['train', 'test'],
                        num_boost_round=10000,
                        early_stopping_rounds= 200,
                        verbose_eval=100
                        )

        oof_preds[valid_idx] = reg.predict(valid_x, num_iteration=reg.best_iteration)
        sub_preds += reg.predict(test_df[feats], num_iteration=reg.best_iteration) / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = np.log1p(reg.feature_importance(importance_type='gain', iteration=reg.best_iteration))
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d RMSE : %.6f' % (n_fold + 1, rmse(valid_y, oof_preds[valid_idx])))
        del reg, train_x, train_y, valid_x, valid_y
        gc.collect()

    # display importances
    display_importances(feature_importance_df)

    if not debug:
        # save submission file
        submission_name = pd.to_datetime("today")
        sub_df = pd.DataFrame({"card_id":test_df2["card_id"].values})
        sub_df["target"] = sub_preds
        sub_df.to_csv(f'submission-{submission_name}.csv', index=False)
#         test_df.loc[:,'target'] = sub_preds
#         test_df = test_df.reset_index()
#         test_df[['card_id', 'target']].to_csv(submission_name, index=False)

# %%
# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]

    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances.png')

# %%
kfold_lightgbm(train_df2, test_df2, num_folds=11, stratified=False, debug=False)
# Out:
# Starting LightGBM. Train shape: (201917, 244), test shape: (123623, 242)
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.65646	test's rmse: 3.73613
# [200]	train's rmse: 3.57825	test's rmse: 3.69908
# [300]	train's rmse: 3.53062	test's rmse: 3.68627
# [400]	train's rmse: 3.49813	test's rmse: 3.68131
# [500]	train's rmse: 3.47268	test's rmse: 3.67856
# [600]	train's rmse: 3.45119	test's rmse: 3.67775
# [700]	train's rmse: 3.43145	test's rmse: 3.67705
# [800]	train's rmse: 3.41343	test's rmse: 3.67726
# [900]	train's rmse: 3.39685	test's rmse: 3.67719
# [1000]	train's rmse: 3.38086	test's rmse: 3.67686
# [1100]	train's rmse: 3.36531	test's rmse: 3.67723
# [1200]	train's rmse: 3.35107	test's rmse: 3.67753
# Early stopping, best iteration is:
# [1011]	train's rmse: 3.37903	test's rmse: 3.67683
# Fold  1 RMSE : 3.676833
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.65398	test's rmse: 3.78569
# [200]	train's rmse: 3.57632	test's rmse: 3.75217
# [300]	train's rmse: 3.52956	test's rmse: 3.74216
# [400]	train's rmse: 3.49744	test's rmse: 3.73938
# [500]	train's rmse: 3.47295	test's rmse: 3.73825
# [600]	train's rmse: 3.4523	test's rmse: 3.73709
# [700]	train's rmse: 3.4327	test's rmse: 3.73686
# [800]	train's rmse: 3.41352	test's rmse: 3.7372
# [900]	train's rmse: 3.39579	test's rmse: 3.73708
# [1000]	train's rmse: 3.37926	test's rmse: 3.73718
# Early stopping, best iteration is:
# [839]	train's rmse: 3.40622	test's rmse: 3.73665
# Fold  2 RMSE : 3.736653
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.65073	test's rmse: 3.80774
# [200]	train's rmse: 3.57127	test's rmse: 3.7818
# [300]	train's rmse: 3.52495	test's rmse: 3.77422
# [400]	train's rmse: 3.49248	test's rmse: 3.77102
# [500]	train's rmse: 3.46681	test's rmse: 3.76904
# [600]	train's rmse: 3.44396	test's rmse: 3.76744
# [700]	train's rmse: 3.42277	test's rmse: 3.76663
# [800]	train's rmse: 3.40441	test's rmse: 3.76566
# [900]	train's rmse: 3.38623	test's rmse: 3.76518
# [1000]	train's rmse: 3.37025	test's rmse: 3.76514
# [1100]	train's rmse: 3.35412	test's rmse: 3.76564
# Early stopping, best iteration is:
# [935]	train's rmse: 3.3797	test's rmse: 3.76506
# Fold  3 RMSE : 3.765059
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.64778	test's rmse: 3.83852
# [200]	train's rmse: 3.56932	test's rmse: 3.80603
# [300]	train's rmse: 3.52185	test's rmse: 3.79543
# [400]	train's rmse: 3.48762	test's rmse: 3.79051
# [500]	train's rmse: 3.46228	test's rmse: 3.78801
# [600]	train's rmse: 3.43986	test's rmse: 3.78692
# [700]	train's rmse: 3.42056	test's rmse: 3.78652
# [800]	train's rmse: 3.40374	test's rmse: 3.78643
# [900]	train's rmse: 3.38766	test's rmse: 3.78676
# [1000]	train's rmse: 3.37243	test's rmse: 3.78792
# Early stopping, best iteration is:
# [859]	train's rmse: 3.39417	test's rmse: 3.78633
# Fold  4 RMSE : 3.786327
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.67699	test's rmse: 3.55498
# [200]	train's rmse: 3.59912	test's rmse: 3.51839
# [300]	train's rmse: 3.55318	test's rmse: 3.5075
# [400]	train's rmse: 3.52092	test's rmse: 3.50294
# [500]	train's rmse: 3.49669	test's rmse: 3.50025
# [600]	train's rmse: 3.47463	test's rmse: 3.49865
# [700]	train's rmse: 3.45337	test's rmse: 3.49773
# [800]	train's rmse: 3.43528	test's rmse: 3.49759
# [900]	train's rmse: 3.41754	test's rmse: 3.49724
# [1000]	train's rmse: 3.40033	test's rmse: 3.49715
# Early stopping, best iteration is:
# [879]	train's rmse: 3.42157	test's rmse: 3.49698
# Fold  5 RMSE : 3.496981
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.66134	test's rmse: 3.72357
# [200]	train's rmse: 3.58424	test's rmse: 3.68147
# [300]	train's rmse: 3.53757	test's rmse: 3.66518
# [400]	train's rmse: 3.5048	test's rmse: 3.65742
# [500]	train's rmse: 3.48049	test's rmse: 3.65332
# [600]	train's rmse: 3.45833	test's rmse: 3.65121
# [700]	train's rmse: 3.43839	test's rmse: 3.64966
# [800]	train's rmse: 3.41956	test's rmse: 3.64831
# [900]	train's rmse: 3.4013	test's rmse: 3.64791
# [1000]	train's rmse: 3.3865	test's rmse: 3.64664
# [1100]	train's rmse: 3.37077	test's rmse: 3.64694
# [1200]	train's rmse: 3.3557	test's rmse: 3.64635
# [1300]	train's rmse: 3.34033	test's rmse: 3.64651
# [1400]	train's rmse: 3.32562	test's rmse: 3.6463
# [1500]	train's rmse: 3.31068	test's rmse: 3.64623
# [1600]	train's rmse: 3.29691	test's rmse: 3.64614
# Early stopping, best iteration is:
# [1441]	train's rmse: 3.3195	test's rmse: 3.64592
# Fold  6 RMSE : 3.645920
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.66425	test's rmse: 3.66213
# [200]	train's rmse: 3.58462	test's rmse: 3.63319
# [300]	train's rmse: 3.53891	test's rmse: 3.62189
# [400]	train's rmse: 3.50736	test's rmse: 3.6166
# [500]	train's rmse: 3.48296	test's rmse: 3.61366
# [600]	train's rmse: 3.46074	test's rmse: 3.61076
# [700]	train's rmse: 3.44131	test's rmse: 3.6088
# [800]	train's rmse: 3.42319	test's rmse: 3.60822
# [900]	train's rmse: 3.40477	test's rmse: 3.60772
# [1000]	train's rmse: 3.38862	test's rmse: 3.60753
# [1100]	train's rmse: 3.37313	test's rmse: 3.60742
# [1200]	train's rmse: 3.35818	test's rmse: 3.60735
# [1300]	train's rmse: 3.34299	test's rmse: 3.60729
# Early stopping, best iteration is:
# [1168]	train's rmse: 3.36292	test's rmse: 3.60716
# Fold  7 RMSE : 3.607161
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.67162	test's rmse: 3.60141
# [200]	train's rmse: 3.5931	test's rmse: 3.56786
# [300]	train's rmse: 3.54603	test's rmse: 3.55553
# [400]	train's rmse: 3.5126	test's rmse: 3.55253
# [500]	train's rmse: 3.48933	test's rmse: 3.5495
# [600]	train's rmse: 3.46721	test's rmse: 3.54871
# [700]	train's rmse: 3.44776	test's rmse: 3.54768
# [800]	train's rmse: 3.4296	test's rmse: 3.54676
# [900]	train's rmse: 3.41239	test's rmse: 3.54681
# [1000]	train's rmse: 3.39629	test's rmse: 3.54696
# Early stopping, best iteration is:
# [875]	train's rmse: 3.41679	test's rmse: 3.54663
# Fold  8 RMSE : 3.546633
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.65752	test's rmse: 3.74834
# [200]	train's rmse: 3.57784	test's rmse: 3.71718
# [300]	train's rmse: 3.52925	test's rmse: 3.7092
# [400]	train's rmse: 3.49503	test's rmse: 3.7061
# [500]	train's rmse: 3.46888	test's rmse: 3.70524
# [600]	train's rmse: 3.44688	test's rmse: 3.70494
# [700]	train's rmse: 3.42711	test's rmse: 3.70397
# [800]	train's rmse: 3.40937	test's rmse: 3.7039
# [900]	train's rmse: 3.39198	test's rmse: 3.70358
# [1000]	train's rmse: 3.37576	test's rmse: 3.70267
# [1100]	train's rmse: 3.3607	test's rmse: 3.70309
# Early stopping, best iteration is:
# [994]	train's rmse: 3.37673	test's rmse: 3.7026
# Fold  9 RMSE : 3.702599
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.67119	test's rmse: 3.58815
# [200]	train's rmse: 3.5931	test's rmse: 3.56026
# [300]	train's rmse: 3.54624	test's rmse: 3.55278
# [400]	train's rmse: 3.51333	test's rmse: 3.55132
# [500]	train's rmse: 3.48802	test's rmse: 3.54943
# [600]	train's rmse: 3.46469	test's rmse: 3.54844
# [700]	train's rmse: 3.4417	test's rmse: 3.54807
# [800]	train's rmse: 3.42165	test's rmse: 3.54847
# Early stopping, best iteration is:
# [675]	train's rmse: 3.44703	test's rmse: 3.54785
# Fold 10 RMSE : 3.547849
# Training until validation scores don't improve for 200 rounds.
# [100]	train's rmse: 3.66083	test's rmse: 3.72784
# [200]	train's rmse: 3.58205	test's rmse: 3.68973
# [300]	train's rmse: 3.53485	test's rmse: 3.67433
# [400]	train's rmse: 3.50272	test's rmse: 3.6687
# [500]	train's rmse: 3.47893	test's rmse: 3.66569
# [600]	train's rmse: 3.45739	test's rmse: 3.66383
# [700]	train's rmse: 3.43714	test's rmse: 3.662
# [800]	train's rmse: 3.41814	test's rmse: 3.66111
# [900]	train's rmse: 3.40102	test's rmse: 3.66047
# [1000]	train's rmse: 3.38338	test's rmse: 3.6602
# [1100]	train's rmse: 3.36649	test's rmse: 3.6601
# [1200]	train's rmse: 3.35079	test's rmse: 3.66038
# [1300]	train's rmse: 3.33588	test's rmse: 3.66073
# Early stopping, best iteration is:
# [1146]	train's rmse: 3.35904	test's rmse: 3.65984
# Fold 11 RMSE : 3.659843
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
submission_name = pd.to_datetime("today")

# %%
sub_df = pd.DataFrame({"card_id":test_df2["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv(f'submission-{submission_name}.csv', index=False)

# %%
# !ls
# Out:
# 'Blending submissions.ipynb'
# 'Elo - ML model - 3.695 beta.ipynb'
# 'Elo - ML model - 3.695.ipynb'
# 'Elo - ML model - 3.696.ipynb'
# 'Elo - ML model - beta.ipynb'
# 'Elo - ML model - cat aggregates.ipynb'
# 'Elo - ML model clean.ipynb'
# 'Elo - ML model proc_df.ipynb'
# 'Elo - ML model-RF copy.ipynb'
# 'Elo - ML model-backup.ipynb'
# 'Elo - ML model-new.ipynb'
# 'Elo RF- New.ipynb'
# 'Elo RF.ipynb'
# 'Elo end 2 end.ipynb'
# 'Elo feature engineering - 3.696.ipynb'
# 'Elo feature engineering 3.695 beta.ipynb'
# 'Elo feature engineering 3.695.ipynb'
# 'Elo feature engineering beta .ipynb'
# 'Elo feature engineering using agg.ipynb'
# 'Elo feature engineering-backup.ipynb'
# 'Elo feature engineering-proc_df - new-Copy1.ipynb'
# 'Elo feature engineering-proc_df - new.ipynb'
# 'Elo feature engineering-proc_df-OLD.ipynb'
# 'Elo feature engineering-proc_df.ipynb'
# 'Elo merchant category reco - using RF.ipynb'
# 'Elo outlier predictions & blending .ipynb'
#  README.md
# 'Scrap pad.ipynb'
# 'Scrap pad.py'
# 'TS Fresh.ipynb'
# 'TS Fresh.py'
# 'Train & test clean.ipynb'
# 'Using DL.ipynb'
# 'Using Feature tools - old.ipynb'
# 'Using feature tools.ipynb'
#  adf
#  authorised_trans_proc_agg
# 'blend-2019-02-02 23:24:52.864854.csv'
#  blend-{submission_name}
#  blend_kfol_st.csv
#  chandu_mean1.csv
#  cols_keep.npy
#  combining_submission.csv
#  data
#  df_auth
#  df_hot_dropped_all
#  df_hot_ext
#  df_hot_test
#  df_hot_test_ext
#  df_new
#  df_non_auth
#  df_proc_dfed
#  df_test_n_o
#  df_xo
#  fastai
#  fm_new_hist
#  hist_trans
#  hist_trans_3_696
#  hist_trans_agg
#  hist_trans_agg_3_696
#  hist_trans_agg_beta
#  hist_trans_agg_n
#  hist_trans_agg_proc
#  hist_trans_beta
# 'kfold lightgbm.ipynb'
#  lgbm_importances.png
#  new_hist_prc
#  new_hist_trans
#  new_hist_trans_3_696
#  new_hist_trans_agg
#  new_hist_trans_agg_3_696
#  new_hist_trans_agg_beta
#  new_hist_trans_agg_n
#  new_hist_trans_beta
#  new_trans_agg_proc
#  new_trans_proc_agg
#  non_authorised_trans_proc
#  non_authorised_trans_proc_agg
#  oof_lgb_3.npy
#  oof_xgb_3.npy
#  predictions_lgb_3.npy
#  predictions_xgb_3.npy
# 'scrap pad 2.ipynb'
# 'submission-2019-01-11 09:49:53.716164.csv'
# 'submission-2019-01-11 10:18:09.909061.csv'
# 'submission-2019-01-12 13:53:27.215115.csv'
# 'submission-2019-01-12 16:27:31.239044.csv'
# 'submission-2019-01-12 17:25:56.678553.csv'
# 'submission-2019-01-12 17:33:29.475835.csv'
# 'submission-2019-01-12 17:42:01.350278.csv'
# 'submission-2019-01-12 22:12:59.947458.csv'
# 'submission-2019-01-13 15:59:45.792347.csv'
# 'submission-2019-01-13 18:24:51.237991.csv'
# 'submission-2019-01-14 19:04:33.028609.csv'
# 'submission-2019-01-14 19:56:09.906235.csv'
# 'submission-2019-01-15 22:18:34.294443.csv'
# 'submission-2019-01-15 22:24:38.071972.csv'
# 'submission-2019-01-15 22:29:20.144417.csv'
# 'submission-2019-01-16 00:35:46.490517.csv'
# 'submission-2019-01-16 00:36:26.004443.csv'
# 'submission-2019-01-16 12:20:00.957329.csv'
# 'submission-2019-01-16 21:37:16.421927.csv'
# 'submission-2019-01-17 10:20:06.724992.csv'
# 'submission-2019-01-17 11:09:17.495216.csv'
# 'submission-2019-01-17 23:23:57.743505.csv'
# 'submission-2019-01-18 01:18:08.182115.csv'
# 'submission-2019-01-18 01:42:20.587834.csv'
# 'submission-2019-01-18 01:47:04.024727.csv'
# 'submission-2019-01-18 16:16:45.475456.csv'
# 'submission-2019-01-18 16:27:58.560480.csv'
# 'submission-2019-01-18 17:22:46.188675.csv'
# 'submission-2019-01-20 00:30:10.643280.csv'
# 'submission-2019-01-20 01:28:12.077657.csv'
# 'submission-2019-01-20 01:46:39.187580.csv'
# 'submission-2019-01-20 02:32:16.439302.csv'
# 'submission-2019-01-20 17:01:54.207459.csv'
# 'submission-2019-01-20 17:27:46.797180.csv'
# 'submission-2019-01-20 18:29:37.773532.csv'
# 'submission-2019-01-20 19:11:58.593189.csv'
# 'submission-2019-01-20 19:35:24.892043.csv'
# 'submission-2019-01-20 20:47:32.743729.csv'
# 'submission-2019-01-22 09:33:02.341491.csv'
# 'submission-2019-01-22 10:35:57.465665.csv'
# 'submission-2019-01-31 22:00:10.810901.csv'
# 'submission-2019-01-31 22:04:41.815902.csv'
# 'submission-2019-02-02 23:13:59.670630.csv'
# 'submission-2019-02-02 23:24:52.864854.csv'
# 'submission-2019-02-03 14:42:22.636262.csv'
# 'submission-2019-02-03 14:43:29.797523.csv'
#  submissions
#  target_all
#  target_outliers_removed
#  test_clean.csv
#  test_clean.csv.zip
#  test_df
#  test_df_3.695
#  test_df_3_696
#  test_df_beta
#  test_df_proc
#  test_df_proc_new
#  test_df_proc_new_m
#  train_clean.csv
#  train_clean.csv.zip
#  train_clean0
#  train_df
#  train_df_3_696
#  train_df_beta
#  train_df_proc
#  train_df_proc_new
#  train_df_proc_new_m

# %%
FileLink(f'submission-{submission_name}.csv')
# Out:
# /home/chandrasekhar/private/kaggle/submission-2019-02-03 14:43:29.797523.csv

# %% [markdown]
# ### Blend

# %%
p1 = pd.read_csv(f'submission-{submission_name}.csv')
p2 = pd.read_csv('submission-2019-02-02 23:13:59.670630.csv')

# %%
p1.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.960024
# 1  C_ID_130fd0cbdd -0.421305
# 2  C_ID_b709037bc5 -1.011111
# 3  C_ID_d27d835a9f -0.141994
# 4  C_ID_2b5e3df5c2 -1.270823

# %%
p2.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.072875
# 1  C_ID_130fd0cbdd -0.348145
# 2  C_ID_b709037bc5 -0.949767
# 3  C_ID_d27d835a9f -0.149493
# 4  C_ID_2b5e3df5c2 -1.212316

# %%
p3 = p1.copy()

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.960024
# 1  C_ID_130fd0cbdd -0.421305
# 2  C_ID_b709037bc5 -1.011111
# 3  C_ID_d27d835a9f -0.141994
# 4  C_ID_2b5e3df5c2 -1.270823

# %%
p3 = pd.DataFrame({"card_id":test_df2["card_id"].values})
p3["target"] = p1['target']*.5 + p2['target']*.5

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.016449
# 1  C_ID_130fd0cbdd -0.384725
# 2  C_ID_b709037bc5 -0.980439
# 3  C_ID_d27d835a9f -0.145743
# 4  C_ID_2b5e3df5c2 -1.241569

# %%
p3.to_csv('blend_kfol_st.csv',index=False)

# %%
message = 'using blend kfold + stratified, purchase amount trimmed'

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.016449
# 1  C_ID_130fd0cbdd -0.384725
# 2  C_ID_b709037bc5 -0.980439
# 3  C_ID_d27d835a9f -0.145743
# 4  C_ID_2b5e3df5c2 -1.241569

# %%
filename = f'submission-{submission_name}.csv'

# %%
filename
# Out:
# 'submission-2019-02-03 14:43:29.797523.csv'

# %%
# !kaggle competitions submit elo-merchant-category-recommendation -f '{filename}' -m '{message}'
# Out:
# 100%|#######################################| 4.24M/4.24M [00:07<00:00, 595kB/s]
# Successfully submitted to Elo Merchant Category Recommendation

# %%
train = train_df2.copy()
train['rounded_target'] = train['target'].round(0)
train = train.sort_values('rounded_target').reset_index(drop=True)
vc = train['rounded_target'].value_counts()
vc = dict(sorted(vc.items()))
df = pd.DataFrame()
train['indexcol'],i = 0,1
for k,v in vc.items():
    step = train.shape[0]/v
    indent = train.shape[0]/(v+1)
    df2 = train[train['rounded_target'] == k].sample(v, random_state=120).reset_index(drop=True)
    for j in range(0, v):
        df2.at[j, 'indexcol'] = indent + j*step + 0.000001*i
    df = pd.concat([df2,df])
    i+=1

# %%
train = df.sort_values('indexcol', ascending=True).reset_index(drop=True)

# %%
train.head().T
# Out:
#                                                       0                    1  \
# first_active_month                  2017-12-01 00:00:00  2016-12-01 00:00:00
# card_id                                 C_ID_176ecc65bd      C_ID_6082929d3a
# feature_1                                     0.0131446            0.0107116
# feature_2                                     0.0113848            0.0113848
# feature_3                                     0.0114275            0.0102828
# target                                        -0.279039            -0.926039
# first_active_monthYear                             2017                 2016
# first_active_monthMonth                              12                   12
# first_active_monthWeek                               48                   48
# first_active_monthDay                                 1                    1
# first_active_monthDayofweek                           4                    3
# first_active_monthDayofyear                         335                  336
# first_active_monthIs_month_end                    False                False
# first_active_monthIs_month_start                   True                 True
# first_active_monthIs_quarter_end                  False                False
# first_active_monthIs_quarter_start                False                False
# first_active_monthIs_year_end                     False                False
# first_active_monthIs_year_start                   False                False
# first_active_monthElapsed                    1512086400           1480550400
# transactions_count                                   10                   46
# city_id_nunique                                       5                   15
# merchant_category_id_nunique                          7                   20
# merchant_id_nunique                                  10                   46
# state_id_nunique                                      2                    8
# subsector_id_nunique                                  7                   13
# purchase_Year_nunique                                 1                    1
# purchase_Month_nunique                                2                    2
# purchase_Week_nunique                                 5                    9
# purchase_Day_nunique                                  7                   17
# purchase_amount_sum                           -0.450675             -22.5638
# ...                                                 ...                  ...
# purchase_amount_sum_sum                         7.36008             -390.031
# purchase_amount_sum_ptp                         23.4604              358.046
# purchase_amount_sum_max                         15.4103            -0.619333
# purchase_amount_max_mean                        9.49366              2.61874
# purchase_amount_max_sum                         18.9873              7.85621
# purchase_amount_max_ptp                         14.2301              8.07011
# purchase_amount_max_max                         16.6087              7.45078
# purchase_amount_mean_mean                      -0.04237            -0.593192
# purchase_amount_mean_sum                       -0.08474             -1.77958
# purchase_amount_mean_ptp                       0.490273            0.0499709
# purchase_amount_mean_max                       0.202767            -0.569362
# elapsed_time                                        426                  791
# card_id_total                                       114                  708
# card_id_count_total                                 114                  708
# purchase_amount_total                            6.9094             -412.594
# purchase_amount_total_mean                    0.0257024             -1.07969
# installments_total                                  124                  742
# hist_first_buy                                        4                   31
# new_first_buy                                        90                  465
# hist_last_buy                                        89                  454
# new_last_buy                                        132                  515
# purchase_amount_max_total                       3.01714             0.574974
# purchased_before_issue                            False                False
# outliers                                              0                    0
# days                                                 62                  427
# days_feature1                                       310                 1708
# days_feature2                                        62                  427
# days_feature3                                        62                    0
# rounded_target                                       -0                   -1
# indexcol                                              2                    5
#
#                                                       2                    3  \
# first_active_month                  2016-09-01 00:00:00  2017-11-01 00:00:00
# card_id                                 C_ID_a87bbd85a7      C_ID_92e4809531
# feature_1                                     0.0104794           0.00805849
# feature_2                                     0.0113848            0.0113848
# feature_3                                     0.0114275            0.0102828
# target                                         0.475326             0.516026
# first_active_monthYear                             2016                 2017
# first_active_monthMonth                               9                   11
# first_active_monthWeek                               35                   44
# first_active_monthDay                                 1                    1
# first_active_monthDayofweek                           3                    2
# first_active_monthDayofyear                         245                  305
# first_active_monthIs_month_end                    False                False
# first_active_monthIs_month_start                   True                 True
# first_active_monthIs_quarter_end                  False                False
# first_active_monthIs_quarter_start                False                False
# first_active_monthIs_year_end                     False                False
# first_active_monthIs_year_start                   False                False
# first_active_monthElapsed                    1472688000           1509494400
# transactions_count                                   22                    6
# city_id_nunique                                       3                    5
# merchant_category_id_nunique                         17                    4
# merchant_id_nunique                                  22                    6
# state_id_nunique                                      1                    3
# subsector_id_nunique                                 11                    4
# purchase_Year_nunique                                 1                    1
# purchase_Month_nunique                                2                    2
# purchase_Week_nunique                                 5                    5
# purchase_Day_nunique                                 13                    6
# purchase_amount_sum                            -15.5147              -3.1597
# ...                                                 ...                  ...
# purchase_amount_sum_sum                         -322.03             -14.6139
# purchase_amount_sum_ptp                          284.74              12.2301
# purchase_amount_sum_max                        -18.6449              -1.1919
# purchase_amount_max_mean                      -0.588055              1.90307
# purchase_amount_max_sum                        -1.17611              3.80614
# purchase_amount_max_ptp                        0.129754              1.82123
# purchase_amount_max_max                       -0.523178              2.81368
# purchase_amount_mean_mean                     -0.712977            -0.280704
# purchase_amount_mean_sum                       -1.42595            -0.561408
# purchase_amount_mean_ptp                     0.00826695             0.164107
# purchase_amount_mean_max                      -0.708844             -0.19865
# elapsed_time                                        882                  456
# card_id_total                                       476                   49
# card_id_count_total                                 476                   49
# purchase_amount_total                          -337.545             -17.7736
# purchase_amount_total_mean                     -1.41453            -0.866476
# installments_total                                    0                   74
# hist_first_buy                                      125                    6
# new_first_buy                                       551                  121
# hist_last_buy                                       540                  117
# new_last_buy                                        598                  172
# purchase_amount_max_total                      -1.31004            -0.932425
# purchased_before_issue                            False                False
# outliers                                              0                    0
# days                                                518                   92
# days_feature1                                      1554                   92
# days_feature2                                       518                   92
# days_feature3                                       518                    0
# rounded_target                                        0                    1
# indexcol                                              5                    5
#
#                                                       4
# first_active_month                  2017-11-01 00:00:00
# card_id                                 C_ID_d2dd6bbf9a
# feature_1                                     0.0107116
# feature_2                                     0.0113848
# feature_3                                     0.0102828
# target                                        -0.100927
# first_active_monthYear                             2017
# first_active_monthMonth                              11
# first_active_monthWeek                               44
# first_active_monthDay                                 1
# first_active_monthDayofweek                           2
# first_active_monthDayofyear                         305
# first_active_monthIs_month_end                    False
# first_active_monthIs_month_start                   True
# first_active_monthIs_quarter_end                  False
# first_active_monthIs_quarter_start                False
# first_active_monthIs_year_end                     False
# first_active_monthIs_year_start                   False
# first_active_monthElapsed                    1509494400
# transactions_count                                   16
# city_id_nunique                                       6
# merchant_category_id_nunique                         13
# merchant_id_nunique                                  16
# state_id_nunique                                      3
# subsector_id_nunique                                  8
# purchase_Year_nunique                                 1
# purchase_Month_nunique                                2
# purchase_Week_nunique                                 6
# purchase_Day_nunique                                  9
# purchase_amount_sum                            -4.21238
# ...                                                 ...
# purchase_amount_sum_sum                        -14.7675
# purchase_amount_sum_ptp                         1.36254
# purchase_amount_sum_max                        -6.70246
# purchase_amount_max_mean                        3.17877
# purchase_amount_max_sum                         6.35754
# purchase_amount_max_ptp                         4.16685
# purchase_amount_max_max                         5.26219
# purchase_amount_mean_mean                     -0.284128
# purchase_amount_mean_sum                      -0.568255
# purchase_amount_mean_ptp                       0.269552
# purchase_amount_mean_max                      -0.149352
# elapsed_time                                        456
# card_id_total                                        86
# card_id_count_total                                  86
# purchase_amount_total                          -18.9798
# purchase_amount_total_mean                    -0.474238
# installments_total                                  180
# hist_first_buy                                      -62
# new_first_buy                                       140
# hist_last_buy                                       116
# new_last_buy                                        180
# purchase_amount_max_total                      0.144826
# purchased_before_issue                             True
# outliers                                              0
# days                                                 92
# days_feature1                                       368
# days_feature2                                        92
# days_feature3                                         0
# rounded_target                                       -0
# indexcol                                              8
#
# [170 rows x 5 columns]
