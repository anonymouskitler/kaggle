# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-imports-and-dfs" data-toc-modified-id="Load-imports-and-dfs-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load imports and dfs</a></span></li><li><span><a href="#Blend" data-toc-modified-id="Blend-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Blend</a></span></li></ul></div>

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 4
# %autosave 120
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 120 seconds

# %% [markdown]
# ### Load imports and dfs

# %%
from fastai.io import *
from fastai.structured import *
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from pandas_summary import DataFrameSummary
from IPython.display import display
from sklearn import metrics
import feather
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import mean_squared_error
import warnings
import gc

# %%
train_df2 = feather.read_dataframe('train_df_alpha')
test_df2 = feather.read_dataframe('test_df_alpha')

# %%
for df in [train_df2, test_df2]:
    for f in ['purchase_date_max','purchase_date_min','purchase_date_max_old',\
                     'purchase_date_min_old', 'observation_date_old']:
        df[f] = df[f].astype(np.int64) * 1e-9

# %%
cols_excluded = ['purchase_date_max', 'purchase_date_max_old', 'card_id', 'first_active_month',
                 'target','outliers','card_id_size', 'card_id_size_old', 
                 'purchase_date_min', 'purchase_date_min_old','first_active_monthYear',
                 'first_active_monthMonth',
                 'first_active_monthWeek',
                 'first_active_monthDay',
                 'first_active_monthDayofweek',
                 'first_active_monthDayofyear',
                 'first_active_monthIs_month_end',
                 'first_active_monthIs_month_start',
                 'first_active_monthIs_quarter_end',
                 'first_active_monthIs_quarter_start',
                 'first_active_monthIs_year_end',
                 'first_active_monthIs_year_start']

# %%
cols_included = ['feature_1','feature_2','feature_3','transactions_count','subsector_id_nunique','merchant_id_nunique','merchant_category_id_nunique','purchase_Month_mean','purchase_Month_min','purchase_Month_max','purchase_Week_nunique','purchase_Week_mean','purchase_Week_min','purchase_Week_max','purchase_Dayofweek_mean','purchase_Dayofweek_min','purchase_Dayofweek_max','purchase_Day_nunique','purchase_Day_mean','purchase_Day_min','purchase_Day_max','purchase_Hour_nunique','purchase_Hour_mean','purchase_Hour_min','purchase_Hour_max','purchase_amount_sum','purchase_amount_max','purchase_amount_min','purchase_amount_mean','purchase_amount_var','purchase_amount_skew','installments_sum','installments_max','installments_mean','installments_var','installments_skew','month_lag_max','month_lag_min','month_lag_mean','month_lag_var','month_lag_skew','month_diff_mean','month_diff_var','month_diff_skew','purchased_on_weekend_mean','category_1_mean','category_2_mean','category_3_mean','card_id_count','price_mean','price_max','price_min','price_var','Christmas_Day_2017_mean','Children_day_2017_mean','Black_Friday_2017_mean','Mothers_Day_2018_mean','duration_mean','duration_min','duration_max','duration_var','duration_skew','amount_month_ratio_mean','amount_month_ratio_min','amount_month_ratio_max','amount_month_ratio_var','amount_month_ratio_skew','category_2_mean_mean','category_3_mean_mean','purchase_date_diff','purchase_date_average','purchase_date_uptonow','purchase_date_uptomin','transactions_count_old','subsector_id_nunique_old','merchant_id_nunique_old','merchant_category_id_nunique_old','purchase_Month_nunique','purchase_Month_mean_old','purchase_Month_min_old','purchase_Month_max_old','purchase_Week_nunique_old','purchase_Week_mean_old','purchase_Week_min_old','purchase_Week_max_old','purchase_Dayofweek_mean_old','purchase_Day_nunique_old','purchase_Day_mean_old','purchase_Day_min_old','purchase_Hour_nunique_old','purchase_Hour_mean_old','purchase_Hour_min_old','purchase_Hour_max_old','purchase_amount_sum_old','purchase_amount_max_old','purchase_amount_min_old','purchase_amount_mean_old','purchase_amount_var_old','purchase_amount_skew_old','installments_sum_old','installments_max_old','installments_mean_old','installments_var_old','installments_skew_old','month_lag_max_old','month_lag_min_old','month_lag_mean_old','month_lag_var_old','month_lag_skew_old','month_diff_max','month_diff_min','month_diff_mean_old','month_diff_var_old','month_diff_skew_old','authorized_flag_mean','purchased_on_weekend_mean_old','category_1_mean_old','category_2_mean_old','category_3_mean_old','card_id_count_old','price_sum','price_mean_old','price_max_old','price_min_old','price_var_old','Christmas_Day_2017_mean_old','Mothers_Day_2017_mean','fathers_day_2017_mean','Children_day_2017_mean_old','Valentine_Day_2017_mean','Black_Friday_2017_mean_old','Mothers_Day_2018_mean_old','duration_mean_old','duration_min_old','duration_max_old','duration_var_old','duration_skew_old','amount_month_ratio_mean_old','amount_month_ratio_min_old','amount_month_ratio_max_old','amount_month_ratio_var_old','amount_month_ratio_skew_old','category_2_mean_mean_old','category_3_mean_mean_old','purchase_date_diff_old','purchase_date_average_old','purchase_date_uptonow_old','purchase_date_uptomin_old','quarter','observed_elapsed_time','days_feature1','days_feature2','days_feature3','days_feature1_ratio','days_feature2_ratio','days_feature3_ratio','feature_sum','feature_mean','feature_max','feature_min','feature_var','card_id_total','card_id_count_total','card_id_count_ratio','purchase_amount_total','purchase_amount_total_mean','purchase_amount_total_max','purchase_amount_total_min','purchase_amount_sum_ratio','hist_first_buy','new_first_buy','hist_last_buy','new_last_buy','month_diff_ratio','installments_total','installments_ratio','price_total','CLV','CLV_old','CLV_ratio']

# %%
df_train_columns = [c for c in cols_included if c not in cols_excluded]

# %%
df_train_columns = [c for c in train_df2.columns.values if c not in cols_excluded and c in test_df2.columns.values]

# %%
target = train_df2['target']

# %%
train_df2.shape, test_df2.shape
# Out:
# ((201917, 354), (123623, 352))

# %%
del train_df2['target']

# %%
len(df_train_columns)
# Out:
# 180

# %%
train_df2.columns.values
# Out:
# array(['first_active_month', 'card_id', 'feature_1', 'feature_2', 'feature_3', 'transactions_count',
#        'subsector_id_nunique', 'merchant_id_nunique', 'merchant_category_id_nunique', 'purchase_Month_mean',
#        'purchase_Month_min', 'purchase_Month_max', 'purchase_Week_nunique', 'purchase_Week_mean',
#        'purchase_Week_min', 'purchase_Week_max', 'purchase_Dayofweek_mean', 'purchase_Dayofweek_min',
#        'purchase_Dayofweek_max', 'purchase_Day_nunique', 'purchase_Day_mean', 'purchase_Day_min',
#        'purchase_Day_max', 'purchase_Hour_nunique', 'purchase_Hour_mean', 'purchase_Hour_min',
#        'purchase_Hour_max', 'purchase_amount_sum', 'purchase_amount_pct_75', 'purchase_amount_pct_25',
#        'purchase_amount_mean', 'purchase_amount_median', 'purchase_amount_max', 'purchase_amount_min',
#        'purchase_amount_var', 'purchase_amount_skew', 'installments_sum', 'installments_max',
#        'installments_mean', 'installments_var', 'installments_skew', 'purchase_date_max',
#        'purchase_date_min', 'month_lag_max', 'month_lag_min', 'month_lag_mean', 'month_lag_var',
#        'month_lag_skew', 'month_diff_mean', 'month_diff_var', 'month_diff_skew', 'purchased_on_weekend_mean',
#        'category_1_mean', 'category_2_mean', 'category_3_mean', 'card_id_size', 'card_id_count',
#        'price_mean', 'price_max', 'price_min', 'price_var', 'Christmas_Day_2017_mean',
#        'Children_day_2017_mean', 'Black_Friday_2017_mean', 'Mothers_Day_2018_mean', 'duration_mean',
#        'duration_min', 'duration_max', 'duration_var', 'duration_skew', 'amount_month_ratio_mean',
#        'amount_month_ratio_min', 'amount_month_ratio_max', 'amount_month_ratio_var',
#        'amount_month_ratio_skew', 'purchase_date_successive_diff_mean', 'category_2_mean_mean',
#        'category_3_mean_mean', 'purchase_date_diff', 'purchase_date_average', 'purchase_date_uptonow',
#        'purchase_date_uptomin', 'inverse_avg_transactions_per_day', 'days_since_last_transaction',
#        'repurchase_merchant_rate', 'merchant_category_repurchase', 'avg_spend_per_merchant',
#        'avg_trans_per_merchant', 'avg_spend_per_transaction', 'transactions_count_old',
#        'subsector_id_nunique_old', 'merchant_id_nunique_old', 'merchant_category_id_nunique_old',
#        'purchase_Month_nunique', 'purchase_Month_mean_old', 'purchase_Month_min_old',
#        'purchase_Month_max_old', 'purchase_Week_nunique_old', 'purchase_Week_mean_old',
#        'purchase_Week_min_old', 'purchase_Week_max_old', 'purchase_Dayofweek_mean_old',
#        'purchase_Day_nunique_old', 'purchase_Day_mean_old', 'purchase_Day_min_old',
#        'purchase_Hour_nunique_old', 'purchase_Hour_mean_old', 'purchase_Hour_min_old',
#        'purchase_Hour_max_old', 'purchase_amount_sum_old', 'purchase_amount_pct_75_old',
#        'purchase_amount_pct_25_old', 'purchase_amount_mean_old', 'purchase_amount_median_old',
#        'purchase_amount_max_old', 'purchase_amount_min_old', 'purchase_amount_var_old',
#        'purchase_amount_skew_old', 'installments_sum_old', 'installments_max_old', 'installments_mean_old',
#        'installments_var_old', 'installments_skew_old', 'purchase_date_max_old', 'purchase_date_min_old',
#        'month_lag_max_old', 'month_lag_min_old', 'month_lag_mean_old', 'month_lag_var_old',
#        'month_lag_skew_old', 'month_diff_max', 'month_diff_min', 'month_diff_mean_old', 'month_diff_var_old',
#        'month_diff_skew_old', 'authorized_flag_mean', 'purchased_on_weekend_mean_old', 'category_1_mean_old',
#        'category_2_mean_old', 'category_3_mean_old', 'card_id_size_old', 'card_id_count_old', 'price_sum',
#        'price_mean_old', 'price_max_old', 'price_min_old', 'price_var_old', 'Christmas_Day_2017_mean_old',
#        'Mothers_Day_2017_mean', 'fathers_day_2017_mean', 'Children_day_2017_mean_old',
#        'Valentine_Day_2017_mean', 'Black_Friday_2017_mean_old', 'Mothers_Day_2018_mean_old',
#        'duration_mean_old', 'duration_min_old', 'duration_max_old', 'duration_var_old', 'duration_skew_old',
#        'amount_month_ratio_mean_old', 'amount_month_ratio_min_old', 'amount_month_ratio_max_old',
#        'amount_month_ratio_var_old', 'amount_month_ratio_skew_old', 'purchase_date_successive_diff_mean_old',
#        'category_2_mean_mean_old', 'category_3_mean_mean_old', 'purchase_date_diff_old',
#        'purchase_date_average_old', 'purchase_date_uptonow_old', 'purchase_date_uptomin_old',
#        'inverse_avg_transactions_per_day_old', 'days_since_last_transaction_old',
#        'repurchase_merchant_rate_old', 'merchant_category_repurchase_old', 'avg_spend_per_merchant_old',
#        'avg_trans_per_merchant_old', 'avg_spend_per_transaction_old', 'purchase_amount_count_mean',
#        'purchase_amount_count_sum', 'purchase_amount_count_ptp', 'purchase_amount_count_max',
#        'purchase_amount_sum_mean', 'purchase_amount_sum_sum', 'purchase_amount_sum_ptp',
#        'purchase_amount_sum_max', 'purchase_amount_max_mean', 'purchase_amount_max_sum',
#        'purchase_amount_max_ptp', 'purchase_amount_max_max', 'purchase_amount_mean_mean',
#        'purchase_amount_mean_sum', 'purchase_amount_mean_ptp', 'purchase_amount_mean_max',
#        'category_1_0_purchase_amount_mean', 'category_1_1_purchase_amount_mean',
#        'category_1_0_purchase_amount_sum', 'category_1_1_purchase_amount_sum',
#        'category_2_1.0_purchase_amount_mean', 'category_2_2.0_purchase_amount_mean',
#        'category_2_3.0_purchase_amount_mean', 'category_2_4.0_purchase_amount_mean',
#        'category_2_5.0_purchase_amount_mean', 'category_2_1.0_purchase_amount_sum',
#        'category_2_2.0_purchase_amount_sum', 'category_2_3.0_purchase_amount_sum',
#        'category_2_4.0_purchase_amount_sum', 'category_2_5.0_purchase_amount_sum',
#        'category_3_0_purchase_amount_mean', 'category_3_1_purchase_amount_mean',
#        'category_3_2_purchase_amount_mean', 'category_3_0_purchase_amount_sum',
#        'category_3_1_purchase_amount_sum', 'category_3_2_purchase_amount_sum',
#        'authorized_flag_0_purchase_amount_mean', 'authorized_flag_1_purchase_amount_mean',
#        'authorized_flag_0_purchase_amount_sum', 'authorized_flag_1_purchase_amount_sum', 'quarter',
#        'elapsed_time', 'days_feature1', 'days_feature2', 'days_feature3', 'days_feature1_ratio',
#        'days_feature2_ratio', 'days_feature3_ratio', 'feature_sum', 'feature_mean', 'feature_max',
#        'feature_min', 'feature_var', 'card_id_total', 'card_id_count_total', 'card_id_count_ratio',
#        'purchase_amount_total', 'purchase_amount_total_mean', 'purchase_amount_total_max',
#        'purchase_amount_total_min', 'purchase_amount_sum_ratio', 'hist_first_buy', 'new_first_buy',
#        'hist_last_buy', 'new_last_buy', 'purchased_before_issue', 'month_diff_ratio', 'installments_total',
#        'installments_ratio', 'price_total', 'CLV', 'CLV_old', 'CLV_ratio', 'outliers'], dtype=object)

# %%
exp_cols = ['observed_elapsed_time']

# %%
df_train_columns = df_train_columns + exp_cols

# %%
len(df_train_columns)
# Out:
# 180

# %%
# df_train_columns

# %%
final_cols =['purchase_amount_max',
 'avg_trans_per_merchant_old',
 'duration_min_old',
 'purchase_date_uptonow',
 'category_1_mean',
 'authorized_flag_mean',
 'purchase_date_uptonow_old',
 'purchase_Week_mean',
 'purchase_amount_mean',
 'purchase_Month_nunique',
 'month_diff_mean_old',
 'category_1_mean_old',
 'duration_mean_old',
 'month_lag_mean_old',
 'purchase_date_average_old',
 'fathers_day_2017_mean',
 'purchase_Month_mean',
 'installments_sum_old',
 'month_lag_mean',
 'days_feature1',
 'purchase_Week_max',
 'hist_last_buy',
 'month_lag_skew',
 'purchase_Week_nunique_old',
 'Mothers_Day_2017_mean',
 'purchase_Dayofweek_mean_old',
 'merchant_category_id_nunique_old',
 'new_last_buy',
 'duration_max_old',
 'new_first_buy',
 'month_lag_max',
 'price_var',
 'installments_var_old',
 'price_min',
 'purchase_amount_sum_old',
 'merchant_id_nunique',
 'purchase_Hour_nunique',
 'purchase_Day_nunique']

# %%
# df_train_columns = final_cols

# %%
n_fold =5

# %%
len(df_train_columns)
# Out:
# 180

# %%
param = {
        'task': 'train',
        'boosting': 'goss',
        'objective': 'regression',
        'metric': 'rmse',
        'learning_rate': 0.01,
        'subsample': 0.9855232997390695,
        'max_depth': 7,
        'top_rate': 0.9064148448434349,
        'num_leaves': 123,
        'min_child_weight': 41.9612869171337,
        'other_rate': 0.0721768246018207,
        'reg_alpha': 9.677537745007898,
        'colsample_bytree': 0.5665320670155495,
        'min_split_gain': 9.820197773625843,
        'reg_lambda': 8.2532317400459,
        'min_data_in_leaf': 21,
        'verbose': -1,
        'seed':int(2**n_fold),
        'bagging_seed':int(2**n_fold),
        'drop_seed':int(2**n_fold)
        }
folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=4590)
oof = np.zeros(len(train_df2))
predictions = np.zeros(len(test_df2))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_df2,train_df2['outliers'].values)):
    print("fold {}".format(fold_))
    trn_data = lgb.Dataset(train_df2.iloc[trn_idx][df_train_columns], label=target.iloc[trn_idx])
    val_data = lgb.Dataset(train_df2.iloc[val_idx][df_train_columns], label=target.iloc[val_idx])

    num_round = 10000
    clf = lgb.train(param, trn_data, num_round, valid_sets = [trn_data, val_data], verbose_eval=100, early_stopping_rounds = 200)
    oof[val_idx] = clf.predict(train_df2.iloc[val_idx][df_train_columns], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = df_train_columns
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test_df2[df_train_columns], num_iteration=clf.best_iteration) / folds.n_splits

np.sqrt(mean_squared_error(oof, target))
# Out:
# fold 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.63985	valid_1's rmse: 3.70698
# [200]	training's rmse: 3.55248	valid_1's rmse: 3.66841
# [300]	training's rmse: 3.49739	valid_1's rmse: 3.65687
# [400]	training's rmse: 3.46129	valid_1's rmse: 3.65235
# [500]	training's rmse: 3.43423	valid_1's rmse: 3.64995
# [600]	training's rmse: 3.41124	valid_1's rmse: 3.64911
# [700]	training's rmse: 3.39093	valid_1's rmse: 3.64896
# [800]	training's rmse: 3.37138	valid_1's rmse: 3.64894
# [900]	training's rmse: 3.35388	valid_1's rmse: 3.649
# [1000]	training's rmse: 3.33773	valid_1's rmse: 3.6491
# Early stopping, best iteration is:
# [844]	training's rmse: 3.3633	valid_1's rmse: 3.64868
# fold 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.64115	valid_1's rmse: 3.69605
# [200]	training's rmse: 3.55215	valid_1's rmse: 3.66095
# [300]	training's rmse: 3.50055	valid_1's rmse: 3.64983
# [400]	training's rmse: 3.46496	valid_1's rmse: 3.64609
# [500]	training's rmse: 3.43674	valid_1's rmse: 3.64487
# [600]	training's rmse: 3.41479	valid_1's rmse: 3.64448
# [700]	training's rmse: 3.39466	valid_1's rmse: 3.64347
# [800]	training's rmse: 3.37502	valid_1's rmse: 3.64274
# [900]	training's rmse: 3.35817	valid_1's rmse: 3.64313
# Early stopping, best iteration is:
# [797]	training's rmse: 3.37569	valid_1's rmse: 3.64273
# fold 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.63837	valid_1's rmse: 3.70715
# [200]	training's rmse: 3.54942	valid_1's rmse: 3.67222
# [300]	training's rmse: 3.49912	valid_1's rmse: 3.66175
# [400]	training's rmse: 3.46244	valid_1's rmse: 3.65763
# [500]	training's rmse: 3.43324	valid_1's rmse: 3.655
# [600]	training's rmse: 3.41234	valid_1's rmse: 3.65387
# [700]	training's rmse: 3.3927	valid_1's rmse: 3.65358
# [800]	training's rmse: 3.37339	valid_1's rmse: 3.65327
# [900]	training's rmse: 3.35595	valid_1's rmse: 3.65256
# [1000]	training's rmse: 3.33901	valid_1's rmse: 3.65221
# [1100]	training's rmse: 3.32235	valid_1's rmse: 3.65196
# [1200]	training's rmse: 3.30614	valid_1's rmse: 3.6519
# Early stopping, best iteration is:
# [1081]	training's rmse: 3.32545	valid_1's rmse: 3.65176
# fold 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.63896	valid_1's rmse: 3.7008
# [200]	training's rmse: 3.54878	valid_1's rmse: 3.66747
# [300]	training's rmse: 3.49605	valid_1's rmse: 3.65849
# [400]	training's rmse: 3.45834	valid_1's rmse: 3.65448
# [500]	training's rmse: 3.44013	valid_1's rmse: 3.66314
# [600]	training's rmse: 3.40198	valid_1's rmse: 3.65283
# [700]	training's rmse: 3.37646	valid_1's rmse: 3.65096
# [800]	training's rmse: 3.35789	valid_1's rmse: 3.65091
# [900]	training's rmse: 3.3439	valid_1's rmse: 3.65055
# [1000]	training's rmse: 3.32713	valid_1's rmse: 3.65053
# [1100]	training's rmse: 3.31242	valid_1's rmse: 3.65026
# [1200]	training's rmse: 3.29681	valid_1's rmse: 3.64975
# [1300]	training's rmse: 3.28075	valid_1's rmse: 3.64971
# [1400]	training's rmse: 3.26511	valid_1's rmse: 3.65006
# Early stopping, best iteration is:
# [1278]	training's rmse: 3.28393	valid_1's rmse: 3.64959
# fold 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.6393	valid_1's rmse: 3.69143
# [200]	training's rmse: 3.549	valid_1's rmse: 3.66153
# [300]	training's rmse: 3.49311	valid_1's rmse: 3.65355
# [400]	training's rmse: 3.45685	valid_1's rmse: 3.65187
# [500]	training's rmse: 3.4294	valid_1's rmse: 3.65038
# [600]	training's rmse: 3.40792	valid_1's rmse: 3.64947
# [700]	training's rmse: 3.38889	valid_1's rmse: 3.64957
# [800]	training's rmse: 3.37184	valid_1's rmse: 3.65001
# Early stopping, best iteration is:
# [670]	training's rmse: 3.39445	valid_1's rmse: 3.64933
# 3.648418646163904

# %% [markdown]
# 1. Base feats - f1,f2,f3 - 3.8421399267932315
# 2. 3.6552368169417204, 3.692
# 3. 3.654460362787254, 3.692
# 4. 3.6538177315106624, 3.691
# 5. 3.6552638224814196- after trimming purchase_amount
# 6. 3.6544381493750677 - base_cols 180
# 7. 3.653984525732515 - added purchase_amount_pct_25_old
# 8. 3.653161955069063 - base_cols - 180 - 16th feb - 181 has first_active_monthElapsed score 3.653410894233743
# 9. 3.6535590767314026 - added 'avg_trans_per_merchant_old','purchase_amount_sum_mean', 'category_2_5.0_purchase_amount_mean'
# 10. 3.6573988258459713 - with 38 cols
# 11. 3.655024925251293 - with 241 cols
# 12. 3.6527864665829197 - with 283 cols - added missed out agg in train, test & added observed date, lb - 3.816
# 13. 3.6535891905746243 - with 181 cols - base + observed_elapsed time, **3.691** better than 3.693 of 180 base cols
# 14. 3.653084106006047 - 414 cols
# 15. 3.648418646163904 - rescaled purchase_amount

# %%
cols = (feature_importance_df[["Feature", "importance"]]
        .groupby("Feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.Feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="Feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')
# Out:
# /home/chandrasekhar/anaconda3/envs/fastai/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
len(best_features.sort_values(by='importance', ascending=False)[:800]['Feature'].unique())
# Out:
# 169

# %%
best_ft_df = best_features.groupby('Feature').agg({'importance': ['mean']})

# %%
best_ft_df.columns = ['_'.join(c).strip() for c in best_ft_df.columns.values]

# %%
best_ft_df = best_ft_df.reset_index().sort_values('importance_mean', ascending=False)

# %%
fts_sorted_by_imp = best_ft_df.sort_values('importance_mean', ascending=False)['Feature'].values

# %%
pd.set_option('display.max_rows', 500)

# %%
best_ft_df.reset_index()
# Out:
#      index                           Feature  importance_mean
# 0      158         purchase_amount_sum_ratio           1949.8
# 1      171             purchase_date_uptonow           1405.8
# 2       84               month_diff_mean_old           1372.8
# 3      172         purchase_date_uptonow_old           1363.6
# 4       23              authorized_flag_mean           1330.6
# 5       30               category_1_mean_old           1212.2
# 6       94                month_lag_mean_old           1092.8
# 7      139            purchase_Month_nunique           1063.2
# 8        2                               CLV           1055.8
# 9      168            purchase_date_diff_old           1002.6
# 10     142                purchase_Week_mean            956.8
# 11      55             fathers_day_2017_mean            906.2
# 12     115                 purchase_Day_mean            838.4
# 13     147         purchase_Week_nunique_old            814.8
# 14      93                    month_lag_mean            804.4
# 15     167                purchase_date_diff            757.4
# 16      12           Valentine_Day_2017_mean            749.2
# 17       6        Children_day_2017_mean_old            739.8
# 18      29                   category_1_mean            737.8
# 19       4                         CLV_ratio            728.0
# 20     100                 month_lag_var_old            724.4
# 21     135               purchase_Month_mean            720.6
# 22      81           merchant_id_nunique_old            719.6
# 23      74              installments_sum_old            694.4
# 24      64                    hist_first_buy            685.4
# 25      98                month_lag_skew_old            680.8
# 26     156               purchase_amount_sum            670.2
# 27      65                     hist_last_buy            670.0
# 28     140                 purchase_Week_max            669.8
# 29     128            purchase_Hour_mean_old            666.6
# 30     113                     price_var_old            643.8
# 31     170         purchase_date_uptomin_old            643.4
# 32       9             Mothers_Day_2017_mean            637.0
# 33     127                purchase_Hour_mean            628.4
# 34     169             purchase_date_uptomin            624.4
# 35     166         purchase_date_average_old            616.6
# 36     116             purchase_Day_mean_old            614.8
# 37     123       purchase_Dayofweek_mean_old            607.6
# 38      88               month_diff_skew_old            568.2
# 39      10             Mothers_Day_2018_mean            563.0
# 40     165             purchase_date_average            558.8
# 41       7           Christmas_Day_2017_mean            542.0
# 42      79  merchant_category_id_nunique_old            521.8
# 43      41                     days_feature2            518.6
# 44      50                  duration_min_old            505.6
# 45     144                 purchase_Week_min            504.0
# 46     174     purchased_on_weekend_mean_old            496.6
# 47      26               card_id_count_ratio            495.8
# 48      18        amount_month_ratio_min_old            494.4
# 49     179            transactions_count_old            493.2
# 50      77              installments_var_old            492.8
# 51      39                     days_feature1            489.4
# 52      53                      duration_var            486.8
# 53      69             installments_mean_old            483.6
# 54       1        Black_Friday_2017_mean_old            472.6
# 55       0            Black_Friday_2017_mean            470.4
# 56     114                  purchase_Day_max            466.0
# 57      13            amount_month_ratio_max            457.8
# 58      37          category_3_mean_mean_old            452.4
# 59     157           purchase_amount_sum_old            449.0
# 60      28                     card_id_total            448.4
# 61      45                      duration_max            440.4
# 62     148               purchase_amount_max            438.4
# 63      52                 duration_skew_old            429.4
# 64       3                           CLV_old            424.4
# 65      70                installments_ratio            424.2
# 66      48                 duration_mean_old            414.2
# 67      40               days_feature1_ratio            414.0
# 68      38               category_3_mean_old            411.6
# 69      16       amount_month_ratio_mean_old            399.0
# 70      42               days_feature2_ratio            394.6
# 71     136           purchase_Month_mean_old            392.6
# 72     155          purchase_amount_skew_old            390.4
# 73      43                     days_feature3            390.0
# 74      75                installments_total            377.4
# 75      20       amount_month_ratio_skew_old            376.4
# 76     153           purchase_amount_min_old            375.8
# 77     163               purchase_amount_var            375.2
# 78       8       Christmas_Day_2017_mean_old            374.0
# 79      86                  month_diff_ratio            372.2
# 80     111                       price_total            369.6
# 81      72             installments_skew_old            369.4
# 82      21            amount_month_ratio_var            362.0
# 83     108                         price_min            361.8
# 84     106                        price_mean            359.6
# 85     101                     new_first_buy            359.2
# 86     117                  purchase_Day_min            358.8
# 87      82                    month_diff_max            355.0
# 88      47                     duration_mean            350.8
# 89      83                   month_diff_mean            348.2
# 90     162         purchase_amount_total_min            348.0
# 91     145             purchase_Week_min_old            344.6
# 92     177          subsector_id_nunique_old            343.4
# 93     143            purchase_Week_mean_old            337.4
# 94     109                     price_min_old            333.0
# 95       5            Children_day_2017_mean            332.2
# 96     104                         price_max            329.0
# 97     107                    price_mean_old            328.8
# 98     151          purchase_amount_mean_old            328.0
# 99     129                 purchase_Hour_min            324.8
# 100     34               category_2_mean_old            321.6
# 101     49                      duration_min            320.8
# 102     15           amount_month_ratio_mean            319.4
# 103     33          category_2_mean_mean_old            316.8
# 104    102                      new_last_buy            309.6
# 105     99                     month_lag_var            302.4
# 106     90                month_diff_var_old            301.0
# 107     68                 installments_mean            300.2
# 108    141             purchase_Week_max_old            295.0
# 109    105                     price_max_old            292.4
# 110    122           purchase_Dayofweek_mean            291.4
# 111     54                  duration_var_old            286.8
# 112     11         Mothers_Day_2018_mean_old            283.2
# 113     46                  duration_max_old            281.2
# 114     17            amount_month_ratio_min            279.6
# 115     22        amount_month_ratio_var_old            275.6
# 116    132         purchase_Hour_nunique_old            271.0
# 117    150              purchase_amount_mean            270.6
# 118    112                         price_var            265.2
# 119    110                         price_sum            264.2
# 120    152               purchase_amount_min            261.2
# 121     14        amount_month_ratio_max_old            260.2
# 122    159             purchase_amount_total            259.6
# 123     56                         feature_1            259.0
# 124     97                    month_lag_skew            255.8
# 125    120          purchase_Day_nunique_old            254.8
# 126     36              category_3_mean_mean            251.8
# 127    149           purchase_amount_max_old            244.6
# 128     44               days_feature3_ratio            241.6
# 129    164           purchase_amount_var_old            240.8
# 130    161        purchase_amount_total_mean            233.4
# 131    103             observed_elapsed_time            225.0
# 132    133                purchase_Month_max            223.8
# 133     25                 card_id_count_old            223.0
# 134    160         purchase_amount_total_max            213.8
# 135     19           amount_month_ratio_skew            207.6
# 136     76                  installments_var            207.0
# 137    154              purchase_amount_skew            205.6
# 138     51                     duration_skew            198.8
# 139     85                    month_diff_min            195.2
# 140     27               card_id_count_total            175.8
# 141     96                 month_lag_min_old            169.8
# 142     89                    month_diff_var            169.4
# 143    130             purchase_Hour_min_old            153.0
# 144     63                       feature_var            150.4
# 145     92                 month_lag_max_old            135.4
# 146     32              category_2_mean_mean            134.4
# 147     71                 installments_skew            129.6
# 148    125                 purchase_Hour_max            119.4
# 149     35                   category_3_mean            117.4
# 150     78      merchant_category_id_nunique            114.8
# 151     91                     month_lag_max            113.8
# 152     67              installments_max_old            112.8
# 153     87                   month_diff_skew            106.8
# 154     73                  installments_sum            106.0
# 155    173         purchased_on_weekend_mean            103.0
# 156    118              purchase_Day_min_old            101.0
# 157    137                purchase_Month_min             98.0
# 158     62                       feature_sum             94.6
# 159     66                  installments_max             91.8
# 160    124            purchase_Dayofweek_min             90.0
# 161     31                   category_2_mean             88.2
# 162    138            purchase_Month_min_old             83.8
# 163     57                         feature_2             83.6
# 164    178                transactions_count             77.8
# 165    146             purchase_Week_nunique             74.2
# 166    176              subsector_id_nunique             68.8
# 167     80               merchant_id_nunique             67.6
# 168    175                           quarter             67.4
# 169    134            purchase_Month_max_old             61.0
# 170    126             purchase_Hour_max_old             49.2
# 171     60                      feature_mean             47.2
# 172     59                       feature_max             47.0
# 173     95                     month_lag_min             44.8
# 174    131             purchase_Hour_nunique             42.0
# 175    121            purchase_Dayofweek_max             37.4
# 176    119              purchase_Day_nunique             34.8
# 177     24                     card_id_count             23.8
# 178     58                         feature_3              5.4
# 179     61                       feature_min              1.8

# %%
fts_sorted_by_imp
# Out:
# array(['purchase_amount_new_sum_ratio', 'purchase_date_uptonow', 'purchase_Month_nunique',
#        'repurchase_merchant_rate_old', 'duration_min_old', 'authorized_flag_mean', 'month_diff_mean_old',
#        'purchase_date_uptonow_old', 'purchase_Week_mean', 'category_1_1_purchase_amount_sum',
#        'authorized_flag_0_purchase_amount_sum', 'purchase_date_diff', 'purchase_date_diff_old',
#        'month_lag_mean_old', 'purchase_Day_mean', 'category_1_1_purchase_amount_sum_old',
#        'purchase_Month_mean', 'purchase_amount_new_sum_old', 'month_lag_var_old', 'days_feature2',
#        'purchase_amount_new_mean_ratio', 'purchase_date_uptomin', 'fathers_day_2017_mean',
#        'days_since_last_transaction', 'days_since_last_transaction_old', 'amount_month_ratio_min_old',
#        'month_lag_mean', 'purchase_Week_max', 'category_1_mean', 'authorized_flag_0_purchase_amount_mean',
#        'category_3_1_purchase_amount_sum', 'duration_min', 'month_lag_skew', 'month_lag_max',
#        'Mothers_Day_2018_mean', 'category_1_mean_old', 'purchase_amount_new_before_after_ratio',
#        'days_feature1', 'Children_day_2017_mean_old', 'category_1_1_purchase_amount_mean',
#        'purchase_date_uptomin_old', 'Valentine_Day_2017_mean', 'purchase_Week_nunique_old',
#        'month_diff_mean', 'avg_trans_per_merchant_old', 'installments_sum_old', 'hist_last_buy',
#        'category_3_1_purchase_amount_mean', 'purchase_date_successive_diff_mean',
#        'purchase_amount_new_first_last_diff', 'purchase_Hour_mean_old', 'purchase_Week_min',
#        'Mothers_Day_2017_mean', 'days_feature3', 'month_lag_skew_old', 'category_3_2_purchase_amount_sum',
#        'category_3_2_purchase_amount_mean', 'hist_first_buy', 'duration_mean_old', 'month_diff_ratio',
#        'Christmas_Day_2017_mean', 'purchase_amount_new_pct_75_ratio', 'purchase_Dayofweek_mean_old',
#        'card_id_count_ratio', 'days_feature1_ratio', 'purchase_Hour_mean',
#        'category_2_1.0_purchase_amount_sum', 'price_skew', 'purchase_date_average', 'month_diff_skew_old',
#        'merchant_category_repurchase_old', 'month_lag_var', 'category_3_0_purchase_amount_sum_old',
#        'days_feature2_ratio', 'category_3_0_purchase_amount_mean_old', 'Black_Friday_2017_mean',
#        'purchase_Day_mean_old', 'duration_var', 'category_2_1.0_purchase_amount_sum_ratio',
#        'purchase_Day_min', 'purchase_amount_new_median_ratio', 'purchase_date_successive_diff_mean_old',
#        'purchase_date_average_old', 'purchase_Day_max', 'avg_spend_per_merchant_old',
#        'Black_Friday_2017_mean_old', 'purchased_on_weekend_mean_old', 'category_2_1.0_purchase_amount_mean',
#        'new_first_buy', 'category_3_0_purchase_amount_mean', 'category_2_1.0_purchase_amount_mean_old',
#        'merchant_id_nunique_old', 'observed_elapsed_time', 'purchase_amount_new_fi_last_old_total',
#        'installments_ratio', 'month_diff_var_old', 'category_3_1_purchase_amount_sum_ratio',
#        'amount_month_ratio_min', 'new_last_buy', 'price_var_old', 'category_1_1_purchase_amount_sum_ratio',
#        'category_1_0_purchase_amount_sum_ratio', 'category_1_0_purchase_amount_mean_ratio',
#        'purchase_amount_skew_old', 'category_1_1_purchase_amount_mean_old', 'purchase_Week_mean_old',
#        'category_1_1_purchase_amount_mean_ratio', 'purchase_Month_mean_old',
#        'purchase_amount_new_gmean_ratio', 'price_max', 'merchant_category_id_nunique_old',
#        'amount_month_ratio_var', 'purchase_amount_new_inter_quartile_ratio', 'price_var',
#        'purchase_amount_new_sum', 'duration_skew_old', 'category_1_1_purchase_amount_sum_total',
#        'category_2_1.0_purchase_amount_mean_ratio', 'Children_day_2017_mean', 'Christmas_Day_2017_mean_old',
#        'category_3_0_purchase_amount_mean_ratio', 'category_3_1_purchase_amount_mean_old',
#        'purchase_Week_min_old', 'category_3_0_purchase_amount_sum', 'purchase_amount_fi_last_new_total',
#        'month_diff_max', 'category_2_1.0_purchase_amount_sum_old', 'duration_mean',
#        'purchase_amount_first_last_diff', 'purchase_amount_new_hmean', 'installments_var_old',
#        'purchase_amount_sum_ptp', 'purchase_amount_new_hmean_ratio',
#        'category_3_1_purchase_amount_mean_total', 'month_lag_min', 'installments_total',
#        'purchase_amount_max', 'purchase_Hour_min', 'category_1_0_purchase_amount_sum_old',
#        'purchase_amount_new_pct_25_ratio', 'category_3_0_purchase_amount_sum_ratio',
#        'category_1_0_purchase_amount_sum', 'purchase_amount_pct_75_ratio', 'feature_1',
#        'purchase_amount_min_old', 'purchase_amount_sum_max', 'amount_month_ratio_skew_old',
#        'purchase_amount_new_head_sum_old', 'purchase_Week_max_old', 'purchase_amount_count_ptp',
#        'purchase_amount_var', 'category_1_1_purchase_amount_mean_total', 'installments_skew_old',
#        'Mothers_Day_2018_mean_old', 'purchase_amount_mean_ptp', 'category_2_1.0_purchase_amount_sum_total',
#        'category_1_0_purchase_amount_sum_total', 'purchase_amount_head_max_old',
#        'category_1_0_purchase_amount_mean_old', 'category_3_1_purchase_amount_sum_old', 'duration_skew',
#        'purchase_amount_before_after_ratio', 'installments_pct_75_old',
#        'category_2_1.0_purchase_amount_mean_total', 'month_diff_skew', 'price_min',
#        'purchase_amount_max_mean_old', 'category_3_mean_old', 'CLV_ratio', 'category_3_mean_mean_old',
#        'purchase_Dayofweek_mean', 'installments_mean_old', 'purchase_amount_max_ptp', 'category_2_mean_old',
#        'category_3_0_purchase_amount_mean_total', 'installments_mean', 'purchase_amount_tail_sum_old',
#        'subsector_id_nunique_old', 'category_3_1_purchase_amount_sum_total', 'purchase_amount_tail_max_old',
#        'purchase_Month_max', 'purchase_amount_skew', 'purchase_amount_head_sum_old',
#        'purchase_amount_pct_25_old', 'purchase_amount_new_skew_ratio', 'price_sum',
#        'purchase_amount_skew_ratio', 'purchase_amount_inter_quartile_ratio', 'purchase_amount_max_sum_old',
#        'inverse_avg_transactions_per_day', 'days_feature3_ratio', 'purchase_amount_sum_max_old',
#        'category_1_0_purchase_amount_mean_total', 'category_2_5.0_purchase_amount_sum_old', 'CLV',
#        'installments_var', 'category_2_5.0_purchase_amount_sum', 'purchase_amount_median_ratio',
#        'category_1_0_purchase_amount_mean', 'category_3_0_purchase_amount_sum_total',
#        'category_2_mean_mean_old', 'purchase_amount_new_fi_last_new_total', 'purchase_amount_max_ptp_old',
#        'purchase_amount_median_old', 'authorized_flag_1_purchase_amount_mean', 'purchase_amount_new_skew',
#        'category_3_1_purchase_amount_mean_ratio', 'purchase_amount_sum_ratio', 'purchase_amount_count_max',
#        'installments_head_sum_old', 'inverse_avg_transactions_per_day_old', 'price_mean_old',
#        'amount_month_ratio_mean_old', 'installments_tail_sum_old', 'purchase_amount_mean_ratio',
#        'purchase_amount_new_head_sum', 'category_3_mean_mean', 'category_3_2_purchase_amount_mean_old',
#        'purchase_amount_mean_sum_old', 'month_lag_min_old', 'purchase_amount_new_tail_sum_old',
#        'category_3_2_purchase_amount_sum_old', 'purchase_amount_sum_ptp_old',
#        'category_3_2_purchase_amount_mean_total', 'purchase_Hour_nunique_old', 'month_diff_var',
#        'purchase_amount_new_var_old', 'authorized_flag_1_purchase_amount_sum', 'purchase_amount_new_max_old',
#        'purchase_amount_sum_mean_old', 'purchase_amount_min', 'purchase_amount_new_sum_total',
#        'purchase_amount_new_tail_max', 'purchase_amount_new_hmean_old', 'purchase_amount_mean_max_old',
#        'purchase_amount_new_inter_quartile_old', 'purchase_amount_new_tail_sum',
#        'purchase_amount_new_inter_quartile', 'category_2_5.0_purchase_amount_mean',
#        'purchase_amount_mean_ptp_old', 'category_3_2_purchase_amount_sum_ratio', 'price_mean',
#        'duration_max_old', 'amount_month_ratio_skew', 'purchase_amount_pct_25_ratio',
#        'purchase_amount_max_max_old', 'category_2_2.0_purchase_amount_mean', 'month_diff_min',
#        'category_2_3.0_purchase_amount_mean_old', 'purchase_Day_nunique_old',
#        'category_2_5.0_purchase_amount_mean_old', 'category_3_2_purchase_amount_mean_ratio', 'price_max_old',
#        'card_id_total', 'purchase_amount_total_min', 'price_min_old', 'purchase_Hour_min_old',
#        'installments_pct_75', 'purchase_amount_new_gmean', 'category_2_3.0_purchase_amount_mean',
#        'merchant_category_id_nunique', 'month_lag_max_old', 'CLV_old', 'purchase_amount_count_mean',
#        'purchase_amount_max_sum', 'purchase_amount_new_hmean_total', 'purchase_amount_tail_max',
#        'purchase_amount_head_max', 'purchase_amount_pct_25', 'purchase_amount_new_head_max',
#        'purchase_Month_min', 'category_2_3.0_purchase_amount_sum', 'category_2_4.0_purchase_amount_sum',
#        'purchase_amount_count_mean_old', 'feature_var', 'installments_max', 'purchase_amount_new_min',
#        'purchase_amount_total_max', 'purchase_amount_new_pct_25', 'category_3_2_purchase_amount_sum_total',
#        'transactions_count_old', 'amount_month_ratio_var_old', 'duration_max', 'amount_month_ratio_max_old',
#        'feature_sum', 'category_2_4.0_purchase_amount_mean', 'purchase_amount_median',
#        'amount_month_ratio_mean', 'purchase_amount_max_mean', 'purchase_amount_new_skew_old',
#        'purchase_amount_new_gmean_total', 'purchase_amount_pct_75_old', 'purchase_amount_tail_sum',
#        'duration_var_old', 'price_total', 'purchase_amount_mean_mean', 'purchase_amount_head_sum',
#        'category_2_3.0_purchase_amount_sum_ratio', 'purchase_amount_sum_mean', 'purchase_amount_max_old',
#        'purchase_amount_inter_quartile_old', 'amount_month_ratio_max', 'purchase_amount_new_median',
#        'purchase_amount_inter_quartile', 'purchase_amount_mean_sum', 'purchase_amount_mean_max',
#        'purchase_amount_fi_last_old_total', 'installments_median', 'purchase_amount_var_old',
#        'purchase_amount_sum', 'purchase_amount_count_max_old', 'purchase_Week_nunique',
#        'purchase_amount_pct_75', 'purchase_Hour_max', 'installments_tail_sum',
#        'category_2_2.0_purchase_amount_sum', 'installments_skew', 'category_2_5.0_purchase_amount_sum_total',
#        'purchase_amount_new_min_total', 'purchase_amount_sum_old',
#        'category_2_3.0_purchase_amount_mean_ratio', 'purchase_amount_new_tail_max_old', 'feature_2',
#        'card_id_count_old', 'purchased_on_weekend_mean', 'observation_date_old',
#        'purchase_amount_new_min_old', 'purchase_Dayofweek_min', 'category_2_5.0_purchase_amount_sum_ratio',
#        'purchase_amount_new_pct_25_old', 'purchase_amount_new_gmean_old', 'purchase_Month_min_old',
#        'purchase_amount_mean_mean_old', 'avg_spend_per_transaction', 'transactions_count', 'quarter',
#        'category_2_mean_mean', 'category_2_3.0_purchase_amount_mean_total', 'purchase_amount_total',
#        'category_2_3.0_purchase_amount_sum_total', 'category_2_5.0_purchase_amount_mean_ratio',
#        'category_2_5.0_purchase_amount_mean_total', 'purchase_amount_mean',
#        'purchase_amount_new_head_max_old', 'installments_sum', 'subsector_id_nunique', 'card_id_count_total',
#        'category_2_2.0_purchase_amount_mean_old', 'purchase_amount_new_pct_75', 'installments_tail_max',
#        'purchase_amount_new_max_total', 'purchase_amount_mean_old', 'installments_max_old',
#        'installments_pct_25', 'purchase_amount_total_mean', 'purchase_Day_nunique',
#        'installments_tail_max_old', 'category_2_4.0_purchase_amount_mean_old', 'purchase_Month_max_old',
#        'avg_spend_per_merchant', 'category_2_4.0_purchase_amount_sum_ratio', 'purchase_amount_min_total',
#        'category_2_4.0_purchase_amount_sum_old', 'purchase_amount_new_pct_75_old',
#        'purchase_amount_new_median_old', 'category_2_mean', 'feature_mean',
#        'category_2_3.0_purchase_amount_sum_old', 'merchant_id_nunique',
#        'category_2_4.0_purchase_amount_mean_total', 'purchase_Day_min_old',
#        'category_2_4.0_purchase_amount_mean_ratio', 'installments_pct_25_old', 'category_3_mean',
#        'purchase_amount_sum_sum', 'installments_head_max', 'category_2_2.0_purchase_amount_sum_old',
#        'purchase_amount_sum_sum_old', 'purchase_amount_new_mean_old', 'purchase_Hour_max_old',
#        'installments_head_max_old', 'purchase_amount_new_mean_total', 'purchase_amount_sum_total',
#        'installments_head_sum', 'purchase_Hour_nunique', 'purchase_amount_count_sum',
#        'category_2_2.0_purchase_amount_mean_total', 'installments_min', 'feature_max',
#        'merchant_category_repurchase', 'purchase_amount_max_max', 'category_2_4.0_purchase_amount_sum_total',
#        'category_2_2.0_purchase_amount_sum_ratio', 'purchase_amount_new_var',
#        'purchase_amount_count_ptp_old', 'purchase_amount_max_total', 'purchase_amount_new_max',
#        'card_id_count', 'purchase_Dayofweek_max', 'category_2_2.0_purchase_amount_mean_ratio',
#        'purchase_amount_new_mean', 'avg_spend_per_transaction_old', 'purchase_amount_count_sum_old',
#        'purchased_before_issue', 'purchase_amount_mean_total', 'authorized_flag_1_purchase_amount_mean_old',
#        'category_2_2.0_purchase_amount_sum_total', 'installments_median_old',
#        'authorized_flag_1_purchase_amount_sum_old', 'feature_3', 'repurchase_merchant_rate', 'feature_min',
#        'avg_trans_per_merchant', 'installments_min_old'], dtype=object)

# %%
picked_feats = best_features.sort_values(by='importance', ascending=False)[:800]['Feature'].unique()

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
import gc

# %%
def kfold_lightgbm(train_df, test_df, num_folds, stratified = False, debug= False):
    print("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))

    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=326)
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=326)

    # Create arrays and dataframes to store results
    oof_preds = np.zeros(train_df.shape[0])
    sub_preds = np.zeros(test_df.shape[0])
    feature_importance_df = pd.DataFrame()
    feats = [f for f in train_df.columns if f not in cols_excluded]

    # k-fold
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['outliers'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['target'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['target'].iloc[valid_idx]

        # set data structure
        lgb_train = lgb.Dataset(train_x,
                                label=train_y,
                                free_raw_data=False)
        lgb_test = lgb.Dataset(valid_x,
                               label=valid_y,
                               free_raw_data=False)

        # params optimized by optuna
        params ={
                'task': 'train',
                'boosting': 'goss',
                'objective': 'regression',
                'metric': 'rmse',
                'learning_rate': 0.01,
                'subsample': 0.9855232997390695,
                'max_depth': 7,
                'top_rate': 0.9064148448434349,
                'num_leaves': 63,
                'min_child_weight': 41.9612869171337,
                'other_rate': 0.0721768246018207,
                'reg_alpha': 9.677537745007898,
                'colsample_bytree': 0.5665320670155495,
                'min_split_gain': 9.820197773625843,
                'reg_lambda': 8.2532317400459,
                'min_data_in_leaf': 21,
                'verbose': -1,
                'seed':int(2**n_fold),
                'bagging_seed':int(2**n_fold),
                'drop_seed':int(2**n_fold)
                }

        reg = lgb.train(
                        params,
                        lgb_train,
                        valid_sets=[lgb_train, lgb_test],
                        valid_names=['train', 'test'],
                        num_boost_round=10000,
                        early_stopping_rounds= 200,
                        verbose_eval=100
                        )

        oof_preds[valid_idx] = reg.predict(valid_x, num_iteration=reg.best_iteration)
        sub_preds += reg.predict(test_df[feats], num_iteration=reg.best_iteration) / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = np.log1p(reg.feature_importance(importance_type='gain', iteration=reg.best_iteration))
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
        print('Fold %2d RMSE : %.6f' % (n_fold + 1, rmse(valid_y, oof_preds[valid_idx])))
        del reg, train_x, train_y, valid_x, valid_y
        gc.collect()

    # display importances
    display_importances(feature_importance_df)

    if not debug:
        # save submission file
        submission_name = pd.to_datetime("today")
        sub_df = pd.DataFrame({"card_id":test_df2["card_id"].values})
        sub_df["target"] = sub_preds
        sub_df.to_csv(f'submission_kfold-{submission_name}.csv', index=False)
#         test_df.loc[:,'target'] = sub_preds
#         test_df = test_df.reset_index()
#         test_df[['card_id', 'target']].to_csv(submission_name, index=False)

# %%
# Display/plot feature importance
def display_importances(feature_importance_df_):
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)[:40].index
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]

    plt.figure(figsize=(8, 10))
    sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False))
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances.png')

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
gc.collect()
# Out:
# 51043

# %%
kfold_lightgbm(train_df2, test_df2, num_folds=11, stratified=False, debug=False)
# Out:
# Starting LightGBM. Train shape: (201917, 252), test shape: (123623, 249)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-75f9825b2274> in <module>
# ----> 1 kfold_lightgbm(train_df2, test_df2, num_folds=11, stratified=False, debug=False)
#
# <ipython-input-42-706fb5a6f518> in kfold_lightgbm(train_df, test_df, num_folds, stratified, debug)
#      16     # k-fold
#      17     for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['outliers'])):
# ---> 18         train_x, train_y = train_df[feats].iloc[train_idx], train_df['target'].iloc[train_idx]
#      19         valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['target'].iloc[valid_idx]
#      20
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'

# %%
submission_name = pd.to_datetime("today")

# %%
sub_df = pd.DataFrame({"card_id":test_df2["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv(f'submission-{submission_name}.csv', index=False)

# %%
# !ls
# Out:
# 'Blending submissions.ipynb'
# 'Elo - ML model - 3.693.ipynb'
# 'Elo - ML model - 3.695 beta.ipynb'
# 'Elo - ML model - 3.695.ipynb'
# 'Elo - ML model - 3.696.ipynb'
# 'Elo - ML model - beta.ipynb'
# 'Elo - ML model - cat aggregates.ipynb'
# 'Elo - ML model 3.691.ipynb'
# 'Elo - ML model clean.ipynb'
# 'Elo - ML model proc_df.ipynb'
# 'Elo - ML model-RF copy.ipynb'
# 'Elo - ML model-backup.ipynb'
# 'Elo - ML model-new.ipynb'
# 'Elo RF- New.ipynb'
# 'Elo RF.ipynb'
# 'Elo end 2 end.ipynb'
# 'Elo feature engineering - 3.691.ipynb'
# 'Elo feature engineering - 3.696.ipynb'
# 'Elo feature engineering 3.693 .ipynb'
# 'Elo feature engineering 3.695 beta.ipynb'
# 'Elo feature engineering 3.695.ipynb'
# 'Elo feature engineering beta.ipynb'
# 'Elo feature engineering using agg.ipynb'
# 'Elo feature engineering-backup.ipynb'
# 'Elo feature engineering-proc_df - new-Copy1.ipynb'
# 'Elo feature engineering-proc_df - new.ipynb'
# 'Elo feature engineering-proc_df-OLD.ipynb'
# 'Elo feature engineering-proc_df.ipynb'
# 'Elo merchant category reco - using RF.ipynb'
# 'Elo outlier predictions & blending .ipynb'
# 'Feature selection using Boruta.ipynb'
# 'Feature selection.ipynb'
# 'Null importances - beta.ipynb'
# 'Outlier classification using Autoencoder.ipynb'
#  README.md
# 'Scrap pad.ipynb'
# 'Scrap pad.py'
# 'TS Fresh.ipynb'
# 'TS Fresh.py'
# 'Train & test clean.ipynb'
# 'Using DL.ipynb'
# 'Using Feature tools - old.ipynb'
# 'Using feature tools-Copy1.ipynb'
# 'Using feature tools.ipynb'
#  actual_importances_ditribution_rf.csv
#  adf
#  alla.pkl
#  authorised_trans_proc_agg
# 'blend-2019-02-02 23:24:52.864854.csv'
#  blend-{submission_name}
#  blend_kfol_st.csv
#  chandu_mean1.csv
#  cols_keep.npy
#  combining_submission.csv
#  corr_scores_null_importances.csv
#  correlation
#  data
#  df_auth
#  df_hot_dropped_all
#  df_hot_ext
#  df_hot_test
#  df_hot_test_ext
#  df_new
#  df_non_auth
#  df_proc_dfed
#  df_test_n_o
#  df_xo
#  fastai
#  fm_new_hist
#  hist_trans
#  hist_trans_3_696
#  hist_trans_agg
#  hist_trans_agg_3_696
#  hist_trans_agg_beta
#  hist_trans_agg_cat
#  hist_trans_agg_month
#  hist_trans_agg_n
#  hist_trans_agg_proc
#  hist_trans_beta
# 'kfold lightgbm.ipynb'
#  latent_representation.png
#  lgbm_importances.png
#  lla
#  new_hist_prc
#  new_hist_trans
#  new_hist_trans_3_696
#  new_hist_trans_agg
#  new_hist_trans_agg_3_696
#  new_hist_trans_agg_beta
#  new_hist_trans_agg_cat
#  new_hist_trans_agg_month
#  new_hist_trans_agg_n
#  new_hist_trans_beta
#  new_trans_agg_proc
#  new_trans_proc_agg
#  non_authorised_trans_proc
#  non_authorised_trans_proc_agg
#  null_importances_distribution_rf.csv
#  oof_lgb_3.npy
#  oof_xgb_3.npy
#  original.png
#  predictions_lgb_3.npy
#  predictions_xgb_3.npy
# 'scrap pad 2.ipynb'
# 'submission-2019-01-11 09:49:53.716164.csv'
# 'submission-2019-01-11 10:18:09.909061.csv'
# 'submission-2019-01-12 13:53:27.215115.csv'
# 'submission-2019-01-12 16:27:31.239044.csv'
# 'submission-2019-01-12 17:25:56.678553.csv'
# 'submission-2019-01-12 17:33:29.475835.csv'
# 'submission-2019-01-12 17:42:01.350278.csv'
# 'submission-2019-01-12 22:12:59.947458.csv'
# 'submission-2019-01-13 15:59:45.792347.csv'
# 'submission-2019-01-13 18:24:51.237991.csv'
# 'submission-2019-01-14 19:04:33.028609.csv'
# 'submission-2019-01-14 19:56:09.906235.csv'
# 'submission-2019-01-15 22:18:34.294443.csv'
# 'submission-2019-01-15 22:24:38.071972.csv'
# 'submission-2019-01-15 22:29:20.144417.csv'
# 'submission-2019-01-16 00:35:46.490517.csv'
# 'submission-2019-01-16 00:36:26.004443.csv'
# 'submission-2019-01-16 12:20:00.957329.csv'
# 'submission-2019-01-16 21:37:16.421927.csv'
# 'submission-2019-01-17 10:20:06.724992.csv'
# 'submission-2019-01-17 11:09:17.495216.csv'
# 'submission-2019-01-17 23:23:57.743505.csv'
# 'submission-2019-01-18 01:18:08.182115.csv'
# 'submission-2019-01-18 01:42:20.587834.csv'
# 'submission-2019-01-18 01:47:04.024727.csv'
# 'submission-2019-01-18 16:16:45.475456.csv'
# 'submission-2019-01-18 16:27:58.560480.csv'
# 'submission-2019-01-18 17:22:46.188675.csv'
# 'submission-2019-01-20 00:30:10.643280.csv'
# 'submission-2019-01-20 01:28:12.077657.csv'
# 'submission-2019-01-20 01:46:39.187580.csv'
# 'submission-2019-01-20 02:32:16.439302.csv'
# 'submission-2019-01-20 17:01:54.207459.csv'
# 'submission-2019-01-20 17:27:46.797180.csv'
# 'submission-2019-01-20 18:29:37.773532.csv'
# 'submission-2019-01-20 19:11:58.593189.csv'
# 'submission-2019-01-20 19:35:24.892043.csv'
# 'submission-2019-01-20 20:47:32.743729.csv'
# 'submission-2019-01-22 09:33:02.341491.csv'
# 'submission-2019-01-22 10:35:57.465665.csv'
# 'submission-2019-01-31 22:00:10.810901.csv'
# 'submission-2019-01-31 22:04:41.815902.csv'
# 'submission-2019-02-02 23:13:59.670630.csv'
# 'submission-2019-02-02 23:24:52.864854.csv'
# 'submission-2019-02-03 14:42:22.636262.csv'
# 'submission-2019-02-03 14:43:29.797523.csv'
# 'submission-2019-02-10 14:58:45.312994.csv'
# 'submission-2019-02-10 17:36:17.986042.csv'
# 'submission-2019-02-10 18:01:58.093819.csv'
# 'submission-2019-02-12 22:57:39.862967.csv'
# 'submission-2019-02-13 00:42:12.274968.csv'
# 'submission-2019-02-13 01:51:25.440947.csv'
# 'submission-2019-02-13 22:48:45.005871.csv'
# 'submission-2019-02-15 14:22:06.881490.csv'
# 'submission_kfold-2019-02-13 00:55:25.132146.csv'
# 'submission_kfold-2019-02-13 01:29:28.856630.csv'
# 'submission_kfold-2019-02-13 01:59:08.971995.csv'
# 'submission_kfold-2019-02-13 23:21:24.051900.csv'
#  submissions
#  target_all
#  target_outliers_removed
#  test_clean.csv
#  test_clean.csv.zip
#  test_df
#  test_df_3.695
#  test_df_3_696
#  test_df_beta
#  test_df_proc
#  test_df_proc_new
#  test_df_proc_new_m
#  train_clean.csv
#  train_clean.csv.zip
#  train_clean0
#  train_df
#  train_df_3_696
#  train_df_beta
#  train_df_proc
#  train_df_proc_new
#  train_df_proc_new_m

# %%
FileLink(f'submission-{submission_name}.csv')
# Out:
# /home/chandrasekhar/private/kaggle/submission-2019-02-19 00:14:48.737899.csv

# %% [markdown]
# ### Blend

# %%
p1 = pd.read_csv(f'submission-{submission_name}.csv')
p2 = pd.read_csv('submission-2019-02-02 23:13:59.670630.csv')

# %%
p1.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.960024
# 1  C_ID_130fd0cbdd -0.421305
# 2  C_ID_b709037bc5 -1.011111
# 3  C_ID_d27d835a9f -0.141994
# 4  C_ID_2b5e3df5c2 -1.270823

# %%
p2.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.072875
# 1  C_ID_130fd0cbdd -0.348145
# 2  C_ID_b709037bc5 -0.949767
# 3  C_ID_d27d835a9f -0.149493
# 4  C_ID_2b5e3df5c2 -1.212316

# %%
p3 = p1.copy()

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.960024
# 1  C_ID_130fd0cbdd -0.421305
# 2  C_ID_b709037bc5 -1.011111
# 3  C_ID_d27d835a9f -0.141994
# 4  C_ID_2b5e3df5c2 -1.270823

# %%
p3 = pd.DataFrame({"card_id":test_df2["card_id"].values})
p3["target"] = p1['target']*.5 + p2['target']*.5

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.016449
# 1  C_ID_130fd0cbdd -0.384725
# 2  C_ID_b709037bc5 -0.980439
# 3  C_ID_d27d835a9f -0.145743
# 4  C_ID_2b5e3df5c2 -1.241569

# %%
p3.to_csv('blend_kfol_st.csv',index=False)

# %%
message = 'using blend kfold + stratified, purchase amount trimmed'

# %%
p3.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -3.016449
# 1  C_ID_130fd0cbdd -0.384725
# 2  C_ID_b709037bc5 -0.980439
# 3  C_ID_d27d835a9f -0.145743
# 4  C_ID_2b5e3df5c2 -1.241569

# %%
filename = f'submission-{submission_name}.csv'

# %%
filename
# Out:
# 'submission-2019-02-19 00:14:48.737899.csv'

# %%
# !kaggle competitions submit elo-merchant-category-recommendation -f 'submission-2019-02-19 00:14:48.737899.csv' -m "rescaled purchase amount with old 180 cols & observed time"
# Out:
# 100%|#######################################| 4.24M/4.24M [00:10<00:00, 440kB/s]
# Successfully submitted to Elo Merchant Category Recommendation

# %%
train = train_df2.copy()
train['rounded_target'] = train['target'].round(0)
train = train.sort_values('rounded_target').reset_index(drop=True)
vc = train['rounded_target'].value_counts()
vc = dict(sorted(vc.items()))
df = pd.DataFrame()
train['indexcol'],i = 0,1
for k,v in vc.items():
    step = train.shape[0]/v
    indent = train.shape[0]/(v+1)
    df2 = train[train['rounded_target'] == k].sample(v, random_state=120).reset_index(drop=True)
    for j in range(0, v):
        df2.at[j, 'indexcol'] = indent + j*step + 0.000001*i
    df = pd.concat([df2,df])
    i+=1

# %%
train = df.sort_values('indexcol', ascending=True).reset_index(drop=True)

# %%
train.head().T
# Out:
#                                                       0                    1  \
# first_active_month                  2017-12-01 00:00:00  2016-12-01 00:00:00
# card_id                                 C_ID_176ecc65bd      C_ID_6082929d3a
# feature_1                                     0.0131446            0.0107116
# feature_2                                     0.0113848            0.0113848
# feature_3                                     0.0114275            0.0102828
# target                                        -0.279039            -0.926039
# first_active_monthYear                             2017                 2016
# first_active_monthMonth                              12                   12
# first_active_monthWeek                               48                   48
# first_active_monthDay                                 1                    1
# first_active_monthDayofweek                           4                    3
# first_active_monthDayofyear                         335                  336
# first_active_monthIs_month_end                    False                False
# first_active_monthIs_month_start                   True                 True
# first_active_monthIs_quarter_end                  False                False
# first_active_monthIs_quarter_start                False                False
# first_active_monthIs_year_end                     False                False
# first_active_monthIs_year_start                   False                False
# first_active_monthElapsed                    1512086400           1480550400
# transactions_count                                   10                   46
# city_id_nunique                                       5                   15
# merchant_category_id_nunique                          7                   20
# merchant_id_nunique                                  10                   46
# state_id_nunique                                      2                    8
# subsector_id_nunique                                  7                   13
# purchase_Year_nunique                                 1                    1
# purchase_Month_nunique                                2                    2
# purchase_Week_nunique                                 5                    9
# purchase_Day_nunique                                  7                   17
# purchase_amount_sum                           -0.450675             -22.5638
# ...                                                 ...                  ...
# purchase_amount_sum_sum                         7.36008             -390.031
# purchase_amount_sum_ptp                         23.4604              358.046
# purchase_amount_sum_max                         15.4103            -0.619333
# purchase_amount_max_mean                        9.49366              2.61874
# purchase_amount_max_sum                         18.9873              7.85621
# purchase_amount_max_ptp                         14.2301              8.07011
# purchase_amount_max_max                         16.6087              7.45078
# purchase_amount_mean_mean                      -0.04237            -0.593192
# purchase_amount_mean_sum                       -0.08474             -1.77958
# purchase_amount_mean_ptp                       0.490273            0.0499709
# purchase_amount_mean_max                       0.202767            -0.569362
# elapsed_time                                        426                  791
# card_id_total                                       114                  708
# card_id_count_total                                 114                  708
# purchase_amount_total                            6.9094             -412.594
# purchase_amount_total_mean                    0.0257024             -1.07969
# installments_total                                  124                  742
# hist_first_buy                                        4                   31
# new_first_buy                                        90                  465
# hist_last_buy                                        89                  454
# new_last_buy                                        132                  515
# purchase_amount_max_total                       3.01714             0.574974
# purchased_before_issue                            False                False
# outliers                                              0                    0
# days                                                 62                  427
# days_feature1                                       310                 1708
# days_feature2                                        62                  427
# days_feature3                                        62                    0
# rounded_target                                       -0                   -1
# indexcol                                              2                    5
#
#                                                       2                    3  \
# first_active_month                  2016-09-01 00:00:00  2017-11-01 00:00:00
# card_id                                 C_ID_a87bbd85a7      C_ID_92e4809531
# feature_1                                     0.0104794           0.00805849
# feature_2                                     0.0113848            0.0113848
# feature_3                                     0.0114275            0.0102828
# target                                         0.475326             0.516026
# first_active_monthYear                             2016                 2017
# first_active_monthMonth                               9                   11
# first_active_monthWeek                               35                   44
# first_active_monthDay                                 1                    1
# first_active_monthDayofweek                           3                    2
# first_active_monthDayofyear                         245                  305
# first_active_monthIs_month_end                    False                False
# first_active_monthIs_month_start                   True                 True
# first_active_monthIs_quarter_end                  False                False
# first_active_monthIs_quarter_start                False                False
# first_active_monthIs_year_end                     False                False
# first_active_monthIs_year_start                   False                False
# first_active_monthElapsed                    1472688000           1509494400
# transactions_count                                   22                    6
# city_id_nunique                                       3                    5
# merchant_category_id_nunique                         17                    4
# merchant_id_nunique                                  22                    6
# state_id_nunique                                      1                    3
# subsector_id_nunique                                 11                    4
# purchase_Year_nunique                                 1                    1
# purchase_Month_nunique                                2                    2
# purchase_Week_nunique                                 5                    5
# purchase_Day_nunique                                 13                    6
# purchase_amount_sum                            -15.5147              -3.1597
# ...                                                 ...                  ...
# purchase_amount_sum_sum                         -322.03             -14.6139
# purchase_amount_sum_ptp                          284.74              12.2301
# purchase_amount_sum_max                        -18.6449              -1.1919
# purchase_amount_max_mean                      -0.588055              1.90307
# purchase_amount_max_sum                        -1.17611              3.80614
# purchase_amount_max_ptp                        0.129754              1.82123
# purchase_amount_max_max                       -0.523178              2.81368
# purchase_amount_mean_mean                     -0.712977            -0.280704
# purchase_amount_mean_sum                       -1.42595            -0.561408
# purchase_amount_mean_ptp                     0.00826695             0.164107
# purchase_amount_mean_max                      -0.708844             -0.19865
# elapsed_time                                        882                  456
# card_id_total                                       476                   49
# card_id_count_total                                 476                   49
# purchase_amount_total                          -337.545             -17.7736
# purchase_amount_total_mean                     -1.41453            -0.866476
# installments_total                                    0                   74
# hist_first_buy                                      125                    6
# new_first_buy                                       551                  121
# hist_last_buy                                       540                  117
# new_last_buy                                        598                  172
# purchase_amount_max_total                      -1.31004            -0.932425
# purchased_before_issue                            False                False
# outliers                                              0                    0
# days                                                518                   92
# days_feature1                                      1554                   92
# days_feature2                                       518                   92
# days_feature3                                       518                    0
# rounded_target                                        0                    1
# indexcol                                              5                    5
#
#                                                       4
# first_active_month                  2017-11-01 00:00:00
# card_id                                 C_ID_d2dd6bbf9a
# feature_1                                     0.0107116
# feature_2                                     0.0113848
# feature_3                                     0.0102828
# target                                        -0.100927
# first_active_monthYear                             2017
# first_active_monthMonth                              11
# first_active_monthWeek                               44
# first_active_monthDay                                 1
# first_active_monthDayofweek                           2
# first_active_monthDayofyear                         305
# first_active_monthIs_month_end                    False
# first_active_monthIs_month_start                   True
# first_active_monthIs_quarter_end                  False
# first_active_monthIs_quarter_start                False
# first_active_monthIs_year_end                     False
# first_active_monthIs_year_start                   False
# first_active_monthElapsed                    1509494400
# transactions_count                                   16
# city_id_nunique                                       6
# merchant_category_id_nunique                         13
# merchant_id_nunique                                  16
# state_id_nunique                                      3
# subsector_id_nunique                                  8
# purchase_Year_nunique                                 1
# purchase_Month_nunique                                2
# purchase_Week_nunique                                 6
# purchase_Day_nunique                                  9
# purchase_amount_sum                            -4.21238
# ...                                                 ...
# purchase_amount_sum_sum                        -14.7675
# purchase_amount_sum_ptp                         1.36254
# purchase_amount_sum_max                        -6.70246
# purchase_amount_max_mean                        3.17877
# purchase_amount_max_sum                         6.35754
# purchase_amount_max_ptp                         4.16685
# purchase_amount_max_max                         5.26219
# purchase_amount_mean_mean                     -0.284128
# purchase_amount_mean_sum                      -0.568255
# purchase_amount_mean_ptp                       0.269552
# purchase_amount_mean_max                      -0.149352
# elapsed_time                                        456
# card_id_total                                        86
# card_id_count_total                                  86
# purchase_amount_total                          -18.9798
# purchase_amount_total_mean                    -0.474238
# installments_total                                  180
# hist_first_buy                                      -62
# new_first_buy                                       140
# hist_last_buy                                       116
# new_last_buy                                        180
# purchase_amount_max_total                      0.144826
# purchased_before_issue                             True
# outliers                                              0
# days                                                 92
# days_feature1                                       368
# days_feature2                                        92
# days_feature3                                         0
# rounded_target                                       -0
# indexcol                                              8
#
# [170 rows x 5 columns]
